# %%
from data_analysis import *

# %% [markdown]
# # SDP

# %%
def plot_multiple_dfs(dfs, labels, venus=False, dataset=None, Cut=False, time_limit=200, x_start=0):
    fig, ax1 = plt.subplots(figsize=(10, 6))
    
    # Define a color map for different dataframes
    colors = plt.cm.get_cmap('tab10', len(dfs))
    
    # Check if any dataframe has 'Cut Generation' with non-zero values
    if Cut:
        has_cut_generation = any('Cut Generation' in df.columns and df['Cut Generation'].sum() > 0 for df in dfs)
    else:
        has_cut_generation = False
    ax2 = None
    for i, (df, label) in enumerate(zip(dfs, labels)):
        # Filter out rows where Status is 'safe'
        if venus:
            df_filtered = df.loc[(df['Status'] == 'safe-incomplete') | (df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        else:
            x_start = df.loc[(df['Status'] == 'safe-incomplete')].shape[0]
            df_filtered = df.loc[(df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        
        # Sort the dataframe by Time
        df_filtered = df_filtered.sort_values(by='Time')
        
        # Compute the cumulative count of verified instances
        df_filtered['Cumulative Count'] = range(x_start, x_start + len(df_filtered))
        
        # Plot Cumulative Count vs. Time
        ax1.plot(df_filtered['Cumulative Count'], df_filtered['Time'], marker='o', linestyle='-', color=colors(i), label=label)
        
        # If 'Cut Generation' exists and has non-zero values, plot it as well
        if Cut:
            if has_cut_generation and 'Cut Generation' in df.columns and df['Cut Generation'].sum() > 0:
                if ax2 is None:
                    ax2 = ax1.twinx()  # Create a second y-axis if needed
                ax2.bar(df_filtered['Cumulative Count'], df_filtered['Cut Generation'], color=colors(i), alpha=0.3, label=f'{label} Cut Generation')
                ax2.set_ylabel('Cut Generation', fontsize=20)

    ax1.set_xlabel(f'Number of Instances Verified in {dataset}', fontsize=20)
    ax1.set_ylabel('Time', fontsize=20)
    ax1.set_title('Number of Instances Verified vs. Time', fontsize=20)
    ax1.grid(True)

    # Set the y-axis limit
    max_time = max(df_filtered['Time'].max(), time_limit)
    ax1.set_ylim(0, max_time + 5)
    
    # Add a horizontal line at y=200 to emphasize the time limitation
    if max_time + 5 > time_limit:
        ax1.axhline(y=time_limit, color='red', linestyle='--', linewidth=2, label='Time Limit (200)')
    
    # Combine legends from both y-axes if 'Cut Generation' was plotted
    lines, labels = ax1.get_legend_handles_labels()
    if has_cut_generation:
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines + lines2, labels + labels2, fontsize=20)
    else:
        ax1.legend(lines, labels, fontsize=20)
    
    plt.show()

# %% [markdown]
# ## cifar_cnn_a_mix

# %%
plot_multiple_dfs(
    [
        log_read('cifar_cnn_a_mix/beta.log'),
        log_read('cifar_cnn_a_mix/biccos_only_cs.log'),
        log_read('cifar_cnn_a_mix/biccos_all.log'),
        log_read('cifar_cnn_a_mix/gcp.log'),
        log_read('cifar_cnn_a_mix/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto',
    ], dataset= 'cifar_cnn_a_mix'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_a_mix/beta.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe    7.6827               0               0            0
# 7     safe    3.2981             242               0            0
# 13    safe    2.4107               0               0            0
# 18    safe    3.0849              58               0            0
# 19    safe    3.1483              17               0            0
# 24    safe    2.7228              14               0            0
# 39    safe    2.3795               0               0            0
# 40    safe   26.7175           70210               0            0
# 42    safe    2.4599               0               0            0
# 52    safe   45.5751          129259               0            0
# 55    safe    2.5576               0               0            0
# 59    safe    4.1377             110               0            0
# 64    safe    2.4336               0               0            0
# 70    safe    2.4263               0               0            0
# 75    safe    2.5753               0               0            0
# 76    safe    2.4511               0               0            0
# 83    safe   25.9475           55191               0            0
# 102   safe    5.3780            1669               0            0
# 107   safe    2.5174               0               0            0
# 111   safe    2.9245              19               0            0
# 112   safe    3.2485              29               0            0
# 115   safe    2.4572               0               0            0
# 135   safe    2.4498               0               0            0
# 136   safe    2.6548               0               0            0
# 139   safe    2.5344               0               0            0
# 142   safe    2.4340               0               0            0
# 143   safe    2.9320              12               0            0
# 160   safe   25.1654           54413               0            0
# 166   safe    2.3858               0               0            0
# 178   safe    2.3874               0               0            0
# 185   safe    2.7684               5               0            0
# 189   safe    3.9314             542               0            0
# 192   safe  181.9241          525311               0            0
# 199   safe   12.8277           11729               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  1         NaN
# 7                  7         NaN
# 13                 1         NaN
# 18                 5         NaN
# 19                 7         NaN
# 24                 4         NaN
# 39                 1         NaN
# 40                26         NaN
# 42                 2         NaN
# 52                35         NaN
# 55                 2         NaN
# 59                10         NaN
# 64                 1         NaN
# 70                 1         NaN
# 75                 2         NaN
# 76                 1         NaN
# 83                43         NaN
# 102               18         NaN
# 107                1         NaN
# 111                4         NaN
# 112                7         NaN
# 115                1         NaN
# 135                1         NaN
# 136                2         NaN
# 139                2         NaN
# 142                1         NaN
# 143                5         NaN
# 160               39         NaN
# 166                1         NaN
# 178                1         NaN
# 185                4         NaN
# 189               11         NaN
# 192               55         NaN
# 199               56         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  217.2033          671305               0            0
# 11   unknown  215.4995          726887               0            0
# 26   unknown  203.5859          688516               0            0
# 35   unknown  207.1832          825158               0            0
# 54   unknown  205.7674          551562               0            0
# 60   unknown  201.7876          662683               0            0
# 67   unknown  215.3897          678169               0            0
# 97   unknown  207.9397          688325               0            0
# 101  unknown  219.1726          682784               0            0
# 103  unknown  204.1852          668548               0            0
# 106  unknown  203.9226          637438               0            0
# 116  unknown  204.6678          676974               0            0
# 150  unknown  212.0083          638470               0            0
# 152  unknown  204.8375          638687               0            0
# 162  unknown  216.8453          693203               0            0
# 172  unknown  205.7867          567693               0            0
# 174  unknown  204.0578          620312               0            0
# 187  unknown  213.4312          656227               0            0
# 188  unknown  201.0045          597178               0            0
# 191  unknown  207.1589          689038               0            0
# 194  unknown  217.2055          739722               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                 26   -0.828528
# 11                25   -0.342921
# 26                27   -0.228702
# 35                44   -0.257049
# 54                32   -0.170002
# 60                21   -0.526703
# 67                26   -0.230905
# 97                27   -0.607241
# 101               30   -0.389527
# 103               25   -0.563550
# 106               30   -0.719502
# 116               24   -0.547851
# 150               62   -0.345252
# 152               25   -0.314424
# 162               31   -0.275517
# 172               54   -0.096554
# 174               32   -0.233450
# 187               32   -0.361274
# 188               50   -0.094222
# 191               29   -0.104119
# 194               25   -0.587800
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe    7.6827               0               0            0
# 1         unsafe-pgd    0.0724               0               0            0
# 2            unknown  217.2033          671305               0            0
# 3         unsafe-pgd    0.0870               0               0            0
# 4         unsafe-pgd    0.0799               0               0            0
# 5         unsafe-pgd    0.0718               0               0            0
# 6         unsafe-pgd    0.0795               0               0            0
# 7               safe    3.2981             242               0            0
# 8    safe-incomplete    0.0685               0               0            0
# 9         unsafe-pgd    0.0781               0               0            0
# 10        unsafe-pgd    0.0571               0               0            0
# 11           unknown  215.4995          726887               0            0
# 12        unsafe-pgd    0.0877               0               0            0
# 13              safe    2.4107               0               0            0
# 14   safe-incomplete    0.0427               0               0            0
# 15        unsafe-pgd    0.0796               0               0            0
# 16        unsafe-pgd    0.0549               0               0            0
# 17   safe-incomplete    0.0498               0               0            0
# 18              safe    3.0849              58               0            0
# 19              safe    3.1483              17               0            0
# 20   safe-incomplete    0.0504               0               0            0
# 21        unsafe-pgd    0.0511               0               0            0
# 22   safe-incomplete    0.0462               0               0            0
# 23   safe-incomplete    0.2145               0               0            0
# 24              safe    2.7228              14               0            0
# 25        unsafe-pgd    0.0647               0               0            0
# 26           unknown  203.5859          688516               0            0
# 27   safe-incomplete    0.0550               0               0            0
# 28   safe-incomplete    0.0635               0               0            0
# 29        unsafe-pgd    0.0545               0               0            0
# 30   safe-incomplete    0.0670               0               0            0
# 31   safe-incomplete    0.0629               0               0            0
# 32        unsafe-pgd    0.0847               0               0            0
# 33   safe-incomplete    0.0490               0               0            0
# 34        unsafe-pgd    0.0708               0               0            0
# 35           unknown  207.1832          825158               0            0
# 36        unsafe-pgd    0.0849               0               0            0
# 37   safe-incomplete    0.0512               0               0            0
# 38        unsafe-pgd    0.0747               0               0            0
# 39              safe    2.3795               0               0            0
# 40              safe   26.7175           70210               0            0
# 41   safe-incomplete    0.0562               0               0            0
# 42              safe    2.4599               0               0            0
# 43        unsafe-pgd    0.0702               0               0            0
# 44        unsafe-pgd    0.0565               0               0            0
# 45        unsafe-pgd    0.0671               0               0            0
# 46        unsafe-pgd    0.0542               0               0            0
# 47   safe-incomplete    0.0563               0               0            0
# 48        unsafe-pgd    0.0723               0               0            0
# 49   safe-incomplete    0.0653               0               0            0
# 50        unsafe-pgd    0.0637               0               0            0
# 51   safe-incomplete    0.0698               0               0            0
# 52              safe   45.5751          129259               0            0
# 53        unsafe-pgd    0.0807               0               0            0
# 54           unknown  205.7674          551562               0            0
# 55              safe    2.5576               0               0            0
# 56        unsafe-pgd    0.0588               0               0            0
# 57        unsafe-pgd    0.0741               0               0            0
# 58        unsafe-pgd    0.0423               0               0            0
# 59              safe    4.1377             110               0            0
# 60           unknown  201.7876          662683               0            0
# 61        unsafe-pgd    0.0901               0               0            0
# 62   safe-incomplete    0.0558               0               0            0
# 63        unsafe-pgd    0.0891               0               0            0
# 64              safe    2.4336               0               0            0
# 65        unsafe-pgd    0.0868               0               0            0
# 66        unsafe-pgd    0.0773               0               0            0
# 67           unknown  215.3897          678169               0            0
# 68   safe-incomplete    0.2218               0               0            0
# 69        unsafe-pgd    0.0718               0               0            0
# 70              safe    2.4263               0               0            0
# 71   safe-incomplete    0.0585               0               0            0
# 72        unsafe-pgd    0.0830               0               0            0
# 73   safe-incomplete    0.2581               0               0            0
# 74   safe-incomplete    0.0812               0               0            0
# 75              safe    2.5753               0               0            0
# 76              safe    2.4511               0               0            0
# 77        unsafe-pgd    0.0856               0               0            0
# 78        unsafe-pgd    0.0600               0               0            0
# 79   safe-incomplete    0.0654               0               0            0
# 80        unsafe-pgd    0.0817               0               0            0
# 81        unsafe-pgd    0.0695               0               0            0
# 82        unsafe-pgd    0.0583               0               0            0
# 83              safe   25.9475           55191               0            0
# 84        unsafe-pgd    0.0748               0               0            0
# 85        unsafe-pgd    0.0711               0               0            0
# 86   safe-incomplete    0.0539               0               0            0
# 87        unsafe-pgd    0.0693               0               0            0
# 88        unsafe-pgd    0.0792               0               0            0
# 89   safe-incomplete    0.0632               0               0            0
# 90        unsafe-pgd    0.0687               0               0            0
# 91        unsafe-pgd    0.0723               0               0            0
# 92        unsafe-pgd    0.0718               0               0            0
# 93        unsafe-pgd    0.0316               0               0            0
# 94        unsafe-pgd    0.0761               0               0            0
# 95        unsafe-pgd    0.0745               0               0            0
# 96        unsafe-pgd    0.0763               0               0            0
# 97           unknown  207.9397          688325               0            0
# 98        unsafe-pgd    0.0872               0               0            0
# 99        unsafe-pgd    0.0494               0               0            0
# 100       unsafe-pgd    0.0557               0               0            0
# 101          unknown  219.1726          682784               0            0
# 102             safe    5.3780            1669               0            0
# 103          unknown  204.1852          668548               0            0
# 104  safe-incomplete    0.0838               0               0            0
# 105       unsafe-pgd    0.0834               0               0            0
# 106          unknown  203.9226          637438               0            0
# 107             safe    2.5174               0               0            0
# 108       unsafe-pgd    0.0801               0               0            0
# 109  safe-incomplete    0.0688               0               0            0
# 110  safe-incomplete    0.0659               0               0            0
# 111             safe    2.9245              19               0            0
# 112             safe    3.2485              29               0            0
# 113       unsafe-pgd    0.0820               0               0            0
# 114  safe-incomplete    0.0717               0               0            0
# 115             safe    2.4572               0               0            0
# 116          unknown  204.6678          676974               0            0
# 117  safe-incomplete    0.0651               0               0            0
# 118  safe-incomplete    0.0647               0               0            0
# 119       unsafe-pgd    0.0793               0               0            0
# 120       unsafe-pgd    0.0503               0               0            0
# 121  safe-incomplete    0.0645               0               0            0
# 122       unsafe-pgd    0.0693               0               0            0
# 123       unsafe-pgd    0.0677               0               0            0
# 124       unsafe-pgd    0.0511               0               0            0
# 125       unsafe-pgd    0.0471               0               0            0
# 126       unsafe-pgd    0.0717               0               0            0
# 127       unsafe-pgd    0.0730               0               0            0
# 128       unsafe-pgd    0.0799               0               0            0
# 129       unsafe-pgd    0.0726               0               0            0
# 130       unsafe-pgd    0.0471               0               0            0
# 131  safe-incomplete    0.0654               0               0            0
# 132  safe-incomplete    0.0652               0               0            0
# 133  safe-incomplete    0.0407               0               0            0
# 134       unsafe-pgd    0.0575               0               0            0
# 135             safe    2.4498               0               0            0
# 136             safe    2.6548               0               0            0
# 137       unsafe-pgd    0.0778               0               0            0
# 138       unsafe-pgd    0.0810               0               0            0
# 139             safe    2.5344               0               0            0
# 140  safe-incomplete    0.0355               0               0            0
# 141       unsafe-pgd    0.0823               0               0            0
# 142             safe    2.4340               0               0            0
# 143             safe    2.9320              12               0            0
# 144       unsafe-pgd    0.0416               0               0            0
# 145       unsafe-pgd    0.0728               0               0            0
# 146  safe-incomplete    0.0364               0               0            0
# 147  safe-incomplete    0.0278               0               0            0
# 148  safe-incomplete    0.0340               0               0            0
# 149       unsafe-pgd    0.0764               0               0            0
# 150          unknown  212.0083          638470               0            0
# 151       unsafe-pgd    0.0896               0               0            0
# 152          unknown  204.8375          638687               0            0
# 153  safe-incomplete    0.0611               0               0            0
# 154       unsafe-pgd    0.0786               0               0            0
# 155       unsafe-pgd    0.0490               0               0            0
# 156       unsafe-pgd    0.0575               0               0            0
# 157  safe-incomplete    0.0484               0               0            0
# 158       unsafe-pgd    0.0425               0               0            0
# 159       unsafe-pgd    0.0652               0               0            0
# 160             safe   25.1654           54413               0            0
# 161  safe-incomplete    0.0730               0               0            0
# 162          unknown  216.8453          693203               0            0
# 163       unsafe-pgd    0.1031               0               0            0
# 164       unsafe-pgd    0.0512               0               0            0
# 165       unsafe-pgd    0.0840               0               0            0
# 166             safe    2.3858               0               0            0
# 167       unsafe-pgd    0.0802               0               0            0
# 168  safe-incomplete    0.0677               0               0            0
# 169  safe-incomplete    0.0672               0               0            0
# 170       unsafe-pgd    0.0572               0               0            0
# 171  safe-incomplete    0.0542               0               0            0
# 172          unknown  205.7867          567693               0            0
# 173       unsafe-pgd    0.0732               0               0            0
# 174          unknown  204.0578          620312               0            0
# 175       unsafe-pgd    0.0879               0               0            0
# 176       unsafe-pgd    0.0771               0               0            0
# 177  safe-incomplete    0.0487               0               0            0
# 178             safe    2.3874               0               0            0
# 179  safe-incomplete    0.0597               0               0            0
# 180  safe-incomplete    0.2559               0               0            0
# 181       unsafe-pgd    0.0553               0               0            0
# 182  safe-incomplete    0.0401               0               0            0
# 183       unsafe-pgd    0.0436               0               0            0
# 184       unsafe-pgd    0.0760               0               0            0
# 185             safe    2.7684               5               0            0
# 186  safe-incomplete    0.0628               0               0            0
# 187          unknown  213.4312          656227               0            0
# 188          unknown  201.0045          597178               0            0
# 189             safe    3.9314             542               0            0
# 190  safe-incomplete    0.0701               0               0            0
# 191          unknown  207.1589          689038               0            0
# 192             safe  181.9241          525311               0            0
# 193  safe-incomplete    0.0720               0               0            0
# 194          unknown  217.2055          739722               0            0
# 195       unsafe-pgd    0.0665               0               0            0
# 196       unsafe-pgd    0.0740               0               0            0
# 197       unsafe-pgd    0.0732               0               0            0
# 198       unsafe-pgd    0.0810               0               0            0
# 199             safe   12.8277           11729               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  1         NaN
# 1                  0         NaN
# 2                 26   -0.828528
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  7         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                25   -0.342921
# 12                 0         NaN
# 13                 1         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 5         NaN
# 19                 7         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 4         NaN
# 25                 0         NaN
# 26                27   -0.228702
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                44   -0.257049
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                26         NaN
# 41                 0         NaN
# 42                 2         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                35         NaN
# 53                 0         NaN
# 54                32   -0.170002
# 55                 2         NaN
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                10         NaN
# 60                21   -0.526703
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                26   -0.230905
# 68                 0         NaN
# 69                 0         NaN
# 70                 1         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                 1         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                43         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                27   -0.607241
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101               30   -0.389527
# 102               18         NaN
# 103               25   -0.563550
# 104                0         NaN
# 105                0         NaN
# 106               30   -0.719502
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                4         NaN
# 112                7         NaN
# 113                0         NaN
# 114                0         NaN
# 115                1         NaN
# 116               24   -0.547851
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                1         NaN
# 136                2         NaN
# 137                0         NaN
# 138                0         NaN
# 139                2         NaN
# 140                0         NaN
# 141                0         NaN
# 142                1         NaN
# 143                5         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150               62   -0.345252
# 151                0         NaN
# 152               25   -0.314424
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160               39         NaN
# 161                0         NaN
# 162               31   -0.275517
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                1         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               54   -0.096554
# 173                0         NaN
# 174               32   -0.233450
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                1         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                4         NaN
# 186                0         NaN
# 187               32   -0.361274
# 188               50   -0.094222
# 189               11         NaN
# 190                0         NaN
# 191               29   -0.104119
# 192               55         NaN
# 193                0         NaN
# 194               25   -0.587800
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199               56         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               34   11.850865   24965.588235            0.0         0.0
# safe-incomplete    51    0.072482       0.000000            0.0         0.0
# unknown            21  208.982867  666613.285714            0.0         0.0
# unsafe-pgd         94    0.070153       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  10.529412
# safe-incomplete        0.000000
# unknown               32.238095
# unsafe-pgd             0.000000
# safe number 85.0
# safe time 4.783835294117647
# safe domain 9986.235294117647
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((85.0, 4.783835294117647, 24965.58823529412, 0.0),)

# %%
main('cifar_cnn_a_mix/biccos_only_cs.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe    7.9489              50               7          656
# 7     safe    5.5304             312              86         1274
# 13    safe    2.8803              50              12          656
# 18    safe    7.0659             292             112         1431
# 19    safe    3.8333              17              81         1467
# 24    safe    5.6900             154              25          908
# 35    safe    5.8944             460              85         1089
# 39    safe    2.6678               0               1          256
# 40    safe   39.7776           45652            1390        23774
# 42    safe    4.1099              50              26         1273
# 52    safe   12.9303            9428              63         6351
# 54    safe    8.1901            5340             106         4301
# 55    safe    5.4311             210              23         1310
# 59    safe    4.5790              99             149         1803
# 64    safe    2.5497               0               1          256
# 70    safe    2.9116              50               5          256
# 75    safe    3.6126               0               1          512
# 76    safe    3.6498             150              28          656
# 83    safe   12.1439            6861              76         4771
# 97    safe   15.8331           14752             175        11277
# 102   safe    5.2234             484              54          945
# 107   safe    2.9543              50               9          653
# 111   safe    6.3597             265              59         1393
# 112   safe    4.0642              29              40          741
# 115   safe    2.5748               0               1          256
# 135   safe    2.6176               0               1          256
# 136   safe    4.5626             150              15          517
# 139   safe    5.1995             250              22         1187
# 142   safe    2.9464              50               8          256
# 143   safe    2.9093              12              19          640
# 150   safe   16.9611           15725             216         9969
# 152   safe  177.6755          201281             328        95449
# 160   safe   10.8599            3875             277         4321
# 166   safe    2.6521               0               1          256
# 172   safe    5.6857             334             173         1769
# 174   safe   23.7992           21503             117        15414
# 178   safe    2.7759              50               8          551
# 185   safe    2.8779               5              10          576
# 188   safe  122.0853          141694             298        82139
# 189   safe    6.5339             377             116         1592
# 191   safe   20.2487           17944             411        10953
# 192   safe   21.5698           17564             318        10145
# 199   safe   14.0652            3212             124         5619
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 7                 11         NaN
# 13                 3         NaN
# 18                12         NaN
# 19                 7         NaN
# 24                 8         NaN
# 35                10         NaN
# 39                 2         NaN
# 40                30         NaN
# 42                 6         NaN
# 52                29         NaN
# 54                19         NaN
# 55                 9         NaN
# 59                 9         NaN
# 64                 2         NaN
# 70                 3         NaN
# 75                 4         NaN
# 76                 5         NaN
# 83                28         NaN
# 97                26         NaN
# 102               10         NaN
# 107                3         NaN
# 111               11         NaN
# 112                7         NaN
# 115                2         NaN
# 135                2         NaN
# 136                7         NaN
# 139                9         NaN
# 142                3         NaN
# 143                5         NaN
# 150               29         NaN
# 152               28         NaN
# 160               24         NaN
# 166                2         NaN
# 172               12         NaN
# 174               43         NaN
# 178                3         NaN
# 185                4         NaN
# 188               52         NaN
# 189               13         NaN
# 191               21         NaN
# 192               35         NaN
# 199               35         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  215.9523          531792             865        13019
# 11   unknown  211.9761          526759             615        39909
# 26   unknown  219.6308          329455             372        87239
# 60   unknown  209.4067          530082             540        27385
# 67   unknown  208.1916          331421             159        42792
# 101  unknown  212.5246          427378             297        16545
# 103  unknown  204.1515          520223             100         5046
# 106  unknown  208.1907          410577             581        55211
# 116  unknown  205.8337          434930             502        60373
# 162  unknown  216.4399          427489             176        35189
# 187  unknown  214.3531          523334            1372        37046
# 194  unknown  206.7240          249525             327        85274
#
#      BaB Round Count  BaB_lb_rhs
# 2                 24   -0.757160
# 11                34   -0.328751
# 26                23   -0.150455
# 60                34   -0.526053
# 67                24   -0.212525
# 101               26   -0.349353
# 103               28   -0.482735
# 106               26   -0.711150
# 116               22   -0.514721
# 162               38   -0.193295
# 187               44   -1.213377
# 194               29   -0.498754
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe    7.9489              50               7          656
# 1         unsafe-pgd    0.0913               0               0            0
# 2            unknown  215.9523          531792             865        13019
# 3         unsafe-pgd    0.0854               0               0            0
# 4         unsafe-pgd    0.1049               0               0            0
# 5         unsafe-pgd    0.1294               0               0            0
# 6         unsafe-pgd    0.0586               0               0            0
# 7               safe    5.5304             312              86         1274
# 8    safe-incomplete    0.0672               0               0            0
# 9         unsafe-pgd    0.0900               0               0            0
# 10        unsafe-pgd    0.1016               0               0            0
# 11           unknown  211.9761          526759             615        39909
# 12        unsafe-pgd    0.1185               0               0            0
# 13              safe    2.8803              50              12          656
# 14   safe-incomplete    0.0878               0               0            0
# 15        unsafe-pgd    0.0779               0               0            0
# 16        unsafe-pgd    0.0982               0               0            0
# 17   safe-incomplete    0.0866               0               0            0
# 18              safe    7.0659             292             112         1431
# 19              safe    3.8333              17              81         1467
# 20   safe-incomplete    0.0771               0               0            0
# 21        unsafe-pgd    0.0772               0               0            0
# 22   safe-incomplete    0.0804               0               0            0
# 23   safe-incomplete    0.2517               0               0            0
# 24              safe    5.6900             154              25          908
# 25        unsafe-pgd    0.0907               0               0            0
# 26           unknown  219.6308          329455             372        87239
# 27   safe-incomplete    0.0814               0               0            0
# 28   safe-incomplete    0.0668               0               0            0
# 29        unsafe-pgd    0.0653               0               0            0
# 30   safe-incomplete    0.0669               0               0            0
# 31   safe-incomplete    0.0683               0               0            0
# 32        unsafe-pgd    0.0961               0               0            0
# 33   safe-incomplete    0.0996               0               0            0
# 34        unsafe-pgd    0.0762               0               0            0
# 35              safe    5.8944             460              85         1089
# 36        unsafe-pgd    0.0804               0               0            0
# 37   safe-incomplete    0.0637               0               0            0
# 38        unsafe-pgd    0.0962               0               0            0
# 39              safe    2.6678               0               1          256
# 40              safe   39.7776           45652            1390        23774
# 41   safe-incomplete    0.0571               0               0            0
# 42              safe    4.1099              50              26         1273
# 43        unsafe-pgd    0.0848               0               0            0
# 44        unsafe-pgd    0.0757               0               0            0
# 45        unsafe-pgd    0.0806               0               0            0
# 46        unsafe-pgd    0.0793               0               0            0
# 47   safe-incomplete    0.0665               0               0            0
# 48        unsafe-pgd    0.0720               0               0            0
# 49   safe-incomplete    0.0790               0               0            0
# 50        unsafe-pgd    0.0906               0               0            0
# 51   safe-incomplete    0.0760               0               0            0
# 52              safe   12.9303            9428              63         6351
# 53        unsafe-pgd    0.0827               0               0            0
# 54              safe    8.1901            5340             106         4301
# 55              safe    5.4311             210              23         1310
# 56        unsafe-pgd    0.0725               0               0            0
# 57        unsafe-pgd    0.0715               0               0            0
# 58        unsafe-pgd    0.0882               0               0            0
# 59              safe    4.5790              99             149         1803
# 60           unknown  209.4067          530082             540        27385
# 61        unsafe-pgd    0.0966               0               0            0
# 62   safe-incomplete    0.0863               0               0            0
# 63        unsafe-pgd    0.1055               0               0            0
# 64              safe    2.5497               0               1          256
# 65        unsafe-pgd    0.1153               0               0            0
# 66        unsafe-pgd    0.0981               0               0            0
# 67           unknown  208.1916          331421             159        42792
# 68   safe-incomplete    0.2316               0               0            0
# 69        unsafe-pgd    0.0442               0               0            0
# 70              safe    2.9116              50               5          256
# 71   safe-incomplete    0.0768               0               0            0
# 72        unsafe-pgd    0.0845               0               0            0
# 73   safe-incomplete    0.2897               0               0            0
# 74   safe-incomplete    0.0905               0               0            0
# 75              safe    3.6126               0               1          512
# 76              safe    3.6498             150              28          656
# 77        unsafe-pgd    0.0721               0               0            0
# 78        unsafe-pgd    0.0874               0               0            0
# 79   safe-incomplete    0.0740               0               0            0
# 80        unsafe-pgd    0.0793               0               0            0
# 81        unsafe-pgd    0.0521               0               0            0
# 82        unsafe-pgd    0.0890               0               0            0
# 83              safe   12.1439            6861              76         4771
# 84        unsafe-pgd    0.0763               0               0            0
# 85        unsafe-pgd    0.0806               0               0            0
# 86   safe-incomplete    0.0856               0               0            0
# 87        unsafe-pgd    0.0808               0               0            0
# 88        unsafe-pgd    0.0866               0               0            0
# 89   safe-incomplete    0.0646               0               0            0
# 90        unsafe-pgd    0.0915               0               0            0
# 91        unsafe-pgd    0.0738               0               0            0
# 92        unsafe-pgd    0.0634               0               0            0
# 93        unsafe-pgd    0.0647               0               0            0
# 94        unsafe-pgd    0.0756               0               0            0
# 95        unsafe-pgd    0.0538               0               0            0
# 96        unsafe-pgd    0.0764               0               0            0
# 97              safe   15.8331           14752             175        11277
# 98        unsafe-pgd    0.0813               0               0            0
# 99        unsafe-pgd    0.0933               0               0            0
# 100       unsafe-pgd    0.0680               0               0            0
# 101          unknown  212.5246          427378             297        16545
# 102             safe    5.2234             484              54          945
# 103          unknown  204.1515          520223             100         5046
# 104  safe-incomplete    0.0717               0               0            0
# 105       unsafe-pgd    0.0819               0               0            0
# 106          unknown  208.1907          410577             581        55211
# 107             safe    2.9543              50               9          653
# 108       unsafe-pgd    0.0711               0               0            0
# 109  safe-incomplete    0.0730               0               0            0
# 110  safe-incomplete    0.0685               0               0            0
# 111             safe    6.3597             265              59         1393
# 112             safe    4.0642              29              40          741
# 113       unsafe-pgd    0.0795               0               0            0
# 114  safe-incomplete    0.0720               0               0            0
# 115             safe    2.5748               0               1          256
# 116          unknown  205.8337          434930             502        60373
# 117  safe-incomplete    0.0688               0               0            0
# 118  safe-incomplete    0.0340               0               0            0
# 119       unsafe-pgd    0.0787               0               0            0
# 120       unsafe-pgd    0.0774               0               0            0
# 121  safe-incomplete    0.0816               0               0            0
# 122       unsafe-pgd    0.0753               0               0            0
# 123       unsafe-pgd    0.0856               0               0            0
# 124       unsafe-pgd    0.0820               0               0            0
# 125       unsafe-pgd    0.0781               0               0            0
# 126       unsafe-pgd    0.0577               0               0            0
# 127       unsafe-pgd    0.0723               0               0            0
# 128       unsafe-pgd    0.0813               0               0            0
# 129       unsafe-pgd    0.0776               0               0            0
# 130       unsafe-pgd    0.0833               0               0            0
# 131  safe-incomplete    0.0342               0               0            0
# 132  safe-incomplete    0.0710               0               0            0
# 133  safe-incomplete    0.0702               0               0            0
# 134       unsafe-pgd    0.0610               0               0            0
# 135             safe    2.6176               0               1          256
# 136             safe    4.5626             150              15          517
# 137       unsafe-pgd    0.0767               0               0            0
# 138       unsafe-pgd    0.0423               0               0            0
# 139             safe    5.1995             250              22         1187
# 140  safe-incomplete    0.0778               0               0            0
# 141       unsafe-pgd    0.0671               0               0            0
# 142             safe    2.9464              50               8          256
# 143             safe    2.9093              12              19          640
# 144       unsafe-pgd    0.0710               0               0            0
# 145       unsafe-pgd    0.0762               0               0            0
# 146  safe-incomplete    0.0689               0               0            0
# 147  safe-incomplete    0.0776               0               0            0
# 148  safe-incomplete    0.0643               0               0            0
# 149       unsafe-pgd    0.1062               0               0            0
# 150             safe   16.9611           15725             216         9969
# 151       unsafe-pgd    0.0836               0               0            0
# 152             safe  177.6755          201281             328        95449
# 153  safe-incomplete    0.0564               0               0            0
# 154       unsafe-pgd    0.0706               0               0            0
# 155       unsafe-pgd    0.0752               0               0            0
# 156       unsafe-pgd    0.0832               0               0            0
# 157  safe-incomplete    0.0506               0               0            0
# 158       unsafe-pgd    0.0439               0               0            0
# 159       unsafe-pgd    0.0717               0               0            0
# 160             safe   10.8599            3875             277         4321
# 161  safe-incomplete    0.0557               0               0            0
# 162          unknown  216.4399          427489             176        35189
# 163       unsafe-pgd    0.0979               0               0            0
# 164       unsafe-pgd    0.0387               0               0            0
# 165       unsafe-pgd    0.0875               0               0            0
# 166             safe    2.6521               0               1          256
# 167       unsafe-pgd    0.0749               0               0            0
# 168  safe-incomplete    0.0805               0               0            0
# 169  safe-incomplete    0.0651               0               0            0
# 170       unsafe-pgd    0.0421               0               0            0
# 171  safe-incomplete    0.0567               0               0            0
# 172             safe    5.6857             334             173         1769
# 173       unsafe-pgd    0.0530               0               0            0
# 174             safe   23.7992           21503             117        15414
# 175       unsafe-pgd    0.0809               0               0            0
# 176       unsafe-pgd    0.0714               0               0            0
# 177  safe-incomplete    0.0379               0               0            0
# 178             safe    2.7759              50               8          551
# 179  safe-incomplete    0.0635               0               0            0
# 180  safe-incomplete    0.2812               0               0            0
# 181       unsafe-pgd    0.0517               0               0            0
# 182  safe-incomplete    0.0793               0               0            0
# 183       unsafe-pgd    0.0752               0               0            0
# 184       unsafe-pgd    0.1096               0               0            0
# 185             safe    2.8779               5              10          576
# 186  safe-incomplete    0.0692               0               0            0
# 187          unknown  214.3531          523334            1372        37046
# 188             safe  122.0853          141694             298        82139
# 189             safe    6.5339             377             116         1592
# 190  safe-incomplete    0.0437               0               0            0
# 191             safe   20.2487           17944             411        10953
# 192             safe   21.5698           17564             318        10145
# 193  safe-incomplete    0.0733               0               0            0
# 194          unknown  206.7240          249525             327        85274
# 195       unsafe-pgd    0.0962               0               0            0
# 196       unsafe-pgd    0.1068               0               0            0
# 197       unsafe-pgd    0.1152               0               0            0
# 198       unsafe-pgd    0.1142               0               0            0
# 199             safe   14.0652            3212             124         5619
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 1                  0         NaN
# 2                 24   -0.757160
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 11         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                34   -0.328751
# 12                 0         NaN
# 13                 3         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                12         NaN
# 19                 7         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 8         NaN
# 25                 0         NaN
# 26                23   -0.150455
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                10         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 2         NaN
# 40                30         NaN
# 41                 0         NaN
# 42                 6         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                29         NaN
# 53                 0         NaN
# 54                19         NaN
# 55                 9         NaN
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 9         NaN
# 60                34   -0.526053
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                24   -0.212525
# 68                 0         NaN
# 69                 0         NaN
# 70                 3         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 4         NaN
# 76                 5         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                28         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                26         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101               26   -0.349353
# 102               10         NaN
# 103               28   -0.482735
# 104                0         NaN
# 105                0         NaN
# 106               26   -0.711150
# 107                3         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               11         NaN
# 112                7         NaN
# 113                0         NaN
# 114                0         NaN
# 115                2         NaN
# 116               22   -0.514721
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                2         NaN
# 136                7         NaN
# 137                0         NaN
# 138                0         NaN
# 139                9         NaN
# 140                0         NaN
# 141                0         NaN
# 142                3         NaN
# 143                5         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150               29         NaN
# 151                0         NaN
# 152               28         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160               24         NaN
# 161                0         NaN
# 162               38   -0.193295
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                2         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               12         NaN
# 173                0         NaN
# 174               43         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                3         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                4         NaN
# 186                0         NaN
# 187               44   -1.213377
# 188               52         NaN
# 189               13         NaN
# 190                0         NaN
# 191               21         NaN
# 192               35         NaN
# 193                0         NaN
# 194               29   -0.498754
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199               35         NaN
# #Cuts 10983
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               43   14.521667   11832.116279     118.069767   7206.372093
# safe-incomplete    51    0.084743       0.000000       0.000000      0.000000
# unknown            12  211.114583  436913.750000     492.166667  42085.666667
# unsafe-pgd         94    0.080338       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  13.627907
# safe-incomplete        0.000000
# unknown               29.333333
# unsafe-pgd             0.000000
# safe number 94.0
# safe time 6.688868085106383
# safe domain 5412.563829787234
# safe cut 54.01063829787234
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((94.0, 6.688868085106383, 11832.116279069767, 118.06976744186046),)

# %%
main('cifar_cnn_a_mix/biccos_all.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe    8.2780              50               7          400
# 7     safe    5.6229             312             149         1194
# 13    safe    2.7282              50              12          400
# 18    safe    5.9420             262              76         1432
# 19    safe    9.7856             380             189         2190
# 24    safe    5.2642             153              44          791
# 35    safe    4.7737             363              98         1190
# 39    safe    2.5019               0               1           12
# 40    safe   39.9138           49456             639        26299
# 42    safe    4.0133              50              26          761
# 52    safe   19.5028           12958             148         7564
# 54    safe   59.3908           70733             155        36103
# 55    safe    5.2964             210              23         1310
# 59    safe   10.7356             510             211         2906
# 64    safe    2.3504               0               1           11
# 70    safe    3.1946              50               5          252
# 75    safe    3.4893               0               1           39
# 76    safe    3.7847             150              28          656
# 83    safe   16.1553            5517             255         5853
# 102   safe    7.3966             592              85         2168
# 103   safe   21.7415           22744             128        11186
# 107   safe    2.9396              50               9          397
# 111   safe    7.1463             262              77         1326
# 112   safe   10.9880             413              42         1757
# 115   safe    2.5606               0               1           20
# 135   safe    2.6762               0               1           19
# 136   safe    4.6261             150              15          449
# 139   safe    5.6822             250              22         1315
# 142   safe    3.0074              50               8          214
# 143   safe    9.2904             307              52         2144
# 150   safe   23.5661           13880             141         9363
# 160   safe   12.0648            2326              90         3735
# 166   safe    2.5369               0               1           19
# 172   safe   20.4386            8573             411         6811
# 174   safe   31.4390           18284             220        15126
# 178   safe    2.9945              50               8          295
# 185   safe    6.1245             150              14          684
# 188   safe  148.5986          153895             347        71006
# 189   safe    6.2195             318              79         1873
# 191   safe   19.4515           18041             242        10686
# 192   safe   21.4659           16435             244        10873
# 194   safe  118.7424          123853             323        79046
# 199   safe   31.5617            4411             586         9770
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 7                 11         NaN
# 13                 2         NaN
# 18                10         NaN
# 19                18         NaN
# 24                 7         NaN
# 35                 9         NaN
# 39                 1         NaN
# 40                31         NaN
# 42                 4         NaN
# 52                37         NaN
# 54                23         NaN
# 55                 9         NaN
# 59                21         NaN
# 64                 1         NaN
# 70                 2         NaN
# 75                 2         NaN
# 76                 5         NaN
# 83                33         NaN
# 102               16         NaN
# 103               22         NaN
# 107                2         NaN
# 111               10         NaN
# 112               17         NaN
# 115                1         NaN
# 135                1         NaN
# 136                5         NaN
# 139                9         NaN
# 142                2         NaN
# 143               13         NaN
# 150               38         NaN
# 160               25         NaN
# 166                1         NaN
# 172               34         NaN
# 174               41         NaN
# 178                2         NaN
# 185                7         NaN
# 188               62         NaN
# 189               12         NaN
# 191               20         NaN
# 192               36         NaN
# 194               27         NaN
# 199               67         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  202.0835          469451             806        13415
# 11   unknown  218.8445          473225             626        39245
# 26   unknown  211.8663          309081             103       117338
# 60   unknown  227.4892          492008             973        30931
# 67   unknown  225.1563          443982             176        59552
# 97   unknown  205.6588          452879             721        28477
# 101  unknown  220.1888          474381             636        16803
# 106  unknown  210.2165          442720             726        53900
# 116  unknown  214.5790          394002             814        49733
# 152  unknown  227.5910          231653             516       147488
# 162  unknown  212.4646          448788             532        54246
# 187  unknown  225.9700          514250            1187        32295
#
#      BaB Round Count  BaB_lb_rhs
# 2                 27   -0.763508
# 11                24   -0.332961
# 26                29   -0.163170
# 60                25   -0.518100
# 67                24   -0.224039
# 97                31   -0.602809
# 101               26   -0.349297
# 106               38   -0.706351
# 116               28   -0.513848
# 152               25   -0.233189
# 162               44   -0.193294
# 187               53   -1.213376
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe    8.2780              50               7          400
# 1         unsafe-pgd    0.0786               0               0            0
# 2            unknown  202.0835          469451             806        13415
# 3         unsafe-pgd    0.0527               0               0            0
# 4         unsafe-pgd    0.0771               0               0            0
# 5         unsafe-pgd    0.0855               0               0            0
# 6         unsafe-pgd    0.0837               0               0            0
# 7               safe    5.6229             312             149         1194
# 8    safe-incomplete    0.0719               0               0            0
# 9         unsafe-pgd    0.0682               0               0            0
# 10        unsafe-pgd    0.0709               0               0            0
# 11           unknown  218.8445          473225             626        39245
# 12        unsafe-pgd    0.0613               0               0            0
# 13              safe    2.7282              50              12          400
# 14   safe-incomplete    0.0721               0               0            0
# 15        unsafe-pgd    0.0805               0               0            0
# 16        unsafe-pgd    0.1205               0               0            0
# 17   safe-incomplete    0.0626               0               0            0
# 18              safe    5.9420             262              76         1432
# 19              safe    9.7856             380             189         2190
# 20   safe-incomplete    0.0672               0               0            0
# 21        unsafe-pgd    0.0698               0               0            0
# 22   safe-incomplete    0.0679               0               0            0
# 23   safe-incomplete    0.2291               0               0            0
# 24              safe    5.2642             153              44          791
# 25        unsafe-pgd    0.0842               0               0            0
# 26           unknown  211.8663          309081             103       117338
# 27   safe-incomplete    0.0672               0               0            0
# 28   safe-incomplete    0.0690               0               0            0
# 29        unsafe-pgd    0.0907               0               0            0
# 30   safe-incomplete    0.0715               0               0            0
# 31   safe-incomplete    0.0680               0               0            0
# 32        unsafe-pgd    0.0860               0               0            0
# 33   safe-incomplete    0.0657               0               0            0
# 34        unsafe-pgd    0.0738               0               0            0
# 35              safe    4.7737             363              98         1190
# 36        unsafe-pgd    0.0973               0               0            0
# 37   safe-incomplete    0.0718               0               0            0
# 38        unsafe-pgd    0.0802               0               0            0
# 39              safe    2.5019               0               1           12
# 40              safe   39.9138           49456             639        26299
# 41   safe-incomplete    0.0825               0               0            0
# 42              safe    4.0133              50              26          761
# 43        unsafe-pgd    0.0912               0               0            0
# 44        unsafe-pgd    0.0722               0               0            0
# 45        unsafe-pgd    0.0771               0               0            0
# 46        unsafe-pgd    0.0813               0               0            0
# 47   safe-incomplete    0.0678               0               0            0
# 48        unsafe-pgd    0.0885               0               0            0
# 49   safe-incomplete    0.0635               0               0            0
# 50        unsafe-pgd    0.1109               0               0            0
# 51   safe-incomplete    0.0662               0               0            0
# 52              safe   19.5028           12958             148         7564
# 53        unsafe-pgd    0.1089               0               0            0
# 54              safe   59.3908           70733             155        36103
# 55              safe    5.2964             210              23         1310
# 56        unsafe-pgd    0.0827               0               0            0
# 57        unsafe-pgd    0.0577               0               0            0
# 58        unsafe-pgd    0.0989               0               0            0
# 59              safe   10.7356             510             211         2906
# 60           unknown  227.4892          492008             973        30931
# 61        unsafe-pgd    0.0820               0               0            0
# 62   safe-incomplete    0.0689               0               0            0
# 63        unsafe-pgd    0.0870               0               0            0
# 64              safe    2.3504               0               1           11
# 65        unsafe-pgd    0.0766               0               0            0
# 66        unsafe-pgd    0.0759               0               0            0
# 67           unknown  225.1563          443982             176        59552
# 68   safe-incomplete    0.2074               0               0            0
# 69        unsafe-pgd    0.0730               0               0            0
# 70              safe    3.1946              50               5          252
# 71   safe-incomplete    0.0743               0               0            0
# 72        unsafe-pgd    0.0808               0               0            0
# 73   safe-incomplete    0.2547               0               0            0
# 74   safe-incomplete    0.0768               0               0            0
# 75              safe    3.4893               0               1           39
# 76              safe    3.7847             150              28          656
# 77        unsafe-pgd    0.0747               0               0            0
# 78        unsafe-pgd    0.0763               0               0            0
# 79   safe-incomplete    0.0891               0               0            0
# 80        unsafe-pgd    0.0864               0               0            0
# 81        unsafe-pgd    0.0839               0               0            0
# 82        unsafe-pgd    0.0806               0               0            0
# 83              safe   16.1553            5517             255         5853
# 84        unsafe-pgd    0.0784               0               0            0
# 85        unsafe-pgd    0.0761               0               0            0
# 86   safe-incomplete    0.0666               0               0            0
# 87        unsafe-pgd    0.0807               0               0            0
# 88        unsafe-pgd    0.0894               0               0            0
# 89   safe-incomplete    0.0757               0               0            0
# 90        unsafe-pgd    0.0884               0               0            0
# 91        unsafe-pgd    0.0893               0               0            0
# 92        unsafe-pgd    0.0728               0               0            0
# 93        unsafe-pgd    0.0789               0               0            0
# 94        unsafe-pgd    0.0741               0               0            0
# 95        unsafe-pgd    0.0816               0               0            0
# 96        unsafe-pgd    0.0774               0               0            0
# 97           unknown  205.6588          452879             721        28477
# 98        unsafe-pgd    0.0471               0               0            0
# 99        unsafe-pgd    0.0880               0               0            0
# 100       unsafe-pgd    0.1221               0               0            0
# 101          unknown  220.1888          474381             636        16803
# 102             safe    7.3966             592              85         2168
# 103             safe   21.7415           22744             128        11186
# 104  safe-incomplete    0.0717               0               0            0
# 105       unsafe-pgd    0.0859               0               0            0
# 106          unknown  210.2165          442720             726        53900
# 107             safe    2.9396              50               9          397
# 108       unsafe-pgd    0.0864               0               0            0
# 109  safe-incomplete    0.0723               0               0            0
# 110  safe-incomplete    0.0790               0               0            0
# 111             safe    7.1463             262              77         1326
# 112             safe   10.9880             413              42         1757
# 113       unsafe-pgd    0.0884               0               0            0
# 114  safe-incomplete    0.1032               0               0            0
# 115             safe    2.5606               0               1           20
# 116          unknown  214.5790          394002             814        49733
# 117  safe-incomplete    0.0696               0               0            0
# 118  safe-incomplete    0.0666               0               0            0
# 119       unsafe-pgd    0.0723               0               0            0
# 120       unsafe-pgd    0.0735               0               0            0
# 121  safe-incomplete    0.0656               0               0            0
# 122       unsafe-pgd    0.0717               0               0            0
# 123       unsafe-pgd    0.0589               0               0            0
# 124       unsafe-pgd    0.0809               0               0            0
# 125       unsafe-pgd    0.0639               0               0            0
# 126       unsafe-pgd    0.0709               0               0            0
# 127       unsafe-pgd    0.0867               0               0            0
# 128       unsafe-pgd    0.0896               0               0            0
# 129       unsafe-pgd    0.0808               0               0            0
# 130       unsafe-pgd    0.0775               0               0            0
# 131  safe-incomplete    0.0687               0               0            0
# 132  safe-incomplete    0.0722               0               0            0
# 133  safe-incomplete    0.0691               0               0            0
# 134       unsafe-pgd    0.0775               0               0            0
# 135             safe    2.6762               0               1           19
# 136             safe    4.6261             150              15          449
# 137       unsafe-pgd    0.0784               0               0            0
# 138       unsafe-pgd    0.0764               0               0            0
# 139             safe    5.6822             250              22         1315
# 140  safe-incomplete    0.0732               0               0            0
# 141       unsafe-pgd    0.0869               0               0            0
# 142             safe    3.0074              50               8          214
# 143             safe    9.2904             307              52         2144
# 144       unsafe-pgd    0.0784               0               0            0
# 145       unsafe-pgd    0.0835               0               0            0
# 146  safe-incomplete    0.0848               0               0            0
# 147  safe-incomplete    0.0835               0               0            0
# 148  safe-incomplete    0.0792               0               0            0
# 149       unsafe-pgd    0.0824               0               0            0
# 150             safe   23.5661           13880             141         9363
# 151       unsafe-pgd    0.0899               0               0            0
# 152          unknown  227.5910          231653             516       147488
# 153  safe-incomplete    0.0753               0               0            0
# 154       unsafe-pgd    0.0816               0               0            0
# 155       unsafe-pgd    0.0840               0               0            0
# 156       unsafe-pgd    0.0906               0               0            0
# 157  safe-incomplete    0.0758               0               0            0
# 158       unsafe-pgd    0.0910               0               0            0
# 159       unsafe-pgd    0.0765               0               0            0
# 160             safe   12.0648            2326              90         3735
# 161  safe-incomplete    0.0764               0               0            0
# 162          unknown  212.4646          448788             532        54246
# 163       unsafe-pgd    0.0910               0               0            0
# 164       unsafe-pgd    0.0899               0               0            0
# 165       unsafe-pgd    0.0982               0               0            0
# 166             safe    2.5369               0               1           19
# 167       unsafe-pgd    0.0833               0               0            0
# 168  safe-incomplete    0.0767               0               0            0
# 169  safe-incomplete    0.0691               0               0            0
# 170       unsafe-pgd    0.0730               0               0            0
# 171  safe-incomplete    0.0684               0               0            0
# 172             safe   20.4386            8573             411         6811
# 173       unsafe-pgd    0.0805               0               0            0
# 174             safe   31.4390           18284             220        15126
# 175       unsafe-pgd    0.0833               0               0            0
# 176       unsafe-pgd    0.0711               0               0            0
# 177  safe-incomplete    0.0673               0               0            0
# 178             safe    2.9945              50               8          295
# 179  safe-incomplete    0.0723               0               0            0
# 180  safe-incomplete    0.2929               0               0            0
# 181       unsafe-pgd    0.0769               0               0            0
# 182  safe-incomplete    0.0721               0               0            0
# 183       unsafe-pgd    0.0821               0               0            0
# 184       unsafe-pgd    0.0868               0               0            0
# 185             safe    6.1245             150              14          684
# 186  safe-incomplete    0.0793               0               0            0
# 187          unknown  225.9700          514250            1187        32295
# 188             safe  148.5986          153895             347        71006
# 189             safe    6.2195             318              79         1873
# 190  safe-incomplete    0.0696               0               0            0
# 191             safe   19.4515           18041             242        10686
# 192             safe   21.4659           16435             244        10873
# 193  safe-incomplete    0.0757               0               0            0
# 194             safe  118.7424          123853             323        79046
# 195       unsafe-pgd    0.0894               0               0            0
# 196       unsafe-pgd    0.0754               0               0            0
# 197       unsafe-pgd    0.0777               0               0            0
# 198       unsafe-pgd    0.0814               0               0            0
# 199             safe   31.5617            4411             586         9770
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 1                  0         NaN
# 2                 27   -0.763508
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 11         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                24   -0.332961
# 12                 0         NaN
# 13                 2         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                10         NaN
# 19                18         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 7         NaN
# 25                 0         NaN
# 26                29   -0.163170
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 9         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                31         NaN
# 41                 0         NaN
# 42                 4         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                37         NaN
# 53                 0         NaN
# 54                23         NaN
# 55                 9         NaN
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                21         NaN
# 60                25   -0.518100
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                24   -0.224039
# 68                 0         NaN
# 69                 0         NaN
# 70                 2         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                 5         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                33         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                31   -0.602809
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101               26   -0.349297
# 102               16         NaN
# 103               22         NaN
# 104                0         NaN
# 105                0         NaN
# 106               38   -0.706351
# 107                2         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               10         NaN
# 112               17         NaN
# 113                0         NaN
# 114                0         NaN
# 115                1         NaN
# 116               28   -0.513848
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                1         NaN
# 136                5         NaN
# 137                0         NaN
# 138                0         NaN
# 139                9         NaN
# 140                0         NaN
# 141                0         NaN
# 142                2         NaN
# 143               13         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150               38         NaN
# 151                0         NaN
# 152               25   -0.233189
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160               25         NaN
# 161                0         NaN
# 162               44   -0.193294
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                1         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               34         NaN
# 173                0         NaN
# 174               41         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                2         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                7         NaN
# 186                0         NaN
# 187               53   -1.213376
# 188               62         NaN
# 189               12         NaN
# 190                0         NaN
# 191               20         NaN
# 192               36         NaN
# 193                0         NaN
# 194               27         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199               67         NaN
# #Cuts 13030
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               43   17.115870   12238.093023     121.255814   7666.162791
# safe-incomplete    51    0.086414       0.000000       0.000000      0.000000
# unknown            12  216.842375  428868.333333     651.333333  53618.583333
# unsafe-pgd         94    0.081451       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  16.232558
# safe-incomplete        0.000000
# unknown               31.166667
# unsafe-pgd             0.000000
# safe number 94.0
# safe time 7.876484042553192
# safe domain 5598.276595744681
# safe cut 55.46808510638298
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((94.0, 7.876484042553192, 12238.093023255815, 121.25581395348837),)

# %%
main('cifar_cnn_a_mix/gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe    6.7414               0               0            0
# 7     safe    4.6933             243               0            0
# 13    safe    3.2868               0               0            0
# 18    safe    3.8658              56               0            0
# 19    safe    4.1628              25               0            0
# 24    safe    3.6817              14               0            0
# 35    safe   22.8746           29950               0            0
# 39    safe    3.0942               0               0            0
# 40    safe   28.2507           60103               0            0
# 42    safe    3.5453               0               0            0
# 52    safe   19.5755           28801               0            0
# 54    safe   59.1633          133120               0            0
# 55    safe    3.2386               0               0            0
# 59    safe    5.4743             110               0            0
# 64    safe    3.2398               0               0            0
# 67    safe  155.3794          200920               0            0
# 70    safe    3.2776               0               0            0
# 75    safe    3.3700               0               0            0
# 76    safe    3.0354               0               0            0
# 83    safe   16.3578           13809               0            0
# 101   safe  102.5132          129115               0            0
# 102   safe    8.0231            1671               0            0
# 107   safe    3.2629               0               0            0
# 111   safe    3.7370              19               0            0
# 112   safe    4.1915              29               0            0
# 115   safe    2.9554               0               0            0
# 135   safe    3.3270               0               0            0
# 136   safe    3.5329               0               0            0
# 139   safe    3.2043               0               0            0
# 142   safe    3.0324               0               0            0
# 143   safe    3.8113              12               0            0
# 150   safe   60.8630           71456               0            0
# 160   safe   29.7769           52299               0            0
# 162   safe   71.7526          137843               0            0
# 166   safe    3.0875               0               0            0
# 172   safe   50.8382          105368               0            0
# 174   safe   57.8184           66409               0            0
# 178   safe    3.2256               0               0            0
# 185   safe    4.2560               5               0            0
# 188   safe   46.5572           83997               0            0
# 189   safe    6.0359             542               0            0
# 191   safe   33.2015           53552               0            0
# 192   safe   22.9215           43709               0            0
# 199   safe   28.7658            9132               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  1         NaN
# 7                  7         NaN
# 13                 1         NaN
# 18                 5         NaN
# 19                 7         NaN
# 24                 4         NaN
# 35                21         NaN
# 39                 1         NaN
# 40                20         NaN
# 42                 2         NaN
# 52                18         NaN
# 54                21         NaN
# 55                 2         NaN
# 59                10         NaN
# 64                 1         NaN
# 67                29         NaN
# 70                 1         NaN
# 75                 2         NaN
# 76                 1         NaN
# 83                27         NaN
# 101               36         NaN
# 102               18         NaN
# 107                1         NaN
# 111                4         NaN
# 112                7         NaN
# 115                1         NaN
# 135                1         NaN
# 136                2         NaN
# 139                2         NaN
# 142                1         NaN
# 143                5         NaN
# 150               33         NaN
# 160               33         NaN
# 162               24         NaN
# 166                1         NaN
# 172               29         NaN
# 174               33         NaN
# 178                1         NaN
# 185                4         NaN
# 188               32         NaN
# 189               11         NaN
# 191               21         NaN
# 192               17         NaN
# 199               46         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  216.9620          262227               0            0
# 11   unknown  214.0145          310053               0            0
# 26   unknown  205.0337          313147               0            0
# 60   unknown  246.4521          380616               0            0
# 97   unknown  217.1970          287278               0            0
# 103  unknown  202.2305          349885               0            0
# 106  unknown  220.1166          288623               0            0
# 116  unknown  221.5262          351487               0            0
# 152  unknown  223.9710          360220               0            0
# 187  unknown  216.2681          223133               0            0
# 194  unknown  214.2739          404894               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                 30   -0.197389
# 11                25   -0.141352
# 26                60   -0.152209
# 60                17   -0.525321
# 97                30   -0.609395
# 103               21   -0.563526
# 106               34   -0.417124
# 116               25   -0.543788
# 152               23   -0.308848
# 187               80   -0.762202
# 194               27   -0.598576
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe    6.7414               0               0            0
# 1         unsafe-pgd    0.0753               0               0            0
# 2            unknown  216.9620          262227               0            0
# 3         unsafe-pgd    0.0749               0               0            0
# 4         unsafe-pgd    0.0861               0               0            0
# 5         unsafe-pgd    0.0593               0               0            0
# 6         unsafe-pgd    0.0784               0               0            0
# 7               safe    4.6933             243               0            0
# 8    safe-incomplete    0.0713               0               0            0
# 9         unsafe-pgd    0.0821               0               0            0
# 10        unsafe-pgd    0.0769               0               0            0
# 11           unknown  214.0145          310053               0            0
# 12        unsafe-pgd    0.0945               0               0            0
# 13              safe    3.2868               0               0            0
# 14   safe-incomplete    0.0680               0               0            0
# 15        unsafe-pgd    0.0909               0               0            0
# 16        unsafe-pgd    0.0785               0               0            0
# 17   safe-incomplete    0.0623               0               0            0
# 18              safe    3.8658              56               0            0
# 19              safe    4.1628              25               0            0
# 20   safe-incomplete    0.0634               0               0            0
# 21        unsafe-pgd    0.0498               0               0            0
# 22   safe-incomplete    0.0788               0               0            0
# 23   safe-incomplete    0.3433               0               0            0
# 24              safe    3.6817              14               0            0
# 25        unsafe-pgd    0.0905               0               0            0
# 26           unknown  205.0337          313147               0            0
# 27   safe-incomplete    0.0791               0               0            0
# 28   safe-incomplete    0.0538               0               0            0
# 29        unsafe-pgd    0.0463               0               0            0
# 30   safe-incomplete    0.0256               0               0            0
# 31   safe-incomplete    0.0676               0               0            0
# 32        unsafe-pgd    0.0861               0               0            0
# 33   safe-incomplete    0.0550               0               0            0
# 34        unsafe-pgd    0.0590               0               0            0
# 35              safe   22.8746           29950               0            0
# 36        unsafe-pgd    0.0936               0               0            0
# 37   safe-incomplete    0.0556               0               0            0
# 38        unsafe-pgd    0.0825               0               0            0
# 39              safe    3.0942               0               0            0
# 40              safe   28.2507           60103               0            0
# 41   safe-incomplete    0.0381               0               0            0
# 42              safe    3.5453               0               0            0
# 43        unsafe-pgd    0.0969               0               0            0
# 44        unsafe-pgd    0.0824               0               0            0
# 45        unsafe-pgd    0.0513               0               0            0
# 46        unsafe-pgd    0.0489               0               0            0
# 47   safe-incomplete    0.0524               0               0            0
# 48        unsafe-pgd    0.0453               0               0            0
# 49   safe-incomplete    0.0653               0               0            0
# 50        unsafe-pgd    0.0550               0               0            0
# 51   safe-incomplete    0.0910               0               0            0
# 52              safe   19.5755           28801               0            0
# 53        unsafe-pgd    0.0874               0               0            0
# 54              safe   59.1633          133120               0            0
# 55              safe    3.2386               0               0            0
# 56        unsafe-pgd    0.0789               0               0            0
# 57        unsafe-pgd    0.0766               0               0            0
# 58        unsafe-pgd    0.0445               0               0            0
# 59              safe    5.4743             110               0            0
# 60           unknown  246.4521          380616               0            0
# 61        unsafe-pgd    0.1567               0               0            0
# 62   safe-incomplete    0.0651               0               0            0
# 63        unsafe-pgd    0.0813               0               0            0
# 64              safe    3.2398               0               0            0
# 65        unsafe-pgd    0.0884               0               0            0
# 66        unsafe-pgd    0.0459               0               0            0
# 67              safe  155.3794          200920               0            0
# 68   safe-incomplete    0.2721               0               0            0
# 69        unsafe-pgd    0.0936               0               0            0
# 70              safe    3.2776               0               0            0
# 71   safe-incomplete    0.0832               0               0            0
# 72        unsafe-pgd    0.1095               0               0            0
# 73   safe-incomplete    0.5321               0               0            0
# 74   safe-incomplete    0.1047               0               0            0
# 75              safe    3.3700               0               0            0
# 76              safe    3.0354               0               0            0
# 77        unsafe-pgd    0.0457               0               0            0
# 78        unsafe-pgd    0.0895               0               0            0
# 79   safe-incomplete    0.0683               0               0            0
# 80        unsafe-pgd    0.0866               0               0            0
# 81        unsafe-pgd    0.0704               0               0            0
# 82        unsafe-pgd    0.0733               0               0            0
# 83              safe   16.3578           13809               0            0
# 84        unsafe-pgd    0.0791               0               0            0
# 85        unsafe-pgd    0.0691               0               0            0
# 86   safe-incomplete    0.0685               0               0            0
# 87        unsafe-pgd    0.0901               0               0            0
# 88        unsafe-pgd    0.0904               0               0            0
# 89   safe-incomplete    0.0680               0               0            0
# 90        unsafe-pgd    0.0871               0               0            0
# 91        unsafe-pgd    0.0788               0               0            0
# 92        unsafe-pgd    0.0761               0               0            0
# 93        unsafe-pgd    0.0706               0               0            0
# 94        unsafe-pgd    0.0783               0               0            0
# 95        unsafe-pgd    0.0991               0               0            0
# 96        unsafe-pgd    0.1079               0               0            0
# 97           unknown  217.1970          287278               0            0
# 98        unsafe-pgd    0.0594               0               0            0
# 99        unsafe-pgd    0.0757               0               0            0
# 100       unsafe-pgd    0.0813               0               0            0
# 101             safe  102.5132          129115               0            0
# 102             safe    8.0231            1671               0            0
# 103          unknown  202.2305          349885               0            0
# 104  safe-incomplete    0.0813               0               0            0
# 105       unsafe-pgd    0.0936               0               0            0
# 106          unknown  220.1166          288623               0            0
# 107             safe    3.2629               0               0            0
# 108       unsafe-pgd    0.0869               0               0            0
# 109  safe-incomplete    0.0725               0               0            0
# 110  safe-incomplete    0.0685               0               0            0
# 111             safe    3.7370              19               0            0
# 112             safe    4.1915              29               0            0
# 113       unsafe-pgd    0.0999               0               0            0
# 114  safe-incomplete    0.0766               0               0            0
# 115             safe    2.9554               0               0            0
# 116          unknown  221.5262          351487               0            0
# 117  safe-incomplete    0.0752               0               0            0
# 118  safe-incomplete    0.0651               0               0            0
# 119       unsafe-pgd    0.0834               0               0            0
# 120       unsafe-pgd    0.0758               0               0            0
# 121  safe-incomplete    0.0657               0               0            0
# 122       unsafe-pgd    0.0610               0               0            0
# 123       unsafe-pgd    0.0855               0               0            0
# 124       unsafe-pgd    0.0655               0               0            0
# 125       unsafe-pgd    0.0741               0               0            0
# 126       unsafe-pgd    0.0751               0               0            0
# 127       unsafe-pgd    0.0771               0               0            0
# 128       unsafe-pgd    0.0742               0               0            0
# 129       unsafe-pgd    0.0731               0               0            0
# 130       unsafe-pgd    0.0854               0               0            0
# 131  safe-incomplete    0.0660               0               0            0
# 132  safe-incomplete    0.0537               0               0            0
# 133  safe-incomplete    0.0662               0               0            0
# 134       unsafe-pgd    0.0824               0               0            0
# 135             safe    3.3270               0               0            0
# 136             safe    3.5329               0               0            0
# 137       unsafe-pgd    0.0970               0               0            0
# 138       unsafe-pgd    0.0752               0               0            0
# 139             safe    3.2043               0               0            0
# 140  safe-incomplete    0.0830               0               0            0
# 141       unsafe-pgd    0.1063               0               0            0
# 142             safe    3.0324               0               0            0
# 143             safe    3.8113              12               0            0
# 144       unsafe-pgd    0.1364               0               0            0
# 145       unsafe-pgd    0.0858               0               0            0
# 146  safe-incomplete    0.0700               0               0            0
# 147  safe-incomplete    0.0676               0               0            0
# 148  safe-incomplete    0.0593               0               0            0
# 149       unsafe-pgd    0.0543               0               0            0
# 150             safe   60.8630           71456               0            0
# 151       unsafe-pgd    0.0797               0               0            0
# 152          unknown  223.9710          360220               0            0
# 153  safe-incomplete    0.0811               0               0            0
# 154       unsafe-pgd    0.0608               0               0            0
# 155       unsafe-pgd    0.0783               0               0            0
# 156       unsafe-pgd    0.0559               0               0            0
# 157  safe-incomplete    0.0372               0               0            0
# 158       unsafe-pgd    0.0762               0               0            0
# 159       unsafe-pgd    0.0466               0               0            0
# 160             safe   29.7769           52299               0            0
# 161  safe-incomplete    0.0664               0               0            0
# 162             safe   71.7526          137843               0            0
# 163       unsafe-pgd    0.0932               0               0            0
# 164       unsafe-pgd    0.0612               0               0            0
# 165       unsafe-pgd    0.0472               0               0            0
# 166             safe    3.0875               0               0            0
# 167       unsafe-pgd    0.0877               0               0            0
# 168  safe-incomplete    0.0730               0               0            0
# 169  safe-incomplete    0.0700               0               0            0
# 170       unsafe-pgd    0.0812               0               0            0
# 171  safe-incomplete    0.0722               0               0            0
# 172             safe   50.8382          105368               0            0
# 173       unsafe-pgd    0.0727               0               0            0
# 174             safe   57.8184           66409               0            0
# 175       unsafe-pgd    0.0867               0               0            0
# 176       unsafe-pgd    0.0814               0               0            0
# 177  safe-incomplete    0.0686               0               0            0
# 178             safe    3.2256               0               0            0
# 179  safe-incomplete    0.0793               0               0            0
# 180  safe-incomplete    0.4682               0               0            0
# 181       unsafe-pgd    0.1099               0               0            0
# 182  safe-incomplete    0.0824               0               0            0
# 183       unsafe-pgd    0.0821               0               0            0
# 184       unsafe-pgd    0.0895               0               0            0
# 185             safe    4.2560               5               0            0
# 186  safe-incomplete    0.1048               0               0            0
# 187          unknown  216.2681          223133               0            0
# 188             safe   46.5572           83997               0            0
# 189             safe    6.0359             542               0            0
# 190  safe-incomplete    0.0762               0               0            0
# 191             safe   33.2015           53552               0            0
# 192             safe   22.9215           43709               0            0
# 193  safe-incomplete    0.0733               0               0            0
# 194          unknown  214.2739          404894               0            0
# 195       unsafe-pgd    0.1634               0               0            0
# 196       unsafe-pgd    0.0833               0               0            0
# 197       unsafe-pgd    0.0808               0               0            0
# 198       unsafe-pgd    0.0901               0               0            0
# 199             safe   28.7658            9132               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  1         NaN
# 1                  0         NaN
# 2                 30   -0.197389
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  7         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                25   -0.141352
# 12                 0         NaN
# 13                 1         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 5         NaN
# 19                 7         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 4         NaN
# 25                 0         NaN
# 26                60   -0.152209
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                21         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                20         NaN
# 41                 0         NaN
# 42                 2         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                18         NaN
# 53                 0         NaN
# 54                21         NaN
# 55                 2         NaN
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                10         NaN
# 60                17   -0.525321
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                29         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 1         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                 1         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                27         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                30   -0.609395
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101               36         NaN
# 102               18         NaN
# 103               21   -0.563526
# 104                0         NaN
# 105                0         NaN
# 106               34   -0.417124
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                4         NaN
# 112                7         NaN
# 113                0         NaN
# 114                0         NaN
# 115                1         NaN
# 116               25   -0.543788
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                1         NaN
# 136                2         NaN
# 137                0         NaN
# 138                0         NaN
# 139                2         NaN
# 140                0         NaN
# 141                0         NaN
# 142                1         NaN
# 143                5         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150               33         NaN
# 151                0         NaN
# 152               23   -0.308848
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160               33         NaN
# 161                0         NaN
# 162               24         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                1         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               29         NaN
# 173                0         NaN
# 174               33         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                1         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                4         NaN
# 186                0         NaN
# 187               80   -0.762202
# 188               32         NaN
# 189               11         NaN
# 190                0         NaN
# 191               21         NaN
# 192               17         NaN
# 193                0         NaN
# 194               27   -0.598576
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199               46         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               44   20.840895   27779.750000            0.0         0.0
# safe-incomplete    51    0.095216       0.000000            0.0         0.0
# unknown            11  218.004145  321051.181818            0.0         0.0
# unsafe-pgd         94    0.079912       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  12.363636
# safe-incomplete        0.000000
# unknown               33.818182
# unsafe-pgd             0.000000
# safe number 95.0
# safe time 9.70374105263158
# safe domain 12866.410526315789
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((95.0, 9.70374105263158, 27779.75, 0.0),)

# %%
main('cifar_cnn_a_mix/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe   10.1557              50               7          400
# 7     safe    7.8430             287             105         1522
# 13    safe    4.6425              50              12          400
# 18    safe    8.4210             262              76         1431
# 19    safe   14.2433             380             195         2191
# 24    safe    7.8128             153              49          791
# 35    safe    7.5847             417              95         1370
# 39    safe    3.8044               0               1           12
# 40    safe   30.1405           23877            1183        11098
# 42    safe    5.6822              50              26          761
# 52    safe   20.6108            6106             709         4055
# 54    safe   50.0834           52102             634        35370
# 55    safe    8.0511             210              23         1310
# 59    safe   13.7170             510             212         2907
# 64    safe    4.0346               0               1           11
# 67    safe   99.5072           87037            1752        84888
# 70    safe    5.0443              50               5          252
# 75    safe    5.2443               0               1           39
# 76    safe    5.0653             150              28          656
# 83    safe   14.2766            1109             647         3336
# 97    safe  116.4138           68922            3353        52464
# 101   safe  120.4773           92685            2530        90786
# 102   safe   10.1207             605              90         2167
# 107   safe    4.2945              50               9          397
# 111   safe    9.1801             262              94         1327
# 112   safe   13.2927             413              53         1757
# 115   safe    3.7229               0               1           20
# 135   safe    4.4037               0               1           19
# 136   safe    6.6096             100              15          447
# 139   safe    7.9912             250              22         1315
# 142   safe    4.1788              50               8          214
# 143   safe   11.2424             257              52         2144
# 150   safe   30.9095           11706            2779         8407
# 160   safe   15.6581            2272              91         3765
# 162   safe   81.5069           73717            2226        66535
# 166   safe    3.7936               0               1           19
# 172   safe   24.8865            8680             361         7055
# 174   safe   37.1830           12993            1881        12007
# 178   safe    4.2127              50               8          295
# 185   safe    8.1562             150              14          703
# 188   safe   32.3820           14933            1208        11638
# 189   safe    9.2658             318              75         1873
# 191   safe   23.0761           14886            1590        12485
# 192   safe   15.2917            6983             882         5512
# 194   safe   26.2527           18788             181        11992
# 199   safe   46.0257            3775            4202         8882
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 7                 10         NaN
# 13                 2         NaN
# 18                10         NaN
# 19                18         NaN
# 24                 7         NaN
# 35                 9         NaN
# 39                 1         NaN
# 40                21         NaN
# 42                 4         NaN
# 52                29         NaN
# 54                22         NaN
# 55                 9         NaN
# 59                21         NaN
# 64                 1         NaN
# 67                19         NaN
# 70                 2         NaN
# 75                 2         NaN
# 76                 5         NaN
# 83                22         NaN
# 97                38         NaN
# 101               26         NaN
# 102               16         NaN
# 107                2         NaN
# 111               10         NaN
# 112               17         NaN
# 115                1         NaN
# 135                1         NaN
# 136                5         NaN
# 139                9         NaN
# 142                2         NaN
# 143               13         NaN
# 150               45         NaN
# 160               25         NaN
# 162               35         NaN
# 166                1         NaN
# 172               35         NaN
# 174               57         NaN
# 178                2         NaN
# 185                7         NaN
# 188               42         NaN
# 189               12         NaN
# 191               19         NaN
# 192               21         NaN
# 194               23         NaN
# 199               65         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  201.0940          209146           11380        60716
# 11   unknown  211.5303          212642            7051        51260
# 26   unknown  207.5173          202199            6884       128078
# 60   unknown  217.4360          250305            8337        47627
# 103  unknown  228.3675          262925            1692        47596
# 106  unknown  213.5078          205391            7130        60975
# 116  unknown  204.7083          150067            7682        50985
# 152  unknown  203.1607          219724            2057        86669
# 187  unknown  206.1123          121721           20804       112314
#
#      BaB Round Count  BaB_lb_rhs
# 2                 53   -0.517040
# 11                24   -0.092060
# 26                70   -0.160278
# 60                25   -0.326387
# 103               27   -0.335337
# 106               40   -0.387486
# 116               29   -0.321611
# 152               30   -0.149913
# 187              109   -2.038097
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   10.1557              50               7          400
# 1         unsafe-pgd    0.0579               0               0            0
# 2            unknown  201.0940          209146           11380        60716
# 3         unsafe-pgd    0.0911               0               0            0
# 4         unsafe-pgd    0.0874               0               0            0
# 5         unsafe-pgd    0.0783               0               0            0
# 6         unsafe-pgd    0.0869               0               0            0
# 7               safe    7.8430             287             105         1522
# 8    safe-incomplete    0.0730               0               0            0
# 9         unsafe-pgd    0.0813               0               0            0
# 10        unsafe-pgd    0.0758               0               0            0
# 11           unknown  211.5303          212642            7051        51260
# 12        unsafe-pgd    0.0906               0               0            0
# 13              safe    4.6425              50              12          400
# 14   safe-incomplete    0.0726               0               0            0
# 15        unsafe-pgd    0.0643               0               0            0
# 16        unsafe-pgd    0.0525               0               0            0
# 17   safe-incomplete    0.0446               0               0            0
# 18              safe    8.4210             262              76         1431
# 19              safe   14.2433             380             195         2191
# 20   safe-incomplete    0.0685               0               0            0
# 21        unsafe-pgd    0.0530               0               0            0
# 22   safe-incomplete    0.0414               0               0            0
# 23   safe-incomplete    0.2779               0               0            0
# 24              safe    7.8128             153              49          791
# 25        unsafe-pgd    0.0542               0               0            0
# 26           unknown  207.5173          202199            6884       128078
# 27   safe-incomplete    0.0612               0               0            0
# 28   safe-incomplete    0.0669               0               0            0
# 29        unsafe-pgd    0.0697               0               0            0
# 30   safe-incomplete    0.0703               0               0            0
# 31   safe-incomplete    0.0423               0               0            0
# 32        unsafe-pgd    0.0595               0               0            0
# 33   safe-incomplete    0.0452               0               0            0
# 34        unsafe-pgd    0.0700               0               0            0
# 35              safe    7.5847             417              95         1370
# 36        unsafe-pgd    0.0817               0               0            0
# 37   safe-incomplete    0.0653               0               0            0
# 38        unsafe-pgd    0.0729               0               0            0
# 39              safe    3.8044               0               1           12
# 40              safe   30.1405           23877            1183        11098
# 41   safe-incomplete    0.0759               0               0            0
# 42              safe    5.6822              50              26          761
# 43        unsafe-pgd    0.0929               0               0            0
# 44        unsafe-pgd    0.0727               0               0            0
# 45        unsafe-pgd    0.0829               0               0            0
# 46        unsafe-pgd    0.0807               0               0            0
# 47   safe-incomplete    0.0659               0               0            0
# 48        unsafe-pgd    0.0757               0               0            0
# 49   safe-incomplete    0.0641               0               0            0
# 50        unsafe-pgd    0.0833               0               0            0
# 51   safe-incomplete    0.0694               0               0            0
# 52              safe   20.6108            6106             709         4055
# 53        unsafe-pgd    0.0862               0               0            0
# 54              safe   50.0834           52102             634        35370
# 55              safe    8.0511             210              23         1310
# 56        unsafe-pgd    0.0801               0               0            0
# 57        unsafe-pgd    0.0707               0               0            0
# 58        unsafe-pgd    0.0815               0               0            0
# 59              safe   13.7170             510             212         2907
# 60           unknown  217.4360          250305            8337        47627
# 61        unsafe-pgd    0.0877               0               0            0
# 62   safe-incomplete    0.0685               0               0            0
# 63        unsafe-pgd    0.0807               0               0            0
# 64              safe    4.0346               0               1           11
# 65        unsafe-pgd    0.1749               0               0            0
# 66        unsafe-pgd    0.0756               0               0            0
# 67              safe   99.5072           87037            1752        84888
# 68   safe-incomplete    0.2736               0               0            0
# 69        unsafe-pgd    0.1414               0               0            0
# 70              safe    5.0443              50               5          252
# 71   safe-incomplete    0.0902               0               0            0
# 72        unsafe-pgd    0.0851               0               0            0
# 73   safe-incomplete    0.3450               0               0            0
# 74   safe-incomplete    0.0826               0               0            0
# 75              safe    5.2443               0               1           39
# 76              safe    5.0653             150              28          656
# 77        unsafe-pgd    0.0544               0               0            0
# 78        unsafe-pgd    0.0812               0               0            0
# 79   safe-incomplete    0.0674               0               0            0
# 80        unsafe-pgd    0.0833               0               0            0
# 81        unsafe-pgd    0.0541               0               0            0
# 82        unsafe-pgd    0.0756               0               0            0
# 83              safe   14.2766            1109             647         3336
# 84        unsafe-pgd    0.0799               0               0            0
# 85        unsafe-pgd    0.0807               0               0            0
# 86   safe-incomplete    0.0705               0               0            0
# 87        unsafe-pgd    0.0452               0               0            0
# 88        unsafe-pgd    0.0794               0               0            0
# 89   safe-incomplete    0.0703               0               0            0
# 90        unsafe-pgd    0.0791               0               0            0
# 91        unsafe-pgd    0.0744               0               0            0
# 92        unsafe-pgd    0.0701               0               0            0
# 93        unsafe-pgd    0.0699               0               0            0
# 94        unsafe-pgd    0.0741               0               0            0
# 95        unsafe-pgd    0.0751               0               0            0
# 96        unsafe-pgd    0.0742               0               0            0
# 97              safe  116.4138           68922            3353        52464
# 98        unsafe-pgd    0.0848               0               0            0
# 99        unsafe-pgd    0.0718               0               0            0
# 100       unsafe-pgd    0.0795               0               0            0
# 101             safe  120.4773           92685            2530        90786
# 102             safe   10.1207             605              90         2167
# 103          unknown  228.3675          262925            1692        47596
# 104  safe-incomplete    0.0697               0               0            0
# 105       unsafe-pgd    0.0820               0               0            0
# 106          unknown  213.5078          205391            7130        60975
# 107             safe    4.2945              50               9          397
# 108       unsafe-pgd    0.1707               0               0            0
# 109  safe-incomplete    0.0720               0               0            0
# 110  safe-incomplete    0.0691               0               0            0
# 111             safe    9.1801             262              94         1327
# 112             safe   13.2927             413              53         1757
# 113       unsafe-pgd    0.2123               0               0            0
# 114  safe-incomplete    0.0673               0               0            0
# 115             safe    3.7229               0               1           20
# 116          unknown  204.7083          150067            7682        50985
# 117  safe-incomplete    0.0785               0               0            0
# 118  safe-incomplete    0.0673               0               0            0
# 119       unsafe-pgd    0.0762               0               0            0
# 120       unsafe-pgd    0.0805               0               0            0
# 121  safe-incomplete    0.0642               0               0            0
# 122       unsafe-pgd    0.0727               0               0            0
# 123       unsafe-pgd    0.0770               0               0            0
# 124       unsafe-pgd    0.0801               0               0            0
# 125       unsafe-pgd    0.0861               0               0            0
# 126       unsafe-pgd    0.0728               0               0            0
# 127       unsafe-pgd    0.0653               0               0            0
# 128       unsafe-pgd    0.0790               0               0            0
# 129       unsafe-pgd    0.0738               0               0            0
# 130       unsafe-pgd    0.0800               0               0            0
# 131  safe-incomplete    0.0632               0               0            0
# 132  safe-incomplete    0.0654               0               0            0
# 133  safe-incomplete    0.0738               0               0            0
# 134       unsafe-pgd    0.0789               0               0            0
# 135             safe    4.4037               0               1           19
# 136             safe    6.6096             100              15          447
# 137       unsafe-pgd    0.0896               0               0            0
# 138       unsafe-pgd    0.0874               0               0            0
# 139             safe    7.9912             250              22         1315
# 140  safe-incomplete    0.0798               0               0            0
# 141       unsafe-pgd    0.0822               0               0            0
# 142             safe    4.1788              50               8          214
# 143             safe   11.2424             257              52         2144
# 144       unsafe-pgd    0.0828               0               0            0
# 145       unsafe-pgd    0.0758               0               0            0
# 146  safe-incomplete    0.0730               0               0            0
# 147  safe-incomplete    0.0275               0               0            0
# 148  safe-incomplete    0.0679               0               0            0
# 149       unsafe-pgd    0.0847               0               0            0
# 150             safe   30.9095           11706            2779         8407
# 151       unsafe-pgd    0.0768               0               0            0
# 152          unknown  203.1607          219724            2057        86669
# 153  safe-incomplete    0.0648               0               0            0
# 154       unsafe-pgd    0.0553               0               0            0
# 155       unsafe-pgd    0.0769               0               0            0
# 156       unsafe-pgd    0.0602               0               0            0
# 157  safe-incomplete    0.0478               0               0            0
# 158       unsafe-pgd    0.0394               0               0            0
# 159       unsafe-pgd    0.0706               0               0            0
# 160             safe   15.6581            2272              91         3765
# 161  safe-incomplete    0.0695               0               0            0
# 162             safe   81.5069           73717            2226        66535
# 163       unsafe-pgd    0.0459               0               0            0
# 164       unsafe-pgd    0.0760               0               0            0
# 165       unsafe-pgd    0.0840               0               0            0
# 166             safe    3.7936               0               1           19
# 167       unsafe-pgd    0.0767               0               0            0
# 168  safe-incomplete    0.0731               0               0            0
# 169  safe-incomplete    0.0658               0               0            0
# 170       unsafe-pgd    0.0698               0               0            0
# 171  safe-incomplete    0.0241               0               0            0
# 172             safe   24.8865            8680             361         7055
# 173       unsafe-pgd    0.0633               0               0            0
# 174             safe   37.1830           12993            1881        12007
# 175       unsafe-pgd    0.0628               0               0            0
# 176       unsafe-pgd    0.0705               0               0            0
# 177  safe-incomplete    0.0651               0               0            0
# 178             safe    4.2127              50               8          295
# 179  safe-incomplete    0.1230               0               0            0
# 180  safe-incomplete    0.3581               0               0            0
# 181       unsafe-pgd    0.0981               0               0            0
# 182  safe-incomplete    0.0743               0               0            0
# 183       unsafe-pgd    0.0857               0               0            0
# 184       unsafe-pgd    0.0739               0               0            0
# 185             safe    8.1562             150              14          703
# 186  safe-incomplete    0.0830               0               0            0
# 187          unknown  206.1123          121721           20804       112314
# 188             safe   32.3820           14933            1208        11638
# 189             safe    9.2658             318              75         1873
# 190  safe-incomplete    0.0711               0               0            0
# 191             safe   23.0761           14886            1590        12485
# 192             safe   15.2917            6983             882         5512
# 193  safe-incomplete    0.0756               0               0            0
# 194             safe   26.2527           18788             181        11992
# 195       unsafe-pgd    0.0796               0               0            0
# 196       unsafe-pgd    0.0544               0               0            0
# 197       unsafe-pgd    0.0743               0               0            0
# 198       unsafe-pgd    0.0830               0               0            0
# 199             safe   46.0257            3775            4202         8882
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 1                  0         NaN
# 2                 53   -0.517040
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 10         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                24   -0.092060
# 12                 0         NaN
# 13                 2         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                10         NaN
# 19                18         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 7         NaN
# 25                 0         NaN
# 26                70   -0.160278
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 9         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                21         NaN
# 41                 0         NaN
# 42                 4         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                29         NaN
# 53                 0         NaN
# 54                22         NaN
# 55                 9         NaN
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                21         NaN
# 60                25   -0.326387
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                19         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 2         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                 5         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                22         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                38         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101               26         NaN
# 102               16         NaN
# 103               27   -0.335337
# 104                0         NaN
# 105                0         NaN
# 106               40   -0.387486
# 107                2         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               10         NaN
# 112               17         NaN
# 113                0         NaN
# 114                0         NaN
# 115                1         NaN
# 116               29   -0.321611
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                1         NaN
# 136                5         NaN
# 137                0         NaN
# 138                0         NaN
# 139                9         NaN
# 140                0         NaN
# 141                0         NaN
# 142                2         NaN
# 143               13         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150               45         NaN
# 151                0         NaN
# 152               30   -0.149913
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160               25         NaN
# 161                0         NaN
# 162               35         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                1         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               35         NaN
# 173                0         NaN
# 174               57         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                2         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                7         NaN
# 186                0         NaN
# 187              109   -2.038097
# 188               42         NaN
# 189               12         NaN
# 190                0         NaN
# 191               19         NaN
# 192               21         NaN
# 193                0         NaN
# 194               23         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199               65         NaN
# #Cuts 100505
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               46   21.662889   10992.282609     597.565217   9935.326087
# safe-incomplete    51    0.086404       0.000000       0.000000      0.000000
# unknown             9  210.381578  203791.111111    8113.000000  71802.222222
# unsafe-pgd         94    0.079076       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  16.195652
# safe-incomplete        0.000000
# unknown               45.222222
# unsafe-pgd             0.000000
# safe number 97.0
# safe time 10.318551546391753
# safe domain 5212.835051546392
# safe cut 283.3814432989691
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((97.0, 10.318551546391753, 10992.282608695652, 597.5652173913044),)

# %% [markdown]
# ## cifar_cnn_a_mix4

# %%
plot_multiple_dfs(
    [
        log_read('cifar_cnn_a_mix4/beta.log'),
        log_read('cifar_cnn_a_mix4/biccos_only_cs.log'),
        log_read('cifar_cnn_a_mix4/biccos_all.log'),
        log_read('cifar_cnn_a_mix4/gcp.log'),
        log_read('cifar_cnn_a_mix4/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN', 
        'Biccos_base', 
        'Biccos_MTS', 
        'GCP-CROWN with MIP cuts',  
        'Biccos_auto'
     ],  time_limit=200, dataset='cifar_cnn_a_mix4'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_a_mix4/beta.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2     safe   6.1621              97               0            0
# 19    safe   2.3232               0               0            0
# 24    safe   2.4539               2               0            0
# 38    safe   2.2779               0               0            0
# 48    safe   2.2640               0               0            0
# 54    safe   2.2185               0               0            0
# 64    safe   2.6691               0               0            0
# 67    safe   2.5685               1               0            0
# 83    safe  15.7565           35820               0            0
# 93    safe   2.3868               0               0            0
# 97    safe   2.3938               0               0            0
# 104   safe   2.3561               0               0            0
# 111   safe   2.3654               0               0            0
# 120   safe   2.3545               0               0            0
# 132   safe   2.3945               0               0            0
# 135   safe   2.5685               8               0            0
# 158   safe   3.3094              82               0            0
# 160   safe   2.2865               0               0            0
# 181   safe   2.4795               0               0            0
# 185   safe   2.6241               4               0            0
# 187   safe   2.6537               0               0            0
# 189   safe   2.4766               0               0            0
# 199   safe   2.5618               2               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                  3         NaN
# 19                 1         NaN
# 24                 2         NaN
# 38                 1         NaN
# 48                 1         NaN
# 54                 1         NaN
# 64                 1         NaN
# 67                 2         NaN
# 83                22         NaN
# 93                 1         NaN
# 97                 1         NaN
# 104                1         NaN
# 111                1         NaN
# 120                1         NaN
# 132                1         NaN
# 135                2         NaN
# 158                7         NaN
# 160                1         NaN
# 181                2         NaN
# 185                3         NaN
# 187                4         NaN
# 189                2         NaN
# 199                2         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 13   unknown  209.8611          621217               0            0
# 57   unknown  211.5666          593721               0            0
# 59   unknown  211.5028          670703               0            0
# 66   unknown  213.1841          608259               0            0
# 76   unknown  204.9436          665661               0            0
# 77   unknown  214.3829          666712               0            0
# 127  unknown  212.0918          647825               0            0
# 137  unknown  215.3092          692833               0            0
# 154  unknown  212.5522          676520               0            0
# 162  unknown  214.3749          678440               0            0
# 172  unknown  219.2365          692561               0            0
# 191  unknown  211.2962          699917               0            0
# 198  unknown  207.4617          850875               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 13                24   -0.205297
# 57                38   -0.016723
# 59                25   -0.215234
# 66                31   -0.062804
# 76                24   -0.163587
# 77                30   -0.076583
# 127               26   -0.181337
# 137               27   -0.076308
# 154               26   -0.022495
# 162               24   -0.072721
# 172               24   -0.147970
# 191               27   -0.039999
# 198               38   -0.123055
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.2007               0               0            0
# 1         unsafe-pgd    0.1150               0               0            0
# 2               safe    6.1621              97               0            0
# 3         unsafe-pgd    0.0543               0               0            0
# 4         unsafe-pgd    0.0516               0               0            0
# 5         unsafe-pgd    0.0616               0               0            0
# 6         unsafe-pgd    0.0549               0               0            0
# 7    safe-incomplete    0.0458               0               0            0
# 8    safe-incomplete    0.0378               0               0            0
# 9         unsafe-pgd    0.0528               0               0            0
# 10        unsafe-pgd    0.0543               0               0            0
# 11   safe-incomplete    0.0632               0               0            0
# 12        unsafe-pgd    0.0374               0               0            0
# 13           unknown  209.8611          621217               0            0
# 14   safe-incomplete    0.0733               0               0            0
# 15        unsafe-pgd    0.0645               0               0            0
# 16        unsafe-pgd    0.0780               0               0            0
# 17   safe-incomplete    0.0447               0               0            0
# 18   safe-incomplete    0.2959               0               0            0
# 19              safe    2.3232               0               0            0
# 20   safe-incomplete    0.0724               0               0            0
# 21        unsafe-pgd    0.0708               0               0            0
# 22   safe-incomplete    0.0454               0               0            0
# 23   safe-incomplete    0.0634               0               0            0
# 24              safe    2.4539               2               0            0
# 25        unsafe-pgd    0.0884               0               0            0
# 26   safe-incomplete    0.0456               0               0            0
# 27   safe-incomplete    0.0208               0               0            0
# 28   safe-incomplete    0.0565               0               0            0
# 29        unsafe-pgd    0.0724               0               0            0
# 30   safe-incomplete    0.0496               0               0            0
# 31   safe-incomplete    0.0448               0               0            0
# 32        unsafe-pgd    0.0765               0               0            0
# 33   safe-incomplete    0.0488               0               0            0
# 34        unsafe-pgd    0.0711               0               0            0
# 35        unsafe-pgd    0.0686               0               0            0
# 36        unsafe-pgd    0.0598               0               0            0
# 37   safe-incomplete    0.0491               0               0            0
# 38              safe    2.2779               0               0            0
# 39   safe-incomplete    0.0738               0               0            0
# 40   safe-incomplete    0.0533               0               0            0
# 41   safe-incomplete    0.0611               0               0            0
# 42   safe-incomplete    0.0666               0               0            0
# 43        unsafe-pgd    0.0641               0               0            0
# 44        unsafe-pgd    0.0562               0               0            0
# 45        unsafe-pgd    0.0579               0               0            0
# 46        unsafe-pgd    0.0555               0               0            0
# 47   safe-incomplete    0.0425               0               0            0
# 48              safe    2.2640               0               0            0
# 49   safe-incomplete    0.0492               0               0            0
# 50        unsafe-pgd    0.0861               0               0            0
# 51   safe-incomplete    0.0622               0               0            0
# 52   safe-incomplete    0.0502               0               0            0
# 53        unsafe-pgd    0.0808               0               0            0
# 54              safe    2.2185               0               0            0
# 55   safe-incomplete    0.0660               0               0            0
# 56        unsafe-pgd    0.0736               0               0            0
# 57           unknown  211.5666          593721               0            0
# 58        unsafe-pgd    0.0637               0               0            0
# 59           unknown  211.5028          670703               0            0
# 60   safe-incomplete    0.0736               0               0            0
# 61        unsafe-pgd    0.0775               0               0            0
# 62   safe-incomplete    0.0630               0               0            0
# 63        unsafe-pgd    0.0826               0               0            0
# 64              safe    2.6691               0               0            0
# 65        unsafe-pgd    0.0671               0               0            0
# 66           unknown  213.1841          608259               0            0
# 67              safe    2.5685               1               0            0
# 68   safe-incomplete    0.0577               0               0            0
# 69   safe-incomplete    0.0499               0               0            0
# 70   safe-incomplete    0.0671               0               0            0
# 71   safe-incomplete    0.0607               0               0            0
# 72        unsafe-pgd    0.0776               0               0            0
# 73   safe-incomplete    0.0720               0               0            0
# 74   safe-incomplete    0.0674               0               0            0
# 75   safe-incomplete    0.0632               0               0            0
# 76           unknown  204.9436          665661               0            0
# 77           unknown  214.3829          666712               0            0
# 78        unsafe-pgd    0.0769               0               0            0
# 79   safe-incomplete    0.0353               0               0            0
# 80        unsafe-pgd    0.0528               0               0            0
# 81   safe-incomplete    0.0577               0               0            0
# 82        unsafe-pgd    0.0475               0               0            0
# 83              safe   15.7565           35820               0            0
# 84        unsafe-pgd    0.0527               0               0            0
# 85   safe-incomplete    0.0656               0               0            0
# 86   safe-incomplete    0.0508               0               0            0
# 87        unsafe-pgd    0.0737               0               0            0
# 88        unsafe-pgd    0.0695               0               0            0
# 89   safe-incomplete    0.0631               0               0            0
# 90        unsafe-pgd    0.0684               0               0            0
# 91        unsafe-pgd    0.0516               0               0            0
# 92        unsafe-pgd    0.0637               0               0            0
# 93              safe    2.3868               0               0            0
# 94        unsafe-pgd    0.0603               0               0            0
# 95        unsafe-pgd    0.0546               0               0            0
# 96        unsafe-pgd    0.0500               0               0            0
# 97              safe    2.3938               0               0            0
# 98   safe-incomplete    0.2315               0               0            0
# 99        unsafe-pgd    0.0526               0               0            0
# 100       unsafe-pgd    0.0802               0               0            0
# 101       unsafe-pgd    0.0317               0               0            0
# 102       unsafe-pgd    0.0574               0               0            0
# 103  safe-incomplete    0.0447               0               0            0
# 104             safe    2.3561               0               0            0
# 105       unsafe-pgd    0.0931               0               0            0
# 106       unsafe-pgd    0.0683               0               0            0
# 107  safe-incomplete    0.0457               0               0            0
# 108       unsafe-pgd    0.0416               0               0            0
# 109  safe-incomplete    0.0588               0               0            0
# 110  safe-incomplete    0.0557               0               0            0
# 111             safe    2.3654               0               0            0
# 112       unsafe-pgd    0.0576               0               0            0
# 113       unsafe-pgd    0.0714               0               0            0
# 114  safe-incomplete    0.0460               0               0            0
# 115  safe-incomplete    0.0439               0               0            0
# 116  safe-incomplete    0.0641               0               0            0
# 117  safe-incomplete    0.0382               0               0            0
# 118  safe-incomplete    0.0549               0               0            0
# 119       unsafe-pgd    0.0631               0               0            0
# 120             safe    2.3545               0               0            0
# 121  safe-incomplete    0.0755               0               0            0
# 122       unsafe-pgd    0.0511               0               0            0
# 123       unsafe-pgd    0.0474               0               0            0
# 124       unsafe-pgd    0.0464               0               0            0
# 125       unsafe-pgd    0.0634               0               0            0
# 126       unsafe-pgd    0.0648               0               0            0
# 127          unknown  212.0918          647825               0            0
# 128       unsafe-pgd    0.0526               0               0            0
# 129       unsafe-pgd    0.0603               0               0            0
# 130       unsafe-pgd    0.0660               0               0            0
# 131  safe-incomplete    0.0300               0               0            0
# 132             safe    2.3945               0               0            0
# 133  safe-incomplete    0.0440               0               0            0
# 134       unsafe-pgd    0.0531               0               0            0
# 135             safe    2.5685               8               0            0
# 136  safe-incomplete    0.0662               0               0            0
# 137          unknown  215.3092          692833               0            0
# 138       unsafe-pgd    0.0762               0               0            0
# 139  safe-incomplete    0.0695               0               0            0
# 140  safe-incomplete    0.0643               0               0            0
# 141       unsafe-pgd    0.0755               0               0            0
# 142  safe-incomplete    0.0657               0               0            0
# 143       unsafe-pgd    0.0662               0               0            0
# 144  safe-incomplete    0.0455               0               0            0
# 145       unsafe-pgd    0.0616               0               0            0
# 146  safe-incomplete    0.0688               0               0            0
# 147  safe-incomplete    0.0598               0               0            0
# 148  safe-incomplete    0.0644               0               0            0
# 149       unsafe-pgd    0.0753               0               0            0
# 150       unsafe-pgd    0.0422               0               0            0
# 151       unsafe-pgd    0.0560               0               0            0
# 152       unsafe-pgd    0.0527               0               0            0
# 153  safe-incomplete    0.0498               0               0            0
# 154          unknown  212.5522          676520               0            0
# 155       unsafe-pgd    0.0878               0               0            0
# 156       unsafe-pgd    0.0522               0               0            0
# 157  safe-incomplete    0.0498               0               0            0
# 158             safe    3.3094              82               0            0
# 159  safe-incomplete    0.0361               0               0            0
# 160             safe    2.2865               0               0            0
# 161  safe-incomplete    0.0541               0               0            0
# 162          unknown  214.3749          678440               0            0
# 163       unsafe-pgd    0.0710               0               0            0
# 164  safe-incomplete    0.0457               0               0            0
# 165       unsafe-pgd    0.0775               0               0            0
# 166  safe-incomplete    0.0590               0               0            0
# 167       unsafe-pgd    0.0512               0               0            0
# 168  safe-incomplete    0.0617               0               0            0
# 169       unsafe-pgd    0.0456               0               0            0
# 170       unsafe-pgd    0.0477               0               0            0
# 171  safe-incomplete    0.0400               0               0            0
# 172          unknown  219.2365          692561               0            0
# 173       unsafe-pgd    0.0730               0               0            0
# 174       unsafe-pgd    0.0500               0               0            0
# 175  safe-incomplete    0.4317               0               0            0
# 176       unsafe-pgd    0.0399               0               0            0
# 177  safe-incomplete    0.0396               0               0            0
# 178       unsafe-pgd    0.0433               0               0            0
# 179  safe-incomplete    0.0306               0               0            0
# 180  safe-incomplete    0.0354               0               0            0
# 181             safe    2.4795               0               0            0
# 182  safe-incomplete    0.0558               0               0            0
# 183       unsafe-pgd    0.0477               0               0            0
# 184       unsafe-pgd    0.0703               0               0            0
# 185             safe    2.6241               4               0            0
# 186  safe-incomplete    0.0505               0               0            0
# 187             safe    2.6537               0               0            0
# 188       unsafe-pgd    0.0595               0               0            0
# 189             safe    2.4766               0               0            0
# 190  safe-incomplete    0.0603               0               0            0
# 191          unknown  211.2962          699917               0            0
# 192  safe-incomplete    0.0690               0               0            0
# 193  safe-incomplete    0.0361               0               0            0
# 194       unsafe-pgd    0.0561               0               0            0
# 195       unsafe-pgd    0.0514               0               0            0
# 196       unsafe-pgd    0.0497               0               0            0
# 197  safe-incomplete    0.0298               0               0            0
# 198          unknown  207.4617          850875               0            0
# 199             safe    2.5618               2               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  3         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                24   -0.205297
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 1         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 2         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                38   -0.016723
# 58                 0         NaN
# 59                25   -0.215234
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                31   -0.062804
# 67                 2         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                24   -0.163587
# 77                30   -0.076583
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                22         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 1         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                 1         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                1         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                1         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127               26   -0.181337
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                2         NaN
# 136                0         NaN
# 137               27   -0.076308
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               26   -0.022495
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                7         NaN
# 159                0         NaN
# 160                1         NaN
# 161                0         NaN
# 162               24   -0.072721
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               24   -0.147970
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                2         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                3         NaN
# 186                0         NaN
# 187                4         NaN
# 188                0         NaN
# 189                2         NaN
# 190                0         NaN
# 191               27   -0.039999
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198               38   -0.123055
# 199                2         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               23    3.213257    1565.913043            0.0         0.0
# safe-incomplete    79    0.091165       0.000000            0.0         0.0
# unknown            13  212.135662  674249.538462            0.0         0.0
# unsafe-pgd         85    0.062331       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                    2.73913
# safe-incomplete         0.00000
# unknown                28.00000
# unsafe-pgd              0.00000
# safe number 102.0
# safe time 0.7951656862745098
# safe domain 353.0980392156863
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((102.0, 0.7951656862745098, 1565.9130434782608, 0.0),)

# %%
main('cifar_cnn_a_mix4/biccos_only_cs.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2     safe   10.5337             249              84         1015
# 19    safe    2.3505               0               1          256
# 24    safe    3.8858             113              37          606
# 38    safe    2.3736               0               1          256
# 48    safe    2.5964              50               6          524
# 54    safe    2.3120               0               1          256
# 57    safe   16.9183           13354             288        11055
# 59    safe  165.8314          190849             141       124035
# 64    safe    2.6179              50               7          656
# 66    safe   90.8676          110850            1177        71311
# 67    safe    2.8365             100              56          656
# 83    safe   18.1696           18316            1075        16290
# 93    safe    2.4471              50              10          656
# 97    safe    2.4840              50               9          656
# 104   safe    2.5811              50               5          656
# 111   safe    2.7992             100              23          656
# 120   safe    2.5060              50               5          656
# 127   safe  134.2831          188061             782        56161
# 132   safe    2.3849               0               1          256
# 135   safe    3.7288             116              16          656
# 137   safe  161.6977          193579             292       124515
# 158   safe    7.5826             342              72         1508
# 160   safe    2.5429              50               6          656
# 172   safe   13.6397           12903             160        10523
# 181   safe    3.2899               0               1          512
# 185   safe    5.2469             251              38         1268
# 187   safe    2.1426               0               0          256
# 189   safe    3.4783              50               3          512
# 191   safe    7.2714            2670              28         2837
# 198   safe   74.6927           92432             415        47539
# 199   safe    3.6155             182              42          640
#
#      BaB Round Count  BaB_lb_rhs
# 2                  8         NaN
# 19                 2         NaN
# 24                 6         NaN
# 38                 2         NaN
# 48                 3         NaN
# 54                 2         NaN
# 57                46         NaN
# 59                31         NaN
# 64                 3         NaN
# 66                73         NaN
# 67                 4         NaN
# 83                19         NaN
# 93                 3         NaN
# 97                 3         NaN
# 104                3         NaN
# 111                4         NaN
# 120                3         NaN
# 127               25         NaN
# 132                2         NaN
# 135                6         NaN
# 137               44         NaN
# 158               15         NaN
# 160                3         NaN
# 172               18         NaN
# 181                4         NaN
# 185               10         NaN
# 187                4         NaN
# 189                5         NaN
# 191               14         NaN
# 198               21         NaN
# 199                6         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 13   unknown  209.8274          360219             127        76502
# 76   unknown  217.2337          441332             108        28855
# 77   unknown  232.3783          301906             220       114326
# 154  unknown  227.0514          434406              15        24238
# 162  unknown  205.3584          468037             595        38473
#
#      BaB Round Count  BaB_lb_rhs
# 13                40   -0.119513
# 76                34   -0.133567
# 77                44   -0.031475
# 154               27   -0.015891
# 162               23   -0.068141
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.4120               0               0            0
# 1         unsafe-pgd    0.1344               0               0            0
# 2               safe   10.5337             249              84         1015
# 3         unsafe-pgd    0.0670               0               0            0
# 4         unsafe-pgd    0.0493               0               0            0
# 5         unsafe-pgd    0.0402               0               0            0
# 6         unsafe-pgd    0.0366               0               0            0
# 7    safe-incomplete    0.0416               0               0            0
# 8    safe-incomplete    0.0278               0               0            0
# 9         unsafe-pgd    0.0560               0               0            0
# 10        unsafe-pgd    0.0395               0               0            0
# 11   safe-incomplete    0.0360               0               0            0
# 12        unsafe-pgd    0.0408               0               0            0
# 13           unknown  209.8274          360219             127        76502
# 14   safe-incomplete    0.0488               0               0            0
# 15        unsafe-pgd    0.0612               0               0            0
# 16        unsafe-pgd    0.0606               0               0            0
# 17   safe-incomplete    0.0307               0               0            0
# 18   safe-incomplete    0.2743               0               0            0
# 19              safe    2.3505               0               1          256
# 20   safe-incomplete    0.0698               0               0            0
# 21        unsafe-pgd    0.0505               0               0            0
# 22   safe-incomplete    0.0470               0               0            0
# 23   safe-incomplete    0.0424               0               0            0
# 24              safe    3.8858             113              37          606
# 25        unsafe-pgd    0.0879               0               0            0
# 26   safe-incomplete    0.0473               0               0            0
# 27   safe-incomplete    0.0418               0               0            0
# 28   safe-incomplete    0.0426               0               0            0
# 29        unsafe-pgd    0.0478               0               0            0
# 30   safe-incomplete    0.0434               0               0            0
# 31   safe-incomplete    0.0277               0               0            0
# 32        unsafe-pgd    0.0708               0               0            0
# 33   safe-incomplete    0.0371               0               0            0
# 34        unsafe-pgd    0.0320               0               0            0
# 35        unsafe-pgd    0.0537               0               0            0
# 36        unsafe-pgd    0.0535               0               0            0
# 37   safe-incomplete    0.0389               0               0            0
# 38              safe    2.3736               0               1          256
# 39   safe-incomplete    0.0455               0               0            0
# 40   safe-incomplete    0.0363               0               0            0
# 41   safe-incomplete    0.0307               0               0            0
# 42   safe-incomplete    0.0308               0               0            0
# 43        unsafe-pgd    0.0560               0               0            0
# 44        unsafe-pgd    0.0454               0               0            0
# 45        unsafe-pgd    0.0510               0               0            0
# 46        unsafe-pgd    0.0737               0               0            0
# 47   safe-incomplete    0.0467               0               0            0
# 48              safe    2.5964              50               6          524
# 49   safe-incomplete    0.0697               0               0            0
# 50        unsafe-pgd    0.0618               0               0            0
# 51   safe-incomplete    0.0602               0               0            0
# 52   safe-incomplete    0.0440               0               0            0
# 53        unsafe-pgd    0.0470               0               0            0
# 54              safe    2.3120               0               1          256
# 55   safe-incomplete    0.0483               0               0            0
# 56        unsafe-pgd    0.0541               0               0            0
# 57              safe   16.9183           13354             288        11055
# 58        unsafe-pgd    0.0619               0               0            0
# 59              safe  165.8314          190849             141       124035
# 60   safe-incomplete    0.0493               0               0            0
# 61        unsafe-pgd    0.0484               0               0            0
# 62   safe-incomplete    0.0533               0               0            0
# 63        unsafe-pgd    0.0619               0               0            0
# 64              safe    2.6179              50               7          656
# 65        unsafe-pgd    0.0863               0               0            0
# 66              safe   90.8676          110850            1177        71311
# 67              safe    2.8365             100              56          656
# 68   safe-incomplete    0.0463               0               0            0
# 69   safe-incomplete    0.0315               0               0            0
# 70   safe-incomplete    0.0472               0               0            0
# 71   safe-incomplete    0.0451               0               0            0
# 72        unsafe-pgd    0.0583               0               0            0
# 73   safe-incomplete    0.0357               0               0            0
# 74   safe-incomplete    0.0432               0               0            0
# 75   safe-incomplete    0.0275               0               0            0
# 76           unknown  217.2337          441332             108        28855
# 77           unknown  232.3783          301906             220       114326
# 78        unsafe-pgd    0.0481               0               0            0
# 79   safe-incomplete    0.0479               0               0            0
# 80        unsafe-pgd    0.0519               0               0            0
# 81   safe-incomplete    0.0379               0               0            0
# 82        unsafe-pgd    0.0359               0               0            0
# 83              safe   18.1696           18316            1075        16290
# 84        unsafe-pgd    0.0555               0               0            0
# 85   safe-incomplete    0.0488               0               0            0
# 86   safe-incomplete    0.0290               0               0            0
# 87        unsafe-pgd    0.0403               0               0            0
# 88        unsafe-pgd    0.0438               0               0            0
# 89   safe-incomplete    0.0444               0               0            0
# 90        unsafe-pgd    0.0612               0               0            0
# 91        unsafe-pgd    0.0501               0               0            0
# 92        unsafe-pgd    0.0379               0               0            0
# 93              safe    2.4471              50              10          656
# 94        unsafe-pgd    0.0639               0               0            0
# 95        unsafe-pgd    0.0346               0               0            0
# 96        unsafe-pgd    0.0534               0               0            0
# 97              safe    2.4840              50               9          656
# 98   safe-incomplete    0.2140               0               0            0
# 99        unsafe-pgd    0.0500               0               0            0
# 100       unsafe-pgd    0.0575               0               0            0
# 101       unsafe-pgd    0.0709               0               0            0
# 102       unsafe-pgd    0.0703               0               0            0
# 103  safe-incomplete    0.0673               0               0            0
# 104             safe    2.5811              50               5          656
# 105       unsafe-pgd    0.0626               0               0            0
# 106       unsafe-pgd    0.0322               0               0            0
# 107  safe-incomplete    0.0512               0               0            0
# 108       unsafe-pgd    0.0580               0               0            0
# 109  safe-incomplete    0.0500               0               0            0
# 110  safe-incomplete    0.0493               0               0            0
# 111             safe    2.7992             100              23          656
# 112       unsafe-pgd    0.0530               0               0            0
# 113       unsafe-pgd    0.0562               0               0            0
# 114  safe-incomplete    0.0464               0               0            0
# 115  safe-incomplete    0.0627               0               0            0
# 116  safe-incomplete    0.0311               0               0            0
# 117  safe-incomplete    0.0427               0               0            0
# 118  safe-incomplete    0.0308               0               0            0
# 119       unsafe-pgd    0.0460               0               0            0
# 120             safe    2.5060              50               5          656
# 121  safe-incomplete    0.0468               0               0            0
# 122       unsafe-pgd    0.0514               0               0            0
# 123       unsafe-pgd    0.0385               0               0            0
# 124       unsafe-pgd    0.0582               0               0            0
# 125       unsafe-pgd    0.0651               0               0            0
# 126       unsafe-pgd    0.0360               0               0            0
# 127             safe  134.2831          188061             782        56161
# 128       unsafe-pgd    0.0572               0               0            0
# 129       unsafe-pgd    0.0437               0               0            0
# 130       unsafe-pgd    0.0393               0               0            0
# 131  safe-incomplete    0.0596               0               0            0
# 132             safe    2.3849               0               1          256
# 133  safe-incomplete    0.0395               0               0            0
# 134       unsafe-pgd    0.0435               0               0            0
# 135             safe    3.7288             116              16          656
# 136  safe-incomplete    0.0474               0               0            0
# 137             safe  161.6977          193579             292       124515
# 138       unsafe-pgd    0.0561               0               0            0
# 139  safe-incomplete    0.0654               0               0            0
# 140  safe-incomplete    0.0463               0               0            0
# 141       unsafe-pgd    0.0390               0               0            0
# 142  safe-incomplete    0.0471               0               0            0
# 143       unsafe-pgd    0.0495               0               0            0
# 144  safe-incomplete    0.0421               0               0            0
# 145       unsafe-pgd    0.0332               0               0            0
# 146  safe-incomplete    0.0408               0               0            0
# 147  safe-incomplete    0.0380               0               0            0
# 148  safe-incomplete    0.0318               0               0            0
# 149       unsafe-pgd    0.0481               0               0            0
# 150       unsafe-pgd    0.0414               0               0            0
# 151       unsafe-pgd    0.0357               0               0            0
# 152       unsafe-pgd    0.0525               0               0            0
# 153  safe-incomplete    0.0300               0               0            0
# 154          unknown  227.0514          434406              15        24238
# 155       unsafe-pgd    0.0723               0               0            0
# 156       unsafe-pgd    0.0579               0               0            0
# 157  safe-incomplete    0.0439               0               0            0
# 158             safe    7.5826             342              72         1508
# 159  safe-incomplete    0.0693               0               0            0
# 160             safe    2.5429              50               6          656
# 161  safe-incomplete    0.0636               0               0            0
# 162          unknown  205.3584          468037             595        38473
# 163       unsafe-pgd    0.0861               0               0            0
# 164  safe-incomplete    0.0310               0               0            0
# 165       unsafe-pgd    0.0714               0               0            0
# 166  safe-incomplete    0.0313               0               0            0
# 167       unsafe-pgd    0.0347               0               0            0
# 168  safe-incomplete    0.0296               0               0            0
# 169       unsafe-pgd    0.0453               0               0            0
# 170       unsafe-pgd    0.0390               0               0            0
# 171  safe-incomplete    0.0329               0               0            0
# 172             safe   13.6397           12903             160        10523
# 173       unsafe-pgd    0.0741               0               0            0
# 174       unsafe-pgd    0.0579               0               0            0
# 175  safe-incomplete    0.4355               0               0            0
# 176       unsafe-pgd    0.0561               0               0            0
# 177  safe-incomplete    0.0329               0               0            0
# 178       unsafe-pgd    0.0707               0               0            0
# 179  safe-incomplete    0.0273               0               0            0
# 180  safe-incomplete    0.0296               0               0            0
# 181             safe    3.2899               0               1          512
# 182  safe-incomplete    0.0433               0               0            0
# 183       unsafe-pgd    0.0383               0               0            0
# 184       unsafe-pgd    0.0493               0               0            0
# 185             safe    5.2469             251              38         1268
# 186  safe-incomplete    0.0476               0               0            0
# 187             safe    2.1426               0               0          256
# 188       unsafe-pgd    0.0582               0               0            0
# 189             safe    3.4783              50               3          512
# 190  safe-incomplete    0.0523               0               0            0
# 191             safe    7.2714            2670              28         2837
# 192  safe-incomplete    0.0460               0               0            0
# 193  safe-incomplete    0.0472               0               0            0
# 194       unsafe-pgd    0.0718               0               0            0
# 195       unsafe-pgd    0.0580               0               0            0
# 196       unsafe-pgd    0.0511               0               0            0
# 197  safe-incomplete    0.0442               0               0            0
# 198             safe   74.6927           92432             415        47539
# 199             safe    3.6155             182              42          640
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  8         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                40   -0.119513
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 2         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 6         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 2         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 3         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 2         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                46         NaN
# 58                 0         NaN
# 59                31         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 3         NaN
# 65                 0         NaN
# 66                73         NaN
# 67                 4         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                34   -0.133567
# 77                44   -0.031475
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                19         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 3         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                 3         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                3         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                4         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                3         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127               25         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                2         NaN
# 133                0         NaN
# 134                0         NaN
# 135                6         NaN
# 136                0         NaN
# 137               44         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               27   -0.015891
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158               15         NaN
# 159                0         NaN
# 160                3         NaN
# 161                0         NaN
# 162               23   -0.068141
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               18         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                4         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               10         NaN
# 186                0         NaN
# 187                4         NaN
# 188                0         NaN
# 189                5         NaN
# 190                0         NaN
# 191               14         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198               21         NaN
# 199                6         NaN
# #Cuts 5847
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               31   24.506700   26608.612903     154.258065  15420.483871
# safe-incomplete    79    0.083497       0.000000       0.000000      0.000000
# unknown             5  218.369840  401180.000000     213.000000  56478.800000
# unsafe-pgd         85    0.054135       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  12.645161
# safe-incomplete        0.000000
# unknown               33.600000
# unsafe-pgd             0.000000
# safe number 110.0
# safe time 6.966400000000001
# safe domain 7498.790909090909
# safe cut 43.472727272727276
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((110.0, 6.966400000000001, 26608.612903225807, 154.25806451612902),)

# %%
main('cifar_cnn_a_mix4/biccos_all.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2     safe  10.2084             226              76          951
# 19    safe   2.4446               0               1            8
# 24    safe   4.2141             112              26          606
# 38    safe   2.4614               0               1           19
# 48    safe   2.7974              50               6          268
# 54    safe   2.4164               0               1           24
# 57    safe  16.7475            4965             313         6440
# 64    safe   2.6762              50               7          400
# 66    safe  54.4841           64742            1246        36519
# 67    safe   2.8310             100              56          400
# 83    safe  24.2685           26043            1259        14443
# 93    safe   2.5548              50              10          400
# 97    safe   2.5903              50               9          400
# 104   safe   2.5710              50               5          400
# 111   safe   2.8895             100              23          400
# 120   safe   2.6407              50               5          400
# 127   safe  42.8851           48281             350        28920
# 132   safe   2.4568               0               1           56
# 135   safe   3.1549             100              15          651
# 137   safe  11.8521            5201             203         4467
# 158   safe   7.6179             341              60         1512
# 160   safe   2.5891              50               6          400
# 181   safe   3.3306               0               1           93
# 185   safe   5.1599             250              30         1012
# 187   safe   5.9586             100              20          835
# 189   safe   3.5545              50               3          102
# 191   safe   6.5944            1088              30         1746
# 198   safe  64.5635           87124             360        42004
# 199   safe   3.7291             182              42          384
#
#      BaB Round Count  BaB_lb_rhs
# 2                  7         NaN
# 19                 1         NaN
# 24                 5         NaN
# 38                 1         NaN
# 48                 2         NaN
# 54                 1         NaN
# 57                40         NaN
# 64                 2         NaN
# 66                50         NaN
# 67                 3         NaN
# 83                21         NaN
# 93                 2         NaN
# 97                 2         NaN
# 104                2         NaN
# 111                3         NaN
# 120                2         NaN
# 127               28         NaN
# 132                1         NaN
# 135                4         NaN
# 137               26         NaN
# 158               14         NaN
# 160                2         NaN
# 181                2         NaN
# 185                8         NaN
# 187                7         NaN
# 189                3         NaN
# 191               13         NaN
# 198               19         NaN
# 199                5         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 13   unknown  204.3024          324492             168       122165
# 59   unknown  230.0976          355862             137        96166
# 76   unknown  230.3641          468810              75        29348
# 77   unknown  217.1651          287040             224        86385
# 154  unknown  226.4092          385098              60        23491
# 162  unknown  212.4474          462355             553        40820
# 172  unknown  205.4769          591980              51        36567
#
#      BaB Round Count  BaB_lb_rhs
# 13                39   -0.118522
# 59                37   -0.159064
# 76                35   -0.133565
# 77                45   -0.031475
# 154               27   -0.015134
# 162               22   -0.068139
# 172               95   -0.136680
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.3861               0               0            0
# 1         unsafe-pgd    0.1827               0               0            0
# 2               safe   10.2084             226              76          951
# 3         unsafe-pgd    0.0557               0               0            0
# 4         unsafe-pgd    0.0538               0               0            0
# 5         unsafe-pgd    0.0794               0               0            0
# 6         unsafe-pgd    0.0709               0               0            0
# 7    safe-incomplete    0.0680               0               0            0
# 8    safe-incomplete    0.0666               0               0            0
# 9         unsafe-pgd    0.0747               0               0            0
# 10        unsafe-pgd    0.0780               0               0            0
# 11   safe-incomplete    0.0740               0               0            0
# 12        unsafe-pgd    0.0758               0               0            0
# 13           unknown  204.3024          324492             168       122165
# 14   safe-incomplete    0.0684               0               0            0
# 15        unsafe-pgd    0.0780               0               0            0
# 16        unsafe-pgd    0.0791               0               0            0
# 17   safe-incomplete    0.0420               0               0            0
# 18   safe-incomplete    0.2742               0               0            0
# 19              safe    2.4446               0               1            8
# 20   safe-incomplete    0.0693               0               0            0
# 21        unsafe-pgd    0.0577               0               0            0
# 22   safe-incomplete    0.0719               0               0            0
# 23   safe-incomplete    0.0663               0               0            0
# 24              safe    4.2141             112              26          606
# 25        unsafe-pgd    0.0704               0               0            0
# 26   safe-incomplete    0.0423               0               0            0
# 27   safe-incomplete    0.0692               0               0            0
# 28   safe-incomplete    0.0674               0               0            0
# 29        unsafe-pgd    0.0934               0               0            0
# 30   safe-incomplete    0.0740               0               0            0
# 31   safe-incomplete    0.0651               0               0            0
# 32        unsafe-pgd    0.0985               0               0            0
# 33   safe-incomplete    0.0708               0               0            0
# 34        unsafe-pgd    0.0853               0               0            0
# 35        unsafe-pgd    0.0842               0               0            0
# 36        unsafe-pgd    0.0769               0               0            0
# 37   safe-incomplete    0.0475               0               0            0
# 38              safe    2.4614               0               1           19
# 39   safe-incomplete    0.0666               0               0            0
# 40   safe-incomplete    0.0654               0               0            0
# 41   safe-incomplete    0.0725               0               0            0
# 42   safe-incomplete    0.0451               0               0            0
# 43        unsafe-pgd    0.0732               0               0            0
# 44        unsafe-pgd    0.0714               0               0            0
# 45        unsafe-pgd    0.0948               0               0            0
# 46        unsafe-pgd    0.0811               0               0            0
# 47   safe-incomplete    0.0697               0               0            0
# 48              safe    2.7974              50               6          268
# 49   safe-incomplete    0.0655               0               0            0
# 50        unsafe-pgd    0.1149               0               0            0
# 51   safe-incomplete    0.0668               0               0            0
# 52   safe-incomplete    0.0714               0               0            0
# 53        unsafe-pgd    0.0830               0               0            0
# 54              safe    2.4164               0               1           24
# 55   safe-incomplete    0.0634               0               0            0
# 56        unsafe-pgd    0.0517               0               0            0
# 57              safe   16.7475            4965             313         6440
# 58        unsafe-pgd    0.0765               0               0            0
# 59           unknown  230.0976          355862             137        96166
# 60   safe-incomplete    0.0690               0               0            0
# 61        unsafe-pgd    0.0782               0               0            0
# 62   safe-incomplete    0.0739               0               0            0
# 63        unsafe-pgd    0.0839               0               0            0
# 64              safe    2.6762              50               7          400
# 65        unsafe-pgd    0.0735               0               0            0
# 66              safe   54.4841           64742            1246        36519
# 67              safe    2.8310             100              56          400
# 68   safe-incomplete    0.0772               0               0            0
# 69   safe-incomplete    0.0704               0               0            0
# 70   safe-incomplete    0.0686               0               0            0
# 71   safe-incomplete    0.0634               0               0            0
# 72        unsafe-pgd    0.0712               0               0            0
# 73   safe-incomplete    0.0346               0               0            0
# 74   safe-incomplete    0.0634               0               0            0
# 75   safe-incomplete    0.0627               0               0            0
# 76           unknown  230.3641          468810              75        29348
# 77           unknown  217.1651          287040             224        86385
# 78        unsafe-pgd    0.0804               0               0            0
# 79   safe-incomplete    0.0661               0               0            0
# 80        unsafe-pgd    0.0445               0               0            0
# 81   safe-incomplete    0.0633               0               0            0
# 82        unsafe-pgd    0.0717               0               0            0
# 83              safe   24.2685           26043            1259        14443
# 84        unsafe-pgd    0.0738               0               0            0
# 85   safe-incomplete    0.0633               0               0            0
# 86   safe-incomplete    0.0731               0               0            0
# 87        unsafe-pgd    0.0748               0               0            0
# 88        unsafe-pgd    0.0819               0               0            0
# 89   safe-incomplete    0.0632               0               0            0
# 90        unsafe-pgd    0.0921               0               0            0
# 91        unsafe-pgd    0.0735               0               0            0
# 92        unsafe-pgd    0.0816               0               0            0
# 93              safe    2.5548              50              10          400
# 94        unsafe-pgd    0.0720               0               0            0
# 95        unsafe-pgd    0.0766               0               0            0
# 96        unsafe-pgd    0.0799               0               0            0
# 97              safe    2.5903              50               9          400
# 98   safe-incomplete    0.2368               0               0            0
# 99        unsafe-pgd    0.0796               0               0            0
# 100       unsafe-pgd    0.0734               0               0            0
# 101       unsafe-pgd    0.0702               0               0            0
# 102       unsafe-pgd    0.0774               0               0            0
# 103  safe-incomplete    0.0672               0               0            0
# 104             safe    2.5710              50               5          400
# 105       unsafe-pgd    0.0813               0               0            0
# 106       unsafe-pgd    0.0799               0               0            0
# 107  safe-incomplete    0.0604               0               0            0
# 108       unsafe-pgd    0.0714               0               0            0
# 109  safe-incomplete    0.0706               0               0            0
# 110  safe-incomplete    0.0688               0               0            0
# 111             safe    2.8895             100              23          400
# 112       unsafe-pgd    0.0716               0               0            0
# 113       unsafe-pgd    0.0724               0               0            0
# 114  safe-incomplete    0.0680               0               0            0
# 115  safe-incomplete    0.0514               0               0            0
# 116  safe-incomplete    0.0700               0               0            0
# 117  safe-incomplete    0.0666               0               0            0
# 118  safe-incomplete    0.0739               0               0            0
# 119       unsafe-pgd    0.0770               0               0            0
# 120             safe    2.6407              50               5          400
# 121  safe-incomplete    0.0632               0               0            0
# 122       unsafe-pgd    0.0760               0               0            0
# 123       unsafe-pgd    0.0707               0               0            0
# 124       unsafe-pgd    0.0830               0               0            0
# 125       unsafe-pgd    0.0606               0               0            0
# 126       unsafe-pgd    0.0738               0               0            0
# 127             safe   42.8851           48281             350        28920
# 128       unsafe-pgd    0.0656               0               0            0
# 129       unsafe-pgd    0.0445               0               0            0
# 130       unsafe-pgd    0.0771               0               0            0
# 131  safe-incomplete    0.0284               0               0            0
# 132             safe    2.4568               0               1           56
# 133  safe-incomplete    0.0655               0               0            0
# 134       unsafe-pgd    0.0540               0               0            0
# 135             safe    3.1549             100              15          651
# 136  safe-incomplete    0.0726               0               0            0
# 137             safe   11.8521            5201             203         4467
# 138       unsafe-pgd    0.0403               0               0            0
# 139  safe-incomplete    0.0644               0               0            0
# 140  safe-incomplete    0.0707               0               0            0
# 141       unsafe-pgd    0.0602               0               0            0
# 142  safe-incomplete    0.0773               0               0            0
# 143       unsafe-pgd    0.0787               0               0            0
# 144  safe-incomplete    0.0635               0               0            0
# 145       unsafe-pgd    0.0721               0               0            0
# 146  safe-incomplete    0.0687               0               0            0
# 147  safe-incomplete    0.0757               0               0            0
# 148  safe-incomplete    0.0685               0               0            0
# 149       unsafe-pgd    0.0737               0               0            0
# 150       unsafe-pgd    0.0751               0               0            0
# 151       unsafe-pgd    0.0779               0               0            0
# 152       unsafe-pgd    0.0590               0               0            0
# 153  safe-incomplete    0.0722               0               0            0
# 154          unknown  226.4092          385098              60        23491
# 155       unsafe-pgd    0.0873               0               0            0
# 156       unsafe-pgd    0.0715               0               0            0
# 157  safe-incomplete    0.0638               0               0            0
# 158             safe    7.6179             341              60         1512
# 159  safe-incomplete    0.0685               0               0            0
# 160             safe    2.5891              50               6          400
# 161  safe-incomplete    0.0633               0               0            0
# 162          unknown  212.4474          462355             553        40820
# 163       unsafe-pgd    0.0984               0               0            0
# 164  safe-incomplete    0.0674               0               0            0
# 165       unsafe-pgd    0.0869               0               0            0
# 166  safe-incomplete    0.0642               0               0            0
# 167       unsafe-pgd    0.0738               0               0            0
# 168  safe-incomplete    0.0450               0               0            0
# 169       unsafe-pgd    0.0777               0               0            0
# 170       unsafe-pgd    0.0778               0               0            0
# 171  safe-incomplete    0.0700               0               0            0
# 172          unknown  205.4769          591980              51        36567
# 173       unsafe-pgd    0.0867               0               0            0
# 174       unsafe-pgd    0.0833               0               0            0
# 175  safe-incomplete    0.4882               0               0            0
# 176       unsafe-pgd    0.0829               0               0            0
# 177  safe-incomplete    0.0666               0               0            0
# 178       unsafe-pgd    0.0484               0               0            0
# 179  safe-incomplete    0.0304               0               0            0
# 180  safe-incomplete    0.0640               0               0            0
# 181             safe    3.3306               0               1           93
# 182  safe-incomplete    0.0743               0               0            0
# 183       unsafe-pgd    0.0752               0               0            0
# 184       unsafe-pgd    0.0718               0               0            0
# 185             safe    5.1599             250              30         1012
# 186  safe-incomplete    0.0674               0               0            0
# 187             safe    5.9586             100              20          835
# 188       unsafe-pgd    0.0743               0               0            0
# 189             safe    3.5545              50               3          102
# 190  safe-incomplete    0.0747               0               0            0
# 191             safe    6.5944            1088              30         1746
# 192  safe-incomplete    0.0668               0               0            0
# 193  safe-incomplete    0.0725               0               0            0
# 194       unsafe-pgd    0.0548               0               0            0
# 195       unsafe-pgd    0.1040               0               0            0
# 196       unsafe-pgd    0.0749               0               0            0
# 197  safe-incomplete    0.0646               0               0            0
# 198             safe   64.5635           87124             360        42004
# 199             safe    3.7291             182              42          384
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  7         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                39   -0.118522
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 1         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 5         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 2         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                40         NaN
# 58                 0         NaN
# 59                37   -0.159064
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                50         NaN
# 67                 3         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                35   -0.133565
# 77                45   -0.031475
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                21         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 2         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                 2         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                2         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                3         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                2         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127               28         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                4         NaN
# 136                0         NaN
# 137               26         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               27   -0.015134
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158               14         NaN
# 159                0         NaN
# 160                2         NaN
# 161                0         NaN
# 162               22   -0.068139
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               95   -0.136680
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                2         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                8         NaN
# 186                0         NaN
# 187                7         NaN
# 188                0         NaN
# 189                3         NaN
# 190                0         NaN
# 191               13         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198               19         NaN
# 199                5         NaN
# #Cuts 5433
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               29   10.422152    8253.620690     143.620690   4974.482759
# safe-incomplete    79    0.104529       0.000000       0.000000      0.000000
# unknown             7  218.037529  410805.285714     181.142857  62134.571429
# unsafe-pgd         85    0.076199       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                   9.517241
# safe-incomplete        0.000000
# unknown               42.857143
# unsafe-pgd             0.000000
# safe number 108.0
# safe time 2.8750018518518514
# safe domain 2216.25
# safe cut 38.56481481481482
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((108.0, 2.8750018518518514, 8253.620689655172, 143.6206896551724),)

# %%
main('cifar_cnn_a_mix4/gcp.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2     safe   6.5550              97               0            0
# 13    safe  93.9814          131524               0            0
# 19    safe   3.0347               0               0            0
# 24    safe   3.0133               2               0            0
# 38    safe   2.7080               0               0            0
# 48    safe   2.6879               0               0            0
# 54    safe   2.6915               0               0            0
# 57    safe  33.3893           54878               0            0
# 64    safe   3.1121               0               0            0
# 66    safe  48.5184           67530               0            0
# 67    safe   3.0716               1               0            0
# 77    safe  39.3251           68979               0            0
# 83    safe  17.7683           32159               0            0
# 93    safe   3.0177               0               0            0
# 97    safe   3.0671               0               0            0
# 104   safe   3.2376               0               0            0
# 111   safe   3.0466               0               0            0
# 120   safe   3.1543               0               0            0
# 127   safe  37.7194           67035               0            0
# 132   safe   2.9749               0               0            0
# 135   safe   3.2524               8               0            0
# 154   safe  31.6759           58499               0            0
# 158   safe   4.5083              82               0            0
# 160   safe   2.9035               0               0            0
# 162   safe  33.0074           67336               0            0
# 181   safe   3.7653               0               0            0
# 185   safe   3.6094               4               0            0
# 187   safe   3.2686               0               0            0
# 189   safe   3.1738               0               0            0
# 199   safe   3.2601               2               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                  3         NaN
# 13                38         NaN
# 19                 1         NaN
# 24                 2         NaN
# 38                 1         NaN
# 48                 1         NaN
# 54                 1         NaN
# 57                24         NaN
# 64                 1         NaN
# 66                44         NaN
# 67                 2         NaN
# 77                19         NaN
# 83                15         NaN
# 93                 1         NaN
# 97                 1         NaN
# 104                1         NaN
# 111                1         NaN
# 120                1         NaN
# 127               17         NaN
# 132                1         NaN
# 135                2         NaN
# 154               15         NaN
# 158                7         NaN
# 160                1         NaN
# 162               14         NaN
# 181                2         NaN
# 185                3         NaN
# 187                4         NaN
# 189                2         NaN
# 199                2         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 59   unknown  209.6016          337473               0            0
# 76   unknown  224.6458          371353               0            0
# 137  unknown  203.7963          280156               0            0
# 172  unknown  205.1920          338210               0            0
# 191  unknown  223.8176          316379               0            0
# 198  unknown  209.2240          328142               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 59                24   -0.216122
# 76                22   -0.044566
# 137               41   -0.038732
# 172               19   -0.074495
# 191               22   -0.015041
# 198               26   -0.033293
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.1545               0               0            0
# 1         unsafe-pgd    0.1201               0               0            0
# 2               safe    6.5550              97               0            0
# 3         unsafe-pgd    0.0829               0               0            0
# 4         unsafe-pgd    0.0673               0               0            0
# 5         unsafe-pgd    0.0695               0               0            0
# 6         unsafe-pgd    0.0722               0               0            0
# 7    safe-incomplete    0.0622               0               0            0
# 8    safe-incomplete    0.0375               0               0            0
# 9         unsafe-pgd    0.0708               0               0            0
# 10        unsafe-pgd    0.0597               0               0            0
# 11   safe-incomplete    0.0620               0               0            0
# 12        unsafe-pgd    0.0527               0               0            0
# 13              safe   93.9814          131524               0            0
# 14   safe-incomplete    0.0505               0               0            0
# 15        unsafe-pgd    0.0590               0               0            0
# 16        unsafe-pgd    0.0679               0               0            0
# 17   safe-incomplete    0.0355               0               0            0
# 18   safe-incomplete    0.3411               0               0            0
# 19              safe    3.0347               0               0            0
# 20   safe-incomplete    0.0694               0               0            0
# 21        unsafe-pgd    0.0564               0               0            0
# 22   safe-incomplete    0.0485               0               0            0
# 23   safe-incomplete    0.0335               0               0            0
# 24              safe    3.0133               2               0            0
# 25        unsafe-pgd    0.0705               0               0            0
# 26   safe-incomplete    0.0413               0               0            0
# 27   safe-incomplete    0.0451               0               0            0
# 28   safe-incomplete    0.0345               0               0            0
# 29        unsafe-pgd    0.0666               0               0            0
# 30   safe-incomplete    0.0529               0               0            0
# 31   safe-incomplete    0.0630               0               0            0
# 32        unsafe-pgd    0.0506               0               0            0
# 33   safe-incomplete    0.0417               0               0            0
# 34        unsafe-pgd    0.0538               0               0            0
# 35        unsafe-pgd    0.0362               0               0            0
# 36        unsafe-pgd    0.0532               0               0            0
# 37   safe-incomplete    0.0482               0               0            0
# 38              safe    2.7080               0               0            0
# 39   safe-incomplete    0.0441               0               0            0
# 40   safe-incomplete    0.0459               0               0            0
# 41   safe-incomplete    0.0567               0               0            0
# 42   safe-incomplete    0.0654               0               0            0
# 43        unsafe-pgd    0.0588               0               0            0
# 44        unsafe-pgd    0.0552               0               0            0
# 45        unsafe-pgd    0.0706               0               0            0
# 46        unsafe-pgd    0.0553               0               0            0
# 47   safe-incomplete    0.0475               0               0            0
# 48              safe    2.6879               0               0            0
# 49   safe-incomplete    0.0639               0               0            0
# 50        unsafe-pgd    0.0664               0               0            0
# 51   safe-incomplete    0.0314               0               0            0
# 52   safe-incomplete    0.0449               0               0            0
# 53        unsafe-pgd    0.0588               0               0            0
# 54              safe    2.6915               0               0            0
# 55   safe-incomplete    0.0696               0               0            0
# 56        unsafe-pgd    0.0720               0               0            0
# 57              safe   33.3893           54878               0            0
# 58        unsafe-pgd    0.0641               0               0            0
# 59           unknown  209.6016          337473               0            0
# 60   safe-incomplete    0.0875               0               0            0
# 61        unsafe-pgd    0.0869               0               0            0
# 62   safe-incomplete    0.0682               0               0            0
# 63        unsafe-pgd    0.0819               0               0            0
# 64              safe    3.1121               0               0            0
# 65        unsafe-pgd    0.0837               0               0            0
# 66              safe   48.5184           67530               0            0
# 67              safe    3.0716               1               0            0
# 68   safe-incomplete    0.0673               0               0            0
# 69   safe-incomplete    0.0694               0               0            0
# 70   safe-incomplete    0.0477               0               0            0
# 71   safe-incomplete    0.0662               0               0            0
# 72        unsafe-pgd    0.0573               0               0            0
# 73   safe-incomplete    0.0474               0               0            0
# 74   safe-incomplete    0.0657               0               0            0
# 75   safe-incomplete    0.0630               0               0            0
# 76           unknown  224.6458          371353               0            0
# 77              safe   39.3251           68979               0            0
# 78        unsafe-pgd    0.1029               0               0            0
# 79   safe-incomplete    0.0736               0               0            0
# 80        unsafe-pgd    0.0816               0               0            0
# 81   safe-incomplete    0.0692               0               0            0
# 82        unsafe-pgd    0.0759               0               0            0
# 83              safe   17.7683           32159               0            0
# 84        unsafe-pgd    0.0770               0               0            0
# 85   safe-incomplete    0.0694               0               0            0
# 86   safe-incomplete    0.0704               0               0            0
# 87        unsafe-pgd    0.0732               0               0            0
# 88        unsafe-pgd    0.0831               0               0            0
# 89   safe-incomplete    0.0640               0               0            0
# 90        unsafe-pgd    0.0654               0               0            0
# 91        unsafe-pgd    0.0694               0               0            0
# 92        unsafe-pgd    0.0821               0               0            0
# 93              safe    3.0177               0               0            0
# 94        unsafe-pgd    0.0919               0               0            0
# 95        unsafe-pgd    0.0811               0               0            0
# 96        unsafe-pgd    0.0833               0               0            0
# 97              safe    3.0671               0               0            0
# 98   safe-incomplete    0.3791               0               0            0
# 99        unsafe-pgd    0.1128               0               0            0
# 100       unsafe-pgd    0.0862               0               0            0
# 101       unsafe-pgd    0.0758               0               0            0
# 102       unsafe-pgd    0.0810               0               0            0
# 103  safe-incomplete    0.0675               0               0            0
# 104             safe    3.2376               0               0            0
# 105       unsafe-pgd    0.0915               0               0            0
# 106       unsafe-pgd    0.0725               0               0            0
# 107  safe-incomplete    0.0751               0               0            0
# 108       unsafe-pgd    0.0769               0               0            0
# 109  safe-incomplete    0.0666               0               0            0
# 110  safe-incomplete    0.0677               0               0            0
# 111             safe    3.0466               0               0            0
# 112       unsafe-pgd    0.0928               0               0            0
# 113       unsafe-pgd    0.0773               0               0            0
# 114  safe-incomplete    0.0685               0               0            0
# 115  safe-incomplete    0.0703               0               0            0
# 116  safe-incomplete    0.0669               0               0            0
# 117  safe-incomplete    0.0681               0               0            0
# 118  safe-incomplete    0.0697               0               0            0
# 119       unsafe-pgd    0.0889               0               0            0
# 120             safe    3.1543               0               0            0
# 121  safe-incomplete    0.0685               0               0            0
# 122       unsafe-pgd    0.0535               0               0            0
# 123       unsafe-pgd    0.0505               0               0            0
# 124       unsafe-pgd    0.0723               0               0            0
# 125       unsafe-pgd    0.0598               0               0            0
# 126       unsafe-pgd    0.0624               0               0            0
# 127             safe   37.7194           67035               0            0
# 128       unsafe-pgd    0.0826               0               0            0
# 129       unsafe-pgd    0.0735               0               0            0
# 130       unsafe-pgd    0.0745               0               0            0
# 131  safe-incomplete    0.0448               0               0            0
# 132             safe    2.9749               0               0            0
# 133  safe-incomplete    0.0700               0               0            0
# 134       unsafe-pgd    0.0700               0               0            0
# 135             safe    3.2524               8               0            0
# 136  safe-incomplete    0.0509               0               0            0
# 137          unknown  203.7963          280156               0            0
# 138       unsafe-pgd    0.0633               0               0            0
# 139  safe-incomplete    0.0534               0               0            0
# 140  safe-incomplete    0.0658               0               0            0
# 141       unsafe-pgd    0.0529               0               0            0
# 142  safe-incomplete    0.0250               0               0            0
# 143       unsafe-pgd    0.0596               0               0            0
# 144  safe-incomplete    0.0462               0               0            0
# 145       unsafe-pgd    0.0538               0               0            0
# 146  safe-incomplete    0.0353               0               0            0
# 147  safe-incomplete    0.0452               0               0            0
# 148  safe-incomplete    0.0453               0               0            0
# 149       unsafe-pgd    0.0350               0               0            0
# 150       unsafe-pgd    0.0712               0               0            0
# 151       unsafe-pgd    0.0414               0               0            0
# 152       unsafe-pgd    0.0423               0               0            0
# 153  safe-incomplete    0.0642               0               0            0
# 154             safe   31.6759           58499               0            0
# 155       unsafe-pgd    0.0697               0               0            0
# 156       unsafe-pgd    0.0604               0               0            0
# 157  safe-incomplete    0.0618               0               0            0
# 158             safe    4.5083              82               0            0
# 159  safe-incomplete    0.0694               0               0            0
# 160             safe    2.9035               0               0            0
# 161  safe-incomplete    0.0644               0               0            0
# 162             safe   33.0074           67336               0            0
# 163       unsafe-pgd    0.0833               0               0            0
# 164  safe-incomplete    0.0668               0               0            0
# 165       unsafe-pgd    0.0825               0               0            0
# 166  safe-incomplete    0.0695               0               0            0
# 167       unsafe-pgd    0.0729               0               0            0
# 168  safe-incomplete    0.0632               0               0            0
# 169       unsafe-pgd    0.0767               0               0            0
# 170       unsafe-pgd    0.0702               0               0            0
# 171  safe-incomplete    0.0619               0               0            0
# 172          unknown  205.1920          338210               0            0
# 173       unsafe-pgd    0.0664               0               0            0
# 174       unsafe-pgd    0.0740               0               0            0
# 175  safe-incomplete    0.5496               0               0            0
# 176       unsafe-pgd    0.1067               0               0            0
# 177  safe-incomplete    0.0801               0               0            0
# 178       unsafe-pgd    0.0779               0               0            0
# 179  safe-incomplete    0.0720               0               0            0
# 180  safe-incomplete    0.0762               0               0            0
# 181             safe    3.7653               0               0            0
# 182  safe-incomplete    0.0993               0               0            0
# 183       unsafe-pgd    0.0935               0               0            0
# 184       unsafe-pgd    0.0751               0               0            0
# 185             safe    3.6094               4               0            0
# 186  safe-incomplete    0.0916               0               0            0
# 187             safe    3.2686               0               0            0
# 188       unsafe-pgd    0.0642               0               0            0
# 189             safe    3.1738               0               0            0
# 190  safe-incomplete    0.0747               0               0            0
# 191          unknown  223.8176          316379               0            0
# 192  safe-incomplete    0.0606               0               0            0
# 193  safe-incomplete    0.0674               0               0            0
# 194       unsafe-pgd    0.0669               0               0            0
# 195       unsafe-pgd    0.0710               0               0            0
# 196       unsafe-pgd    0.0604               0               0            0
# 197  safe-incomplete    0.0607               0               0            0
# 198          unknown  209.2240          328142               0            0
# 199             safe    3.2601               2               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  3         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                38         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 1         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 2         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                24         NaN
# 58                 0         NaN
# 59                24   -0.216122
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                44         NaN
# 67                 2         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                22   -0.044566
# 77                19         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                15         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 1         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                 1         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                1         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                1         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127               17         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                2         NaN
# 136                0         NaN
# 137               41   -0.038732
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               15         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                7         NaN
# 159                0         NaN
# 160                1         NaN
# 161                0         NaN
# 162               14         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               19   -0.074495
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                2         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                3         NaN
# 186                0         NaN
# 187                4         NaN
# 188                0         NaN
# 189                2         NaN
# 190                0         NaN
# 191               22   -0.015041
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198               26   -0.033293
# 199                2         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               30   13.616630   18271.200000            0.0         0.0
# safe-incomplete    79    0.100292       0.000000            0.0         0.0
# unknown             6  212.712883  328618.833333            0.0         0.0
# unsafe-pgd         85    0.070981       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                   7.566667
# safe-incomplete        0.000000
# unknown               25.666667
# unsafe-pgd             0.000000
# safe number 109.0
# safe time 3.8203853211009173
# safe domain 5028.770642201835
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((109.0, 3.8203853211009173, 18271.2, 0.0),)

# %%
main('cifar_cnn_a_mix4/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2     safe   12.4112             226              64          953
# 13    safe  154.3116          123686            8975       108892
# 19    safe    4.1852               0               1            8
# 24    safe    5.4166             112              26          606
# 38    safe    3.6757               0               1           19
# 48    safe    4.0118              50               6          268
# 54    safe    3.9413               0               1           24
# 57    safe   24.8925            4848            1421         6001
# 64    safe    4.8336              50               7          400
# 66    safe   46.5845           38334            2461        24946
# 67    safe    4.8060             100              56          400
# 77    safe   25.7418           15784            1657        12494
# 83    safe   23.9677           20100             603         8498
# 93    safe    4.1935              50              10          400
# 97    safe    4.2632              50               9          400
# 104   safe    4.5489              50               5          400
# 111   safe    4.7426             100              23          400
# 120   safe    4.3875              50               5          400
# 127   safe   34.9801           23130            1380        20634
# 132   safe    3.8560               0               1           56
# 135   safe    4.9416             100              15          651
# 137   safe   21.9938            9475            1867         7290
# 154   safe   35.3145           27114            1962        25724
# 158   safe   10.9916             341              54         1512
# 160   safe    4.1372              50               6          400
# 162   safe   36.3109           35610            1495        33838
# 181   safe    5.5385               0               1           93
# 185   safe    7.7548             250              30         1012
# 187   safe    7.4463             100              20          868
# 189   safe    5.2457              50               3          102
# 191   safe   10.4813            1088              30         1746
# 198   safe   42.5116           30893            2590        26555
# 199   safe    5.8444             182              42          384
#
#      BaB Round Count  BaB_lb_rhs
# 2                  7         NaN
# 13                41         NaN
# 19                 1         NaN
# 24                 5         NaN
# 38                 1         NaN
# 48                 2         NaN
# 54                 1         NaN
# 57                38         NaN
# 64                 2         NaN
# 66                35         NaN
# 67                 3         NaN
# 77                28         NaN
# 83                14         NaN
# 93                 2         NaN
# 97                 2         NaN
# 104                2         NaN
# 111                3         NaN
# 120                2         NaN
# 127               26         NaN
# 132                1         NaN
# 135                4         NaN
# 137               27         NaN
# 154               26         NaN
# 158               14         NaN
# 160                2         NaN
# 162               16         NaN
# 181                2         NaN
# 185                8         NaN
# 187                7         NaN
# 189                3         NaN
# 191               13         NaN
# 198               18         NaN
# 199                5         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 59   unknown  255.4850          284840            3066        34257
# 76   unknown  225.6538          269132            3414        72818
# 172  unknown  224.1106          253267            2994        60806
#
#      BaB Round Count  BaB_lb_rhs
# 59                29   -0.128557
# 76                39   -0.029929
# 172               28   -0.071274
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.3505               0               0            0
# 1         unsafe-pgd    0.1021               0               0            0
# 2               safe   12.4112             226              64          953
# 3         unsafe-pgd    0.0779               0               0            0
# 4         unsafe-pgd    0.0352               0               0            0
# 5         unsafe-pgd    0.0455               0               0            0
# 6         unsafe-pgd    0.0562               0               0            0
# 7    safe-incomplete    0.0354               0               0            0
# 8    safe-incomplete    0.0385               0               0            0
# 9         unsafe-pgd    0.0395               0               0            0
# 10        unsafe-pgd    0.0424               0               0            0
# 11   safe-incomplete    0.0579               0               0            0
# 12        unsafe-pgd    0.0393               0               0            0
# 13              safe  154.3116          123686            8975       108892
# 14   safe-incomplete    0.0691               0               0            0
# 15        unsafe-pgd    0.0733               0               0            0
# 16        unsafe-pgd    0.0698               0               0            0
# 17   safe-incomplete    0.0501               0               0            0
# 18   safe-incomplete    0.3327               0               0            0
# 19              safe    4.1852               0               1            8
# 20   safe-incomplete    0.0774               0               0            0
# 21        unsafe-pgd    0.0453               0               0            0
# 22   safe-incomplete    0.0510               0               0            0
# 23   safe-incomplete    0.0632               0               0            0
# 24              safe    5.4166             112              26          606
# 25        unsafe-pgd    0.0800               0               0            0
# 26   safe-incomplete    0.0637               0               0            0
# 27   safe-incomplete    0.0485               0               0            0
# 28   safe-incomplete    0.0655               0               0            0
# 29        unsafe-pgd    0.0676               0               0            0
# 30   safe-incomplete    0.0651               0               0            0
# 31   safe-incomplete    0.0526               0               0            0
# 32        unsafe-pgd    0.0761               0               0            0
# 33   safe-incomplete    0.0634               0               0            0
# 34        unsafe-pgd    0.0513               0               0            0
# 35        unsafe-pgd    0.0294               0               0            0
# 36        unsafe-pgd    0.0662               0               0            0
# 37   safe-incomplete    0.0428               0               0            0
# 38              safe    3.6757               0               1           19
# 39   safe-incomplete    0.0549               0               0            0
# 40   safe-incomplete    0.0318               0               0            0
# 41   safe-incomplete    0.0635               0               0            0
# 42   safe-incomplete    0.0586               0               0            0
# 43        unsafe-pgd    0.0671               0               0            0
# 44        unsafe-pgd    0.0637               0               0            0
# 45        unsafe-pgd    0.0837               0               0            0
# 46        unsafe-pgd    0.0664               0               0            0
# 47   safe-incomplete    0.0464               0               0            0
# 48              safe    4.0118              50               6          268
# 49   safe-incomplete    0.0762               0               0            0
# 50        unsafe-pgd    0.0879               0               0            0
# 51   safe-incomplete    0.0665               0               0            0
# 52   safe-incomplete    0.0535               0               0            0
# 53        unsafe-pgd    0.0867               0               0            0
# 54              safe    3.9413               0               1           24
# 55   safe-incomplete    0.0679               0               0            0
# 56        unsafe-pgd    0.0714               0               0            0
# 57              safe   24.8925            4848            1421         6001
# 58        unsafe-pgd    0.0634               0               0            0
# 59           unknown  255.4850          284840            3066        34257
# 60   safe-incomplete    0.0723               0               0            0
# 61        unsafe-pgd    0.0807               0               0            0
# 62   safe-incomplete    0.0676               0               0            0
# 63        unsafe-pgd    0.0752               0               0            0
# 64              safe    4.8336              50               7          400
# 65        unsafe-pgd    0.0799               0               0            0
# 66              safe   46.5845           38334            2461        24946
# 67              safe    4.8060             100              56          400
# 68   safe-incomplete    0.0696               0               0            0
# 69   safe-incomplete    0.0705               0               0            0
# 70   safe-incomplete    0.0672               0               0            0
# 71   safe-incomplete    0.0661               0               0            0
# 72        unsafe-pgd    0.0613               0               0            0
# 73   safe-incomplete    0.0641               0               0            0
# 74   safe-incomplete    0.0660               0               0            0
# 75   safe-incomplete    0.0484               0               0            0
# 76           unknown  225.6538          269132            3414        72818
# 77              safe   25.7418           15784            1657        12494
# 78        unsafe-pgd    0.0824               0               0            0
# 79   safe-incomplete    0.0632               0               0            0
# 80        unsafe-pgd    0.0782               0               0            0
# 81   safe-incomplete    0.0675               0               0            0
# 82        unsafe-pgd    0.0724               0               0            0
# 83              safe   23.9677           20100             603         8498
# 84        unsafe-pgd    0.0734               0               0            0
# 85   safe-incomplete    0.0644               0               0            0
# 86   safe-incomplete    0.0668               0               0            0
# 87        unsafe-pgd    0.0703               0               0            0
# 88        unsafe-pgd    0.0802               0               0            0
# 89   safe-incomplete    0.0614               0               0            0
# 90        unsafe-pgd    0.0795               0               0            0
# 91        unsafe-pgd    0.0691               0               0            0
# 92        unsafe-pgd    0.0712               0               0            0
# 93              safe    4.1935              50              10          400
# 94        unsafe-pgd    0.1592               0               0            0
# 95        unsafe-pgd    0.0726               0               0            0
# 96        unsafe-pgd    0.0735               0               0            0
# 97              safe    4.2632              50               9          400
# 98   safe-incomplete    0.4186               0               0            0
# 99        unsafe-pgd    0.1010               0               0            0
# 100       unsafe-pgd    0.0874               0               0            0
# 101       unsafe-pgd    0.0727               0               0            0
# 102       unsafe-pgd    0.0794               0               0            0
# 103  safe-incomplete    0.0639               0               0            0
# 104             safe    4.5489              50               5          400
# 105       unsafe-pgd    0.1258               0               0            0
# 106       unsafe-pgd    0.0582               0               0            0
# 107  safe-incomplete    0.0665               0               0            0
# 108       unsafe-pgd    0.0852               0               0            0
# 109  safe-incomplete    0.0667               0               0            0
# 110  safe-incomplete    0.0640               0               0            0
# 111             safe    4.7426             100              23          400
# 112       unsafe-pgd    0.1857               0               0            0
# 113       unsafe-pgd    0.0767               0               0            0
# 114  safe-incomplete    0.0338               0               0            0
# 115  safe-incomplete    0.0466               0               0            0
# 116  safe-incomplete    0.0486               0               0            0
# 117  safe-incomplete    0.0250               0               0            0
# 118  safe-incomplete    0.0352               0               0            0
# 119       unsafe-pgd    0.0887               0               0            0
# 120             safe    4.3875              50               5          400
# 121  safe-incomplete    0.1597               0               0            0
# 122       unsafe-pgd    0.0534               0               0            0
# 123       unsafe-pgd    0.0676               0               0            0
# 124       unsafe-pgd    0.0815               0               0            0
# 125       unsafe-pgd    0.0772               0               0            0
# 126       unsafe-pgd    0.0826               0               0            0
# 127             safe   34.9801           23130            1380        20634
# 128       unsafe-pgd    0.0746               0               0            0
# 129       unsafe-pgd    0.0778               0               0            0
# 130       unsafe-pgd    0.0652               0               0            0
# 131  safe-incomplete    0.0369               0               0            0
# 132             safe    3.8560               0               1           56
# 133  safe-incomplete    0.1731               0               0            0
# 134       unsafe-pgd    0.0807               0               0            0
# 135             safe    4.9416             100              15          651
# 136  safe-incomplete    0.0596               0               0            0
# 137             safe   21.9938            9475            1867         7290
# 138       unsafe-pgd    0.0733               0               0            0
# 139  safe-incomplete    0.0744               0               0            0
# 140  safe-incomplete    0.0659               0               0            0
# 141       unsafe-pgd    0.0704               0               0            0
# 142  safe-incomplete    0.0297               0               0            0
# 143       unsafe-pgd    0.0677               0               0            0
# 144  safe-incomplete    0.0436               0               0            0
# 145       unsafe-pgd    0.0540               0               0            0
# 146  safe-incomplete    0.0625               0               0            0
# 147  safe-incomplete    0.0653               0               0            0
# 148  safe-incomplete    0.0656               0               0            0
# 149       unsafe-pgd    0.0689               0               0            0
# 150       unsafe-pgd    0.0529               0               0            0
# 151       unsafe-pgd    0.0726               0               0            0
# 152       unsafe-pgd    0.0661               0               0            0
# 153  safe-incomplete    0.0453               0               0            0
# 154             safe   35.3145           27114            1962        25724
# 155       unsafe-pgd    0.0619               0               0            0
# 156       unsafe-pgd    0.0534               0               0            0
# 157  safe-incomplete    0.0422               0               0            0
# 158             safe   10.9916             341              54         1512
# 159  safe-incomplete    0.0689               0               0            0
# 160             safe    4.1372              50               6          400
# 161  safe-incomplete    0.1397               0               0            0
# 162             safe   36.3109           35610            1495        33838
# 163       unsafe-pgd    0.0809               0               0            0
# 164  safe-incomplete    0.0462               0               0            0
# 165       unsafe-pgd    0.0662               0               0            0
# 166  safe-incomplete    0.0483               0               0            0
# 167       unsafe-pgd    0.0656               0               0            0
# 168  safe-incomplete    0.0621               0               0            0
# 169       unsafe-pgd    0.0486               0               0            0
# 170       unsafe-pgd    0.0678               0               0            0
# 171  safe-incomplete    0.0646               0               0            0
# 172          unknown  224.1106          253267            2994        60806
# 173       unsafe-pgd    0.0628               0               0            0
# 174       unsafe-pgd    0.0718               0               0            0
# 175  safe-incomplete    0.5593               0               0            0
# 176       unsafe-pgd    0.1012               0               0            0
# 177  safe-incomplete    0.0706               0               0            0
# 178       unsafe-pgd    0.0777               0               0            0
# 179  safe-incomplete    0.0635               0               0            0
# 180  safe-incomplete    0.0658               0               0            0
# 181             safe    5.5385               0               1           93
# 182  safe-incomplete    0.0764               0               0            0
# 183       unsafe-pgd    0.0719               0               0            0
# 184       unsafe-pgd    0.0693               0               0            0
# 185             safe    7.7548             250              30         1012
# 186  safe-incomplete    0.0704               0               0            0
# 187             safe    7.4463             100              20          868
# 188       unsafe-pgd    0.0457               0               0            0
# 189             safe    5.2457              50               3          102
# 190  safe-incomplete    0.0571               0               0            0
# 191             safe   10.4813            1088              30         1746
# 192  safe-incomplete    0.0710               0               0            0
# 193  safe-incomplete    0.0658               0               0            0
# 194       unsafe-pgd    0.0734               0               0            0
# 195       unsafe-pgd    0.0740               0               0            0
# 196       unsafe-pgd    0.0465               0               0            0
# 197  safe-incomplete    0.0646               0               0            0
# 198             safe   42.5116           30893            2590        26555
# 199             safe    5.8444             182              42          384
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  7         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                41         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 1         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 5         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 2         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                38         NaN
# 58                 0         NaN
# 59                29   -0.128557
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                35         NaN
# 67                 3         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                39   -0.029929
# 77                28         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                14         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 2         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                 2         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                2         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                3         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                2         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127               26         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                4         NaN
# 136                0         NaN
# 137               27         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               26         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158               14         NaN
# 159                0         NaN
# 160                2         NaN
# 161                0         NaN
# 162               16         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172               28   -0.071274
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                2         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185                8         NaN
# 186                0         NaN
# 187                7         NaN
# 188                0         NaN
# 189                3         NaN
# 190                0         NaN
# 191               13         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198               18         NaN
# 199                5         NaN
# #Cuts 34301
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               33   17.523136   10059.787879     752.333333   8678.000000
# safe-incomplete    79    0.105681       0.000000       0.000000      0.000000
# unknown             3  235.083133  269079.666667    3158.000000  55960.333333
# unsafe-pgd         85    0.072382       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  10.939394
# safe-incomplete        0.000000
# unknown               32.000000
# unsafe-pgd             0.000000
# safe number 112.0
# safe time 5.237609821428571
# safe domain 2964.0446428571427
# safe cut 221.66964285714286
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((112.0, 5.237609821428571, 10059.787878787878, 752.3333333333334),)

# %% [markdown]
# ## cifar_cnn_a_adv

# %%
plot_multiple_dfs(
    [
        log_read('cifar_cnn_a_adv/beta.log'),
log_read('cifar_cnn_a_adv/biccos_only_cs.log'),
log_read('cifar_cnn_a_adv/biccos_all.log'),
log_read('cifar_cnn_a_adv/gcp.log'),
log_read('cifar_cnn_a_adv/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],
     time_limit=200, dataset='cifar_cnn_a_adv'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_a_adv/beta.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe    5.9707             176               0            0
# 38    safe    2.3691               0               0            0
# 42    safe    9.2644           16543               0            0
# 54    safe    2.3530               0               0            0
# 60    safe    2.3584               0               0            0
# 84    safe    2.4069               0               0            0
# 89    safe   14.1241           23800               0            0
# 95    safe    2.5740               3               0            0
# 103   safe   57.4964          162394               0            0
# 107   safe    2.4310               0               0            0
# 112   safe    2.4804               0               0            0
# 132   safe    2.4847               0               0            0
# 139   safe    5.2863            1304               0            0
# 158   safe    2.5721               0               0            0
# 160   safe    2.6315               0               0            0
# 167   safe  160.3570          456715               0            0
# 169   safe  185.6446          487641               0            0
# 172   safe    2.5299               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 11                 5         NaN
# 38                 1         NaN
# 42                18         NaN
# 54                 1         NaN
# 60                 1         NaN
# 84                 1         NaN
# 89                27         NaN
# 95                 2         NaN
# 103               33         NaN
# 107                1         NaN
# 112                1         NaN
# 132                1         NaN
# 139               14         NaN
# 158                2         NaN
# 160                1         NaN
# 167               67         NaN
# 169               37         NaN
# 172                2         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24   unknown  207.4112          620977               0            0
# 55   unknown  205.8589          716541               0            0
# 70   unknown  202.5285          661531               0            0
# 97   unknown  207.6185          697406               0            0
# 116  unknown  203.0608          667898               0            0
# 183  unknown  204.3161          703307               0            0
# 187  unknown  215.5524          691027               0            0
# 195  unknown  211.6443          637474               0            0
# 198  unknown  203.1607          761610               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 24                27   -0.119733
# 55                20   -0.185493
# 70                26   -0.091782
# 97                24   -0.080026
# 116               26   -0.070493
# 183               22   -0.235383
# 187               23   -0.252157
# 195               25   -0.033126
# 198               40   -0.069028
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    1.2080               0               0            0
# 1         unsafe-pgd    0.2856               0               0            0
# 2    safe-incomplete    0.0649               0               0            0
# 3         unsafe-pgd    0.0713               0               0            0
# 4         unsafe-pgd    0.0689               0               0            0
# 5         unsafe-pgd    0.0757               0               0            0
# 6         unsafe-pgd    0.0699               0               0            0
# 7         unsafe-pgd    0.0689               0               0            0
# 8    safe-incomplete    0.0634               0               0            0
# 9         unsafe-pgd    0.0823               0               0            0
# 10        unsafe-pgd    0.0759               0               0            0
# 11              safe    5.9707             176               0            0
# 12        unsafe-pgd    0.0799               0               0            0
# 13        unsafe-pgd    0.0763               0               0            0
# 14   safe-incomplete    0.0695               0               0            0
# 15        unsafe-pgd    0.0694               0               0            0
# 16        unsafe-pgd    0.0804               0               0            0
# 17   safe-incomplete    0.0662               0               0            0
# 18        unsafe-pgd    0.0735               0               0            0
# 19        unsafe-pgd    0.0710               0               0            0
# 20   safe-incomplete    0.0652               0               0            0
# 21   safe-incomplete    0.0644               0               0            0
# 22   safe-incomplete    0.0704               0               0            0
# 23   safe-incomplete    0.0689               0               0            0
# 24           unknown  207.4112          620977               0            0
# 25        unsafe-pgd    0.1115               0               0            0
# 26   safe-incomplete    0.0675               0               0            0
# 27   safe-incomplete    0.0675               0               0            0
# 28   safe-incomplete    0.0684               0               0            0
# 29        unsafe-pgd    0.0815               0               0            0
# 30   safe-incomplete    0.0695               0               0            0
# 31   safe-incomplete    0.0686               0               0            0
# 32        unsafe-pgd    0.0825               0               0            0
# 33   safe-incomplete    0.0711               0               0            0
# 34        unsafe-pgd    0.0789               0               0            0
# 35        unsafe-pgd    0.0684               0               0            0
# 36        unsafe-pgd    0.0494               0               0            0
# 37   safe-incomplete    0.0622               0               0            0
# 38              safe    2.3691               0               0            0
# 39   safe-incomplete    0.0690               0               0            0
# 40   safe-incomplete    0.0369               0               0            0
# 41   safe-incomplete    0.0604               0               0            0
# 42              safe    9.2644           16543               0            0
# 43        unsafe-pgd    0.0736               0               0            0
# 44        unsafe-pgd    0.0748               0               0            0
# 45        unsafe-pgd    0.0821               0               0            0
# 46        unsafe-pgd    0.0750               0               0            0
# 47   safe-incomplete    0.0328               0               0            0
# 48   safe-incomplete    0.0556               0               0            0
# 49   safe-incomplete    0.0651               0               0            0
# 50        unsafe-pgd    0.0827               0               0            0
# 51   safe-incomplete    0.0694               0               0            0
# 52   safe-incomplete    0.0673               0               0            0
# 53        unsafe-pgd    0.0785               0               0            0
# 54              safe    2.3530               0               0            0
# 55           unknown  205.8589          716541               0            0
# 56        unsafe-pgd    0.0446               0               0            0
# 57        unsafe-pgd    0.0875               0               0            0
# 58        unsafe-pgd    0.0634               0               0            0
# 59        unsafe-pgd    0.0733               0               0            0
# 60              safe    2.3584               0               0            0
# 61        unsafe-pgd    0.0916               0               0            0
# 62   safe-incomplete    0.0537               0               0            0
# 63        unsafe-pgd    0.0764               0               0            0
# 64        unsafe-pgd    0.0752               0               0            0
# 65        unsafe-pgd    0.0800               0               0            0
# 66        unsafe-pgd    0.0698               0               0            0
# 67        unsafe-pgd    0.0623               0               0            0
# 68   safe-incomplete    0.0680               0               0            0
# 69        unsafe-pgd    0.0514               0               0            0
# 70           unknown  202.5285          661531               0            0
# 71   safe-incomplete    0.0837               0               0            0
# 72        unsafe-pgd    0.0797               0               0            0
# 73   safe-incomplete    0.0568               0               0            0
# 74   safe-incomplete    0.0379               0               0            0
# 75        unsafe-pgd    0.0665               0               0            0
# 76   safe-incomplete    0.0562               0               0            0
# 77        unsafe-pgd    0.0571               0               0            0
# 78        unsafe-pgd    0.0607               0               0            0
# 79   safe-incomplete    0.0366               0               0            0
# 80        unsafe-pgd    0.0526               0               0            0
# 81   safe-incomplete    0.0649               0               0            0
# 82        unsafe-pgd    0.0772               0               0            0
# 83   safe-incomplete    0.0635               0               0            0
# 84              safe    2.4069               0               0            0
# 85   safe-incomplete    0.0929               0               0            0
# 86   safe-incomplete    0.0510               0               0            0
# 87        unsafe-pgd    0.0478               0               0            0
# 88        unsafe-pgd    0.0706               0               0            0
# 89              safe   14.1241           23800               0            0
# 90        unsafe-pgd    0.0893               0               0            0
# 91        unsafe-pgd    0.0744               0               0            0
# 92        unsafe-pgd    0.0745               0               0            0
# 93   safe-incomplete    0.0661               0               0            0
# 94        unsafe-pgd    0.0764               0               0            0
# 95              safe    2.5740               3               0            0
# 96        unsafe-pgd    0.0864               0               0            0
# 97           unknown  207.6185          697406               0            0
# 98        unsafe-pgd    0.0876               0               0            0
# 99        unsafe-pgd    0.0782               0               0            0
# 100       unsafe-pgd    0.0744               0               0            0
# 101       unsafe-pgd    0.0768               0               0            0
# 102       unsafe-pgd    0.0744               0               0            0
# 103             safe   57.4964          162394               0            0
# 104  safe-incomplete    0.0721               0               0            0
# 105       unsafe-pgd    0.0842               0               0            0
# 106       unsafe-pgd    0.0755               0               0            0
# 107             safe    2.4310               0               0            0
# 108       unsafe-pgd    0.0820               0               0            0
# 109  safe-incomplete    0.0707               0               0            0
# 110  safe-incomplete    0.0680               0               0            0
# 111  safe-incomplete    0.2940               0               0            0
# 112             safe    2.4804               0               0            0
# 113       unsafe-pgd    0.0570               0               0            0
# 114  safe-incomplete    0.0698               0               0            0
# 115  safe-incomplete    0.0411               0               0            0
# 116          unknown  203.0608          667898               0            0
# 117  safe-incomplete    0.0840               0               0            0
# 118  safe-incomplete    0.0760               0               0            0
# 119       unsafe-pgd    0.0808               0               0            0
# 120       unsafe-pgd    0.0838               0               0            0
# 121  safe-incomplete    0.0537               0               0            0
# 122       unsafe-pgd    0.0429               0               0            0
# 123       unsafe-pgd    0.0804               0               0            0
# 124       unsafe-pgd    0.0812               0               0            0
# 125       unsafe-pgd    0.0441               0               0            0
# 126       unsafe-pgd    0.0763               0               0            0
# 127       unsafe-pgd    0.0470               0               0            0
# 128       unsafe-pgd    0.0716               0               0            0
# 129       unsafe-pgd    0.0452               0               0            0
# 130       unsafe-pgd    0.0486               0               0            0
# 131  safe-incomplete    0.0638               0               0            0
# 132             safe    2.4847               0               0            0
# 133  safe-incomplete    0.0771               0               0            0
# 134       unsafe-pgd    0.0699               0               0            0
# 135       unsafe-pgd    0.0709               0               0            0
# 136  safe-incomplete    0.0722               0               0            0
# 137       unsafe-pgd    0.0616               0               0            0
# 138       unsafe-pgd    0.0785               0               0            0
# 139             safe    5.2863            1304               0            0
# 140  safe-incomplete    0.0855               0               0            0
# 141       unsafe-pgd    0.0852               0               0            0
# 142  safe-incomplete    0.0690               0               0            0
# 143       unsafe-pgd    0.0805               0               0            0
# 144  safe-incomplete    0.0678               0               0            0
# 145       unsafe-pgd    0.0708               0               0            0
# 146  safe-incomplete    0.0642               0               0            0
# 147  safe-incomplete    0.0769               0               0            0
# 148  safe-incomplete    0.0712               0               0            0
# 149       unsafe-pgd    0.0648               0               0            0
# 150       unsafe-pgd    0.0723               0               0            0
# 151       unsafe-pgd    0.0732               0               0            0
# 152       unsafe-pgd    0.0691               0               0            0
# 153  safe-incomplete    0.0644               0               0            0
# 154       unsafe-pgd    0.0444               0               0            0
# 155       unsafe-pgd    0.0637               0               0            0
# 156       unsafe-pgd    0.0670               0               0            0
# 157  safe-incomplete    0.0618               0               0            0
# 158             safe    2.5721               0               0            0
# 159  safe-incomplete    0.0751               0               0            0
# 160             safe    2.6315               0               0            0
# 161  safe-incomplete    0.0746               0               0            0
# 162  safe-incomplete    0.0705               0               0            0
# 163       unsafe-pgd    0.0745               0               0            0
# 164  safe-incomplete    0.0629               0               0            0
# 165       unsafe-pgd    0.0757               0               0            0
# 166  safe-incomplete    0.2189               0               0            0
# 167             safe  160.3570          456715               0            0
# 168  safe-incomplete    0.0828               0               0            0
# 169             safe  185.6446          487641               0            0
# 170       unsafe-pgd    0.0561               0               0            0
# 171  safe-incomplete    0.0655               0               0            0
# 172             safe    2.5299               0               0            0
# 173       unsafe-pgd    0.0827               0               0            0
# 174       unsafe-pgd    0.0801               0               0            0
# 175       unsafe-pgd    0.0713               0               0            0
# 176       unsafe-pgd    0.0745               0               0            0
# 177  safe-incomplete    0.0661               0               0            0
# 178  safe-incomplete    0.0727               0               0            0
# 179  safe-incomplete    0.0676               0               0            0
# 180  safe-incomplete    0.0684               0               0            0
# 181       unsafe-pgd    0.0710               0               0            0
# 182  safe-incomplete    0.0671               0               0            0
# 183          unknown  204.3161          703307               0            0
# 184       unsafe-pgd    0.0786               0               0            0
# 185       unsafe-pgd    0.0765               0               0            0
# 186  safe-incomplete    0.0639               0               0            0
# 187          unknown  215.5524          691027               0            0
# 188       unsafe-pgd    0.0992               0               0            0
# 189  safe-incomplete    0.0677               0               0            0
# 190  safe-incomplete    0.0527               0               0            0
# 191       unsafe-pgd    0.0477               0               0            0
# 192  safe-incomplete    0.0629               0               0            0
# 193  safe-incomplete    0.0449               0               0            0
# 194       unsafe-pgd    0.0596               0               0            0
# 195          unknown  211.6443          637474               0            0
# 196       unsafe-pgd    0.0835               0               0            0
# 197  safe-incomplete    0.0694               0               0            0
# 198          unknown  203.1607          761610               0            0
# 199       unsafe-pgd    0.0877               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 5         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                27   -0.119733
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                18         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                20   -0.185493
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 1         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                26   -0.091782
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 1         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                27         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 2         NaN
# 96                 0         NaN
# 97                24   -0.080026
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103               33         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                1         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116               26   -0.070493
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139               14         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                2         NaN
# 159                0         NaN
# 160                1         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167               67         NaN
# 168                0         NaN
# 169               37         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183               22   -0.235383
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187               23   -0.252157
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195               25   -0.033126
# 196                0         NaN
# 197                0         NaN
# 198               40   -0.069028
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               18   25.851917   63809.777778            0.0         0.0
# safe-incomplete    73    0.070582       0.000000            0.0         0.0
# unknown             9  206.794600  684196.777778            0.0         0.0
# unsafe-pgd        100    0.085672       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  11.944444
# safe-incomplete        0.000000
# unknown               25.888889
# unsafe-pgd             0.000000
# safe number 91.0
# safe time 5.170186813186813
# safe domain 12621.714285714286
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((91.0, 5.170186813186813, 63809.77777777778, 0.0),)

# %%
main('cifar_cnn_a_adv/gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe    7.0081             176               0            0
# 24    safe   39.9197           72132               0            0
# 38    safe    2.7917               0               0            0
# 42    safe   12.8234           16538               0            0
# 54    safe    2.8457               0               0            0
# 60    safe    3.1072               0               0            0
# 70    safe  105.2261          140260               0            0
# 84    safe    3.2103               0               0            0
# 89    safe   17.9034           23622               0            0
# 95    safe    3.1835               3               0            0
# 97    safe   22.0904           37229               0            0
# 103   safe   24.0098           40387               0            0
# 107   safe    3.0266               0               0            0
# 112   safe    3.3098               0               0            0
# 116   safe   42.4932           73486               0            0
# 132   safe    3.2353               0               0            0
# 139   safe    7.0781            1304               0            0
# 158   safe    3.2404               0               0            0
# 160   safe    2.8554               0               0            0
# 167   safe   28.8694           61519               0            0
# 169   safe   37.8761           70228               0            0
# 172   safe    3.3765               0               0            0
# 195   safe   45.7529           89631               0            0
# 198   safe   34.2050           58894               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 11                 5         NaN
# 24                23         NaN
# 38                 1         NaN
# 42                18         NaN
# 54                 1         NaN
# 60                 1         NaN
# 70                30         NaN
# 84                 1         NaN
# 89                25         NaN
# 95                 2         NaN
# 97                12         NaN
# 103               20         NaN
# 107                1         NaN
# 112                1         NaN
# 116               23         NaN
# 132                1         NaN
# 139               14         NaN
# 158                2         NaN
# 160                1         NaN
# 167               19         NaN
# 169               21         NaN
# 172                2         NaN
# 195               13         NaN
# 198               17         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 55   unknown  229.8872          451362               0            0
# 183  unknown  204.4633          360995               0            0
# 187  unknown  206.7571          324196               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 55                17   -0.185496
# 183               22   -0.246424
# 187               38   -0.144796
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    4.7944               0               0            0
# 1         unsafe-pgd    0.9418               0               0            0
# 2    safe-incomplete    0.0550               0               0            0
# 3         unsafe-pgd    0.0557               0               0            0
# 4         unsafe-pgd    0.0579               0               0            0
# 5         unsafe-pgd    0.0544               0               0            0
# 6         unsafe-pgd    0.0379               0               0            0
# 7         unsafe-pgd    0.0543               0               0            0
# 8    safe-incomplete    0.0332               0               0            0
# 9         unsafe-pgd    0.0737               0               0            0
# 10        unsafe-pgd    0.0439               0               0            0
# 11              safe    7.0081             176               0            0
# 12        unsafe-pgd    0.0506               0               0            0
# 13        unsafe-pgd    0.0538               0               0            0
# 14   safe-incomplete    0.0336               0               0            0
# 15        unsafe-pgd    0.0407               0               0            0
# 16        unsafe-pgd    0.0642               0               0            0
# 17   safe-incomplete    0.0455               0               0            0
# 18        unsafe-pgd    0.0425               0               0            0
# 19        unsafe-pgd    0.0497               0               0            0
# 20   safe-incomplete    0.0411               0               0            0
# 21   safe-incomplete    0.0447               0               0            0
# 22   safe-incomplete    0.0482               0               0            0
# 23   safe-incomplete    0.0267               0               0            0
# 24              safe   39.9197           72132               0            0
# 25        unsafe-pgd    0.0534               0               0            0
# 26   safe-incomplete    0.0493               0               0            0
# 27   safe-incomplete    0.0450               0               0            0
# 28   safe-incomplete    0.0477               0               0            0
# 29        unsafe-pgd    0.0605               0               0            0
# 30   safe-incomplete    0.0446               0               0            0
# 31   safe-incomplete    0.0408               0               0            0
# 32        unsafe-pgd    0.0525               0               0            0
# 33   safe-incomplete    0.0640               0               0            0
# 34        unsafe-pgd    0.0571               0               0            0
# 35        unsafe-pgd    0.0625               0               0            0
# 36        unsafe-pgd    0.0537               0               0            0
# 37   safe-incomplete    0.0444               0               0            0
# 38              safe    2.7917               0               0            0
# 39   safe-incomplete    0.0700               0               0            0
# 40   safe-incomplete    0.0513               0               0            0
# 41   safe-incomplete    0.0450               0               0            0
# 42              safe   12.8234           16538               0            0
# 43        unsafe-pgd    0.0841               0               0            0
# 44        unsafe-pgd    0.0793               0               0            0
# 45        unsafe-pgd    0.0885               0               0            0
# 46        unsafe-pgd    0.0805               0               0            0
# 47   safe-incomplete    0.0720               0               0            0
# 48   safe-incomplete    0.0652               0               0            0
# 49   safe-incomplete    0.0698               0               0            0
# 50        unsafe-pgd    0.0892               0               0            0
# 51   safe-incomplete    0.0655               0               0            0
# 52   safe-incomplete    0.0508               0               0            0
# 53        unsafe-pgd    0.0652               0               0            0
# 54              safe    2.8457               0               0            0
# 55           unknown  229.8872          451362               0            0
# 56        unsafe-pgd    0.1917               0               0            0
# 57        unsafe-pgd    0.1000               0               0            0
# 58        unsafe-pgd    0.0799               0               0            0
# 59        unsafe-pgd    0.0547               0               0            0
# 60              safe    3.1072               0               0            0
# 61        unsafe-pgd    0.0759               0               0            0
# 62   safe-incomplete    0.0481               0               0            0
# 63        unsafe-pgd    0.0599               0               0            0
# 64        unsafe-pgd    0.0559               0               0            0
# 65        unsafe-pgd    0.0662               0               0            0
# 66        unsafe-pgd    0.0458               0               0            0
# 67        unsafe-pgd    0.0557               0               0            0
# 68   safe-incomplete    0.0406               0               0            0
# 69        unsafe-pgd    0.0450               0               0            0
# 70              safe  105.2261          140260               0            0
# 71   safe-incomplete    0.0300               0               0            0
# 72        unsafe-pgd    0.0526               0               0            0
# 73   safe-incomplete    0.0408               0               0            0
# 74   safe-incomplete    0.0650               0               0            0
# 75        unsafe-pgd    0.0390               0               0            0
# 76   safe-incomplete    0.0638               0               0            0
# 77        unsafe-pgd    0.0535               0               0            0
# 78        unsafe-pgd    0.0647               0               0            0
# 79   safe-incomplete    0.0476               0               0            0
# 80        unsafe-pgd    0.0625               0               0            0
# 81   safe-incomplete    0.0419               0               0            0
# 82        unsafe-pgd    0.0766               0               0            0
# 83   safe-incomplete    0.0463               0               0            0
# 84              safe    3.2103               0               0            0
# 85   safe-incomplete    0.0570               0               0            0
# 86   safe-incomplete    0.0678               0               0            0
# 87        unsafe-pgd    0.0836               0               0            0
# 88        unsafe-pgd    0.0778               0               0            0
# 89              safe   17.9034           23622               0            0
# 90        unsafe-pgd    0.0931               0               0            0
# 91        unsafe-pgd    0.0532               0               0            0
# 92        unsafe-pgd    0.0801               0               0            0
# 93   safe-incomplete    0.0711               0               0            0
# 94        unsafe-pgd    0.0892               0               0            0
# 95              safe    3.1835               3               0            0
# 96        unsafe-pgd    0.0933               0               0            0
# 97              safe   22.0904           37229               0            0
# 98        unsafe-pgd    0.0901               0               0            0
# 99        unsafe-pgd    0.0823               0               0            0
# 100       unsafe-pgd    0.0801               0               0            0
# 101       unsafe-pgd    0.0779               0               0            0
# 102       unsafe-pgd    0.0829               0               0            0
# 103             safe   24.0098           40387               0            0
# 104  safe-incomplete    0.0476               0               0            0
# 105       unsafe-pgd    0.0827               0               0            0
# 106       unsafe-pgd    0.0740               0               0            0
# 107             safe    3.0266               0               0            0
# 108       unsafe-pgd    0.0891               0               0            0
# 109  safe-incomplete    0.0713               0               0            0
# 110  safe-incomplete    0.0718               0               0            0
# 111  safe-incomplete    0.4412               0               0            0
# 112             safe    3.3098               0               0            0
# 113       unsafe-pgd    0.0905               0               0            0
# 114  safe-incomplete    0.0494               0               0            0
# 115  safe-incomplete    0.0696               0               0            0
# 116             safe   42.4932           73486               0            0
# 117  safe-incomplete    0.0797               0               0            0
# 118  safe-incomplete    0.0414               0               0            0
# 119       unsafe-pgd    0.0576               0               0            0
# 120       unsafe-pgd    0.0649               0               0            0
# 121  safe-incomplete    0.0501               0               0            0
# 122       unsafe-pgd    0.0593               0               0            0
# 123       unsafe-pgd    0.0529               0               0            0
# 124       unsafe-pgd    0.0489               0               0            0
# 125       unsafe-pgd    0.0609               0               0            0
# 126       unsafe-pgd    0.0735               0               0            0
# 127       unsafe-pgd    0.0808               0               0            0
# 128       unsafe-pgd    0.0655               0               0            0
# 129       unsafe-pgd    0.0705               0               0            0
# 130       unsafe-pgd    0.0567               0               0            0
# 131  safe-incomplete    0.0675               0               0            0
# 132             safe    3.2353               0               0            0
# 133  safe-incomplete    0.0562               0               0            0
# 134       unsafe-pgd    0.0645               0               0            0
# 135       unsafe-pgd    0.0746               0               0            0
# 136  safe-incomplete    0.0705               0               0            0
# 137       unsafe-pgd    0.0831               0               0            0
# 138       unsafe-pgd    0.0807               0               0            0
# 139             safe    7.0781            1304               0            0
# 140  safe-incomplete    0.0533               0               0            0
# 141       unsafe-pgd    0.0767               0               0            0
# 142  safe-incomplete    0.0555               0               0            0
# 143       unsafe-pgd    0.0457               0               0            0
# 144  safe-incomplete    0.0599               0               0            0
# 145       unsafe-pgd    0.0530               0               0            0
# 146  safe-incomplete    0.0464               0               0            0
# 147  safe-incomplete    0.0501               0               0            0
# 148  safe-incomplete    0.0498               0               0            0
# 149       unsafe-pgd    0.0681               0               0            0
# 150       unsafe-pgd    0.0609               0               0            0
# 151       unsafe-pgd    0.0556               0               0            0
# 152       unsafe-pgd    0.0544               0               0            0
# 153  safe-incomplete    0.0645               0               0            0
# 154       unsafe-pgd    0.0456               0               0            0
# 155       unsafe-pgd    0.0543               0               0            0
# 156       unsafe-pgd    0.0544               0               0            0
# 157  safe-incomplete    0.0442               0               0            0
# 158             safe    3.2404               0               0            0
# 159  safe-incomplete    0.0675               0               0            0
# 160             safe    2.8554               0               0            0
# 161  safe-incomplete    0.0407               0               0            0
# 162  safe-incomplete    0.0530               0               0            0
# 163       unsafe-pgd    0.0570               0               0            0
# 164  safe-incomplete    0.0443               0               0            0
# 165       unsafe-pgd    0.0536               0               0            0
# 166  safe-incomplete    0.2846               0               0            0
# 167             safe   28.8694           61519               0            0
# 168  safe-incomplete    0.0573               0               0            0
# 169             safe   37.8761           70228               0            0
# 170       unsafe-pgd    0.0744               0               0            0
# 171  safe-incomplete    0.0689               0               0            0
# 172             safe    3.3765               0               0            0
# 173       unsafe-pgd    0.0873               0               0            0
# 174       unsafe-pgd    0.0888               0               0            0
# 175       unsafe-pgd    0.0729               0               0            0
# 176       unsafe-pgd    0.0580               0               0            0
# 177  safe-incomplete    0.0687               0               0            0
# 178  safe-incomplete    0.0679               0               0            0
# 179  safe-incomplete    0.0707               0               0            0
# 180  safe-incomplete    0.0692               0               0            0
# 181       unsafe-pgd    0.0716               0               0            0
# 182  safe-incomplete    0.0670               0               0            0
# 183          unknown  204.4633          360995               0            0
# 184       unsafe-pgd    0.0840               0               0            0
# 185       unsafe-pgd    0.0777               0               0            0
# 186  safe-incomplete    0.0673               0               0            0
# 187          unknown  206.7571          324196               0            0
# 188       unsafe-pgd    0.0832               0               0            0
# 189  safe-incomplete    0.0681               0               0            0
# 190  safe-incomplete    0.0780               0               0            0
# 191       unsafe-pgd    0.0783               0               0            0
# 192  safe-incomplete    0.0660               0               0            0
# 193  safe-incomplete    0.0677               0               0            0
# 194       unsafe-pgd    0.0770               0               0            0
# 195             safe   45.7529           89631               0            0
# 196       unsafe-pgd    0.0846               0               0            0
# 197  safe-incomplete    0.0664               0               0            0
# 198             safe   34.2050           58894               0            0
# 199       unsafe-pgd    0.0787               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 5         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                23         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                18         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                17   -0.185496
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 1         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                30         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 1         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                25         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 2         NaN
# 96                 0         NaN
# 97                12         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103               20         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                1         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116               23         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139               14         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                2         NaN
# 159                0         NaN
# 160                1         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167               19         NaN
# 168                0         NaN
# 169               21         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183               22   -0.246424
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187               38   -0.144796
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195               13         NaN
# 196                0         NaN
# 197                0         NaN
# 198               17         NaN
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               24   19.143250   28558.708333            0.0         0.0
# safe-incomplete    73    0.064201       0.000000            0.0         0.0
# unknown             3  213.702533  378851.000000            0.0         0.0
# unsafe-pgd        100    0.124317       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  10.583333
# safe-incomplete        0.000000
# unknown               25.666667
# unsafe-pgd             0.000000
# safe number 97.0
# safe time 4.784790721649484
# safe domain 7066.072164948454
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((97.0, 4.784790721649484, 28558.708333333332, 0.0),)

# %%
main('cifar_cnn_a_adv/biccos_only_cs.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe   11.2892             195              42         1150
# 38    safe    2.9092              50               9          615
# 42    safe   14.0340            7460             344         6618
# 54    safe    2.6891               0               1          256
# 60    safe    2.4644               0               1          256
# 70    safe   10.1848            6226             127         5947
# 84    safe    3.1698              50               7          656
# 89    safe   20.1447           12847             164         8268
# 95    safe    3.3952             100              21          655
# 103   safe   29.6858           25335             222        14200
# 107   safe    2.3677               0               1          256
# 112   safe    3.3759             100              67          656
# 116   safe  106.2064          125407             689        55196
# 132   safe    2.5006               0               1          256
# 139   safe    9.1324            1124             230         1931
# 158   safe    3.7070              50               8          912
# 160   safe    3.2355             100               7          650
# 167   safe   95.5082           97440             960        55014
# 169   safe   49.3168           51951             232        21370
# 172   safe    3.4005               0               1          512
# 187   safe   55.5266           52353             360        40589
# 198   safe   24.0854           28713             224        14925
#
#      BaB Round Count  BaB_lb_rhs
# 11                 7         NaN
# 38                 3         NaN
# 42                19         NaN
# 54                 2         NaN
# 60                 2         NaN
# 70                14         NaN
# 84                 3         NaN
# 89                29         NaN
# 95                 4         NaN
# 103               33         NaN
# 107                2         NaN
# 112                4         NaN
# 116               20         NaN
# 132                2         NaN
# 139               18         NaN
# 158                5         NaN
# 160                4         NaN
# 167               51         NaN
# 169               32         NaN
# 172                4         NaN
# 187               37         NaN
# 198               17         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24   unknown  201.0826          304519             233       102982
# 55   unknown  205.7681          458951              46          643
# 97   unknown  206.4848          466087             613        39008
# 183  unknown  203.9881          423444              81        62274
# 195  unknown  236.1790          380414            1207        36400
#
#      BaB Round Count  BaB_lb_rhs
# 24                39   -0.087683
# 55                20   -0.179468
# 97                30   -0.069346
# 183               25   -0.199637
# 195               22   -0.027446
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    5.3509               0               0            0
# 1         unsafe-pgd    1.1304               0               0            0
# 2    safe-incomplete    0.0636               0               0            0
# 3         unsafe-pgd    0.0658               0               0            0
# 4         unsafe-pgd    0.0608               0               0            0
# 5         unsafe-pgd    0.0883               0               0            0
# 6         unsafe-pgd    0.0759               0               0            0
# 7         unsafe-pgd    0.0743               0               0            0
# 8    safe-incomplete    0.0722               0               0            0
# 9         unsafe-pgd    0.0866               0               0            0
# 10        unsafe-pgd    0.0828               0               0            0
# 11              safe   11.2892             195              42         1150
# 12        unsafe-pgd    0.0792               0               0            0
# 13        unsafe-pgd    0.0788               0               0            0
# 14   safe-incomplete    0.0675               0               0            0
# 15        unsafe-pgd    0.0781               0               0            0
# 16        unsafe-pgd    0.0684               0               0            0
# 17   safe-incomplete    0.0797               0               0            0
# 18        unsafe-pgd    0.0779               0               0            0
# 19        unsafe-pgd    0.0771               0               0            0
# 20   safe-incomplete    0.0697               0               0            0
# 21   safe-incomplete    0.0787               0               0            0
# 22   safe-incomplete    0.0682               0               0            0
# 23   safe-incomplete    0.0722               0               0            0
# 24           unknown  201.0826          304519             233       102982
# 25        unsafe-pgd    0.0958               0               0            0
# 26   safe-incomplete    0.0723               0               0            0
# 27   safe-incomplete    0.0790               0               0            0
# 28   safe-incomplete    0.0653               0               0            0
# 29        unsafe-pgd    0.0670               0               0            0
# 30   safe-incomplete    0.0672               0               0            0
# 31   safe-incomplete    0.0894               0               0            0
# 32        unsafe-pgd    0.0854               0               0            0
# 33   safe-incomplete    0.0618               0               0            0
# 34        unsafe-pgd    0.0943               0               0            0
# 35        unsafe-pgd    0.0827               0               0            0
# 36        unsafe-pgd    0.0561               0               0            0
# 37   safe-incomplete    0.0708               0               0            0
# 38              safe    2.9092              50               9          615
# 39   safe-incomplete    0.0750               0               0            0
# 40   safe-incomplete    0.0678               0               0            0
# 41   safe-incomplete    0.0742               0               0            0
# 42              safe   14.0340            7460             344         6618
# 43        unsafe-pgd    0.1019               0               0            0
# 44        unsafe-pgd    0.0761               0               0            0
# 45        unsafe-pgd    0.0927               0               0            0
# 46        unsafe-pgd    0.0847               0               0            0
# 47   safe-incomplete    0.0680               0               0            0
# 48   safe-incomplete    0.0717               0               0            0
# 49   safe-incomplete    0.0678               0               0            0
# 50        unsafe-pgd    0.0939               0               0            0
# 51   safe-incomplete    0.0732               0               0            0
# 52   safe-incomplete    0.0608               0               0            0
# 53        unsafe-pgd    0.0859               0               0            0
# 54              safe    2.6891               0               1          256
# 55           unknown  205.7681          458951              46          643
# 56        unsafe-pgd    0.0450               0               0            0
# 57        unsafe-pgd    0.0832               0               0            0
# 58        unsafe-pgd    0.0788               0               0            0
# 59        unsafe-pgd    0.0786               0               0            0
# 60              safe    2.4644               0               1          256
# 61        unsafe-pgd    0.0854               0               0            0
# 62   safe-incomplete    0.0690               0               0            0
# 63        unsafe-pgd    0.0779               0               0            0
# 64        unsafe-pgd    0.0755               0               0            0
# 65        unsafe-pgd    0.0778               0               0            0
# 66        unsafe-pgd    0.0812               0               0            0
# 67        unsafe-pgd    0.0801               0               0            0
# 68   safe-incomplete    0.0662               0               0            0
# 69        unsafe-pgd    0.0748               0               0            0
# 70              safe   10.1848            6226             127         5947
# 71   safe-incomplete    0.0836               0               0            0
# 72        unsafe-pgd    0.0745               0               0            0
# 73   safe-incomplete    0.0722               0               0            0
# 74   safe-incomplete    0.0754               0               0            0
# 75        unsafe-pgd    0.0793               0               0            0
# 76   safe-incomplete    0.0935               0               0            0
# 77        unsafe-pgd    0.0752               0               0            0
# 78        unsafe-pgd    0.0868               0               0            0
# 79   safe-incomplete    0.0675               0               0            0
# 80        unsafe-pgd    0.0891               0               0            0
# 81   safe-incomplete    0.0672               0               0            0
# 82        unsafe-pgd    0.0830               0               0            0
# 83   safe-incomplete    0.0657               0               0            0
# 84              safe    3.1698              50               7          656
# 85   safe-incomplete    0.0765               0               0            0
# 86   safe-incomplete    0.0710               0               0            0
# 87        unsafe-pgd    0.0803               0               0            0
# 88        unsafe-pgd    0.0742               0               0            0
# 89              safe   20.1447           12847             164         8268
# 90        unsafe-pgd    0.0941               0               0            0
# 91        unsafe-pgd    0.0731               0               0            0
# 92        unsafe-pgd    0.0792               0               0            0
# 93   safe-incomplete    0.0643               0               0            0
# 94        unsafe-pgd    0.0849               0               0            0
# 95              safe    3.3952             100              21          655
# 96        unsafe-pgd    0.0877               0               0            0
# 97           unknown  206.4848          466087             613        39008
# 98        unsafe-pgd    0.0751               0               0            0
# 99        unsafe-pgd    0.0811               0               0            0
# 100       unsafe-pgd    0.0842               0               0            0
# 101       unsafe-pgd    0.0702               0               0            0
# 102       unsafe-pgd    0.0828               0               0            0
# 103             safe   29.6858           25335             222        14200
# 104  safe-incomplete    0.0628               0               0            0
# 105       unsafe-pgd    0.0776               0               0            0
# 106       unsafe-pgd    0.0736               0               0            0
# 107             safe    2.3677               0               1          256
# 108       unsafe-pgd    0.0906               0               0            0
# 109  safe-incomplete    0.0736               0               0            0
# 110  safe-incomplete    0.0734               0               0            0
# 111  safe-incomplete    0.3615               0               0            0
# 112             safe    3.3759             100              67          656
# 113       unsafe-pgd    0.0933               0               0            0
# 114  safe-incomplete    0.0693               0               0            0
# 115  safe-incomplete    0.0702               0               0            0
# 116             safe  106.2064          125407             689        55196
# 117  safe-incomplete    0.0354               0               0            0
# 118  safe-incomplete    0.0676               0               0            0
# 119       unsafe-pgd    0.0799               0               0            0
# 120       unsafe-pgd    0.0843               0               0            0
# 121  safe-incomplete    0.0694               0               0            0
# 122       unsafe-pgd    0.0676               0               0            0
# 123       unsafe-pgd    0.0783               0               0            0
# 124       unsafe-pgd    0.0760               0               0            0
# 125       unsafe-pgd    0.0868               0               0            0
# 126       unsafe-pgd    0.0783               0               0            0
# 127       unsafe-pgd    0.0829               0               0            0
# 128       unsafe-pgd    0.0808               0               0            0
# 129       unsafe-pgd    0.0677               0               0            0
# 130       unsafe-pgd    0.0755               0               0            0
# 131  safe-incomplete    0.0735               0               0            0
# 132             safe    2.5006               0               1          256
# 133  safe-incomplete    0.0763               0               0            0
# 134       unsafe-pgd    0.0771               0               0            0
# 135       unsafe-pgd    0.0548               0               0            0
# 136  safe-incomplete    0.0693               0               0            0
# 137       unsafe-pgd    0.0870               0               0            0
# 138       unsafe-pgd    0.0798               0               0            0
# 139             safe    9.1324            1124             230         1931
# 140  safe-incomplete    0.0753               0               0            0
# 141       unsafe-pgd    0.0862               0               0            0
# 142  safe-incomplete    0.0790               0               0            0
# 143       unsafe-pgd    0.0747               0               0            0
# 144  safe-incomplete    0.0669               0               0            0
# 145       unsafe-pgd    0.0771               0               0            0
# 146  safe-incomplete    0.0652               0               0            0
# 147  safe-incomplete    0.0650               0               0            0
# 148  safe-incomplete    0.0641               0               0            0
# 149       unsafe-pgd    0.0737               0               0            0
# 150       unsafe-pgd    0.0752               0               0            0
# 151       unsafe-pgd    0.0713               0               0            0
# 152       unsafe-pgd    0.0718               0               0            0
# 153  safe-incomplete    0.0655               0               0            0
# 154       unsafe-pgd    0.0700               0               0            0
# 155       unsafe-pgd    0.0795               0               0            0
# 156       unsafe-pgd    0.0737               0               0            0
# 157  safe-incomplete    0.0628               0               0            0
# 158             safe    3.7070              50               8          912
# 159  safe-incomplete    0.0688               0               0            0
# 160             safe    3.2355             100               7          650
# 161  safe-incomplete    0.0851               0               0            0
# 162  safe-incomplete    0.0672               0               0            0
# 163       unsafe-pgd    0.0743               0               0            0
# 164  safe-incomplete    0.0416               0               0            0
# 165       unsafe-pgd    0.0820               0               0            0
# 166  safe-incomplete    0.2169               0               0            0
# 167             safe   95.5082           97440             960        55014
# 168  safe-incomplete    0.0988               0               0            0
# 169             safe   49.3168           51951             232        21370
# 170       unsafe-pgd    0.0844               0               0            0
# 171  safe-incomplete    0.0711               0               0            0
# 172             safe    3.4005               0               1          512
# 173       unsafe-pgd    0.0788               0               0            0
# 174       unsafe-pgd    0.0884               0               0            0
# 175       unsafe-pgd    0.0760               0               0            0
# 176       unsafe-pgd    0.0763               0               0            0
# 177  safe-incomplete    0.0662               0               0            0
# 178  safe-incomplete    0.0707               0               0            0
# 179  safe-incomplete    0.0703               0               0            0
# 180  safe-incomplete    0.0882               0               0            0
# 181       unsafe-pgd    0.0761               0               0            0
# 182  safe-incomplete    0.0662               0               0            0
# 183          unknown  203.9881          423444              81        62274
# 184       unsafe-pgd    0.0786               0               0            0
# 185       unsafe-pgd    0.0567               0               0            0
# 186  safe-incomplete    0.0775               0               0            0
# 187             safe   55.5266           52353             360        40589
# 188       unsafe-pgd    0.0854               0               0            0
# 189  safe-incomplete    0.0663               0               0            0
# 190  safe-incomplete    0.0735               0               0            0
# 191       unsafe-pgd    0.0792               0               0            0
# 192  safe-incomplete    0.0728               0               0            0
# 193  safe-incomplete    0.0644               0               0            0
# 194       unsafe-pgd    0.0807               0               0            0
# 195          unknown  236.1790          380414            1207        36400
# 196       unsafe-pgd    0.0997               0               0            0
# 197  safe-incomplete    0.0708               0               0            0
# 198             safe   24.0854           28713             224        14925
# 199       unsafe-pgd    0.0920               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 7         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                39   -0.087683
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 3         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                19         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 2         NaN
# 55                20   -0.179468
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 2         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                14         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 3         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                29         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 4         NaN
# 96                 0         NaN
# 97                30   -0.069346
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103               33         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                2         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                4         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116               20         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                2         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139               18         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                5         NaN
# 159                0         NaN
# 160                4         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167               51         NaN
# 168                0         NaN
# 169               32         NaN
# 170                0         NaN
# 171                0         NaN
# 172                4         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183               25   -0.199637
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187               37         NaN
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195               22   -0.027446
# 196                0         NaN
# 197                0         NaN
# 198               17         NaN
# 199                0         NaN
# #Cuts 5898
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               22   20.833145   18613.681818          169.0  10494.909091
# safe-incomplete    73    0.076585       0.000000            0.0      0.000000
# unknown             5  210.700520  406683.000000          436.0  48261.400000
# unsafe-pgd        100    0.142386       0.000000            0.0      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  14.181818
# safe-incomplete        0.000000
# unknown               27.200000
# unsafe-pgd             0.000000
# safe number 95.0
# safe time 4.8833673684210535
# safe domain 4310.5368421052635
# safe cut 39.136842105263156
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((95.0, 4.8833673684210535, 18613.68181818182, 169.0),)

# %%
main('cifar_cnn_a_adv/biccos_all.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe   10.9533             169              15         1284
# 38    safe    2.7397              50               9          359
# 42    safe   11.6498            7457             167         6398
# 54    safe    2.3588               0               1           26
# 60    safe    2.3459               0               1           12
# 70    safe    6.6255            3074              84         3100
# 84    safe    2.6087              50               7          400
# 89    safe   17.6888           12958             182         8763
# 95    safe    3.0826             100              21          655
# 103   safe   22.2698           21832             124        12074
# 107   safe    2.5762               0               1           11
# 112   safe    3.0860             100              67          656
# 116   safe  125.0573          149219            1011        79431
# 132   safe    2.4621               0               1           17
# 139   safe    8.7977            1130             329         1588
# 158   safe    3.6591              50               8          453
# 160   safe    3.4509             100               7          394
# 167   safe   88.1030           92101             956        53013
# 169   safe   82.5398           92362             254        44797
# 172   safe    3.5144               0               1           20
# 187   safe   32.1179           26776             132        21029
# 198   safe   32.8268           35426             132        16044
#
#      BaB Round Count  BaB_lb_rhs
# 11                 7         NaN
# 38                 2         NaN
# 42                18         NaN
# 54                 1         NaN
# 60                 1         NaN
# 70                11         NaN
# 84                 2         NaN
# 89                29         NaN
# 95                 4         NaN
# 103               29         NaN
# 107                1         NaN
# 112                4         NaN
# 116               23         NaN
# 132                1         NaN
# 139               17         NaN
# 158                3         NaN
# 160                3         NaN
# 167               32         NaN
# 169               33         NaN
# 172                2         NaN
# 187               32         NaN
# 198               24         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24   unknown  240.7701          312594             270        60322
# 55   unknown  213.4263          524457              44          582
# 97   unknown  204.7157          471440             648        48966
# 183  unknown  219.9094          504562              48        12385
# 195  unknown  222.7735          384897             709        35651
#
#      BaB Round Count  BaB_lb_rhs
# 24                28   -0.096939
# 55                21   -0.178884
# 97                31   -0.071934
# 183               26   -0.207943
# 195               25   -0.026948
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    5.1951               0               0            0
# 1         unsafe-pgd    1.1863               0               0            0
# 2    safe-incomplete    0.0687               0               0            0
# 3         unsafe-pgd    0.0724               0               0            0
# 4         unsafe-pgd    0.0759               0               0            0
# 5         unsafe-pgd    0.0843               0               0            0
# 6         unsafe-pgd    0.0752               0               0            0
# 7         unsafe-pgd    0.0799               0               0            0
# 8    safe-incomplete    0.0705               0               0            0
# 9         unsafe-pgd    0.0863               0               0            0
# 10        unsafe-pgd    0.0909               0               0            0
# 11              safe   10.9533             169              15         1284
# 12        unsafe-pgd    0.0799               0               0            0
# 13        unsafe-pgd    0.0846               0               0            0
# 14   safe-incomplete    0.0727               0               0            0
# 15        unsafe-pgd    0.0724               0               0            0
# 16        unsafe-pgd    0.0780               0               0            0
# 17   safe-incomplete    0.0689               0               0            0
# 18        unsafe-pgd    0.0755               0               0            0
# 19        unsafe-pgd    0.0699               0               0            0
# 20   safe-incomplete    0.0657               0               0            0
# 21   safe-incomplete    0.0635               0               0            0
# 22   safe-incomplete    0.0660               0               0            0
# 23   safe-incomplete    0.0804               0               0            0
# 24           unknown  240.7701          312594             270        60322
# 25        unsafe-pgd    0.1162               0               0            0
# 26   safe-incomplete    0.0713               0               0            0
# 27   safe-incomplete    0.0872               0               0            0
# 28   safe-incomplete    0.0641               0               0            0
# 29        unsafe-pgd    0.1177               0               0            0
# 30   safe-incomplete    0.0656               0               0            0
# 31   safe-incomplete    0.0379               0               0            0
# 32        unsafe-pgd    0.0909               0               0            0
# 33   safe-incomplete    0.0660               0               0            0
# 34        unsafe-pgd    0.0837               0               0            0
# 35        unsafe-pgd    0.0816               0               0            0
# 36        unsafe-pgd    0.0933               0               0            0
# 37   safe-incomplete    0.0622               0               0            0
# 38              safe    2.7397              50               9          359
# 39   safe-incomplete    0.0324               0               0            0
# 40   safe-incomplete    0.0621               0               0            0
# 41   safe-incomplete    0.0642               0               0            0
# 42              safe   11.6498            7457             167         6398
# 43        unsafe-pgd    0.0931               0               0            0
# 44        unsafe-pgd    0.0751               0               0            0
# 45        unsafe-pgd    0.0823               0               0            0
# 46        unsafe-pgd    0.0738               0               0            0
# 47   safe-incomplete    0.0669               0               0            0
# 48   safe-incomplete    0.0627               0               0            0
# 49   safe-incomplete    0.0658               0               0            0
# 50        unsafe-pgd    0.0882               0               0            0
# 51   safe-incomplete    0.0665               0               0            0
# 52   safe-incomplete    0.0646               0               0            0
# 53        unsafe-pgd    0.0700               0               0            0
# 54              safe    2.3588               0               1           26
# 55           unknown  213.4263          524457              44          582
# 56        unsafe-pgd    0.0778               0               0            0
# 57        unsafe-pgd    0.0805               0               0            0
# 58        unsafe-pgd    0.0747               0               0            0
# 59        unsafe-pgd    0.0856               0               0            0
# 60              safe    2.3459               0               1           12
# 61        unsafe-pgd    0.0840               0               0            0
# 62   safe-incomplete    0.0745               0               0            0
# 63        unsafe-pgd    0.0767               0               0            0
# 64        unsafe-pgd    0.0737               0               0            0
# 65        unsafe-pgd    0.0889               0               0            0
# 66        unsafe-pgd    0.0743               0               0            0
# 67        unsafe-pgd    0.0708               0               0            0
# 68   safe-incomplete    0.0822               0               0            0
# 69        unsafe-pgd    0.0733               0               0            0
# 70              safe    6.6255            3074              84         3100
# 71   safe-incomplete    0.1029               0               0            0
# 72        unsafe-pgd    0.0785               0               0            0
# 73   safe-incomplete    0.0673               0               0            0
# 74   safe-incomplete    0.0693               0               0            0
# 75        unsafe-pgd    0.0693               0               0            0
# 76   safe-incomplete    0.0800               0               0            0
# 77        unsafe-pgd    0.0699               0               0            0
# 78        unsafe-pgd    0.0808               0               0            0
# 79   safe-incomplete    0.0649               0               0            0
# 80        unsafe-pgd    0.0812               0               0            0
# 81   safe-incomplete    0.0673               0               0            0
# 82        unsafe-pgd    0.1101               0               0            0
# 83   safe-incomplete    0.1030               0               0            0
# 84              safe    2.6087              50               7          400
# 85   safe-incomplete    0.0829               0               0            0
# 86   safe-incomplete    0.0653               0               0            0
# 87        unsafe-pgd    0.0790               0               0            0
# 88        unsafe-pgd    0.0802               0               0            0
# 89              safe   17.6888           12958             182         8763
# 90        unsafe-pgd    0.0459               0               0            0
# 91        unsafe-pgd    0.0678               0               0            0
# 92        unsafe-pgd    0.0707               0               0            0
# 93   safe-incomplete    0.0658               0               0            0
# 94        unsafe-pgd    0.0717               0               0            0
# 95              safe    3.0826             100              21          655
# 96        unsafe-pgd    0.0859               0               0            0
# 97           unknown  204.7157          471440             648        48966
# 98        unsafe-pgd    0.0729               0               0            0
# 99        unsafe-pgd    0.0703               0               0            0
# 100       unsafe-pgd    0.0860               0               0            0
# 101       unsafe-pgd    0.0370               0               0            0
# 102       unsafe-pgd    0.0830               0               0            0
# 103             safe   22.2698           21832             124        12074
# 104  safe-incomplete    0.0639               0               0            0
# 105       unsafe-pgd    0.0983               0               0            0
# 106       unsafe-pgd    0.0697               0               0            0
# 107             safe    2.5762               0               1           11
# 108       unsafe-pgd    0.0775               0               0            0
# 109  safe-incomplete    0.0669               0               0            0
# 110  safe-incomplete    0.0347               0               0            0
# 111  safe-incomplete    0.2959               0               0            0
# 112             safe    3.0860             100              67          656
# 113       unsafe-pgd    0.0694               0               0            0
# 114  safe-incomplete    0.0621               0               0            0
# 115  safe-incomplete    0.0390               0               0            0
# 116             safe  125.0573          149219            1011        79431
# 117  safe-incomplete    0.0374               0               0            0
# 118  safe-incomplete    0.0759               0               0            0
# 119       unsafe-pgd    0.0747               0               0            0
# 120       unsafe-pgd    0.0818               0               0            0
# 121  safe-incomplete    0.0622               0               0            0
# 122       unsafe-pgd    0.0488               0               0            0
# 123       unsafe-pgd    0.0713               0               0            0
# 124       unsafe-pgd    0.0761               0               0            0
# 125       unsafe-pgd    0.1016               0               0            0
# 126       unsafe-pgd    0.0857               0               0            0
# 127       unsafe-pgd    0.0851               0               0            0
# 128       unsafe-pgd    0.1118               0               0            0
# 129       unsafe-pgd    0.0706               0               0            0
# 130       unsafe-pgd    0.0784               0               0            0
# 131  safe-incomplete    0.0684               0               0            0
# 132             safe    2.4621               0               1           17
# 133  safe-incomplete    0.0726               0               0            0
# 134       unsafe-pgd    0.0843               0               0            0
# 135       unsafe-pgd    0.0715               0               0            0
# 136  safe-incomplete    0.0624               0               0            0
# 137       unsafe-pgd    0.0882               0               0            0
# 138       unsafe-pgd    0.0802               0               0            0
# 139             safe    8.7977            1130             329         1588
# 140  safe-incomplete    0.0778               0               0            0
# 141       unsafe-pgd    0.0767               0               0            0
# 142  safe-incomplete    0.0664               0               0            0
# 143       unsafe-pgd    0.0710               0               0            0
# 144  safe-incomplete    0.0627               0               0            0
# 145       unsafe-pgd    0.0867               0               0            0
# 146  safe-incomplete    0.0713               0               0            0
# 147  safe-incomplete    0.0680               0               0            0
# 148  safe-incomplete    0.0647               0               0            0
# 149       unsafe-pgd    0.0693               0               0            0
# 150       unsafe-pgd    0.0722               0               0            0
# 151       unsafe-pgd    0.0711               0               0            0
# 152       unsafe-pgd    0.0678               0               0            0
# 153  safe-incomplete    0.0952               0               0            0
# 154       unsafe-pgd    0.0695               0               0            0
# 155       unsafe-pgd    0.0749               0               0            0
# 156       unsafe-pgd    0.0738               0               0            0
# 157  safe-incomplete    0.0617               0               0            0
# 158             safe    3.6591              50               8          453
# 159  safe-incomplete    0.0764               0               0            0
# 160             safe    3.4509             100               7          394
# 161  safe-incomplete    0.0735               0               0            0
# 162  safe-incomplete    0.0765               0               0            0
# 163       unsafe-pgd    0.0715               0               0            0
# 164  safe-incomplete    0.0659               0               0            0
# 165       unsafe-pgd    0.0831               0               0            0
# 166  safe-incomplete    0.2138               0               0            0
# 167             safe   88.1030           92101             956        53013
# 168  safe-incomplete    0.0859               0               0            0
# 169             safe   82.5398           92362             254        44797
# 170       unsafe-pgd    0.0774               0               0            0
# 171  safe-incomplete    0.0659               0               0            0
# 172             safe    3.5144               0               1           20
# 173       unsafe-pgd    0.0735               0               0            0
# 174       unsafe-pgd    0.0738               0               0            0
# 175       unsafe-pgd    0.0832               0               0            0
# 176       unsafe-pgd    0.0783               0               0            0
# 177  safe-incomplete    0.0656               0               0            0
# 178  safe-incomplete    0.0700               0               0            0
# 179  safe-incomplete    0.0695               0               0            0
# 180  safe-incomplete    0.0683               0               0            0
# 181       unsafe-pgd    0.0777               0               0            0
# 182  safe-incomplete    0.0658               0               0            0
# 183          unknown  219.9094          504562              48        12385
# 184       unsafe-pgd    0.0825               0               0            0
# 185       unsafe-pgd    0.0791               0               0            0
# 186  safe-incomplete    0.0622               0               0            0
# 187             safe   32.1179           26776             132        21029
# 188       unsafe-pgd    0.0558               0               0            0
# 189  safe-incomplete    0.0816               0               0            0
# 190  safe-incomplete    0.0456               0               0            0
# 191       unsafe-pgd    0.0728               0               0            0
# 192  safe-incomplete    0.0675               0               0            0
# 193  safe-incomplete    0.0657               0               0            0
# 194       unsafe-pgd    0.0740               0               0            0
# 195          unknown  222.7735          384897             709        35651
# 196       unsafe-pgd    0.0858               0               0            0
# 197  safe-incomplete    0.0705               0               0            0
# 198             safe   32.8268           35426             132        16044
# 199       unsafe-pgd    0.0861               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 7         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                28   -0.096939
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 2         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                18         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                21   -0.178884
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 1         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                11         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 2         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                29         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 4         NaN
# 96                 0         NaN
# 97                31   -0.071934
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103               29         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                4         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116               23         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139               17         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                3         NaN
# 159                0         NaN
# 160                3         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167               32         NaN
# 168                0         NaN
# 169               33         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183               26   -0.207943
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187               32         NaN
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195               25   -0.026948
# 196                0         NaN
# 197                0         NaN
# 198               24         NaN
# 199                0         NaN
# #Cuts 5229
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               22   21.387005   20134.272727     159.545455  11387.454545
# safe-incomplete    73    0.072886       0.000000       0.000000      0.000000
# unknown             5  220.319000  439590.000000     343.800000  31581.200000
# unsafe-pgd        100    0.140856       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  12.681818
# safe-incomplete        0.000000
# unknown               26.200000
# unsafe-pgd             0.000000
# safe number 95.0
# safe time 5.008787368421053
# safe domain 4662.6736842105265
# safe cut 36.94736842105263
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((95.0, 5.008787368421053, 20134.272727272728, 159.54545454545453),)

# %%
main('cifar_cnn_a_adv/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe  11.0908             169              15         1284
# 24    safe  32.2906           23977            2191        21103
# 38    safe   4.2012              50               9          359
# 42    safe  15.2334            7461             553         6408
# 54    safe   3.7584               0               1           26
# 60    safe   4.6124               0               1           12
# 70    safe  11.8538            5784             102         5641
# 84    safe   4.0450              50               7          400
# 89    safe  18.9451           11589             441         7573
# 95    safe   4.9327             100              21          655
# 97    safe  26.0965           19222            1313        18899
# 103   safe  20.3046           12511             464         6600
# 107   safe   3.6288               0               1           11
# 112   safe   5.0810             100              67          656
# 116   safe  40.2422           32308            1012        26486
# 132   safe   3.9875               0               1           17
# 139   safe  11.3378            1131             330         1588
# 158   safe   5.1644              50               8          453
# 160   safe   4.8976             100               7          394
# 167   safe  31.3066           21774             868        11818
# 169   safe  35.1581           28111            1795        22137
# 172   safe   4.7893               0               1           20
# 187   safe  50.1958           35891            1279        23020
# 195   safe  35.6113           33671            1120        31541
# 198   safe  23.8775           13525            1065        11935
#
#      BaB Round Count  BaB_lb_rhs
# 11                 7         NaN
# 24                24         NaN
# 38                 2         NaN
# 42                18         NaN
# 54                 1         NaN
# 60                 1         NaN
# 70                13         NaN
# 84                 2         NaN
# 89                20         NaN
# 95                 4         NaN
# 97                15         NaN
# 103               21         NaN
# 107                1         NaN
# 112                4         NaN
# 116               20         NaN
# 132                1         NaN
# 139               17         NaN
# 158                3         NaN
# 160                3         NaN
# 167               26         NaN
# 169               27         NaN
# 172                2         NaN
# 187               33         NaN
# 195               19         NaN
# 198               22         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 55   unknown  212.1398          391631            1213         2300
# 183  unknown  206.8471          313958            7374         9306
#
#      BaB Round Count  BaB_lb_rhs
# 55                29   -0.120924
# 183               27   -0.147090
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    2.1149               0               0            0
# 1         unsafe-pgd    0.4637               0               0            0
# 2    safe-incomplete    0.0486               0               0            0
# 3         unsafe-pgd    0.0390               0               0            0
# 4         unsafe-pgd    0.0507               0               0            0
# 5         unsafe-pgd    0.0638               0               0            0
# 6         unsafe-pgd    0.0625               0               0            0
# 7         unsafe-pgd    0.0681               0               0            0
# 8    safe-incomplete    0.0660               0               0            0
# 9         unsafe-pgd    0.0865               0               0            0
# 10        unsafe-pgd    0.0684               0               0            0
# 11              safe   11.0908             169              15         1284
# 12        unsafe-pgd    0.0745               0               0            0
# 13        unsafe-pgd    0.0765               0               0            0
# 14   safe-incomplete    0.0339               0               0            0
# 15        unsafe-pgd    0.0689               0               0            0
# 16        unsafe-pgd    0.0759               0               0            0
# 17   safe-incomplete    0.0575               0               0            0
# 18        unsafe-pgd    0.0549               0               0            0
# 19        unsafe-pgd    0.0404               0               0            0
# 20   safe-incomplete    0.0482               0               0            0
# 21   safe-incomplete    0.0341               0               0            0
# 22   safe-incomplete    0.0240               0               0            0
# 23   safe-incomplete    0.0639               0               0            0
# 24              safe   32.2906           23977            2191        21103
# 25        unsafe-pgd    0.0677               0               0            0
# 26   safe-incomplete    0.0643               0               0            0
# 27   safe-incomplete    0.0630               0               0            0
# 28   safe-incomplete    0.0665               0               0            0
# 29        unsafe-pgd    0.0475               0               0            0
# 30   safe-incomplete    0.0648               0               0            0
# 31   safe-incomplete    0.0627               0               0            0
# 32        unsafe-pgd    0.0763               0               0            0
# 33   safe-incomplete    0.0680               0               0            0
# 34        unsafe-pgd    0.0777               0               0            0
# 35        unsafe-pgd    0.0724               0               0            0
# 36        unsafe-pgd    0.0725               0               0            0
# 37   safe-incomplete    0.0654               0               0            0
# 38              safe    4.2012              50               9          359
# 39   safe-incomplete    0.0686               0               0            0
# 40   safe-incomplete    0.0579               0               0            0
# 41   safe-incomplete    0.0664               0               0            0
# 42              safe   15.2334            7461             553         6408
# 43        unsafe-pgd    0.0731               0               0            0
# 44        unsafe-pgd    0.0653               0               0            0
# 45        unsafe-pgd    0.0629               0               0            0
# 46        unsafe-pgd    0.0441               0               0            0
# 47   safe-incomplete    0.0628               0               0            0
# 48   safe-incomplete    0.0509               0               0            0
# 49   safe-incomplete    0.0741               0               0            0
# 50        unsafe-pgd    0.0848               0               0            0
# 51   safe-incomplete    0.0540               0               0            0
# 52   safe-incomplete    0.0310               0               0            0
# 53        unsafe-pgd    0.0779               0               0            0
# 54              safe    3.7584               0               1           26
# 55           unknown  212.1398          391631            1213         2300
# 56        unsafe-pgd    0.0491               0               0            0
# 57        unsafe-pgd    0.0841               0               0            0
# 58        unsafe-pgd    0.0805               0               0            0
# 59        unsafe-pgd    0.2941               0               0            0
# 60              safe    4.6124               0               1           12
# 61        unsafe-pgd    0.1867               0               0            0
# 62   safe-incomplete    0.0393               0               0            0
# 63        unsafe-pgd    0.0515               0               0            0
# 64        unsafe-pgd    0.0746               0               0            0
# 65        unsafe-pgd    0.0636               0               0            0
# 66        unsafe-pgd    0.0678               0               0            0
# 67        unsafe-pgd    0.0672               0               0            0
# 68   safe-incomplete    0.0669               0               0            0
# 69        unsafe-pgd    0.0704               0               0            0
# 70              safe   11.8538            5784             102         5641
# 71   safe-incomplete    0.0662               0               0            0
# 72        unsafe-pgd    0.0758               0               0            0
# 73   safe-incomplete    0.0624               0               0            0
# 74   safe-incomplete    0.0640               0               0            0
# 75        unsafe-pgd    0.0552               0               0            0
# 76   safe-incomplete    0.0512               0               0            0
# 77        unsafe-pgd    0.0718               0               0            0
# 78        unsafe-pgd    0.0767               0               0            0
# 79   safe-incomplete    0.0627               0               0            0
# 80        unsafe-pgd    0.0805               0               0            0
# 81   safe-incomplete    0.0631               0               0            0
# 82        unsafe-pgd    0.0767               0               0            0
# 83   safe-incomplete    0.0621               0               0            0
# 84              safe    4.0450              50               7          400
# 85   safe-incomplete    0.1195               0               0            0
# 86   safe-incomplete    0.0688               0               0            0
# 87        unsafe-pgd    0.0805               0               0            0
# 88        unsafe-pgd    0.0830               0               0            0
# 89              safe   18.9451           11589             441         7573
# 90        unsafe-pgd    0.0860               0               0            0
# 91        unsafe-pgd    0.0692               0               0            0
# 92        unsafe-pgd    0.0722               0               0            0
# 93   safe-incomplete    0.0660               0               0            0
# 94        unsafe-pgd    0.0773               0               0            0
# 95              safe    4.9327             100              21          655
# 96        unsafe-pgd    0.0887               0               0            0
# 97              safe   26.0965           19222            1313        18899
# 98        unsafe-pgd    0.0321               0               0            0
# 99        unsafe-pgd    0.0718               0               0            0
# 100       unsafe-pgd    0.0612               0               0            0
# 101       unsafe-pgd    0.0545               0               0            0
# 102       unsafe-pgd    0.0742               0               0            0
# 103             safe   20.3046           12511             464         6600
# 104  safe-incomplete    0.0662               0               0            0
# 105       unsafe-pgd    0.0535               0               0            0
# 106       unsafe-pgd    0.0487               0               0            0
# 107             safe    3.6288               0               1           11
# 108       unsafe-pgd    0.1300               0               0            0
# 109  safe-incomplete    0.0735               0               0            0
# 110  safe-incomplete    0.0677               0               0            0
# 111  safe-incomplete    0.4256               0               0            0
# 112             safe    5.0810             100              67          656
# 113       unsafe-pgd    0.0772               0               0            0
# 114  safe-incomplete    0.0654               0               0            0
# 115  safe-incomplete    0.0676               0               0            0
# 116             safe   40.2422           32308            1012        26486
# 117  safe-incomplete    0.0716               0               0            0
# 118  safe-incomplete    0.0651               0               0            0
# 119       unsafe-pgd    0.0698               0               0            0
# 120       unsafe-pgd    0.0472               0               0            0
# 121  safe-incomplete    0.0306               0               0            0
# 122       unsafe-pgd    0.0438               0               0            0
# 123       unsafe-pgd    0.0857               0               0            0
# 124       unsafe-pgd    0.0481               0               0            0
# 125       unsafe-pgd    0.0486               0               0            0
# 126       unsafe-pgd    0.0871               0               0            0
# 127       unsafe-pgd    0.0894               0               0            0
# 128       unsafe-pgd    0.0796               0               0            0
# 129       unsafe-pgd    0.0687               0               0            0
# 130       unsafe-pgd    0.0800               0               0            0
# 131  safe-incomplete    0.0624               0               0            0
# 132             safe    3.9875               0               1           17
# 133  safe-incomplete    0.1285               0               0            0
# 134       unsafe-pgd    0.0736               0               0            0
# 135       unsafe-pgd    0.0785               0               0            0
# 136  safe-incomplete    0.0683               0               0            0
# 137       unsafe-pgd    0.0779               0               0            0
# 138       unsafe-pgd    0.0397               0               0            0
# 139             safe   11.3378            1131             330         1588
# 140  safe-incomplete    0.0679               0               0            0
# 141       unsafe-pgd    0.0760               0               0            0
# 142  safe-incomplete    0.0645               0               0            0
# 143       unsafe-pgd    0.0721               0               0            0
# 144  safe-incomplete    0.0635               0               0            0
# 145       unsafe-pgd    0.0691               0               0            0
# 146  safe-incomplete    0.0644               0               0            0
# 147  safe-incomplete    0.0704               0               0            0
# 148  safe-incomplete    0.0635               0               0            0
# 149       unsafe-pgd    0.0707               0               0            0
# 150       unsafe-pgd    0.0593               0               0            0
# 151       unsafe-pgd    0.0727               0               0            0
# 152       unsafe-pgd    0.0697               0               0            0
# 153  safe-incomplete    0.0651               0               0            0
# 154       unsafe-pgd    0.0706               0               0            0
# 155       unsafe-pgd    0.0818               0               0            0
# 156       unsafe-pgd    0.0753               0               0            0
# 157  safe-incomplete    0.0618               0               0            0
# 158             safe    5.1644              50               8          453
# 159  safe-incomplete    0.0794               0               0            0
# 160             safe    4.8976             100               7          394
# 161  safe-incomplete    0.0293               0               0            0
# 162  safe-incomplete    0.0645               0               0            0
# 163       unsafe-pgd    0.0721               0               0            0
# 164  safe-incomplete    0.0762               0               0            0
# 165       unsafe-pgd    0.0784               0               0            0
# 166  safe-incomplete    0.3132               0               0            0
# 167             safe   31.3066           21774             868        11818
# 168  safe-incomplete    0.0691               0               0            0
# 169             safe   35.1581           28111            1795        22137
# 170       unsafe-pgd    0.0668               0               0            0
# 171  safe-incomplete    0.0563               0               0            0
# 172             safe    4.7893               0               1           20
# 173       unsafe-pgd    0.0787               0               0            0
# 174       unsafe-pgd    0.0587               0               0            0
# 175       unsafe-pgd    0.0680               0               0            0
# 176       unsafe-pgd    0.0558               0               0            0
# 177  safe-incomplete    0.0512               0               0            0
# 178  safe-incomplete    0.0464               0               0            0
# 179  safe-incomplete    0.0565               0               0            0
# 180  safe-incomplete    0.0638               0               0            0
# 181       unsafe-pgd    0.0554               0               0            0
# 182  safe-incomplete    0.0741               0               0            0
# 183          unknown  206.8471          313958            7374         9306
# 184       unsafe-pgd    0.0799               0               0            0
# 185       unsafe-pgd    0.0595               0               0            0
# 186  safe-incomplete    0.0443               0               0            0
# 187             safe   50.1958           35891            1279        23020
# 188       unsafe-pgd    0.0716               0               0            0
# 189  safe-incomplete    0.0474               0               0            0
# 190  safe-incomplete    0.0382               0               0            0
# 191       unsafe-pgd    0.0690               0               0            0
# 192  safe-incomplete    0.0581               0               0            0
# 193  safe-incomplete    0.0687               0               0            0
# 194       unsafe-pgd    0.0717               0               0            0
# 195             safe   35.6113           33671            1120        31541
# 196       unsafe-pgd    0.0653               0               0            0
# 197  safe-incomplete    0.0651               0               0            0
# 198             safe   23.8775           13525            1065        11935
# 199       unsafe-pgd    0.0483               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 7         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                24         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 2         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                18         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                 1         NaN
# 55                29   -0.120924
# 56                 0         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 1         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                13         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 2         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                20         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 4         NaN
# 96                 0         NaN
# 97                15         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103               21         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                1         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                4         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116               20         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139               17         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                3         NaN
# 159                0         NaN
# 160                3         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167               26         NaN
# 168                0         NaN
# 169               27         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183               27   -0.147090
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187               33         NaN
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195               19         NaN
# 196                0         NaN
# 197                0         NaN
# 198               22         NaN
# 199                0         NaN
# #Cuts 21259
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               25   16.505696        9902.96         506.88     7961.44
# safe-incomplete    73    0.069921           0.00           0.00        0.00
# unknown             2  209.493450      352794.50        4293.50     5803.00
# unsafe-pgd        100    0.096515           0.00           0.00        0.00
#
#                 BaB Round Count
#                            mean
# Status
# safe                      12.24
# safe-incomplete            0.00
# unknown                   28.00
# unsafe-pgd                 0.00
# safe number 98.0
# safe time 4.262720408163266
# safe domain 2526.2653061224487
# safe cut 129.30612244897958
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((98.0, 4.262720408163266, 9902.96, 506.88),)

# %% [markdown]
# ## cifar_cnn_a_adv4

# %%
plot_multiple_dfs(
    [
log_read('cifar_cnn_a_adv4/beta.log'),
log_read('cifar_cnn_a_adv4/biccos_only_cs.log'),
log_read('cifar_cnn_a_adv4/biccos_all.log'),
log_read('cifar_cnn_a_adv4/gcp.log'),
log_read('cifar_cnn_a_adv4/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
        #'x_cut'
    ],  time_limit=200, dataset='cifar_cnn_a_adv4',
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_a_adv4/beta.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24    safe   4.9809               0               0            0
# 57    safe   2.2450               0               0            0
# 123   safe  45.2908          133583               0            0
# 128   safe   3.4424             282               0            0
# 137   safe   2.3288               0               0            0
# 159   safe   2.3541               0               0            0
# 169   safe   2.4279               0               0            0
# 183   safe   2.4642               0               0            0
# 188   safe   2.3883               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 24                 1         NaN
# 57                 1         NaN
# 123               36         NaN
# 128                5         NaN
# 137                1         NaN
# 159                1         NaN
# 169                1         NaN
# 183                1         NaN
# 188                1         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 52   unknown  203.0801          640653               0            0
# 64   unknown  212.7077          669133               0            0
# 67   unknown  217.0129          812736               0            0
# 97   unknown  209.8011          727506               0            0
# 178  unknown  214.5667          719980               0            0
# 181  unknown  205.7041          611228               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 52                28   -0.016769
# 64                22   -0.021576
# 67                21   -0.050354
# 97                21   -0.045002
# 178               23   -0.029598
# 181               42   -0.011158
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    2.5343               0               0            0
# 1         unsafe-pgd    0.0681               0               0            0
# 2    safe-incomplete    0.0469               0               0            0
# 3         unsafe-pgd    0.0497               0               0            0
# 4         unsafe-pgd    0.0509               0               0            0
# 5         unsafe-pgd    0.0483               0               0            0
# 6         unsafe-pgd    0.0575               0               0            0
# 7    safe-incomplete    0.0488               0               0            0
# 8    safe-incomplete    0.0619               0               0            0
# 9         unsafe-pgd    0.0683               0               0            0
# 10        unsafe-pgd    0.0568               0               0            0
# 11        unsafe-pgd    0.0601               0               0            0
# 12        unsafe-pgd    0.5981               0               0            0
# 13        unsafe-pgd    0.0600               0               0            0
# 14   safe-incomplete    0.0378               0               0            0
# 15   safe-incomplete    0.0335               0               0            0
# 16        unsafe-pgd    0.0439               0               0            0
# 17   safe-incomplete    0.0375               0               0            0
# 18   safe-incomplete    0.0376               0               0            0
# 19        unsafe-pgd    0.0382               0               0            0
# 20   safe-incomplete    0.0581               0               0            0
# 21        unsafe-pgd    0.0649               0               0            0
# 22   safe-incomplete    0.0443               0               0            0
# 23        unsafe-pgd    0.0457               0               0            0
# 24              safe    4.9809               0               0            0
# 25        unsafe-pgd    0.0475               0               0            0
# 26        unsafe-pgd    0.0621               0               0            0
# 27   safe-incomplete    0.0483               0               0            0
# 28   safe-incomplete    0.0448               0               0            0
# 29        unsafe-pgd    0.0578               0               0            0
# 30   safe-incomplete    0.0422               0               0            0
# 31   safe-incomplete    0.0541               0               0            0
# 32        unsafe-pgd    0.0612               0               0            0
# 33   safe-incomplete    0.0430               0               0            0
# 34        unsafe-pgd    0.0699               0               0            0
# 35        unsafe-pgd    0.0524               0               0            0
# 36        unsafe-pgd    0.0575               0               0            0
# 37        unsafe-pgd    0.0365               0               0            0
# 38   safe-incomplete    0.0477               0               0            0
# 39   safe-incomplete    0.0380               0               0            0
# 40   safe-incomplete    0.0277               0               0            0
# 41   safe-incomplete    0.0317               0               0            0
# 42   safe-incomplete    0.0351               0               0            0
# 43        unsafe-pgd    0.0452               0               0            0
# 44        unsafe-pgd    0.0407               0               0            0
# 45        unsafe-pgd    0.0661               0               0            0
# 46        unsafe-pgd    0.0525               0               0            0
# 47   safe-incomplete    0.0413               0               0            0
# 48        unsafe-pgd    0.0520               0               0            0
# 49   safe-incomplete    0.0231               0               0            0
# 50        unsafe-pgd    0.0503               0               0            0
# 51   safe-incomplete    0.0328               0               0            0
# 52           unknown  203.0801          640653               0            0
# 53        unsafe-pgd    0.0686               0               0            0
# 54        unsafe-pgd    0.0766               0               0            0
# 55   safe-incomplete    0.0624               0               0            0
# 56        unsafe-pgd    0.0523               0               0            0
# 57              safe    2.2450               0               0            0
# 58        unsafe-pgd    0.0658               0               0            0
# 59   safe-incomplete    0.0481               0               0            0
# 60   safe-incomplete    0.0625               0               0            0
# 61        unsafe-pgd    0.0432               0               0            0
# 62   safe-incomplete    0.0312               0               0            0
# 63        unsafe-pgd    0.0455               0               0            0
# 64           unknown  212.7077          669133               0            0
# 65        unsafe-pgd    0.0721               0               0            0
# 66        unsafe-pgd    0.0707               0               0            0
# 67           unknown  217.0129          812736               0            0
# 68   safe-incomplete    0.0655               0               0            0
# 69   safe-incomplete    0.0652               0               0            0
# 70   safe-incomplete    0.0263               0               0            0
# 71   safe-incomplete    0.0589               0               0            0
# 72        unsafe-pgd    0.0617               0               0            0
# 73   safe-incomplete    0.0304               0               0            0
# 74   safe-incomplete    0.0625               0               0            0
# 75   safe-incomplete    0.0582               0               0            0
# 76        unsafe-pgd    0.0706               0               0            0
# 77        unsafe-pgd    0.0519               0               0            0
# 78        unsafe-pgd    0.0588               0               0            0
# 79   safe-incomplete    0.0504               0               0            0
# 80        unsafe-pgd    0.0440               0               0            0
# 81   safe-incomplete    0.0437               0               0            0
# 82        unsafe-pgd    0.0481               0               0            0
# 83   safe-incomplete    0.0334               0               0            0
# 84        unsafe-pgd    0.0749               0               0            0
# 85   safe-incomplete    0.0589               0               0            0
# 86   safe-incomplete    0.0441               0               0            0
# 87        unsafe-pgd    0.0703               0               0            0
# 88        unsafe-pgd    0.0402               0               0            0
# 89        unsafe-pgd    0.0543               0               0            0
# 90        unsafe-pgd    0.0588               0               0            0
# 91   safe-incomplete    0.0623               0               0            0
# 92   safe-incomplete    0.0460               0               0            0
# 93   safe-incomplete    0.0498               0               0            0
# 94        unsafe-pgd    0.0639               0               0            0
# 95        unsafe-pgd    0.0627               0               0            0
# 96        unsafe-pgd    0.0314               0               0            0
# 97           unknown  209.8011          727506               0            0
# 98        unsafe-pgd    0.0762               0               0            0
# 99   safe-incomplete    0.0453               0               0            0
# 100       unsafe-pgd    0.0529               0               0            0
# 101       unsafe-pgd    0.0478               0               0            0
# 102       unsafe-pgd    0.0718               0               0            0
# 103  safe-incomplete    0.0618               0               0            0
# 104       unsafe-pgd    0.0517               0               0            0
# 105       unsafe-pgd    0.0775               0               0            0
# 106       unsafe-pgd    0.0667               0               0            0
# 107  safe-incomplete    0.0636               0               0            0
# 108       unsafe-pgd    0.0721               0               0            0
# 109  safe-incomplete    0.0647               0               0            0
# 110  safe-incomplete    0.0431               0               0            0
# 111  safe-incomplete    0.0657               0               0            0
# 112  safe-incomplete    0.0319               0               0            0
# 113       unsafe-pgd    0.0570               0               0            0
# 114  safe-incomplete    0.0518               0               0            0
# 115  safe-incomplete    0.0604               0               0            0
# 116  safe-incomplete    0.0456               0               0            0
# 117  safe-incomplete    0.0548               0               0            0
# 118  safe-incomplete    0.0365               0               0            0
# 119       unsafe-pgd    0.0725               0               0            0
# 120       unsafe-pgd    0.0698               0               0            0
# 121  safe-incomplete    0.0618               0               0            0
# 122       unsafe-pgd    0.0409               0               0            0
# 123             safe   45.2908          133583               0            0
# 124       unsafe-pgd    0.0815               0               0            0
# 125       unsafe-pgd    0.0730               0               0            0
# 126       unsafe-pgd    0.0410               0               0            0
# 127       unsafe-pgd    0.0796               0               0            0
# 128             safe    3.4424             282               0            0
# 129       unsafe-pgd    0.0821               0               0            0
# 130       unsafe-pgd    0.0826               0               0            0
# 131  safe-incomplete    0.0646               0               0            0
# 132       unsafe-pgd    0.0719               0               0            0
# 133  safe-incomplete    0.0650               0               0            0
# 134       unsafe-pgd    0.0541               0               0            0
# 135  safe-incomplete    0.0585               0               0            0
# 136  safe-incomplete    0.0473               0               0            0
# 137             safe    2.3288               0               0            0
# 138  safe-incomplete    0.0523               0               0            0
# 139  safe-incomplete    0.0727               0               0            0
# 140  safe-incomplete    0.0551               0               0            0
# 141       unsafe-pgd    0.0722               0               0            0
# 142  safe-incomplete    0.0638               0               0            0
# 143       unsafe-pgd    0.0685               0               0            0
# 144  safe-incomplete    0.0652               0               0            0
# 145       unsafe-pgd    0.0572               0               0            0
# 146  safe-incomplete    0.0635               0               0            0
# 147  safe-incomplete    0.0596               0               0            0
# 148       unsafe-pgd    0.0742               0               0            0
# 149       unsafe-pgd    0.0552               0               0            0
# 150       unsafe-pgd    0.0720               0               0            0
# 151       unsafe-pgd    0.0429               0               0            0
# 152       unsafe-pgd    0.0561               0               0            0
# 153  safe-incomplete    0.0621               0               0            0
# 154  safe-incomplete    0.0655               0               0            0
# 155       unsafe-pgd    0.0713               0               0            0
# 156       unsafe-pgd    0.0615               0               0            0
# 157  safe-incomplete    0.0485               0               0            0
# 158       unsafe-pgd    0.0723               0               0            0
# 159             safe    2.3541               0               0            0
# 160  safe-incomplete    0.0727               0               0            0
# 161  safe-incomplete    0.0645               0               0            0
# 162  safe-incomplete    0.3065               0               0            0
# 163       unsafe-pgd    0.0669               0               0            0
# 164  safe-incomplete    0.0665               0               0            0
# 165       unsafe-pgd    0.0604               0               0            0
# 166  safe-incomplete    0.0516               0               0            0
# 167       unsafe-pgd    0.0499               0               0            0
# 168  safe-incomplete    0.0652               0               0            0
# 169             safe    2.4279               0               0            0
# 170       unsafe-pgd    0.0822               0               0            0
# 171  safe-incomplete    0.0615               0               0            0
# 172       unsafe-pgd    0.0621               0               0            0
# 173       unsafe-pgd    0.0775               0               0            0
# 174       unsafe-pgd    0.0699               0               0            0
# 175  safe-incomplete    0.0673               0               0            0
# 176       unsafe-pgd    0.0709               0               0            0
# 177  safe-incomplete    0.0667               0               0            0
# 178          unknown  214.5667          719980               0            0
# 179  safe-incomplete    0.0486               0               0            0
# 180  safe-incomplete    0.0678               0               0            0
# 181          unknown  205.7041          611228               0            0
# 182  safe-incomplete    0.0770               0               0            0
# 183             safe    2.4642               0               0            0
# 184       unsafe-pgd    0.0754               0               0            0
# 185       unsafe-pgd    0.0788               0               0            0
# 186  safe-incomplete    0.0649               0               0            0
# 187       unsafe-pgd    0.0394               0               0            0
# 188             safe    2.3883               0               0            0
# 189       unsafe-pgd    0.0701               0               0            0
# 190  safe-incomplete    0.0535               0               0            0
# 191       unsafe-pgd    0.0740               0               0            0
# 192       unsafe-pgd    0.0511               0               0            0
# 193       unsafe-pgd    0.0461               0               0            0
# 194       unsafe-pgd    0.0711               0               0            0
# 195       unsafe-pgd    0.0664               0               0            0
# 196       unsafe-pgd    0.0729               0               0            0
# 197  safe-incomplete    0.0637               0               0            0
# 198  safe-incomplete    0.0650               0               0            0
# 199       unsafe-pgd    0.0559               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 1         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                28   -0.016769
# 53                 0         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                 1         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                22   -0.021576
# 65                 0         NaN
# 66                 0         NaN
# 67                21   -0.050354
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                21   -0.045002
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123               36         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                5         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                1         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                1         NaN
# 160                0         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                1         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178               23   -0.029598
# 179                0         NaN
# 180                0         NaN
# 181               42   -0.011158
# 182                0         NaN
# 183                1         NaN
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187                0         NaN
# 188                1         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe                9    7.546933   14873.888889            0.0         0.0
# safe-incomplete    84    0.055592       0.000000            0.0         0.0
# unknown             6  210.478767  696872.666667            0.0         0.0
# unsafe-pgd        101    0.090594       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                   5.333333
# safe-incomplete        0.000000
# unknown               26.166667
# unsafe-pgd             0.000000
# safe number 93.0
# safe time 0.7805602150537635
# safe domain 1439.4086021505377
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((93.0, 0.7805602150537635, 14873.888888888889, 0.0),)

# %%
main('cifar_cnn_a_adv4/biccos_only_cs.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24    safe   5.8359               0               1          256
# 52    safe  28.1921           29268             308        19720
# 57    safe   2.6432               0               1          256
# 64    safe   9.6194            6195             123         3222
# 123   safe  17.3450           16230             274        10624
# 128   safe   5.2362             346              83         1078
# 137   safe   2.6983              50               4          656
# 159   safe   2.5030               0               1          256
# 169   safe   3.1983             100              49          638
# 181   safe  33.2071           41737             720        17347
# 183   safe   2.9258              50               4          256
# 188   safe   2.7057              50               5          656
#
#      BaB Round Count  BaB_lb_rhs
# 24                 2         NaN
# 52                19         NaN
# 57                 2         NaN
# 64                12         NaN
# 123               19         NaN
# 128                9         NaN
# 137                3         NaN
# 159                2         NaN
# 169                4         NaN
# 181               17         NaN
# 183                3         NaN
# 188                3         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 67   unknown  213.1656          448299             398        10719
# 97   unknown  219.3749          530050              67        12428
# 178  unknown  218.1318          467386             852        30325
#
#      BaB Round Count  BaB_lb_rhs
# 67                20   -0.046194
# 97                23   -0.044284
# 178               21   -0.025846
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    2.2980               0               0            0
# 1         unsafe-pgd    0.0910               0               0            0
# 2    safe-incomplete    0.0750               0               0            0
# 3         unsafe-pgd    0.0712               0               0            0
# 4         unsafe-pgd    0.0543               0               0            0
# 5         unsafe-pgd    0.0759               0               0            0
# 6         unsafe-pgd    0.0737               0               0            0
# 7    safe-incomplete    0.0795               0               0            0
# 8    safe-incomplete    0.0720               0               0            0
# 9         unsafe-pgd    0.1215               0               0            0
# 10        unsafe-pgd    0.0848               0               0            0
# 11        unsafe-pgd    0.0835               0               0            0
# 12        unsafe-pgd    0.4733               0               0            0
# 13        unsafe-pgd    0.0940               0               0            0
# 14   safe-incomplete    0.0591               0               0            0
# 15   safe-incomplete    0.0659               0               0            0
# 16        unsafe-pgd    0.0716               0               0            0
# 17   safe-incomplete    0.0868               0               0            0
# 18   safe-incomplete    0.0673               0               0            0
# 19        unsafe-pgd    0.0694               0               0            0
# 20   safe-incomplete    0.0732               0               0            0
# 21        unsafe-pgd    0.0725               0               0            0
# 22   safe-incomplete    0.0679               0               0            0
# 23        unsafe-pgd    0.0716               0               0            0
# 24              safe    5.8359               0               1          256
# 25        unsafe-pgd    0.0751               0               0            0
# 26        unsafe-pgd    0.0841               0               0            0
# 27   safe-incomplete    0.0680               0               0            0
# 28   safe-incomplete    0.0970               0               0            0
# 29        unsafe-pgd    0.0795               0               0            0
# 30   safe-incomplete    0.0647               0               0            0
# 31   safe-incomplete    0.0663               0               0            0
# 32        unsafe-pgd    0.0906               0               0            0
# 33   safe-incomplete    0.0823               0               0            0
# 34        unsafe-pgd    0.0551               0               0            0
# 35        unsafe-pgd    0.0862               0               0            0
# 36        unsafe-pgd    0.0654               0               0            0
# 37        unsafe-pgd    0.0427               0               0            0
# 38   safe-incomplete    0.0680               0               0            0
# 39   safe-incomplete    0.0701               0               0            0
# 40   safe-incomplete    0.0720               0               0            0
# 41   safe-incomplete    0.0812               0               0            0
# 42   safe-incomplete    0.0618               0               0            0
# 43        unsafe-pgd    0.0867               0               0            0
# 44        unsafe-pgd    0.0754               0               0            0
# 45        unsafe-pgd    0.0892               0               0            0
# 46        unsafe-pgd    0.0793               0               0            0
# 47   safe-incomplete    0.0675               0               0            0
# 48        unsafe-pgd    0.0601               0               0            0
# 49   safe-incomplete    0.0628               0               0            0
# 50        unsafe-pgd    0.0810               0               0            0
# 51   safe-incomplete    0.0222               0               0            0
# 52              safe   28.1921           29268             308        19720
# 53        unsafe-pgd    0.0948               0               0            0
# 54        unsafe-pgd    0.1096               0               0            0
# 55   safe-incomplete    0.1235               0               0            0
# 56        unsafe-pgd    0.1285               0               0            0
# 57              safe    2.6432               0               1          256
# 58        unsafe-pgd    0.1146               0               0            0
# 59   safe-incomplete    0.0326               0               0            0
# 60   safe-incomplete    0.0684               0               0            0
# 61        unsafe-pgd    0.0937               0               0            0
# 62   safe-incomplete    0.0644               0               0            0
# 63        unsafe-pgd    0.0981               0               0            0
# 64              safe    9.6194            6195             123         3222
# 65        unsafe-pgd    0.0892               0               0            0
# 66        unsafe-pgd    0.0749               0               0            0
# 67           unknown  213.1656          448299             398        10719
# 68   safe-incomplete    0.0809               0               0            0
# 69   safe-incomplete    0.0410               0               0            0
# 70   safe-incomplete    0.0773               0               0            0
# 71   safe-incomplete    0.0685               0               0            0
# 72        unsafe-pgd    0.0453               0               0            0
# 73   safe-incomplete    0.0635               0               0            0
# 74   safe-incomplete    0.0696               0               0            0
# 75   safe-incomplete    0.0674               0               0            0
# 76        unsafe-pgd    0.0640               0               0            0
# 77        unsafe-pgd    0.0403               0               0            0
# 78        unsafe-pgd    0.0847               0               0            0
# 79   safe-incomplete    0.0455               0               0            0
# 80        unsafe-pgd    0.0761               0               0            0
# 81   safe-incomplete    0.0661               0               0            0
# 82        unsafe-pgd    0.0473               0               0            0
# 83   safe-incomplete    0.0645               0               0            0
# 84        unsafe-pgd    0.0804               0               0            0
# 85   safe-incomplete    0.0647               0               0            0
# 86   safe-incomplete    0.0682               0               0            0
# 87        unsafe-pgd    0.0741               0               0            0
# 88        unsafe-pgd    0.0739               0               0            0
# 89        unsafe-pgd    0.0598               0               0            0
# 90        unsafe-pgd    0.0606               0               0            0
# 91   safe-incomplete    0.0644               0               0            0
# 92   safe-incomplete    0.0612               0               0            0
# 93   safe-incomplete    0.0470               0               0            0
# 94        unsafe-pgd    0.0562               0               0            0
# 95        unsafe-pgd    0.0720               0               0            0
# 96        unsafe-pgd    0.0719               0               0            0
# 97           unknown  219.3749          530050              67        12428
# 98        unsafe-pgd    0.0847               0               0            0
# 99   safe-incomplete    0.0704               0               0            0
# 100       unsafe-pgd    0.0734               0               0            0
# 101       unsafe-pgd    0.0759               0               0            0
# 102       unsafe-pgd    0.0739               0               0            0
# 103  safe-incomplete    0.0731               0               0            0
# 104       unsafe-pgd    0.0778               0               0            0
# 105       unsafe-pgd    0.0815               0               0            0
# 106       unsafe-pgd    0.0724               0               0            0
# 107  safe-incomplete    0.0897               0               0            0
# 108       unsafe-pgd    0.0743               0               0            0
# 109  safe-incomplete    0.0661               0               0            0
# 110  safe-incomplete    0.0569               0               0            0
# 111  safe-incomplete    0.0660               0               0            0
# 112  safe-incomplete    0.0705               0               0            0
# 113       unsafe-pgd    0.0391               0               0            0
# 114  safe-incomplete    0.0629               0               0            0
# 115  safe-incomplete    0.0721               0               0            0
# 116  safe-incomplete    0.0541               0               0            0
# 117  safe-incomplete    0.0640               0               0            0
# 118  safe-incomplete    0.0643               0               0            0
# 119       unsafe-pgd    0.0838               0               0            0
# 120       unsafe-pgd    0.0844               0               0            0
# 121  safe-incomplete    0.0696               0               0            0
# 122       unsafe-pgd    0.0709               0               0            0
# 123             safe   17.3450           16230             274        10624
# 124       unsafe-pgd    0.0856               0               0            0
# 125       unsafe-pgd    0.0801               0               0            0
# 126       unsafe-pgd    0.0462               0               0            0
# 127       unsafe-pgd    0.0782               0               0            0
# 128             safe    5.2362             346              83         1078
# 129       unsafe-pgd    0.0646               0               0            0
# 130       unsafe-pgd    0.0763               0               0            0
# 131  safe-incomplete    0.0652               0               0            0
# 132       unsafe-pgd    0.0702               0               0            0
# 133  safe-incomplete    0.0709               0               0            0
# 134       unsafe-pgd    0.0379               0               0            0
# 135  safe-incomplete    0.0596               0               0            0
# 136  safe-incomplete    0.0679               0               0            0
# 137             safe    2.6983              50               4          656
# 138  safe-incomplete    0.0667               0               0            0
# 139  safe-incomplete    0.0743               0               0            0
# 140  safe-incomplete    0.0622               0               0            0
# 141       unsafe-pgd    0.0725               0               0            0
# 142  safe-incomplete    0.0651               0               0            0
# 143       unsafe-pgd    0.0733               0               0            0
# 144  safe-incomplete    0.0670               0               0            0
# 145       unsafe-pgd    0.0742               0               0            0
# 146  safe-incomplete    0.0674               0               0            0
# 147  safe-incomplete    0.0645               0               0            0
# 148       unsafe-pgd    0.0827               0               0            0
# 149       unsafe-pgd    0.0454               0               0            0
# 150       unsafe-pgd    0.0763               0               0            0
# 151       unsafe-pgd    0.0724               0               0            0
# 152       unsafe-pgd    0.0715               0               0            0
# 153  safe-incomplete    0.0631               0               0            0
# 154  safe-incomplete    0.0651               0               0            0
# 155       unsafe-pgd    0.0816               0               0            0
# 156       unsafe-pgd    0.0753               0               0            0
# 157  safe-incomplete    0.0519               0               0            0
# 158       unsafe-pgd    0.0714               0               0            0
# 159             safe    2.5030               0               1          256
# 160  safe-incomplete    0.0664               0               0            0
# 161  safe-incomplete    0.0626               0               0            0
# 162  safe-incomplete    0.3489               0               0            0
# 163       unsafe-pgd    0.0814               0               0            0
# 164  safe-incomplete    0.0316               0               0            0
# 165       unsafe-pgd    0.1224               0               0            0
# 166  safe-incomplete    0.1197               0               0            0
# 167       unsafe-pgd    0.0746               0               0            0
# 168  safe-incomplete    0.0492               0               0            0
# 169             safe    3.1983             100              49          638
# 170       unsafe-pgd    0.0773               0               0            0
# 171  safe-incomplete    0.0882               0               0            0
# 172       unsafe-pgd    0.0702               0               0            0
# 173       unsafe-pgd    0.0810               0               0            0
# 174       unsafe-pgd    0.0834               0               0            0
# 175  safe-incomplete    0.0681               0               0            0
# 176       unsafe-pgd    0.0906               0               0            0
# 177  safe-incomplete    0.0600               0               0            0
# 178          unknown  218.1318          467386             852        30325
# 179  safe-incomplete    0.0799               0               0            0
# 180  safe-incomplete    0.0751               0               0            0
# 181             safe   33.2071           41737             720        17347
# 182  safe-incomplete    0.0724               0               0            0
# 183             safe    2.9258              50               4          256
# 184       unsafe-pgd    0.0730               0               0            0
# 185       unsafe-pgd    0.0808               0               0            0
# 186  safe-incomplete    0.0630               0               0            0
# 187       unsafe-pgd    0.0731               0               0            0
# 188             safe    2.7057              50               5          656
# 189       unsafe-pgd    0.0765               0               0            0
# 190  safe-incomplete    0.0665               0               0            0
# 191       unsafe-pgd    0.0768               0               0            0
# 192       unsafe-pgd    0.0791               0               0            0
# 193       unsafe-pgd    0.0721               0               0            0
# 194       unsafe-pgd    0.0541               0               0            0
# 195       unsafe-pgd    0.0744               0               0            0
# 196       unsafe-pgd    0.0736               0               0            0
# 197  safe-incomplete    0.0658               0               0            0
# 198  safe-incomplete    0.0622               0               0            0
# 199       unsafe-pgd    0.0757               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 2         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                19         NaN
# 53                 0         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                 2         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                12         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                20   -0.046194
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                23   -0.044284
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123               19         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                9         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                3         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                2         NaN
# 160                0         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                4         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178               21   -0.025846
# 179                0         NaN
# 180                0         NaN
# 181               17         NaN
# 182                0         NaN
# 183                3         NaN
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187                0         NaN
# 188                3         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                0         NaN
# #Cuts 2890
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               12    9.675833    7835.500000     131.083333   4580.416667
# safe-incomplete    84    0.070708       0.000000       0.000000      0.000000
# unknown             3  216.890767  481911.666667     439.000000  17824.000000
# unsafe-pgd        101    0.101828       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                   7.916667
# safe-incomplete        0.000000
# unknown               21.333333
# unsafe-pgd             0.000000
# safe number 96.0
# safe time 1.2713489583333333
# safe domain 979.4375
# safe cut 16.385416666666668
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((96.0, 1.2713489583333333, 7835.5, 131.08333333333334),)

# %%
main('cifar_cnn_a_adv4/biccos_all.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24    safe   5.3146               0               1            3
# 52    safe  25.6757           25713             314        16290
# 57    safe   2.4374               0               1           41
# 123   safe  16.3231           14574             373         9087
# 128   safe   5.5706             327              64         1062
# 137   safe   2.5783              50               3          400
# 159   safe   2.4294               0               1           18
# 169   safe   3.1060             100              52          378
# 181   safe  34.7330           41316             635        17189
# 183   safe   2.8005              50               4          139
# 188   safe   2.7262              50               5          400
#
#      BaB Round Count  BaB_lb_rhs
# 24                 1         NaN
# 52                20         NaN
# 57                 1         NaN
# 123               18         NaN
# 128                9         NaN
# 137                2         NaN
# 159                1         NaN
# 169                3         NaN
# 181               18         NaN
# 183                2         NaN
# 188                2         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 64   unknown  223.3458          434556             106        41701
# 67   unknown  229.1438          508391             825        30500
# 97   unknown  217.6086          512450             259        14228
# 178  unknown  212.0653          465237             933        31031
#
#      BaB Round Count  BaB_lb_rhs
# 64                29   -0.018347
# 67                22   -0.047034
# 97                22   -0.045076
# 178               23   -0.025612
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    1.1907               0               0            0
# 1         unsafe-pgd    0.0778               0               0            0
# 2    safe-incomplete    0.0687               0               0            0
# 3         unsafe-pgd    0.0781               0               0            0
# 4         unsafe-pgd    0.0695               0               0            0
# 5         unsafe-pgd    0.0899               0               0            0
# 6         unsafe-pgd    0.0907               0               0            0
# 7    safe-incomplete    0.0390               0               0            0
# 8    safe-incomplete    0.0723               0               0            0
# 9         unsafe-pgd    0.0850               0               0            0
# 10        unsafe-pgd    0.0721               0               0            0
# 11        unsafe-pgd    0.0764               0               0            0
# 12        unsafe-pgd    0.3518               0               0            0
# 13        unsafe-pgd    0.0711               0               0            0
# 14   safe-incomplete    0.0678               0               0            0
# 15   safe-incomplete    0.0654               0               0            0
# 16        unsafe-pgd    0.0738               0               0            0
# 17   safe-incomplete    0.0678               0               0            0
# 18   safe-incomplete    0.0653               0               0            0
# 19        unsafe-pgd    0.0738               0               0            0
# 20   safe-incomplete    0.0647               0               0            0
# 21        unsafe-pgd    0.0707               0               0            0
# 22   safe-incomplete    0.0694               0               0            0
# 23        unsafe-pgd    0.0698               0               0            0
# 24              safe    5.3146               0               1            3
# 25        unsafe-pgd    0.0837               0               0            0
# 26        unsafe-pgd    0.0762               0               0            0
# 27   safe-incomplete    0.0696               0               0            0
# 28   safe-incomplete    0.0661               0               0            0
# 29        unsafe-pgd    0.0775               0               0            0
# 30   safe-incomplete    0.0651               0               0            0
# 31   safe-incomplete    0.0618               0               0            0
# 32        unsafe-pgd    0.0705               0               0            0
# 33   safe-incomplete    0.0672               0               0            0
# 34        unsafe-pgd    0.0742               0               0            0
# 35        unsafe-pgd    0.0745               0               0            0
# 36        unsafe-pgd    0.0818               0               0            0
# 37        unsafe-pgd    0.0598               0               0            0
# 38   safe-incomplete    0.0676               0               0            0
# 39   safe-incomplete    0.0648               0               0            0
# 40   safe-incomplete    0.0636               0               0            0
# 41   safe-incomplete    0.0294               0               0            0
# 42   safe-incomplete    0.0685               0               0            0
# 43        unsafe-pgd    0.0755               0               0            0
# 44        unsafe-pgd    0.0740               0               0            0
# 45        unsafe-pgd    0.0847               0               0            0
# 46        unsafe-pgd    0.0696               0               0            0
# 47   safe-incomplete    0.0651               0               0            0
# 48        unsafe-pgd    0.0677               0               0            0
# 49   safe-incomplete    0.0652               0               0            0
# 50        unsafe-pgd    0.0815               0               0            0
# 51   safe-incomplete    0.0654               0               0            0
# 52              safe   25.6757           25713             314        16290
# 53        unsafe-pgd    0.0884               0               0            0
# 54        unsafe-pgd    0.0916               0               0            0
# 55   safe-incomplete    0.0771               0               0            0
# 56        unsafe-pgd    0.0707               0               0            0
# 57              safe    2.4374               0               1           41
# 58        unsafe-pgd    0.0824               0               0            0
# 59   safe-incomplete    0.0635               0               0            0
# 60   safe-incomplete    0.0657               0               0            0
# 61        unsafe-pgd    0.0786               0               0            0
# 62   safe-incomplete    0.0834               0               0            0
# 63        unsafe-pgd    0.0802               0               0            0
# 64           unknown  223.3458          434556             106        41701
# 65        unsafe-pgd    0.0843               0               0            0
# 66        unsafe-pgd    0.0843               0               0            0
# 67           unknown  229.1438          508391             825        30500
# 68   safe-incomplete    0.0677               0               0            0
# 69   safe-incomplete    0.0683               0               0            0
# 70   safe-incomplete    0.0623               0               0            0
# 71   safe-incomplete    0.0695               0               0            0
# 72        unsafe-pgd    0.0802               0               0            0
# 73   safe-incomplete    0.0652               0               0            0
# 74   safe-incomplete    0.0664               0               0            0
# 75   safe-incomplete    0.0680               0               0            0
# 76        unsafe-pgd    0.0742               0               0            0
# 77        unsafe-pgd    0.0736               0               0            0
# 78        unsafe-pgd    0.0753               0               0            0
# 79   safe-incomplete    0.0656               0               0            0
# 80        unsafe-pgd    0.0766               0               0            0
# 81   safe-incomplete    0.0658               0               0            0
# 82        unsafe-pgd    0.0768               0               0            0
# 83   safe-incomplete    0.0623               0               0            0
# 84        unsafe-pgd    0.0816               0               0            0
# 85   safe-incomplete    0.0621               0               0            0
# 86   safe-incomplete    0.0637               0               0            0
# 87        unsafe-pgd    0.0757               0               0            0
# 88        unsafe-pgd    0.0417               0               0            0
# 89        unsafe-pgd    0.0791               0               0            0
# 90        unsafe-pgd    0.0697               0               0            0
# 91   safe-incomplete    0.0696               0               0            0
# 92   safe-incomplete    0.0699               0               0            0
# 93   safe-incomplete    0.0748               0               0            0
# 94        unsafe-pgd    0.0767               0               0            0
# 95        unsafe-pgd    0.0803               0               0            0
# 96        unsafe-pgd    0.0782               0               0            0
# 97           unknown  217.6086          512450             259        14228
# 98        unsafe-pgd    0.1658               0               0            0
# 99   safe-incomplete    0.0906               0               0            0
# 100       unsafe-pgd    0.0937               0               0            0
# 101       unsafe-pgd    0.0709               0               0            0
# 102       unsafe-pgd    0.0797               0               0            0
# 103  safe-incomplete    0.0850               0               0            0
# 104       unsafe-pgd    0.0775               0               0            0
# 105       unsafe-pgd    0.0799               0               0            0
# 106       unsafe-pgd    0.0735               0               0            0
# 107  safe-incomplete    0.0609               0               0            0
# 108       unsafe-pgd    0.0721               0               0            0
# 109  safe-incomplete    0.0674               0               0            0
# 110  safe-incomplete    0.0660               0               0            0
# 111  safe-incomplete    0.0699               0               0            0
# 112  safe-incomplete    0.0680               0               0            0
# 113       unsafe-pgd    0.0640               0               0            0
# 114  safe-incomplete    0.0676               0               0            0
# 115  safe-incomplete    0.0663               0               0            0
# 116  safe-incomplete    0.0586               0               0            0
# 117  safe-incomplete    0.0648               0               0            0
# 118  safe-incomplete    0.0622               0               0            0
# 119       unsafe-pgd    0.0984               0               0            0
# 120       unsafe-pgd    0.0838               0               0            0
# 121  safe-incomplete    0.0790               0               0            0
# 122       unsafe-pgd    0.0702               0               0            0
# 123             safe   16.3231           14574             373         9087
# 124       unsafe-pgd    0.1100               0               0            0
# 125       unsafe-pgd    0.0769               0               0            0
# 126       unsafe-pgd    0.0737               0               0            0
# 127       unsafe-pgd    0.0818               0               0            0
# 128             safe    5.5706             327              64         1062
# 129       unsafe-pgd    0.0841               0               0            0
# 130       unsafe-pgd    0.0745               0               0            0
# 131  safe-incomplete    0.0668               0               0            0
# 132       unsafe-pgd    0.0760               0               0            0
# 133  safe-incomplete    0.0700               0               0            0
# 134       unsafe-pgd    0.0749               0               0            0
# 135  safe-incomplete    0.0670               0               0            0
# 136  safe-incomplete    0.0632               0               0            0
# 137             safe    2.5783              50               3          400
# 138  safe-incomplete    0.0657               0               0            0
# 139  safe-incomplete    0.0684               0               0            0
# 140  safe-incomplete    0.0710               0               0            0
# 141       unsafe-pgd    0.0760               0               0            0
# 142  safe-incomplete    0.0929               0               0            0
# 143       unsafe-pgd    0.0692               0               0            0
# 144  safe-incomplete    0.0705               0               0            0
# 145       unsafe-pgd    0.0755               0               0            0
# 146  safe-incomplete    0.0630               0               0            0
# 147  safe-incomplete    0.0339               0               0            0
# 148       unsafe-pgd    0.0799               0               0            0
# 149       unsafe-pgd    0.0728               0               0            0
# 150       unsafe-pgd    0.0824               0               0            0
# 151       unsafe-pgd    0.0711               0               0            0
# 152       unsafe-pgd    0.0513               0               0            0
# 153  safe-incomplete    0.0641               0               0            0
# 154  safe-incomplete    0.0728               0               0            0
# 155       unsafe-pgd    0.0827               0               0            0
# 156       unsafe-pgd    0.0714               0               0            0
# 157  safe-incomplete    0.0698               0               0            0
# 158       unsafe-pgd    0.0697               0               0            0
# 159             safe    2.4294               0               1           18
# 160  safe-incomplete    0.0747               0               0            0
# 161  safe-incomplete    0.0612               0               0            0
# 162  safe-incomplete    0.3304               0               0            0
# 163       unsafe-pgd    0.0934               0               0            0
# 164  safe-incomplete    0.0616               0               0            0
# 165       unsafe-pgd    0.0996               0               0            0
# 166  safe-incomplete    0.0722               0               0            0
# 167       unsafe-pgd    0.0763               0               0            0
# 168  safe-incomplete    0.0774               0               0            0
# 169             safe    3.1060             100              52          378
# 170       unsafe-pgd    0.0740               0               0            0
# 171  safe-incomplete    0.0615               0               0            0
# 172       unsafe-pgd    0.0713               0               0            0
# 173       unsafe-pgd    0.0856               0               0            0
# 174       unsafe-pgd    0.0858               0               0            0
# 175  safe-incomplete    0.0697               0               0            0
# 176       unsafe-pgd    0.0732               0               0            0
# 177  safe-incomplete    0.0683               0               0            0
# 178          unknown  212.0653          465237             933        31031
# 179  safe-incomplete    0.0727               0               0            0
# 180  safe-incomplete    0.0710               0               0            0
# 181             safe   34.7330           41316             635        17189
# 182  safe-incomplete    0.0709               0               0            0
# 183             safe    2.8005              50               4          139
# 184       unsafe-pgd    0.0783               0               0            0
# 185       unsafe-pgd    0.1000               0               0            0
# 186  safe-incomplete    0.0658               0               0            0
# 187       unsafe-pgd    0.1040               0               0            0
# 188             safe    2.7262              50               5          400
# 189       unsafe-pgd    0.0860               0               0            0
# 190  safe-incomplete    0.0690               0               0            0
# 191       unsafe-pgd    0.0884               0               0            0
# 192       unsafe-pgd    0.0768               0               0            0
# 193       unsafe-pgd    0.0708               0               0            0
# 194       unsafe-pgd    0.0741               0               0            0
# 195       unsafe-pgd    0.0847               0               0            0
# 196       unsafe-pgd    0.0784               0               0            0
# 197  safe-incomplete    0.0735               0               0            0
# 198  safe-incomplete    0.0602               0               0            0
# 199       unsafe-pgd    0.0769               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 1         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                20         NaN
# 53                 0         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                 1         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                29   -0.018347
# 65                 0         NaN
# 66                 0         NaN
# 67                22   -0.047034
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                22   -0.045076
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123               18         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                9         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                2         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                1         NaN
# 160                0         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                3         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178               23   -0.025612
# 179                0         NaN
# 180                0         NaN
# 181               18         NaN
# 182                0         NaN
# 183                2         NaN
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187                0         NaN
# 188                2         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                0         NaN
# #Cuts 3576
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               11    9.426800    7470.909091     132.090909   4091.545455
# safe-incomplete    84    0.070193       0.000000       0.000000      0.000000
# unknown             4  220.540875  480158.500000     530.750000  29365.000000
# unsafe-pgd        101    0.092610       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                        7.0
# safe-incomplete             0.0
# unknown                    24.0
# unsafe-pgd                  0.0
# safe number 95.0
# safe time 1.1535894736842105
# safe domain 865.0526315789474
# safe cut 15.294736842105262
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((95.0, 1.1535894736842105, 7470.909090909091, 132.0909090909091),)

# %%
main('cifar_cnn_a_adv4/gcp.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24    safe   5.3958               0               0            0
# 52    safe  28.7735           58752               0            0
# 57    safe   2.8141               0               0            0
# 64    safe  33.6220           51340               0            0
# 123   safe  24.0327           35261               0            0
# 128   safe   4.2128             282               0            0
# 137   safe   3.0059               0               0            0
# 159   safe   2.9590               0               0            0
# 169   safe   3.2859               0               0            0
# 178   safe  22.4324           38128               0            0
# 183   safe   3.0707               0               0            0
# 188   safe   3.0309               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 24                 1         NaN
# 52                16         NaN
# 57                 1         NaN
# 64                22         NaN
# 123               24         NaN
# 128                5         NaN
# 137                1         NaN
# 159                1         NaN
# 169                1         NaN
# 178               11         NaN
# 183                1         NaN
# 188                1         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 67   unknown  220.2497          425586               0            0
# 97   unknown  219.4081          397138               0            0
# 181  unknown  225.4445          377553               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 67                15   -0.034495
# 97                16   -0.044174
# 181               22   -0.007143
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    1.1445               0               0            0
# 1         unsafe-pgd    0.0791               0               0            0
# 2    safe-incomplete    0.0685               0               0            0
# 3         unsafe-pgd    0.0702               0               0            0
# 4         unsafe-pgd    0.0674               0               0            0
# 5         unsafe-pgd    0.0746               0               0            0
# 6         unsafe-pgd    0.0727               0               0            0
# 7    safe-incomplete    0.0488               0               0            0
# 8    safe-incomplete    0.0535               0               0            0
# 9         unsafe-pgd    0.0699               0               0            0
# 10        unsafe-pgd    0.0745               0               0            0
# 11        unsafe-pgd    0.0695               0               0            0
# 12        unsafe-pgd    0.2985               0               0            0
# 13        unsafe-pgd    0.0480               0               0            0
# 14   safe-incomplete    0.0638               0               0            0
# 15   safe-incomplete    0.0651               0               0            0
# 16        unsafe-pgd    0.0621               0               0            0
# 17   safe-incomplete    0.0632               0               0            0
# 18   safe-incomplete    0.0678               0               0            0
# 19        unsafe-pgd    0.0371               0               0            0
# 20   safe-incomplete    0.0770               0               0            0
# 21        unsafe-pgd    0.0524               0               0            0
# 22   safe-incomplete    0.0643               0               0            0
# 23        unsafe-pgd    0.0752               0               0            0
# 24              safe    5.3958               0               0            0
# 25        unsafe-pgd    0.0920               0               0            0
# 26        unsafe-pgd    0.0839               0               0            0
# 27   safe-incomplete    0.0674               0               0            0
# 28   safe-incomplete    0.0655               0               0            0
# 29        unsafe-pgd    0.0875               0               0            0
# 30   safe-incomplete    0.0640               0               0            0
# 31   safe-incomplete    0.0686               0               0            0
# 32        unsafe-pgd    0.0731               0               0            0
# 33   safe-incomplete    0.0634               0               0            0
# 34        unsafe-pgd    0.0742               0               0            0
# 35        unsafe-pgd    0.0737               0               0            0
# 36        unsafe-pgd    0.0792               0               0            0
# 37        unsafe-pgd    0.0759               0               0            0
# 38   safe-incomplete    0.0619               0               0            0
# 39   safe-incomplete    0.0657               0               0            0
# 40   safe-incomplete    0.0622               0               0            0
# 41   safe-incomplete    0.0723               0               0            0
# 42   safe-incomplete    0.0625               0               0            0
# 43        unsafe-pgd    0.0755               0               0            0
# 44        unsafe-pgd    0.0712               0               0            0
# 45        unsafe-pgd    0.0801               0               0            0
# 46        unsafe-pgd    0.0497               0               0            0
# 47   safe-incomplete    0.0654               0               0            0
# 48        unsafe-pgd    0.0698               0               0            0
# 49   safe-incomplete    0.0753               0               0            0
# 50        unsafe-pgd    0.0776               0               0            0
# 51   safe-incomplete    0.0579               0               0            0
# 52              safe   28.7735           58752               0            0
# 53        unsafe-pgd    0.0844               0               0            0
# 54        unsafe-pgd    0.0807               0               0            0
# 55   safe-incomplete    0.0620               0               0            0
# 56        unsafe-pgd    0.0676               0               0            0
# 57              safe    2.8141               0               0            0
# 58        unsafe-pgd    0.0812               0               0            0
# 59   safe-incomplete    0.0655               0               0            0
# 60   safe-incomplete    0.0634               0               0            0
# 61        unsafe-pgd    0.0727               0               0            0
# 62   safe-incomplete    0.0670               0               0            0
# 63        unsafe-pgd    0.0723               0               0            0
# 64              safe   33.6220           51340               0            0
# 65        unsafe-pgd    0.0832               0               0            0
# 66        unsafe-pgd    0.0577               0               0            0
# 67           unknown  220.2497          425586               0            0
# 68   safe-incomplete    0.0411               0               0            0
# 69   safe-incomplete    0.0727               0               0            0
# 70   safe-incomplete    0.0283               0               0            0
# 71   safe-incomplete    0.0775               0               0            0
# 72        unsafe-pgd    0.0784               0               0            0
# 73   safe-incomplete    0.0688               0               0            0
# 74   safe-incomplete    0.0634               0               0            0
# 75   safe-incomplete    0.0663               0               0            0
# 76        unsafe-pgd    0.0419               0               0            0
# 77        unsafe-pgd    0.0700               0               0            0
# 78        unsafe-pgd    0.0697               0               0            0
# 79   safe-incomplete    0.0657               0               0            0
# 80        unsafe-pgd    0.0738               0               0            0
# 81   safe-incomplete    0.0588               0               0            0
# 82        unsafe-pgd    0.0653               0               0            0
# 83   safe-incomplete    0.0340               0               0            0
# 84        unsafe-pgd    0.0384               0               0            0
# 85   safe-incomplete    0.0616               0               0            0
# 86   safe-incomplete    0.0526               0               0            0
# 87        unsafe-pgd    0.0584               0               0            0
# 88        unsafe-pgd    0.0553               0               0            0
# 89        unsafe-pgd    0.0678               0               0            0
# 90        unsafe-pgd    0.0764               0               0            0
# 91   safe-incomplete    0.0521               0               0            0
# 92   safe-incomplete    0.0612               0               0            0
# 93   safe-incomplete    0.0649               0               0            0
# 94        unsafe-pgd    0.0682               0               0            0
# 95        unsafe-pgd    0.0741               0               0            0
# 96        unsafe-pgd    0.0695               0               0            0
# 97           unknown  219.4081          397138               0            0
# 98        unsafe-pgd    0.1026               0               0            0
# 99   safe-incomplete    0.0337               0               0            0
# 100       unsafe-pgd    0.0657               0               0            0
# 101       unsafe-pgd    0.0326               0               0            0
# 102       unsafe-pgd    0.0449               0               0            0
# 103  safe-incomplete    0.0669               0               0            0
# 104       unsafe-pgd    0.0590               0               0            0
# 105       unsafe-pgd    0.0823               0               0            0
# 106       unsafe-pgd    0.0715               0               0            0
# 107  safe-incomplete    0.0695               0               0            0
# 108       unsafe-pgd    0.0488               0               0            0
# 109  safe-incomplete    0.0457               0               0            0
# 110  safe-incomplete    0.0633               0               0            0
# 111  safe-incomplete    0.0618               0               0            0
# 112  safe-incomplete    0.0632               0               0            0
# 113       unsafe-pgd    0.0665               0               0            0
# 114  safe-incomplete    0.0313               0               0            0
# 115  safe-incomplete    0.0371               0               0            0
# 116  safe-incomplete    0.0519               0               0            0
# 117  safe-incomplete    0.0265               0               0            0
# 118  safe-incomplete    0.0342               0               0            0
# 119       unsafe-pgd    0.0789               0               0            0
# 120       unsafe-pgd    0.0753               0               0            0
# 121  safe-incomplete    0.0299               0               0            0
# 122       unsafe-pgd    0.0669               0               0            0
# 123             safe   24.0327           35261               0            0
# 124       unsafe-pgd    0.0946               0               0            0
# 125       unsafe-pgd    0.0755               0               0            0
# 126       unsafe-pgd    0.0426               0               0            0
# 127       unsafe-pgd    0.0678               0               0            0
# 128             safe    4.2128             282               0            0
# 129       unsafe-pgd    0.1246               0               0            0
# 130       unsafe-pgd    0.0983               0               0            0
# 131  safe-incomplete    0.0756               0               0            0
# 132       unsafe-pgd    0.0548               0               0            0
# 133  safe-incomplete    0.0738               0               0            0
# 134       unsafe-pgd    0.0742               0               0            0
# 135  safe-incomplete    0.0483               0               0            0
# 136  safe-incomplete    0.0700               0               0            0
# 137             safe    3.0059               0               0            0
# 138  safe-incomplete    0.0785               0               0            0
# 139  safe-incomplete    0.0517               0               0            0
# 140  safe-incomplete    0.0491               0               0            0
# 141       unsafe-pgd    0.0545               0               0            0
# 142  safe-incomplete    0.0661               0               0            0
# 143       unsafe-pgd    0.0636               0               0            0
# 144  safe-incomplete    0.0434               0               0            0
# 145       unsafe-pgd    0.1041               0               0            0
# 146  safe-incomplete    0.0409               0               0            0
# 147  safe-incomplete    0.0512               0               0            0
# 148       unsafe-pgd    0.0624               0               0            0
# 149       unsafe-pgd    0.0938               0               0            0
# 150       unsafe-pgd    0.0772               0               0            0
# 151       unsafe-pgd    0.0756               0               0            0
# 152       unsafe-pgd    0.0728               0               0            0
# 153  safe-incomplete    0.0679               0               0            0
# 154  safe-incomplete    0.0490               0               0            0
# 155       unsafe-pgd    0.0644               0               0            0
# 156       unsafe-pgd    0.0694               0               0            0
# 157  safe-incomplete    0.0676               0               0            0
# 158       unsafe-pgd    0.0629               0               0            0
# 159             safe    2.9590               0               0            0
# 160  safe-incomplete    0.0450               0               0            0
# 161  safe-incomplete    0.0783               0               0            0
# 162  safe-incomplete    0.4407               0               0            0
# 163       unsafe-pgd    0.1107               0               0            0
# 164  safe-incomplete    0.0635               0               0            0
# 165       unsafe-pgd    0.0895               0               0            0
# 166  safe-incomplete    0.0901               0               0            0
# 167       unsafe-pgd    0.0867               0               0            0
# 168  safe-incomplete    0.0725               0               0            0
# 169             safe    3.2859               0               0            0
# 170       unsafe-pgd    0.0732               0               0            0
# 171  safe-incomplete    0.0356               0               0            0
# 172       unsafe-pgd    0.0644               0               0            0
# 173       unsafe-pgd    0.0812               0               0            0
# 174       unsafe-pgd    0.0751               0               0            0
# 175  safe-incomplete    0.0716               0               0            0
# 176       unsafe-pgd    0.0780               0               0            0
# 177  safe-incomplete    0.0337               0               0            0
# 178             safe   22.4324           38128               0            0
# 179  safe-incomplete    0.0682               0               0            0
# 180  safe-incomplete    0.0284               0               0            0
# 181          unknown  225.4445          377553               0            0
# 182  safe-incomplete    0.0570               0               0            0
# 183             safe    3.0707               0               0            0
# 184       unsafe-pgd    0.0863               0               0            0
# 185       unsafe-pgd    0.0797               0               0            0
# 186  safe-incomplete    0.0627               0               0            0
# 187       unsafe-pgd    0.0725               0               0            0
# 188             safe    3.0309               0               0            0
# 189       unsafe-pgd    0.0761               0               0            0
# 190  safe-incomplete    0.0630               0               0            0
# 191       unsafe-pgd    0.0409               0               0            0
# 192       unsafe-pgd    0.0735               0               0            0
# 193       unsafe-pgd    0.0396               0               0            0
# 194       unsafe-pgd    0.0521               0               0            0
# 195       unsafe-pgd    0.0679               0               0            0
# 196       unsafe-pgd    0.0952               0               0            0
# 197  safe-incomplete    0.0739               0               0            0
# 198  safe-incomplete    0.0395               0               0            0
# 199       unsafe-pgd    0.0575               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 1         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                16         NaN
# 53                 0         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                 1         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                22         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                15   -0.034495
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                16   -0.044174
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123               24         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                5         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                1         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                1         NaN
# 160                0         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                1         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178               11         NaN
# 179                0         NaN
# 180                0         NaN
# 181               22   -0.007143
# 182                0         NaN
# 183                1         NaN
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187                0         NaN
# 188                1         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               12   11.386308   15313.583333            0.0         0.0
# safe-incomplete    84    0.063367       0.000000            0.0         0.0
# unknown             3  221.700767  400092.333333            0.0         0.0
# unsafe-pgd        101    0.084102       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                   7.083333
# safe-incomplete        0.000000
# unknown               17.666667
# unsafe-pgd             0.000000
# safe number 96.0
# safe time 1.4787343750000002
# safe domain 1914.1979166666667
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((96.0, 1.4787343750000002, 15313.583333333334, 0.0),)

# %%
main('cifar_cnn_a_adv4/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24    safe   6.3103               0               1            3
# 52    safe  15.6585            7025             726         5744
# 57    safe   3.4880               0               1           41
# 64    safe  27.0393           17031            1918        16330
# 123   safe  16.1507            9113             564         6028
# 128   safe   7.6613             330              79         1054
# 137   safe   4.0018              50               3          400
# 159   safe   3.6262               0               1           19
# 169   safe   5.0540             100              42          373
# 178   safe  16.8198            8895            1398         9077
# 181   safe  57.3040           44854            4241        22585
# 183   safe   3.9891              50               4          139
# 188   safe   4.1597              50               5          400
#
#      BaB Round Count  BaB_lb_rhs
# 24                 1         NaN
# 52                16         NaN
# 57                 1         NaN
# 64                26         NaN
# 123               16         NaN
# 128                9         NaN
# 137                2         NaN
# 159                1         NaN
# 169                3         NaN
# 178               15         NaN
# 181               23         NaN
# 183                2         NaN
# 188                2         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 67  unknown  201.6428          309399            7016        22625
# 97  unknown  207.2375          357568            2905         4626
#
#     BaB Round Count  BaB_lb_rhs
# 67               23   -0.029649
# 97               24   -0.029589
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0         unsafe-pgd    1.8280               0               0            0
# 1         unsafe-pgd    0.0811               0               0            0
# 2    safe-incomplete    0.0546               0               0            0
# 3         unsafe-pgd    0.0702               0               0            0
# 4         unsafe-pgd    0.0453               0               0            0
# 5         unsafe-pgd    0.0751               0               0            0
# 6         unsafe-pgd    0.0465               0               0            0
# 7    safe-incomplete    0.0583               0               0            0
# 8    safe-incomplete    0.0627               0               0            0
# 9         unsafe-pgd    0.0782               0               0            0
# 10        unsafe-pgd    0.0425               0               0            0
# 11        unsafe-pgd    0.0547               0               0            0
# 12        unsafe-pgd    0.3892               0               0            0
# 13        unsafe-pgd    0.0383               0               0            0
# 14   safe-incomplete    0.0330               0               0            0
# 15   safe-incomplete    0.0508               0               0            0
# 16        unsafe-pgd    0.0731               0               0            0
# 17   safe-incomplete    0.0618               0               0            0
# 18   safe-incomplete    0.0439               0               0            0
# 19        unsafe-pgd    0.0532               0               0            0
# 20   safe-incomplete    0.0417               0               0            0
# 21        unsafe-pgd    0.0407               0               0            0
# 22   safe-incomplete    0.0564               0               0            0
# 23        unsafe-pgd    0.0485               0               0            0
# 24              safe    6.3103               0               1            3
# 25        unsafe-pgd    0.0832               0               0            0
# 26        unsafe-pgd    0.0695               0               0            0
# 27   safe-incomplete    0.0631               0               0            0
# 28   safe-incomplete    0.0491               0               0            0
# 29        unsafe-pgd    0.0728               0               0            0
# 30   safe-incomplete    0.0474               0               0            0
# 31   safe-incomplete    0.0605               0               0            0
# 32        unsafe-pgd    0.0512               0               0            0
# 33   safe-incomplete    0.0455               0               0            0
# 34        unsafe-pgd    0.0678               0               0            0
# 35        unsafe-pgd    0.0708               0               0            0
# 36        unsafe-pgd    0.0542               0               0            0
# 37        unsafe-pgd    0.0592               0               0            0
# 38   safe-incomplete    0.0469               0               0            0
# 39   safe-incomplete    0.0288               0               0            0
# 40   safe-incomplete    0.0304               0               0            0
# 41   safe-incomplete    0.0626               0               0            0
# 42   safe-incomplete    0.0729               0               0            0
# 43        unsafe-pgd    0.0782               0               0            0
# 44        unsafe-pgd    0.0677               0               0            0
# 45        unsafe-pgd    0.0623               0               0            0
# 46        unsafe-pgd    0.0308               0               0            0
# 47   safe-incomplete    0.0301               0               0            0
# 48        unsafe-pgd    0.0535               0               0            0
# 49   safe-incomplete    0.0616               0               0            0
# 50        unsafe-pgd    0.0633               0               0            0
# 51   safe-incomplete    0.0407               0               0            0
# 52              safe   15.6585            7025             726         5744
# 53        unsafe-pgd    0.0489               0               0            0
# 54        unsafe-pgd    0.0817               0               0            0
# 55   safe-incomplete    0.0373               0               0            0
# 56        unsafe-pgd    0.0576               0               0            0
# 57              safe    3.4880               0               1           41
# 58        unsafe-pgd    0.0498               0               0            0
# 59   safe-incomplete    0.0349               0               0            0
# 60   safe-incomplete    0.0467               0               0            0
# 61        unsafe-pgd    0.0766               0               0            0
# 62   safe-incomplete    0.0394               0               0            0
# 63        unsafe-pgd    0.0582               0               0            0
# 64              safe   27.0393           17031            1918        16330
# 65        unsafe-pgd    0.0852               0               0            0
# 66        unsafe-pgd    0.0714               0               0            0
# 67           unknown  201.6428          309399            7016        22625
# 68   safe-incomplete    0.0662               0               0            0
# 69   safe-incomplete    0.0455               0               0            0
# 70   safe-incomplete    0.0454               0               0            0
# 71   safe-incomplete    0.0500               0               0            0
# 72        unsafe-pgd    0.0772               0               0            0
# 73   safe-incomplete    0.0495               0               0            0
# 74   safe-incomplete    0.0653               0               0            0
# 75   safe-incomplete    0.0450               0               0            0
# 76        unsafe-pgd    0.0764               0               0            0
# 77        unsafe-pgd    0.0539               0               0            0
# 78        unsafe-pgd    0.0721               0               0            0
# 79   safe-incomplete    0.0628               0               0            0
# 80        unsafe-pgd    0.0538               0               0            0
# 81   safe-incomplete    0.0633               0               0            0
# 82        unsafe-pgd    0.0731               0               0            0
# 83   safe-incomplete    0.0442               0               0            0
# 84        unsafe-pgd    0.0744               0               0            0
# 85   safe-incomplete    0.0544               0               0            0
# 86   safe-incomplete    0.0350               0               0            0
# 87        unsafe-pgd    0.0523               0               0            0
# 88        unsafe-pgd    0.0565               0               0            0
# 89        unsafe-pgd    0.0505               0               0            0
# 90        unsafe-pgd    0.0495               0               0            0
# 91   safe-incomplete    0.0440               0               0            0
# 92   safe-incomplete    0.0513               0               0            0
# 93   safe-incomplete    0.0622               0               0            0
# 94        unsafe-pgd    0.0705               0               0            0
# 95        unsafe-pgd    0.0572               0               0            0
# 96        unsafe-pgd    0.0526               0               0            0
# 97           unknown  207.2375          357568            2905         4626
# 98        unsafe-pgd    0.0739               0               0            0
# 99   safe-incomplete    0.0534               0               0            0
# 100       unsafe-pgd    0.0567               0               0            0
# 101       unsafe-pgd    0.0484               0               0            0
# 102       unsafe-pgd    0.0730               0               0            0
# 103  safe-incomplete    0.0475               0               0            0
# 104       unsafe-pgd    0.0646               0               0            0
# 105       unsafe-pgd    0.0596               0               0            0
# 106       unsafe-pgd    0.0559               0               0            0
# 107  safe-incomplete    0.0497               0               0            0
# 108       unsafe-pgd    0.0507               0               0            0
# 109  safe-incomplete    0.0671               0               0            0
# 110  safe-incomplete    0.0476               0               0            0
# 111  safe-incomplete    0.0600               0               0            0
# 112  safe-incomplete    0.0473               0               0            0
# 113       unsafe-pgd    0.0451               0               0            0
# 114  safe-incomplete    0.0469               0               0            0
# 115  safe-incomplete    0.0627               0               0            0
# 116  safe-incomplete    0.0488               0               0            0
# 117  safe-incomplete    0.0595               0               0            0
# 118  safe-incomplete    0.0406               0               0            0
# 119       unsafe-pgd    0.0555               0               0            0
# 120       unsafe-pgd    0.0567               0               0            0
# 121  safe-incomplete    0.0624               0               0            0
# 122       unsafe-pgd    0.0513               0               0            0
# 123             safe   16.1507            9113             564         6028
# 124       unsafe-pgd    0.0958               0               0            0
# 125       unsafe-pgd    0.0357               0               0            0
# 126       unsafe-pgd    0.0756               0               0            0
# 127       unsafe-pgd    0.0858               0               0            0
# 128             safe    7.6613             330              79         1054
# 129       unsafe-pgd    0.0915               0               0            0
# 130       unsafe-pgd    0.0632               0               0            0
# 131  safe-incomplete    0.0502               0               0            0
# 132       unsafe-pgd    0.0679               0               0            0
# 133  safe-incomplete    0.0613               0               0            0
# 134       unsafe-pgd    0.0538               0               0            0
# 135  safe-incomplete    0.0518               0               0            0
# 136  safe-incomplete    0.0290               0               0            0
# 137             safe    4.0018              50               3          400
# 138  safe-incomplete    0.1452               0               0            0
# 139  safe-incomplete    0.0706               0               0            0
# 140  safe-incomplete    0.0637               0               0            0
# 141       unsafe-pgd    0.0612               0               0            0
# 142  safe-incomplete    0.0633               0               0            0
# 143       unsafe-pgd    0.0671               0               0            0
# 144  safe-incomplete    0.0370               0               0            0
# 145       unsafe-pgd    0.0730               0               0            0
# 146  safe-incomplete    0.0597               0               0            0
# 147  safe-incomplete    0.0653               0               0            0
# 148       unsafe-pgd    0.0667               0               0            0
# 149       unsafe-pgd    0.0560               0               0            0
# 150       unsafe-pgd    0.0728               0               0            0
# 151       unsafe-pgd    0.0705               0               0            0
# 152       unsafe-pgd    0.0636               0               0            0
# 153  safe-incomplete    0.0521               0               0            0
# 154  safe-incomplete    0.0609               0               0            0
# 155       unsafe-pgd    0.0785               0               0            0
# 156       unsafe-pgd    0.0696               0               0            0
# 157  safe-incomplete    0.0366               0               0            0
# 158       unsafe-pgd    0.0710               0               0            0
# 159             safe    3.6262               0               1           19
# 160  safe-incomplete    0.1457               0               0            0
# 161  safe-incomplete    0.0601               0               0            0
# 162  safe-incomplete    0.4128               0               0            0
# 163       unsafe-pgd    0.0925               0               0            0
# 164  safe-incomplete    0.0732               0               0            0
# 165       unsafe-pgd    0.0810               0               0            0
# 166  safe-incomplete    0.0665               0               0            0
# 167       unsafe-pgd    0.0677               0               0            0
# 168  safe-incomplete    0.0638               0               0            0
# 169             safe    5.0540             100              42          373
# 170       unsafe-pgd    0.0680               0               0            0
# 171  safe-incomplete    0.0414               0               0            0
# 172       unsafe-pgd    0.0606               0               0            0
# 173       unsafe-pgd    0.0728               0               0            0
# 174       unsafe-pgd    0.0687               0               0            0
# 175  safe-incomplete    0.0617               0               0            0
# 176       unsafe-pgd    0.0528               0               0            0
# 177  safe-incomplete    0.0629               0               0            0
# 178             safe   16.8198            8895            1398         9077
# 179  safe-incomplete    0.0712               0               0            0
# 180  safe-incomplete    0.0633               0               0            0
# 181             safe   57.3040           44854            4241        22585
# 182  safe-incomplete    0.0505               0               0            0
# 183             safe    3.9891              50               4          139
# 184       unsafe-pgd    0.0921               0               0            0
# 185       unsafe-pgd    0.1331               0               0            0
# 186  safe-incomplete    0.0485               0               0            0
# 187       unsafe-pgd    0.0411               0               0            0
# 188             safe    4.1597              50               5          400
# 189       unsafe-pgd    0.1531               0               0            0
# 190  safe-incomplete    0.0797               0               0            0
# 191       unsafe-pgd    0.0520               0               0            0
# 192       unsafe-pgd    0.0712               0               0            0
# 193       unsafe-pgd    0.0675               0               0            0
# 194       unsafe-pgd    0.0614               0               0            0
# 195       unsafe-pgd    0.0333               0               0            0
# 196       unsafe-pgd    0.0628               0               0            0
# 197  safe-incomplete    0.0564               0               0            0
# 198  safe-incomplete    0.0591               0               0            0
# 199       unsafe-pgd    0.0425               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 0         NaN
# 19                 0         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 1         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                16         NaN
# 53                 0         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                 1         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                26         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                23   -0.029649
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 0         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 0         NaN
# 95                 0         NaN
# 96                 0         NaN
# 97                24   -0.029589
# 98                 0         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113                0         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123               16         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                0         NaN
# 128                9         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136                0         NaN
# 137                2         NaN
# 138                0         NaN
# 139                0         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                0         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                1         NaN
# 160                0         NaN
# 161                0         NaN
# 162                0         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                3         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178               15         NaN
# 179                0         NaN
# 180                0         NaN
# 181               23         NaN
# 182                0         NaN
# 183                2         NaN
# 184                0         NaN
# 185                0         NaN
# 186                0         NaN
# 187                0         NaN
# 188                2         NaN
# 189                0         NaN
# 190                0         NaN
# 191                0         NaN
# 192                0         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                0         NaN
# #Cuts 18904
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               13   13.174054    6730.615385          691.0   4784.076923
# safe-incomplete    84    0.059550       0.000000            0.0      0.000000
# unknown             2  204.440150  333483.500000         4960.5  13625.500000
# unsafe-pgd        101    0.085479       0.000000            0.0      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                        9.0
# safe-incomplete             0.0
# unknown                    23.5
# unsafe-pgd                  0.0
# safe number 97.0
# safe time 1.817163917525773
# safe domain 902.0412371134021
# safe cut 92.6082474226804
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((97.0, 1.817163917525773, 6730.615384615385, 691.0),)

# %% [markdown]
# ## cifar_cnn_b_adv

# %% [markdown]
# python abcrown.py --config exp_configs/GCP-CROWN/cifar_cnn_b_adv.yaml &> /home/duo/log/cifar_cnn_b_adv_.log

# %%
plot_multiple_dfs(
    [
log_read('cifar_cnn_b_adv/beta.log'),
log_read('cifar_cnn_b_adv/biccos_only_cs.log'),
log_read('cifar_cnn_b_adv/biccos_all.log'),
log_read('cifar_cnn_b_adv/gcp.log'),
log_read('cifar_cnn_b_adv/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts', 
        'Biccos_auto'
     ],  time_limit=200, dataset='cifar_cnn_b_adv'

)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_b_adv/beta.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe    4.7873             187               0            0
# 7     safe    2.6164               1               0            0
# 11    safe    2.6395               6               0            0
# 14    safe    2.4546               0               0            0
# 18    safe    7.9988            2762               0            0
# 37    safe   20.0710           15001               0            0
# 39    safe    3.5820              65               0            0
# 42    safe    3.7816             201               0            0
# 49    safe    2.5180               0               0            0
# 51    safe    2.4843               0               0            0
# 54    safe    3.0299               8               0            0
# 55    safe    2.9351               3               0            0
# 56    safe  197.8851          450797               0            0
# 59    safe    3.3464              44               0            0
# 64    safe    2.7144               0               0            0
# 70    safe    8.3231            1200               0            0
# 73    safe    2.7912               0               0            0
# 79    safe    2.6711               0               0            0
# 83    safe    7.5013             389               0            0
# 95    safe    7.5259            1230               0            0
# 104   safe    2.7092               0               0            0
# 106   safe    3.9576              99               0            0
# 107   safe    3.0619               8               0            0
# 111   safe   13.2416           10116               0            0
# 115   safe    2.7923               0               0            0
# 120   safe    2.6636               0               0            0
# 131   safe    2.8750               1               0            0
# 132   safe    2.6915               0               0            0
# 135   safe    2.6453               1               0            0
# 136   safe    4.2763             171               0            0
# 142   safe    2.9993               2               0            0
# 148   safe    2.8753               2               0            0
# 154   safe    4.8153             117               0            0
# 159   safe    2.8000               0               0            0
# 160   safe    7.6527            1431               0            0
# 162   safe    7.5440             794               0            0
# 164   safe    2.8918               0               0            0
# 166   safe    4.1509             126               0            0
# 172   safe    2.5695               0               0            0
# 174   safe   18.4004           18783               0            0
# 181   safe    3.0376               7               0            0
# 185   safe    3.9533              43               0            0
# 186   safe    2.6519               0               0            0
# 188   safe   14.3716           14315               0            0
# 189   safe    3.7700              64               0            0
# 190   safe    2.6472               0               0            0
# 195   safe    2.7170               0               0            0
# 197   safe    2.7432               0               0            0
# 199   safe  177.6427          369243               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 6                 16         NaN
# 7                  2         NaN
# 11                 2         NaN
# 14                 1         NaN
# 18                31         NaN
# 37                78         NaN
# 39                 9         NaN
# 42                11         NaN
# 49                 1         NaN
# 51                 1         NaN
# 54                 4         NaN
# 55                 4         NaN
# 56                93         NaN
# 59                 7         NaN
# 64                 1         NaN
# 70                34         NaN
# 73                 2         NaN
# 79                 1         NaN
# 83                34         NaN
# 95                30         NaN
# 104                1         NaN
# 106                9         NaN
# 107                5         NaN
# 111               43         NaN
# 115                2         NaN
# 120                1         NaN
# 131                2         NaN
# 132                1         NaN
# 135                2         NaN
# 136               10         NaN
# 142                3         NaN
# 148                2         NaN
# 154               15         NaN
# 159                4         NaN
# 160               31         NaN
# 162               32         NaN
# 164                4         NaN
# 166               14         NaN
# 172                1         NaN
# 174               58         NaN
# 181                5         NaN
# 185               11         NaN
# 186                1         NaN
# 188               44         NaN
# 189                8         NaN
# 190                1         NaN
# 195                1         NaN
# 197                2         NaN
# 199              171         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  204.5696          594623               0            0
# 19   unknown  202.3015          537062               0            0
# 35   unknown  209.2992          558361               0            0
# 38   unknown  203.5543          668378               0            0
# 48   unknown  202.0139          562664               0            0
# 52   unknown  200.2274          456348               0            0
# 53   unknown  201.2257          545809               0            0
# 62   unknown  203.6320          703414               0            0
# 67   unknown  202.8707          513815               0            0
# 72   unknown  201.3526          499050               0            0
# 75   unknown  201.6160          579609               0            0
# 76   unknown  200.4957          455873               0            0
# 80   unknown  201.9276          509008               0            0
# 81   unknown  204.2603          668518               0            0
# 84   unknown  204.3585          667193               0            0
# 85   unknown  203.2660          583430               0            0
# 93   unknown  202.1276          603336               0            0
# 97   unknown  201.9343          441544               0            0
# 99   unknown  204.8982          504372               0            0
# 101  unknown  202.6900          655203               0            0
# 102  unknown  203.8627          543718               0            0
# 103  unknown  202.5985          580169               0            0
# 112  unknown  201.6685          625762               0            0
# 122  unknown  209.7417          610960               0            0
# 124  unknown  202.2326          530132               0            0
# 127  unknown  203.4415          555162               0            0
# 139  unknown  200.3770          457193               0            0
# 144  unknown  201.6988          549816               0            0
# 149  unknown  202.1750          628862               0            0
# 150  unknown  200.7656          477273               0            0
# 163  unknown  204.2575          601842               0            0
# 184  unknown  201.5113          475726               0            0
# 187  unknown  204.2241          586334               0            0
# 191  unknown  207.5594          633242               0            0
# 194  unknown  201.4228          592970               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                 89   -0.972024
# 19                46   -0.282933
# 35                37   -0.505882
# 38                64   -0.794402
# 48                70   -0.612070
# 52               129   -0.087153
# 53                67   -0.499692
# 62                36   -1.029352
# 67                66   -0.355061
# 72               115   -1.090034
# 75                66   -0.918499
# 76                84   -0.203795
# 80                65   -1.201740
# 81                38   -0.523040
# 84                61   -0.770492
# 85                65   -0.790857
# 93                65   -0.843752
# 97               152   -0.330209
# 99                62   -0.686576
# 101               59   -1.062315
# 102               61   -0.770697
# 103               37   -0.563246
# 112               47   -0.683199
# 122               42   -0.877894
# 124              150   -0.915480
# 127               70   -1.016978
# 139               86   -0.228949
# 144               68   -0.295148
# 149               71   -1.089578
# 150               69   -0.405367
# 163               60   -2.118242
# 184               75   -0.208796
# 187               64   -1.073600
# 191               39   -0.534288
# 194               77   -0.680208
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.2099               0               0            0
# 1         unsafe-pgd    0.1000               0               0            0
# 2            unknown  204.5696          594623               0            0
# 3         unsafe-pgd    0.0602               0               0            0
# 4         unsafe-pgd    0.0598               0               0            0
# 5         unsafe-pgd    0.0535               0               0            0
# 6               safe    4.7873             187               0            0
# 7               safe    2.6164               1               0            0
# 8    safe-incomplete    0.0407               0               0            0
# 9         unsafe-pgd    0.0535               0               0            0
# 10        unsafe-pgd    0.0500               0               0            0
# 11              safe    2.6395               6               0            0
# 12        unsafe-pgd    0.0601               0               0            0
# 13   safe-incomplete    0.3390               0               0            0
# 14              safe    2.4546               0               0            0
# 15        unsafe-pgd    0.0578               0               0            0
# 16        unsafe-pgd    0.0510               0               0            0
# 17   safe-incomplete    0.0373               0               0            0
# 18              safe    7.9988            2762               0            0
# 19           unknown  202.3015          537062               0            0
# 20   safe-incomplete    0.0429               0               0            0
# 21        unsafe-pgd    0.0501               0               0            0
# 22   safe-incomplete    0.0380               0               0            0
# 23   safe-incomplete    0.0378               0               0            0
# 24        unsafe-pgd    0.0487               0               0            0
# 25        unsafe-pgd    0.0559               0               0            0
# 26        unsafe-pgd    0.0411               0               0            0
# 27   safe-incomplete    0.0356               0               0            0
# 28   safe-incomplete    0.0367               0               0            0
# 29        unsafe-pgd    0.0527               0               0            0
# 30   safe-incomplete    0.0356               0               0            0
# 31   safe-incomplete    0.0373               0               0            0
# 32        unsafe-pgd    0.0512               0               0            0
# 33   safe-incomplete    0.0376               0               0            0
# 34        unsafe-pgd    0.0445               0               0            0
# 35           unknown  209.2992          558361               0            0
# 36   safe-incomplete    0.0409               0               0            0
# 37              safe   20.0710           15001               0            0
# 38           unknown  203.5543          668378               0            0
# 39              safe    3.5820              65               0            0
# 40   safe-incomplete    0.0459               0               0            0
# 41   safe-incomplete    0.0382               0               0            0
# 42              safe    3.7816             201               0            0
# 43        unsafe-pgd    0.0583               0               0            0
# 44        unsafe-pgd    0.0521               0               0            0
# 45        unsafe-pgd    0.0538               0               0            0
# 46        unsafe-pgd    0.0543               0               0            0
# 47   safe-incomplete    0.0374               0               0            0
# 48           unknown  202.0139          562664               0            0
# 49              safe    2.5180               0               0            0
# 50        unsafe-pgd    0.0574               0               0            0
# 51              safe    2.4843               0               0            0
# 52           unknown  200.2274          456348               0            0
# 53           unknown  201.2257          545809               0            0
# 54              safe    3.0299               8               0            0
# 55              safe    2.9351               3               0            0
# 56              safe  197.8851          450797               0            0
# 57        unsafe-pgd    0.0632               0               0            0
# 58        unsafe-pgd    0.0472               0               0            0
# 59              safe    3.3464              44               0            0
# 60   safe-incomplete    0.0452               0               0            0
# 61        unsafe-pgd    0.0563               0               0            0
# 62           unknown  203.6320          703414               0            0
# 63        unsafe-pgd    0.1328               0               0            0
# 64              safe    2.7144               0               0            0
# 65        unsafe-pgd    0.1220               0               0            0
# 66        unsafe-pgd    0.1084               0               0            0
# 67           unknown  202.8707          513815               0            0
# 68   safe-incomplete    0.0645               0               0            0
# 69        unsafe-pgd    0.0584               0               0            0
# 70              safe    8.3231            1200               0            0
# 71   safe-incomplete    0.0456               0               0            0
# 72           unknown  201.3526          499050               0            0
# 73              safe    2.7912               0               0            0
# 74   safe-incomplete    0.0456               0               0            0
# 75           unknown  201.6160          579609               0            0
# 76           unknown  200.4957          455873               0            0
# 77   safe-incomplete    0.0495               0               0            0
# 78        unsafe-pgd    0.0564               0               0            0
# 79              safe    2.6711               0               0            0
# 80           unknown  201.9276          509008               0            0
# 81           unknown  204.2603          668518               0            0
# 82        unsafe-pgd    0.0622               0               0            0
# 83              safe    7.5013             389               0            0
# 84           unknown  204.3585          667193               0            0
# 85           unknown  203.2660          583430               0            0
# 86   safe-incomplete    0.0532               0               0            0
# 87        unsafe-pgd    0.0608               0               0            0
# 88        unsafe-pgd    0.0509               0               0            0
# 89   safe-incomplete    0.0400               0               0            0
# 90        unsafe-pgd    0.0546               0               0            0
# 91        unsafe-pgd    0.0479               0               0            0
# 92        unsafe-pgd    0.0470               0               0            0
# 93           unknown  202.1276          603336               0            0
# 94        unsafe-pgd    0.0664               0               0            0
# 95              safe    7.5259            1230               0            0
# 96        unsafe-pgd    0.0621               0               0            0
# 97           unknown  201.9343          441544               0            0
# 98        unsafe-pgd    0.0630               0               0            0
# 99           unknown  204.8982          504372               0            0
# 100       unsafe-pgd    0.0758               0               0            0
# 101          unknown  202.6900          655203               0            0
# 102          unknown  203.8627          543718               0            0
# 103          unknown  202.5985          580169               0            0
# 104             safe    2.7092               0               0            0
# 105       unsafe-pgd    0.0663               0               0            0
# 106             safe    3.9576              99               0            0
# 107             safe    3.0619               8               0            0
# 108       unsafe-pgd    0.0634               0               0            0
# 109  safe-incomplete    0.0437               0               0            0
# 110  safe-incomplete    0.0414               0               0            0
# 111             safe   13.2416           10116               0            0
# 112          unknown  201.6685          625762               0            0
# 113       unsafe-pgd    0.0608               0               0            0
# 114  safe-incomplete    0.0424               0               0            0
# 115             safe    2.7923               0               0            0
# 116       unsafe-pgd    0.0634               0               0            0
# 117  safe-incomplete    0.0401               0               0            0
# 118  safe-incomplete    0.0424               0               0            0
# 119       unsafe-pgd    0.0477               0               0            0
# 120             safe    2.6636               0               0            0
# 121  safe-incomplete    0.0435               0               0            0
# 122          unknown  209.7417          610960               0            0
# 123       unsafe-pgd    0.0679               0               0            0
# 124          unknown  202.2326          530132               0            0
# 125       unsafe-pgd    0.0625               0               0            0
# 126       unsafe-pgd    0.0518               0               0            0
# 127          unknown  203.4415          555162               0            0
# 128       unsafe-pgd    0.0863               0               0            0
# 129       unsafe-pgd    0.1153               0               0            0
# 130       unsafe-pgd    0.0865               0               0            0
# 131             safe    2.8750               1               0            0
# 132             safe    2.6915               0               0            0
# 133  safe-incomplete    0.0443               0               0            0
# 134       unsafe-pgd    0.0497               0               0            0
# 135             safe    2.6453               1               0            0
# 136             safe    4.2763             171               0            0
# 137       unsafe-pgd    0.0546               0               0            0
# 138       unsafe-pgd    0.0524               0               0            0
# 139          unknown  200.3770          457193               0            0
# 140  safe-incomplete    0.0534               0               0            0
# 141       unsafe-pgd    0.0584               0               0            0
# 142             safe    2.9993               2               0            0
# 143       unsafe-pgd    0.0543               0               0            0
# 144          unknown  201.6988          549816               0            0
# 145       unsafe-pgd    0.0598               0               0            0
# 146  safe-incomplete    0.0391               0               0            0
# 147  safe-incomplete    0.0393               0               0            0
# 148             safe    2.8753               2               0            0
# 149          unknown  202.1750          628862               0            0
# 150          unknown  200.7656          477273               0            0
# 151       unsafe-pgd    0.0660               0               0            0
# 152  safe-incomplete    0.0393               0               0            0
# 153  safe-incomplete    0.3269               0               0            0
# 154             safe    4.8153             117               0            0
# 155       unsafe-pgd    0.0616               0               0            0
# 156       unsafe-pgd    0.0489               0               0            0
# 157  safe-incomplete    0.0404               0               0            0
# 158  safe-incomplete    0.0370               0               0            0
# 159             safe    2.8000               0               0            0
# 160             safe    7.6527            1431               0            0
# 161  safe-incomplete    0.0436               0               0            0
# 162             safe    7.5440             794               0            0
# 163          unknown  204.2575          601842               0            0
# 164             safe    2.8918               0               0            0
# 165       unsafe-pgd    0.0599               0               0            0
# 166             safe    4.1509             126               0            0
# 167       unsafe-pgd    0.0517               0               0            0
# 168       unsafe-pgd    0.0448               0               0            0
# 169  safe-incomplete    0.0381               0               0            0
# 170       unsafe-pgd    0.0460               0               0            0
# 171  safe-incomplete    0.3102               0               0            0
# 172             safe    2.5695               0               0            0
# 173       unsafe-pgd    0.0503               0               0            0
# 174             safe   18.4004           18783               0            0
# 175       unsafe-pgd    0.0509               0               0            0
# 176       unsafe-pgd    0.0473               0               0            0
# 177  safe-incomplete    0.0385               0               0            0
# 178  safe-incomplete    0.0390               0               0            0
# 179  safe-incomplete    0.0384               0               0            0
# 180  safe-incomplete    0.0375               0               0            0
# 181             safe    3.0376               7               0            0
# 182  safe-incomplete    0.0436               0               0            0
# 183       unsafe-pgd    0.0471               0               0            0
# 184          unknown  201.5113          475726               0            0
# 185             safe    3.9533              43               0            0
# 186             safe    2.6519               0               0            0
# 187          unknown  204.2241          586334               0            0
# 188             safe   14.3716           14315               0            0
# 189             safe    3.7700              64               0            0
# 190             safe    2.6472               0               0            0
# 191          unknown  207.5594          633242               0            0
# 192       unsafe-pgd    0.1134               0               0            0
# 193  safe-incomplete    0.0535               0               0            0
# 194          unknown  201.4228          592970               0            0
# 195             safe    2.7170               0               0            0
# 196       unsafe-pgd    0.0528               0               0            0
# 197             safe    2.7432               0               0            0
# 198       unsafe-pgd    0.0529               0               0            0
# 199             safe  177.6427          369243               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                 89   -0.972024
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 16         NaN
# 7                  2         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 2         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 1         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                31         NaN
# 19                46   -0.282933
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 0         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                37   -0.505882
# 36                 0         NaN
# 37                78         NaN
# 38                64   -0.794402
# 39                 9         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                11         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                70   -0.612070
# 49                 1         NaN
# 50                 0         NaN
# 51                 1         NaN
# 52               129   -0.087153
# 53                67   -0.499692
# 54                 4         NaN
# 55                 4         NaN
# 56                93         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 7         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                36   -1.029352
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                66   -0.355061
# 68                 0         NaN
# 69                 0         NaN
# 70                34         NaN
# 71                 0         NaN
# 72               115   -1.090034
# 73                 2         NaN
# 74                 0         NaN
# 75                66   -0.918499
# 76                84   -0.203795
# 77                 0         NaN
# 78                 0         NaN
# 79                 1         NaN
# 80                65   -1.201740
# 81                38   -0.523040
# 82                 0         NaN
# 83                34         NaN
# 84                61   -0.770492
# 85                65   -0.790857
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                65   -0.843752
# 94                 0         NaN
# 95                30         NaN
# 96                 0         NaN
# 97               152   -0.330209
# 98                 0         NaN
# 99                62   -0.686576
# 100                0         NaN
# 101               59   -1.062315
# 102               61   -0.770697
# 103               37   -0.563246
# 104                1         NaN
# 105                0         NaN
# 106                9         NaN
# 107                5         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               43         NaN
# 112               47   -0.683199
# 113                0         NaN
# 114                0         NaN
# 115                2         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122               42   -0.877894
# 123                0         NaN
# 124              150   -0.915480
# 125                0         NaN
# 126                0         NaN
# 127               70   -1.016978
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                2         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                2         NaN
# 136               10         NaN
# 137                0         NaN
# 138                0         NaN
# 139               86   -0.228949
# 140                0         NaN
# 141                0         NaN
# 142                3         NaN
# 143                0         NaN
# 144               68   -0.295148
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                2         NaN
# 149               71   -1.089578
# 150               69   -0.405367
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               15         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                4         NaN
# 160               31         NaN
# 161                0         NaN
# 162               32         NaN
# 163               60   -2.118242
# 164                4         NaN
# 165                0         NaN
# 166               14         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                1         NaN
# 173                0         NaN
# 174               58         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                5         NaN
# 182                0         NaN
# 183                0         NaN
# 184               75   -0.208796
# 185               11         NaN
# 186                1         NaN
# 187               64   -1.073600
# 188               44         NaN
# 189                8         NaN
# 190                1         NaN
# 191               39   -0.534288
# 192                0         NaN
# 193                0         NaN
# 194               77   -0.680208
# 195                1         NaN
# 196                0         NaN
# 197                2         NaN
# 198                0         NaN
# 199              171         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               49   12.302143   18106.469388            0.0         0.0
# safe-incomplete    46    0.107609       0.000000            0.0         0.0
# unknown            35  203.033089  564479.171429            0.0         0.0
# unsafe-pgd         70    0.061373       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  17.265306
# safe-incomplete        0.000000
# unknown               70.057143
# unsafe-pgd             0.000000
# safe number 95.0
# safe time 6.3974210526315805
# safe domain 9339.126315789475
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((95.0, 6.3974210526315805, 18106.469387755104, 0.0),)

# %%
main('cifar_cnn_b_adv/biccos_only_cs.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe   8.2909             315             191         1017
# 7     safe   3.4482             100              16          432
# 11    safe   3.5143             100              35          419
# 14    safe   2.9458               0               1           32
# 18    safe  12.5098            1612             127         1678
# 19    safe  88.2729           92648             283        59971
# 37    safe  19.1531            5308             499         3461
# 39    safe   3.8686              59              34          164
# 42    safe   4.3194             201              48          230
# 49    safe   3.1475              50              12          432
# 51    safe   3.4121              50               5          350
# 54    safe   5.1204             104              29          423
# 55    safe   6.3916             223              47          860
# 56    safe  15.2918            6941             434         5100
# 59    safe   3.4102              44               6          104
# 64    safe   3.2223              50              11          183
# 67    safe  16.6477            9310             485         6580
# 70    safe  11.5560             844             376         1638
# 73    safe   5.6327              50              24          858
# 79    safe   3.1050              50              15          432
# 83    safe  10.4876             377              92          497
# 95    safe   8.2678             876             216          760
# 97    safe  50.6893           38443            1314        23291
# 99    safe  25.5444           20365             583        11696
# 102   safe  84.7083           97217              81        39659
# 104   safe   3.4439             100              17          432
# 106   safe   6.7070             210              45          827
# 107   safe   2.6222               8               1           64
# 111   safe  10.8901            2297              81         1623
# 115   safe   4.6857             100              13          474
# 120   safe   2.9081               0               1           32
# 131   safe   3.9493             104              16          432
# 132   safe   2.8310               0               1          107
# 135   safe   3.3883             100              67          432
# 136   safe   7.1251             288              31          598
# 142   safe   5.3505             151              18          862
# 144   safe  79.6546           87495             692        28242
# 148   safe   3.5265             100              23          428
# 154   safe   8.8609             342             116         1004
# 159   safe   2.3017               0               0           32
# 160   safe   8.0880             770             112          556
# 162   safe  10.9286             458             228         1494
# 164   safe   2.3782               0               0           32
# 166   safe   5.3401             126              10          225
# 172   safe   3.1200              50               6          223
# 174   safe  14.1094            2560             139         1399
# 181   safe   2.7824               7              11          111
# 184   safe  33.8746           28243             144        16039
# 185   safe   4.4875              43              20          153
# 186   safe   2.7937               0               1           32
# 188   safe  10.9939            2379              91         1388
# 189   safe   4.9944             153             113          542
# 190   safe   3.3147             100              16          432
# 191   safe  59.7337           72133             155        34332
# 194   safe  80.7733           75038            1823        28022
# 195   safe   2.8417               0               1           80
# 197   safe   4.8665             100              28          863
# 199   safe  36.3916           19838             474        13480
#
#      BaB Round Count  BaB_lb_rhs
# 6                 19         NaN
# 7                  4         NaN
# 11                 4         NaN
# 14                 2         NaN
# 18                35         NaN
# 19                43         NaN
# 37                66         NaN
# 39                 9         NaN
# 42                11         NaN
# 49                 3         NaN
# 51                 3         NaN
# 54                 7         NaN
# 55                10         NaN
# 56                34         NaN
# 59                 7         NaN
# 64                 3         NaN
# 67                26         NaN
# 70                35         NaN
# 73                 6         NaN
# 79                 3         NaN
# 83                34         NaN
# 95                28         NaN
# 97               111         NaN
# 99                25         NaN
# 102               50         NaN
# 104                4         NaN
# 106               12         NaN
# 107                5         NaN
# 111               40         NaN
# 115                6         NaN
# 120                2         NaN
# 131                5         NaN
# 132                2         NaN
# 135                4         NaN
# 136               14         NaN
# 142                8         NaN
# 144               54         NaN
# 148                4         NaN
# 154               20         NaN
# 159                4         NaN
# 160               29         NaN
# 162               29         NaN
# 164                4         NaN
# 166               14         NaN
# 172                3         NaN
# 174               57         NaN
# 181                5         NaN
# 184               42         NaN
# 185               11         NaN
# 186                2         NaN
# 188               42         NaN
# 189               10         NaN
# 190                4         NaN
# 191               26         NaN
# 194               81         NaN
# 195                2         NaN
# 197                7         NaN
# 199               95         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  206.6660          343470            1492        22530
# 35   unknown  202.0089          409849             106        16931
# 38   unknown  206.4863          529383              75        29685
# 48   unknown  206.6548          352105             299        77956
# 52   unknown  205.4132          297625             587        59582
# 53   unknown  203.4228          303092            1524        46275
# 62   unknown  206.5609          387959             694        18965
# 72   unknown  204.4594          462549             511        23657
# 75   unknown  202.8297          396868             690        42494
# 76   unknown  205.0453          289029             347        80718
# 80   unknown  203.5590          329803            1061        93047
# 81   unknown  215.2202          452585             664        32389
# 84   unknown  201.9702          448002             559        24853
# 85   unknown  203.3698          440853             564        38429
# 93   unknown  204.1858          396891             601        31539
# 101  unknown  202.0691          393085             558        44692
# 103  unknown  206.6032          423098             153        32900
# 112  unknown  201.8900          391640             619        31260
# 122  unknown  201.6440          361832            1040        42442
# 124  unknown  203.7303          365964            2168        58035
# 127  unknown  206.5712          254562            1890        95370
# 139  unknown  205.0657          311433             411        86592
# 149  unknown  203.8263          424735             520        39191
# 150  unknown  202.2272          293618             211        77260
# 163  unknown  203.6535          320480             651        78605
# 187  unknown  201.3787          313845            1179       105648
#
#      BaB Round Count  BaB_lb_rhs
# 2                 66   -0.913270
# 35                56   -0.426823
# 38                54   -0.739289
# 48                61   -0.347356
# 52                59   -0.446971
# 53                74   -0.574909
# 62                43   -0.975127
# 72                59   -0.851513
# 75                48   -0.873336
# 76                65   -0.094347
# 80                80   -1.175580
# 81                35   -0.490194
# 84                51   -0.717073
# 85                53   -0.721186
# 93                60   -0.740597
# 101               47   -0.995755
# 103               56   -0.485583
# 112               52   -0.655447
# 122               52   -0.812925
# 124              128   -1.068526
# 127              105   -1.005007
# 139               85   -0.040684
# 149               59   -0.997521
# 150               57   -0.245231
# 163               44   -1.776592
# 187              112   -0.154399
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.7373               0               0            0
# 1         unsafe-pgd    0.1108               0               0            0
# 2            unknown  206.6660          343470            1492        22530
# 3         unsafe-pgd    0.0591               0               0            0
# 4         unsafe-pgd    0.0574               0               0            0
# 5         unsafe-pgd    0.0533               0               0            0
# 6               safe    8.2909             315             191         1017
# 7               safe    3.4482             100              16          432
# 8    safe-incomplete    0.0404               0               0            0
# 9         unsafe-pgd    0.0531               0               0            0
# 10        unsafe-pgd    0.0506               0               0            0
# 11              safe    3.5143             100              35          419
# 12        unsafe-pgd    0.0589               0               0            0
# 13   safe-incomplete    0.3482               0               0            0
# 14              safe    2.9458               0               1           32
# 15        unsafe-pgd    0.1055               0               0            0
# 16        unsafe-pgd    0.1093               0               0            0
# 17   safe-incomplete    0.0455               0               0            0
# 18              safe   12.5098            1612             127         1678
# 19              safe   88.2729           92648             283        59971
# 20   safe-incomplete    0.0366               0               0            0
# 21        unsafe-pgd    0.0486               0               0            0
# 22   safe-incomplete    0.0375               0               0            0
# 23   safe-incomplete    0.0380               0               0            0
# 24        unsafe-pgd    0.0499               0               0            0
# 25        unsafe-pgd    0.0541               0               0            0
# 26        unsafe-pgd    0.0426               0               0            0
# 27   safe-incomplete    0.0352               0               0            0
# 28   safe-incomplete    0.0371               0               0            0
# 29        unsafe-pgd    0.0518               0               0            0
# 30   safe-incomplete    0.0361               0               0            0
# 31   safe-incomplete    0.0356               0               0            0
# 32        unsafe-pgd    0.0506               0               0            0
# 33   safe-incomplete    0.0373               0               0            0
# 34        unsafe-pgd    0.0448               0               0            0
# 35           unknown  202.0089          409849             106        16931
# 36   safe-incomplete    0.0466               0               0            0
# 37              safe   19.1531            5308             499         3461
# 38           unknown  206.4863          529383              75        29685
# 39              safe    3.8686              59              34          164
# 40   safe-incomplete    0.0390               0               0            0
# 41   safe-incomplete    0.0379               0               0            0
# 42              safe    4.3194             201              48          230
# 43        unsafe-pgd    0.0522               0               0            0
# 44        unsafe-pgd    0.0505               0               0            0
# 45        unsafe-pgd    0.0511               0               0            0
# 46        unsafe-pgd    0.0524               0               0            0
# 47   safe-incomplete    0.0364               0               0            0
# 48           unknown  206.6548          352105             299        77956
# 49              safe    3.1475              50              12          432
# 50        unsafe-pgd    0.0508               0               0            0
# 51              safe    3.4121              50               5          350
# 52           unknown  205.4132          297625             587        59582
# 53           unknown  203.4228          303092            1524        46275
# 54              safe    5.1204             104              29          423
# 55              safe    6.3916             223              47          860
# 56              safe   15.2918            6941             434         5100
# 57        unsafe-pgd    0.0472               0               0            0
# 58        unsafe-pgd    0.0434               0               0            0
# 59              safe    3.4102              44               6          104
# 60   safe-incomplete    0.0373               0               0            0
# 61        unsafe-pgd    0.0521               0               0            0
# 62           unknown  206.5609          387959             694        18965
# 63        unsafe-pgd    0.0586               0               0            0
# 64              safe    3.2223              50              11          183
# 65        unsafe-pgd    0.0561               0               0            0
# 66        unsafe-pgd    0.0432               0               0            0
# 67              safe   16.6477            9310             485         6580
# 68   safe-incomplete    0.0367               0               0            0
# 69        unsafe-pgd    0.0532               0               0            0
# 70              safe   11.5560             844             376         1638
# 71   safe-incomplete    0.0422               0               0            0
# 72           unknown  204.4594          462549             511        23657
# 73              safe    5.6327              50              24          858
# 74   safe-incomplete    0.0395               0               0            0
# 75           unknown  202.8297          396868             690        42494
# 76           unknown  205.0453          289029             347        80718
# 77   safe-incomplete    0.0501               0               0            0
# 78        unsafe-pgd    0.0475               0               0            0
# 79              safe    3.1050              50              15          432
# 80           unknown  203.5590          329803            1061        93047
# 81           unknown  215.2202          452585             664        32389
# 82        unsafe-pgd    0.0546               0               0            0
# 83              safe   10.4876             377              92          497
# 84           unknown  201.9702          448002             559        24853
# 85           unknown  203.3698          440853             564        38429
# 86   safe-incomplete    0.0469               0               0            0
# 87        unsafe-pgd    0.0533               0               0            0
# 88        unsafe-pgd    0.0452               0               0            0
# 89   safe-incomplete    0.0365               0               0            0
# 90        unsafe-pgd    0.0513               0               0            0
# 91        unsafe-pgd    0.0438               0               0            0
# 92        unsafe-pgd    0.0451               0               0            0
# 93           unknown  204.1858          396891             601        31539
# 94        unsafe-pgd    0.0526               0               0            0
# 95              safe    8.2678             876             216          760
# 96        unsafe-pgd    0.0482               0               0            0
# 97              safe   50.6893           38443            1314        23291
# 98        unsafe-pgd    0.0473               0               0            0
# 99              safe   25.5444           20365             583        11696
# 100       unsafe-pgd    0.0544               0               0            0
# 101          unknown  202.0691          393085             558        44692
# 102             safe   84.7083           97217              81        39659
# 103          unknown  206.6032          423098             153        32900
# 104             safe    3.4439             100              17          432
# 105       unsafe-pgd    0.0554               0               0            0
# 106             safe    6.7070             210              45          827
# 107             safe    2.6222               8               1           64
# 108       unsafe-pgd    0.0535               0               0            0
# 109  safe-incomplete    0.0382               0               0            0
# 110  safe-incomplete    0.0368               0               0            0
# 111             safe   10.8901            2297              81         1623
# 112          unknown  201.8900          391640             619        31260
# 113       unsafe-pgd    0.0573               0               0            0
# 114  safe-incomplete    0.0409               0               0            0
# 115             safe    4.6857             100              13          474
# 116       unsafe-pgd    0.0533               0               0            0
# 117  safe-incomplete    0.0396               0               0            0
# 118  safe-incomplete    0.0381               0               0            0
# 119       unsafe-pgd    0.0446               0               0            0
# 120             safe    2.9081               0               1           32
# 121  safe-incomplete    0.0387               0               0            0
# 122          unknown  201.6440          361832            1040        42442
# 123       unsafe-pgd    0.0629               0               0            0
# 124          unknown  203.7303          365964            2168        58035
# 125       unsafe-pgd    0.0549               0               0            0
# 126       unsafe-pgd    0.0482               0               0            0
# 127          unknown  206.5712          254562            1890        95370
# 128       unsafe-pgd    0.0574               0               0            0
# 129       unsafe-pgd    0.0527               0               0            0
# 130       unsafe-pgd    0.0490               0               0            0
# 131             safe    3.9493             104              16          432
# 132             safe    2.8310               0               1          107
# 133  safe-incomplete    0.0466               0               0            0
# 134       unsafe-pgd    0.0433               0               0            0
# 135             safe    3.3883             100              67          432
# 136             safe    7.1251             288              31          598
# 137       unsafe-pgd    0.0470               0               0            0
# 138       unsafe-pgd    0.0467               0               0            0
# 139          unknown  205.0657          311433             411        86592
# 140  safe-incomplete    0.0460               0               0            0
# 141       unsafe-pgd    0.0534               0               0            0
# 142             safe    5.3505             151              18          862
# 143       unsafe-pgd    0.0463               0               0            0
# 144             safe   79.6546           87495             692        28242
# 145       unsafe-pgd    0.0498               0               0            0
# 146  safe-incomplete    0.0369               0               0            0
# 147  safe-incomplete    0.0368               0               0            0
# 148             safe    3.5265             100              23          428
# 149          unknown  203.8263          424735             520        39191
# 150          unknown  202.2272          293618             211        77260
# 151       unsafe-pgd    0.0597               0               0            0
# 152  safe-incomplete    0.0374               0               0            0
# 153  safe-incomplete    0.3122               0               0            0
# 154             safe    8.8609             342             116         1004
# 155       unsafe-pgd    0.0540               0               0            0
# 156       unsafe-pgd    0.0454               0               0            0
# 157  safe-incomplete    0.0385               0               0            0
# 158  safe-incomplete    0.0347               0               0            0
# 159             safe    2.3017               0               0           32
# 160             safe    8.0880             770             112          556
# 161  safe-incomplete    0.0477               0               0            0
# 162             safe   10.9286             458             228         1494
# 163          unknown  203.6535          320480             651        78605
# 164             safe    2.3782               0               0           32
# 165       unsafe-pgd    0.0543               0               0            0
# 166             safe    5.3401             126              10          225
# 167       unsafe-pgd    0.0492               0               0            0
# 168       unsafe-pgd    0.0459               0               0            0
# 169  safe-incomplete    0.0371               0               0            0
# 170       unsafe-pgd    0.0444               0               0            0
# 171  safe-incomplete    0.3067               0               0            0
# 172             safe    3.1200              50               6          223
# 173       unsafe-pgd    0.0466               0               0            0
# 174             safe   14.1094            2560             139         1399
# 175       unsafe-pgd    0.0475               0               0            0
# 176       unsafe-pgd    0.0445               0               0            0
# 177  safe-incomplete    0.0403               0               0            0
# 178  safe-incomplete    0.0372               0               0            0
# 179  safe-incomplete    0.0377               0               0            0
# 180  safe-incomplete    0.0368               0               0            0
# 181             safe    2.7824               7              11          111
# 182  safe-incomplete    0.0436               0               0            0
# 183       unsafe-pgd    0.0474               0               0            0
# 184             safe   33.8746           28243             144        16039
# 185             safe    4.4875              43              20          153
# 186             safe    2.7937               0               1           32
# 187          unknown  201.3787          313845            1179       105648
# 188             safe   10.9939            2379              91         1388
# 189             safe    4.9944             153             113          542
# 190             safe    3.3147             100              16          432
# 191             safe   59.7337           72133             155        34332
# 192       unsafe-pgd    0.0492               0               0            0
# 193  safe-incomplete    0.0372               0               0            0
# 194             safe   80.7733           75038            1823        28022
# 195             safe    2.8417               0               1           80
# 196       unsafe-pgd    0.0459               0               0            0
# 197             safe    4.8665             100              28          863
# 198       unsafe-pgd    0.0510               0               0            0
# 199             safe   36.3916           19838             474        13480
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                 66   -0.913270
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 19         NaN
# 7                  4         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 4         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 2         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                35         NaN
# 19                43         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 0         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                56   -0.426823
# 36                 0         NaN
# 37                66         NaN
# 38                54   -0.739289
# 39                 9         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                11         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                61   -0.347356
# 49                 3         NaN
# 50                 0         NaN
# 51                 3         NaN
# 52                59   -0.446971
# 53                74   -0.574909
# 54                 7         NaN
# 55                10         NaN
# 56                34         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 7         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                43   -0.975127
# 63                 0         NaN
# 64                 3         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                26         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                35         NaN
# 71                 0         NaN
# 72                59   -0.851513
# 73                 6         NaN
# 74                 0         NaN
# 75                48   -0.873336
# 76                65   -0.094347
# 77                 0         NaN
# 78                 0         NaN
# 79                 3         NaN
# 80                80   -1.175580
# 81                35   -0.490194
# 82                 0         NaN
# 83                34         NaN
# 84                51   -0.717073
# 85                53   -0.721186
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                60   -0.740597
# 94                 0         NaN
# 95                28         NaN
# 96                 0         NaN
# 97               111         NaN
# 98                 0         NaN
# 99                25         NaN
# 100                0         NaN
# 101               47   -0.995755
# 102               50         NaN
# 103               56   -0.485583
# 104                4         NaN
# 105                0         NaN
# 106               12         NaN
# 107                5         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               40         NaN
# 112               52   -0.655447
# 113                0         NaN
# 114                0         NaN
# 115                6         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                2         NaN
# 121                0         NaN
# 122               52   -0.812925
# 123                0         NaN
# 124              128   -1.068526
# 125                0         NaN
# 126                0         NaN
# 127              105   -1.005007
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                5         NaN
# 132                2         NaN
# 133                0         NaN
# 134                0         NaN
# 135                4         NaN
# 136               14         NaN
# 137                0         NaN
# 138                0         NaN
# 139               85   -0.040684
# 140                0         NaN
# 141                0         NaN
# 142                8         NaN
# 143                0         NaN
# 144               54         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                4         NaN
# 149               59   -0.997521
# 150               57   -0.245231
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               20         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                4         NaN
# 160               29         NaN
# 161                0         NaN
# 162               29         NaN
# 163               44   -1.776592
# 164                4         NaN
# 165                0         NaN
# 166               14         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                3         NaN
# 173                0         NaN
# 174               57         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                5         NaN
# 182                0         NaN
# 183                0         NaN
# 184               42         NaN
# 185               11         NaN
# 186                2         NaN
# 187              112   -0.154399
# 188               42         NaN
# 189               10         NaN
# 190                4         NaN
# 191               26         NaN
# 192                0         NaN
# 193                0         NaN
# 194               81         NaN
# 195                2         NaN
# 196                0         NaN
# 197                7         NaN
# 198                0         NaN
# 199               95         NaN
# #Cuts 28632
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               58   14.534740    9803.965517     163.068966   5090.672414
# safe-incomplete    46    0.094774       0.000000       0.000000      0.000000
# unknown            26  204.481212  372859.807692     737.461538  51194.038462
# unsafe-pgd         70    0.053074       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  21.120690
# safe-incomplete        0.000000
# unknown               63.884615
# unsafe-pgd             0.000000
# safe number 104.0
# safe time 8.14783173076923
# safe domain 5467.596153846154
# safe cut 90.9423076923077
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((104.0, 8.14783173076923, 9803.965517241379, 163.06896551724137),)

# %%
main('cifar_cnn_b_adv/biccos_all.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe    8.3142             306             163          964
# 7     safe    3.5122             100              16          400
# 11    safe    3.6628             100              35          419
# 14    safe    2.8570               0               1           24
# 18    safe   12.5685            1399             131         1537
# 19    safe   96.0354           86273             778        28763
# 37    safe   22.9579            5064             677         4556
# 39    safe    8.4905             231             117          861
# 42    safe    9.7726             311              34          806
# 48    safe   62.0838           58436             339        29743
# 49    safe    3.1549              50              12          400
# 51    safe    3.1564              50               5          318
# 54    safe    5.2759             102              33          412
# 55    safe    6.3303             223              48          876
# 56    safe    8.4812            1174             319          975
# 59    safe    9.3354             278              69         1402
# 64    safe    3.3035              50              11          151
# 70    safe   11.5650             818             276         1646
# 73    safe    4.8601              50              24          794
# 79    safe    3.0689              50              15          400
# 81    safe  154.8660          150068            1409        68610
# 83    safe   25.0534            1064             336         3164
# 95    safe   16.5670            1458             406         2810
# 97    safe   67.6045           37016            1571        21660
# 99    safe   33.4649           22789             388        16343
# 102   safe   22.9989            6003             171         4725
# 104   safe    3.4729             100              17          400
# 106   safe    6.8618             205              52          835
# 107   safe    8.3753             211              53         1063
# 111   safe   16.1938            2518              91         2807
# 115   safe    4.7391             100              13          410
# 120   safe    2.8002               0               1           12
# 131   safe    4.1642             104              16          432
# 132   safe    2.8172               0               1           75
# 135   safe    3.3592             100              67          400
# 136   safe    6.9096             274              29          614
# 142   safe    5.3002             150              18          830
# 144   safe  111.7894          100404             890        38870
# 148   safe    3.6584             100              23          428
# 154   safe    8.9088             340             103          974
# 159   safe    8.1691             200              31         1025
# 160   safe   13.2490             760             275         1274
# 162   safe   10.4267             381             147         1332
# 164   safe    7.5996             150              41          699
# 166   safe   14.6012             489             129         2462
# 172   safe    3.1256              50               6          191
# 174   safe   22.4167            2971             430         3416
# 181   safe    7.1491             250              40         1144
# 184   safe   15.9901            2636              81         2552
# 185   safe   12.8390             454             135         2454
# 186   safe    2.7997               0               1           22
# 188   safe   20.3162            2806             349         3499
# 189   safe    5.4595             146              74          833
# 190   safe    3.4176             100              16          400
# 191   safe   27.9138           19277             126         9538
# 194   safe   25.8293            6159             561         5651
# 195   safe    2.7884               0               1           48
# 197   safe    4.8378             100              28          799
# 199   safe   53.0898           16750             485        11197
#
#      BaB Round Count  BaB_lb_rhs
# 6                 18         NaN
# 7                  3         NaN
# 11                 4         NaN
# 14                 1         NaN
# 18                35         NaN
# 19                53         NaN
# 37                71         NaN
# 39                13         NaN
# 42                14         NaN
# 48                51         NaN
# 49                 2         NaN
# 51                 2         NaN
# 54                 6         NaN
# 55                10         NaN
# 56                21         NaN
# 59                15         NaN
# 64                 2         NaN
# 70                33         NaN
# 73                 4         NaN
# 79                 2         NaN
# 81                28         NaN
# 83                51         NaN
# 95                37         NaN
# 97               122         NaN
# 99                34         NaN
# 102               45         NaN
# 104                3         NaN
# 106               12         NaN
# 107               11         NaN
# 111               50         NaN
# 115                4         NaN
# 120                1         NaN
# 131                5         NaN
# 132                1         NaN
# 135                3         NaN
# 136               12         NaN
# 142                6         NaN
# 144               65         NaN
# 148                4         NaN
# 154               19         NaN
# 159                9         NaN
# 160               33         NaN
# 162               25         NaN
# 164                8         NaN
# 166               23         NaN
# 172                2         NaN
# 174               69         NaN
# 181               10         NaN
# 184               37         NaN
# 185               20         NaN
# 186                1         NaN
# 188               55         NaN
# 189               10         NaN
# 190                3         NaN
# 191               33         NaN
# 194               81         NaN
# 195                1         NaN
# 197                5         NaN
# 199              136         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  201.9391          299872            1543        23056
# 35   unknown  206.5247          411292              94        14747
# 38   unknown  204.9891          437661            1070        23970
# 52   unknown  207.1943          266505            1087        52586
# 53   unknown  207.0963          319970            1606        53438
# 62   unknown  201.8129          388107             971        19330
# 67   unknown  205.6034          421071             538        30434
# 72   unknown  204.8310          429574             264        23643
# 75   unknown  206.7023          355566             713        29172
# 76   unknown  202.4499          304219             583        53096
# 80   unknown  204.1875          328171            1511        83212
# 84   unknown  206.9273          466522             580        17484
# 85   unknown  204.5709          338876             247        80093
# 93   unknown  205.3240          318113            1013        55128
# 101  unknown  205.4607          395498             501        54722
# 103  unknown  208.8680          387275             366        37184
# 112  unknown  203.8524          350928             780        27885
# 122  unknown  206.0792          396908             849        15627
# 124  unknown  203.4162          325202            2038        57561
# 127  unknown  208.4877          395860            1310        40798
# 139  unknown  202.4196          380095             381        32114
# 149  unknown  207.0674          291509            2005        52165
# 150  unknown  207.3695          239459             367        88476
# 163  unknown  204.8611          294023             604        50511
# 187  unknown  206.0884          323186            1970        56626
#
#      BaB Round Count  BaB_lb_rhs
# 2                 74   -0.905954
# 35                55   -0.423785
# 38                53   -0.746259
# 52                67   -0.409347
# 53                84   -0.572727
# 62                43   -0.975119
# 67                62   -0.257492
# 72                64   -0.849308
# 75                51   -0.867633
# 76                66   -0.111598
# 80                80   -1.230325
# 84                52   -0.716623
# 85                63   -0.609169
# 93                56   -0.669371
# 101               47   -0.995754
# 103               52   -0.514338
# 112               61   -0.659371
# 122               54   -0.797171
# 124              159   -0.712715
# 127               60   -0.888108
# 139               82   -0.117817
# 149               59   -1.017418
# 150               59   -0.225417
# 163               46   -1.776599
# 187               50   -0.894539
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.1889               0               0            0
# 1         unsafe-pgd    0.1110               0               0            0
# 2            unknown  201.9391          299872            1543        23056
# 3         unsafe-pgd    0.0599               0               0            0
# 4         unsafe-pgd    0.0596               0               0            0
# 5         unsafe-pgd    0.0544               0               0            0
# 6               safe    8.3142             306             163          964
# 7               safe    3.5122             100              16          400
# 8    safe-incomplete    0.0412               0               0            0
# 9         unsafe-pgd    0.0534               0               0            0
# 10        unsafe-pgd    0.0514               0               0            0
# 11              safe    3.6628             100              35          419
# 12        unsafe-pgd    0.0606               0               0            0
# 13   safe-incomplete    0.3497               0               0            0
# 14              safe    2.8570               0               1           24
# 15        unsafe-pgd    0.0529               0               0            0
# 16        unsafe-pgd    0.0509               0               0            0
# 17   safe-incomplete    0.0380               0               0            0
# 18              safe   12.5685            1399             131         1537
# 19              safe   96.0354           86273             778        28763
# 20   safe-incomplete    0.0374               0               0            0
# 21        unsafe-pgd    0.0495               0               0            0
# 22   safe-incomplete    0.0399               0               0            0
# 23   safe-incomplete    0.0385               0               0            0
# 24        unsafe-pgd    0.0511               0               0            0
# 25        unsafe-pgd    0.0547               0               0            0
# 26        unsafe-pgd    0.0431               0               0            0
# 27   safe-incomplete    0.0363               0               0            0
# 28   safe-incomplete    0.0376               0               0            0
# 29        unsafe-pgd    0.0525               0               0            0
# 30   safe-incomplete    0.0377               0               0            0
# 31   safe-incomplete    0.0358               0               0            0
# 32        unsafe-pgd    0.0509               0               0            0
# 33   safe-incomplete    0.0375               0               0            0
# 34        unsafe-pgd    0.0459               0               0            0
# 35           unknown  206.5247          411292              94        14747
# 36   safe-incomplete    0.0431               0               0            0
# 37              safe   22.9579            5064             677         4556
# 38           unknown  204.9891          437661            1070        23970
# 39              safe    8.4905             231             117          861
# 40   safe-incomplete    0.0402               0               0            0
# 41   safe-incomplete    0.0388               0               0            0
# 42              safe    9.7726             311              34          806
# 43        unsafe-pgd    0.0527               0               0            0
# 44        unsafe-pgd    0.0501               0               0            0
# 45        unsafe-pgd    0.0509               0               0            0
# 46        unsafe-pgd    0.0507               0               0            0
# 47   safe-incomplete    0.0356               0               0            0
# 48              safe   62.0838           58436             339        29743
# 49              safe    3.1549              50              12          400
# 50        unsafe-pgd    0.0531               0               0            0
# 51              safe    3.1564              50               5          318
# 52           unknown  207.1943          266505            1087        52586
# 53           unknown  207.0963          319970            1606        53438
# 54              safe    5.2759             102              33          412
# 55              safe    6.3303             223              48          876
# 56              safe    8.4812            1174             319          975
# 57        unsafe-pgd    0.0463               0               0            0
# 58        unsafe-pgd    0.0452               0               0            0
# 59              safe    9.3354             278              69         1402
# 60   safe-incomplete    0.0399               0               0            0
# 61        unsafe-pgd    0.0516               0               0            0
# 62           unknown  201.8129          388107             971        19330
# 63        unsafe-pgd    0.1102               0               0            0
# 64              safe    3.3035              50              11          151
# 65        unsafe-pgd    0.0532               0               0            0
# 66        unsafe-pgd    0.0437               0               0            0
# 67           unknown  205.6034          421071             538        30434
# 68   safe-incomplete    0.0420               0               0            0
# 69        unsafe-pgd    0.0545               0               0            0
# 70              safe   11.5650             818             276         1646
# 71   safe-incomplete    0.0417               0               0            0
# 72           unknown  204.8310          429574             264        23643
# 73              safe    4.8601              50              24          794
# 74   safe-incomplete    0.0412               0               0            0
# 75           unknown  206.7023          355566             713        29172
# 76           unknown  202.4499          304219             583        53096
# 77   safe-incomplete    0.0470               0               0            0
# 78        unsafe-pgd    0.0464               0               0            0
# 79              safe    3.0689              50              15          400
# 80           unknown  204.1875          328171            1511        83212
# 81              safe  154.8660          150068            1409        68610
# 82        unsafe-pgd    0.0680               0               0            0
# 83              safe   25.0534            1064             336         3164
# 84           unknown  206.9273          466522             580        17484
# 85           unknown  204.5709          338876             247        80093
# 86   safe-incomplete    0.0455               0               0            0
# 87        unsafe-pgd    0.0542               0               0            0
# 88        unsafe-pgd    0.0473               0               0            0
# 89   safe-incomplete    0.0386               0               0            0
# 90        unsafe-pgd    0.0531               0               0            0
# 91        unsafe-pgd    0.0452               0               0            0
# 92        unsafe-pgd    0.0463               0               0            0
# 93           unknown  205.3240          318113            1013        55128
# 94        unsafe-pgd    0.0538               0               0            0
# 95              safe   16.5670            1458             406         2810
# 96        unsafe-pgd    0.0535               0               0            0
# 97              safe   67.6045           37016            1571        21660
# 98        unsafe-pgd    0.0479               0               0            0
# 99              safe   33.4649           22789             388        16343
# 100       unsafe-pgd    0.0550               0               0            0
# 101          unknown  205.4607          395498             501        54722
# 102             safe   22.9989            6003             171         4725
# 103          unknown  208.8680          387275             366        37184
# 104             safe    3.4729             100              17          400
# 105       unsafe-pgd    0.0549               0               0            0
# 106             safe    6.8618             205              52          835
# 107             safe    8.3753             211              53         1063
# 108       unsafe-pgd    0.0555               0               0            0
# 109  safe-incomplete    0.0389               0               0            0
# 110  safe-incomplete    0.0373               0               0            0
# 111             safe   16.1938            2518              91         2807
# 112          unknown  203.8524          350928             780        27885
# 113       unsafe-pgd    0.0552               0               0            0
# 114  safe-incomplete    0.0410               0               0            0
# 115             safe    4.7391             100              13          410
# 116       unsafe-pgd    0.0551               0               0            0
# 117  safe-incomplete    0.0375               0               0            0
# 118  safe-incomplete    0.0391               0               0            0
# 119       unsafe-pgd    0.0478               0               0            0
# 120             safe    2.8002               0               1           12
# 121  safe-incomplete    0.0387               0               0            0
# 122          unknown  206.0792          396908             849        15627
# 123       unsafe-pgd    0.0608               0               0            0
# 124          unknown  203.4162          325202            2038        57561
# 125       unsafe-pgd    0.0554               0               0            0
# 126       unsafe-pgd    0.0488               0               0            0
# 127          unknown  208.4877          395860            1310        40798
# 128       unsafe-pgd    0.0605               0               0            0
# 129       unsafe-pgd    0.0531               0               0            0
# 130       unsafe-pgd    0.0496               0               0            0
# 131             safe    4.1642             104              16          432
# 132             safe    2.8172               0               1           75
# 133  safe-incomplete    0.0435               0               0            0
# 134       unsafe-pgd    0.0434               0               0            0
# 135             safe    3.3592             100              67          400
# 136             safe    6.9096             274              29          614
# 137       unsafe-pgd    0.0465               0               0            0
# 138       unsafe-pgd    0.0462               0               0            0
# 139          unknown  202.4196          380095             381        32114
# 140  safe-incomplete    0.0476               0               0            0
# 141       unsafe-pgd    0.0567               0               0            0
# 142             safe    5.3002             150              18          830
# 143       unsafe-pgd    0.0468               0               0            0
# 144             safe  111.7894          100404             890        38870
# 145       unsafe-pgd    0.0508               0               0            0
# 146  safe-incomplete    0.0374               0               0            0
# 147  safe-incomplete    0.0366               0               0            0
# 148             safe    3.6584             100              23          428
# 149          unknown  207.0674          291509            2005        52165
# 150          unknown  207.3695          239459             367        88476
# 151       unsafe-pgd    0.0593               0               0            0
# 152  safe-incomplete    0.0379               0               0            0
# 153  safe-incomplete    0.3197               0               0            0
# 154             safe    8.9088             340             103          974
# 155       unsafe-pgd    0.0552               0               0            0
# 156       unsafe-pgd    0.0449               0               0            0
# 157  safe-incomplete    0.0371               0               0            0
# 158  safe-incomplete    0.0355               0               0            0
# 159             safe    8.1691             200              31         1025
# 160             safe   13.2490             760             275         1274
# 161  safe-incomplete    0.0404               0               0            0
# 162             safe   10.4267             381             147         1332
# 163          unknown  204.8611          294023             604        50511
# 164             safe    7.5996             150              41          699
# 165       unsafe-pgd    0.0560               0               0            0
# 166             safe   14.6012             489             129         2462
# 167       unsafe-pgd    0.0493               0               0            0
# 168       unsafe-pgd    0.0458               0               0            0
# 169  safe-incomplete    0.0376               0               0            0
# 170       unsafe-pgd    0.0445               0               0            0
# 171  safe-incomplete    0.3001               0               0            0
# 172             safe    3.1256              50               6          191
# 173       unsafe-pgd    0.0484               0               0            0
# 174             safe   22.4167            2971             430         3416
# 175       unsafe-pgd    0.0475               0               0            0
# 176       unsafe-pgd    0.0484               0               0            0
# 177  safe-incomplete    0.0432               0               0            0
# 178  safe-incomplete    0.0411               0               0            0
# 179  safe-incomplete    0.0387               0               0            0
# 180  safe-incomplete    0.0376               0               0            0
# 181             safe    7.1491             250              40         1144
# 182  safe-incomplete    0.0450               0               0            0
# 183       unsafe-pgd    0.0454               0               0            0
# 184             safe   15.9901            2636              81         2552
# 185             safe   12.8390             454             135         2454
# 186             safe    2.7997               0               1           22
# 187          unknown  206.0884          323186            1970        56626
# 188             safe   20.3162            2806             349         3499
# 189             safe    5.4595             146              74          833
# 190             safe    3.4176             100              16          400
# 191             safe   27.9138           19277             126         9538
# 192       unsafe-pgd    0.0498               0               0            0
# 193  safe-incomplete    0.0376               0               0            0
# 194             safe   25.8293            6159             561         5651
# 195             safe    2.7884               0               1           48
# 196       unsafe-pgd    0.0469               0               0            0
# 197             safe    4.8378             100              28          799
# 198       unsafe-pgd    0.0508               0               0            0
# 199             safe   53.0898           16750             485        11197
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                 74   -0.905954
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 18         NaN
# 7                  3         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 4         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 1         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                35         NaN
# 19                53         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 0         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                55   -0.423785
# 36                 0         NaN
# 37                71         NaN
# 38                53   -0.746259
# 39                13         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                14         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                51         NaN
# 49                 2         NaN
# 50                 0         NaN
# 51                 2         NaN
# 52                67   -0.409347
# 53                84   -0.572727
# 54                 6         NaN
# 55                10         NaN
# 56                21         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                15         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                43   -0.975119
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                62   -0.257492
# 68                 0         NaN
# 69                 0         NaN
# 70                33         NaN
# 71                 0         NaN
# 72                64   -0.849308
# 73                 4         NaN
# 74                 0         NaN
# 75                51   -0.867633
# 76                66   -0.111598
# 77                 0         NaN
# 78                 0         NaN
# 79                 2         NaN
# 80                80   -1.230325
# 81                28         NaN
# 82                 0         NaN
# 83                51         NaN
# 84                52   -0.716623
# 85                63   -0.609169
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                56   -0.669371
# 94                 0         NaN
# 95                37         NaN
# 96                 0         NaN
# 97               122         NaN
# 98                 0         NaN
# 99                34         NaN
# 100                0         NaN
# 101               47   -0.995754
# 102               45         NaN
# 103               52   -0.514338
# 104                3         NaN
# 105                0         NaN
# 106               12         NaN
# 107               11         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               50         NaN
# 112               61   -0.659371
# 113                0         NaN
# 114                0         NaN
# 115                4         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122               54   -0.797171
# 123                0         NaN
# 124              159   -0.712715
# 125                0         NaN
# 126                0         NaN
# 127               60   -0.888108
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                5         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                3         NaN
# 136               12         NaN
# 137                0         NaN
# 138                0         NaN
# 139               82   -0.117817
# 140                0         NaN
# 141                0         NaN
# 142                6         NaN
# 143                0         NaN
# 144               65         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                4         NaN
# 149               59   -1.017418
# 150               59   -0.225417
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               19         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                9         NaN
# 160               33         NaN
# 161                0         NaN
# 162               25         NaN
# 163               46   -1.776599
# 164                8         NaN
# 165                0         NaN
# 166               23         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174               69         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181               10         NaN
# 182                0         NaN
# 183                0         NaN
# 184               37         NaN
# 185               20         NaN
# 186                1         NaN
# 187               50   -0.894539
# 188               55         NaN
# 189               10         NaN
# 190                3         NaN
# 191               33         NaN
# 192                0         NaN
# 193                0         NaN
# 194               81         NaN
# 195                1         NaN
# 196                0         NaN
# 197                5         NaN
# 198                0         NaN
# 199              136         NaN
# #Cuts 34705
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               59   17.978127    9012.677966     198.542373   4905.847458
# safe-incomplete    46    0.083070       0.000000       0.000000      0.000000
# unknown            25  205.364916  354618.480000     919.640000  42922.320000
# unsafe-pgd         70    0.053057       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  24.305085
# safe-incomplete        0.000000
# unknown               63.960000
# unsafe-pgd             0.000000
# safe number 105.0
# safe time 10.13838761904762
# safe domain 5064.266666666666
# safe cut 111.56190476190476
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((105.0, 10.13838761904762, 9012.677966101695, 198.54237288135593),)

# %%
main('cifar_cnn_b_adv/gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe    6.5585             187               0            0
# 7     safe    3.2760               1               0            0
# 11    safe    3.4646               6               0            0
# 14    safe    3.2520               0               0            0
# 18    safe   11.4742            2763               0            0
# 37    safe   35.8213           15041               0            0
# 39    safe    5.2983              65               0            0
# 42    safe    5.6278             201               0            0
# 49    safe    3.6831               0               0            0
# 51    safe    3.5434               0               0            0
# 54    safe    4.4351               8               0            0
# 55    safe    3.9243               3               0            0
# 56    safe   80.0719          127057               0            0
# 59    safe    4.9208              39               0            0
# 64    safe    3.4639               0               0            0
# 70    safe   12.9342            1197               0            0
# 73    safe    3.7805               0               0            0
# 76    safe  135.1134          192866               0            0
# 79    safe    3.5533               0               0            0
# 83    safe   11.7892             367               0            0
# 95    safe   11.6171            1228               0            0
# 104   safe    3.5088               0               0            0
# 106   safe    5.5168              99               0            0
# 107   safe    4.2883               8               0            0
# 111   safe   23.4096           10109               0            0
# 115   safe    3.7919               0               0            0
# 120   safe    3.3700               0               0            0
# 131   safe    3.8904               1               0            0
# 132   safe    3.6126               0               0            0
# 135   safe    3.7664               1               0            0
# 136   safe    5.9320             171               0            0
# 142   safe    4.0828               2               0            0
# 148   safe    3.7524               2               0            0
# 150   safe  157.8410          206740               0            0
# 154   safe    7.7291             117               0            0
# 159   safe    4.1346               0               0            0
# 160   safe   12.0045            1420               0            0
# 162   safe   11.4091             796               0            0
# 164   safe    4.1948               0               0            0
# 166   safe    6.2917             123               0            0
# 172   safe    3.5746               0               0            0
# 174   safe   40.6785           18767               0            0
# 181   safe    4.2323               7               0            0
# 184   safe  101.2723          130930               0            0
# 185   safe    5.5981              39               0            0
# 186   safe    3.2309               0               0            0
# 188   safe   29.3976           14335               0            0
# 189   safe    4.9468              64               0            0
# 190   safe    3.4998               0               0            0
# 195   safe    3.6970               0               0            0
# 197   safe    3.9581               0               0            0
# 199   safe  147.4252          175341               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 6                 16         NaN
# 7                  2         NaN
# 11                 2         NaN
# 14                 1         NaN
# 18                31         NaN
# 37                78         NaN
# 39                 9         NaN
# 42                11         NaN
# 49                 1         NaN
# 51                 1         NaN
# 54                 4         NaN
# 55                 4         NaN
# 56                57         NaN
# 59                 7         NaN
# 64                 1         NaN
# 70                34         NaN
# 73                 2         NaN
# 76                56         NaN
# 79                 1         NaN
# 83                34         NaN
# 95                30         NaN
# 104                1         NaN
# 106                9         NaN
# 107                5         NaN
# 111               43         NaN
# 115                2         NaN
# 120                1         NaN
# 131                2         NaN
# 132                1         NaN
# 135                2         NaN
# 136               10         NaN
# 142                3         NaN
# 148                2         NaN
# 150               61         NaN
# 154               15         NaN
# 159                4         NaN
# 160               31         NaN
# 162               32         NaN
# 164                4         NaN
# 166               14         NaN
# 172                1         NaN
# 174               58         NaN
# 181                5         NaN
# 184               52         NaN
# 185               11         NaN
# 186                1         NaN
# 188               44         NaN
# 189                8         NaN
# 190                1         NaN
# 195                1         NaN
# 197                2         NaN
# 199              159         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  202.6813          322759               0            0
# 19   unknown  209.9724          311277               0            0
# 35   unknown  204.5337          326372               0            0
# 38   unknown  202.9299          247640               0            0
# 48   unknown  205.1658          338970               0            0
# 52   unknown  205.5778          294294               0            0
# 53   unknown  210.7118          289281               0            0
# 62   unknown  211.4284          354569               0            0
# 67   unknown  206.9469          231392               0            0
# 72   unknown  207.5698          337900               0            0
# 75   unknown  204.2653          333067               0            0
# 80   unknown  212.9578          283236               0            0
# 81   unknown  204.4125          334643               0            0
# 84   unknown  202.0180          397607               0            0
# 85   unknown  202.3451          225482               0            0
# 93   unknown  206.4153          313097               0            0
# 97   unknown  202.2348          162558               0            0
# 99   unknown  205.3798          314356               0            0
# 101  unknown  206.7366          298867               0            0
# 102  unknown  204.2163          314325               0            0
# 103  unknown  206.2227          385426               0            0
# 112  unknown  213.1531          408607               0            0
# 122  unknown  210.6127          356333               0            0
# 124  unknown  202.4398          336993               0            0
# 127  unknown  206.7441          185541               0            0
# 139  unknown  202.1986          275522               0            0
# 144  unknown  203.6236          189084               0            0
# 149  unknown  205.9685          314832               0            0
# 163  unknown  206.8411          207403               0            0
# 187  unknown  203.3364          164487               0            0
# 191  unknown  206.9684          373646               0            0
# 194  unknown  208.1472          307585               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 2                 97   -0.984071
# 19                60   -0.290296
# 35                40   -0.505879
# 38                82   -0.158178
# 48                52   -0.612078
# 52                93   -0.493771
# 53                72   -0.499693
# 62                35   -1.029347
# 67                45   -0.355060
# 72                42   -0.477799
# 75                47   -0.918535
# 80                81   -1.577635
# 81                37   -0.538917
# 84                42   -0.770491
# 85                65   -0.796465
# 93                54   -0.292554
# 97                81   -0.021126
# 99                49   -0.686575
# 101               35   -1.062314
# 102               57   -0.770696
# 103               43   -0.571609
# 112               54   -0.686615
# 122               48   -0.895522
# 124              113   -1.215143
# 127               90   -0.753030
# 139               99   -0.235292
# 144               71   -0.112486
# 149               72   -1.100679
# 163              101   -1.126575
# 187               51   -1.694130
# 191               45   -0.554212
# 194               77   -0.680208
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.1317               0               0            0
# 1         unsafe-pgd    0.0616               0               0            0
# 2            unknown  202.6813          322759               0            0
# 3         unsafe-pgd    0.0594               0               0            0
# 4         unsafe-pgd    0.0583               0               0            0
# 5         unsafe-pgd    0.0539               0               0            0
# 6               safe    6.5585             187               0            0
# 7               safe    3.2760               1               0            0
# 8    safe-incomplete    0.0591               0               0            0
# 9         unsafe-pgd    0.0610               0               0            0
# 10        unsafe-pgd    0.0569               0               0            0
# 11              safe    3.4646               6               0            0
# 12        unsafe-pgd    0.0649               0               0            0
# 13   safe-incomplete    0.4758               0               0            0
# 14              safe    3.2520               0               0            0
# 15        unsafe-pgd    0.1211               0               0            0
# 16        unsafe-pgd    0.1110               0               0            0
# 17   safe-incomplete    0.0940               0               0            0
# 18              safe   11.4742            2763               0            0
# 19           unknown  209.9724          311277               0            0
# 20   safe-incomplete    0.0733               0               0            0
# 21        unsafe-pgd    0.0586               0               0            0
# 22   safe-incomplete    0.0406               0               0            0
# 23   safe-incomplete    0.0435               0               0            0
# 24        unsafe-pgd    0.0584               0               0            0
# 25        unsafe-pgd    0.0621               0               0            0
# 26        unsafe-pgd    0.0457               0               0            0
# 27   safe-incomplete    0.0391               0               0            0
# 28   safe-incomplete    0.0456               0               0            0
# 29        unsafe-pgd    0.0611               0               0            0
# 30   safe-incomplete    0.0430               0               0            0
# 31   safe-incomplete    0.0400               0               0            0
# 32        unsafe-pgd    0.0563               0               0            0
# 33   safe-incomplete    0.0428               0               0            0
# 34        unsafe-pgd    0.0542               0               0            0
# 35           unknown  204.5337          326372               0            0
# 36   safe-incomplete    0.1636               0               0            0
# 37              safe   35.8213           15041               0            0
# 38           unknown  202.9299          247640               0            0
# 39              safe    5.2983              65               0            0
# 40   safe-incomplete    0.0714               0               0            0
# 41   safe-incomplete    0.0500               0               0            0
# 42              safe    5.6278             201               0            0
# 43        unsafe-pgd    0.1150               0               0            0
# 44        unsafe-pgd    0.0670               0               0            0
# 45        unsafe-pgd    0.0816               0               0            0
# 46        unsafe-pgd    0.0631               0               0            0
# 47   safe-incomplete    0.0442               0               0            0
# 48           unknown  205.1658          338970               0            0
# 49              safe    3.6831               0               0            0
# 50        unsafe-pgd    0.1208               0               0            0
# 51              safe    3.5434               0               0            0
# 52           unknown  205.5778          294294               0            0
# 53           unknown  210.7118          289281               0            0
# 54              safe    4.4351               8               0            0
# 55              safe    3.9243               3               0            0
# 56              safe   80.0719          127057               0            0
# 57        unsafe-pgd    0.0682               0               0            0
# 58        unsafe-pgd    0.0499               0               0            0
# 59              safe    4.9208              39               0            0
# 60   safe-incomplete    0.1071               0               0            0
# 61        unsafe-pgd    0.1156               0               0            0
# 62           unknown  211.4284          354569               0            0
# 63        unsafe-pgd    0.0706               0               0            0
# 64              safe    3.4639               0               0            0
# 65        unsafe-pgd    0.1389               0               0            0
# 66        unsafe-pgd    0.1128               0               0            0
# 67           unknown  206.9469          231392               0            0
# 68   safe-incomplete    0.1351               0               0            0
# 69        unsafe-pgd    0.0680               0               0            0
# 70              safe   12.9342            1197               0            0
# 71   safe-incomplete    0.0982               0               0            0
# 72           unknown  207.5698          337900               0            0
# 73              safe    3.7805               0               0            0
# 74   safe-incomplete    0.0713               0               0            0
# 75           unknown  204.2653          333067               0            0
# 76              safe  135.1134          192866               0            0
# 77   safe-incomplete    0.0803               0               0            0
# 78        unsafe-pgd    0.0620               0               0            0
# 79              safe    3.5533               0               0            0
# 80           unknown  212.9578          283236               0            0
# 81           unknown  204.4125          334643               0            0
# 82        unsafe-pgd    0.1139               0               0            0
# 83              safe   11.7892             367               0            0
# 84           unknown  202.0180          397607               0            0
# 85           unknown  202.3451          225482               0            0
# 86   safe-incomplete    0.0855               0               0            0
# 87        unsafe-pgd    0.0613               0               0            0
# 88        unsafe-pgd    0.0569               0               0            0
# 89   safe-incomplete    0.0427               0               0            0
# 90        unsafe-pgd    0.0570               0               0            0
# 91        unsafe-pgd    0.0510               0               0            0
# 92        unsafe-pgd    0.0524               0               0            0
# 93           unknown  206.4153          313097               0            0
# 94        unsafe-pgd    0.1021               0               0            0
# 95              safe   11.6171            1228               0            0
# 96        unsafe-pgd    0.0795               0               0            0
# 97           unknown  202.2348          162558               0            0
# 98        unsafe-pgd    0.1426               0               0            0
# 99           unknown  205.3798          314356               0            0
# 100       unsafe-pgd    0.1257               0               0            0
# 101          unknown  206.7366          298867               0            0
# 102          unknown  204.2163          314325               0            0
# 103          unknown  206.2227          385426               0            0
# 104             safe    3.5088               0               0            0
# 105       unsafe-pgd    0.1061               0               0            0
# 106             safe    5.5168              99               0            0
# 107             safe    4.2883               8               0            0
# 108       unsafe-pgd    0.0764               0               0            0
# 109  safe-incomplete    0.0519               0               0            0
# 110  safe-incomplete    0.0474               0               0            0
# 111             safe   23.4096           10109               0            0
# 112          unknown  213.1531          408607               0            0
# 113       unsafe-pgd    0.0835               0               0            0
# 114  safe-incomplete    0.0479               0               0            0
# 115             safe    3.7919               0               0            0
# 116       unsafe-pgd    0.0883               0               0            0
# 117  safe-incomplete    0.0589               0               0            0
# 118  safe-incomplete    0.0546               0               0            0
# 119       unsafe-pgd    0.0637               0               0            0
# 120             safe    3.3700               0               0            0
# 121  safe-incomplete    0.0771               0               0            0
# 122          unknown  210.6127          356333               0            0
# 123       unsafe-pgd    0.0718               0               0            0
# 124          unknown  202.4398          336993               0            0
# 125       unsafe-pgd    0.1145               0               0            0
# 126       unsafe-pgd    0.0542               0               0            0
# 127          unknown  206.7441          185541               0            0
# 128       unsafe-pgd    0.1234               0               0            0
# 129       unsafe-pgd    0.0660               0               0            0
# 130       unsafe-pgd    0.0591               0               0            0
# 131             safe    3.8904               1               0            0
# 132             safe    3.6126               0               0            0
# 133  safe-incomplete    0.0686               0               0            0
# 134       unsafe-pgd    0.0644               0               0            0
# 135             safe    3.7664               1               0            0
# 136             safe    5.9320             171               0            0
# 137       unsafe-pgd    0.0697               0               0            0
# 138       unsafe-pgd    0.0604               0               0            0
# 139          unknown  202.1986          275522               0            0
# 140  safe-incomplete    0.1209               0               0            0
# 141       unsafe-pgd    0.1179               0               0            0
# 142             safe    4.0828               2               0            0
# 143       unsafe-pgd    0.1285               0               0            0
# 144          unknown  203.6236          189084               0            0
# 145       unsafe-pgd    0.1546               0               0            0
# 146  safe-incomplete    0.0495               0               0            0
# 147  safe-incomplete    0.0498               0               0            0
# 148             safe    3.7524               2               0            0
# 149          unknown  205.9685          314832               0            0
# 150             safe  157.8410          206740               0            0
# 151       unsafe-pgd    0.1133               0               0            0
# 152  safe-incomplete    0.0480               0               0            0
# 153  safe-incomplete    0.5961               0               0            0
# 154             safe    7.7291             117               0            0
# 155       unsafe-pgd    0.1315               0               0            0
# 156       unsafe-pgd    0.1141               0               0            0
# 157  safe-incomplete    0.0987               0               0            0
# 158  safe-incomplete    0.0540               0               0            0
# 159             safe    4.1346               0               0            0
# 160             safe   12.0045            1420               0            0
# 161  safe-incomplete    0.0969               0               0            0
# 162             safe   11.4091             796               0            0
# 163          unknown  206.8411          207403               0            0
# 164             safe    4.1948               0               0            0
# 165       unsafe-pgd    0.1316               0               0            0
# 166             safe    6.2917             123               0            0
# 167       unsafe-pgd    0.0725               0               0            0
# 168       unsafe-pgd    0.0564               0               0            0
# 169  safe-incomplete    0.0470               0               0            0
# 170       unsafe-pgd    0.0605               0               0            0
# 171  safe-incomplete    0.5775               0               0            0
# 172             safe    3.5746               0               0            0
# 173       unsafe-pgd    0.1136               0               0            0
# 174             safe   40.6785           18767               0            0
# 175       unsafe-pgd    0.1069               0               0            0
# 176       unsafe-pgd    0.0567               0               0            0
# 177  safe-incomplete    0.0450               0               0            0
# 178  safe-incomplete    0.0453               0               0            0
# 179  safe-incomplete    0.0477               0               0            0
# 180  safe-incomplete    0.0423               0               0            0
# 181             safe    4.2323               7               0            0
# 182  safe-incomplete    0.1095               0               0            0
# 183       unsafe-pgd    0.0692               0               0            0
# 184             safe  101.2723          130930               0            0
# 185             safe    5.5981              39               0            0
# 186             safe    3.2309               0               0            0
# 187          unknown  203.3364          164487               0            0
# 188             safe   29.3976           14335               0            0
# 189             safe    4.9468              64               0            0
# 190             safe    3.4998               0               0            0
# 191          unknown  206.9684          373646               0            0
# 192       unsafe-pgd    0.1110               0               0            0
# 193  safe-incomplete    0.0487               0               0            0
# 194          unknown  208.1472          307585               0            0
# 195             safe    3.6970               0               0            0
# 196       unsafe-pgd    0.1196               0               0            0
# 197             safe    3.9581               0               0            0
# 198       unsafe-pgd    0.1255               0               0            0
# 199             safe  147.4252          175341               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                 97   -0.984071
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 16         NaN
# 7                  2         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 2         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 1         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                31         NaN
# 19                60   -0.290296
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 0         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                40   -0.505879
# 36                 0         NaN
# 37                78         NaN
# 38                82   -0.158178
# 39                 9         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                11         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                52   -0.612078
# 49                 1         NaN
# 50                 0         NaN
# 51                 1         NaN
# 52                93   -0.493771
# 53                72   -0.499693
# 54                 4         NaN
# 55                 4         NaN
# 56                57         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 7         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                35   -1.029347
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                45   -0.355060
# 68                 0         NaN
# 69                 0         NaN
# 70                34         NaN
# 71                 0         NaN
# 72                42   -0.477799
# 73                 2         NaN
# 74                 0         NaN
# 75                47   -0.918535
# 76                56         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 1         NaN
# 80                81   -1.577635
# 81                37   -0.538917
# 82                 0         NaN
# 83                34         NaN
# 84                42   -0.770491
# 85                65   -0.796465
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                54   -0.292554
# 94                 0         NaN
# 95                30         NaN
# 96                 0         NaN
# 97                81   -0.021126
# 98                 0         NaN
# 99                49   -0.686575
# 100                0         NaN
# 101               35   -1.062314
# 102               57   -0.770696
# 103               43   -0.571609
# 104                1         NaN
# 105                0         NaN
# 106                9         NaN
# 107                5         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               43         NaN
# 112               54   -0.686615
# 113                0         NaN
# 114                0         NaN
# 115                2         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122               48   -0.895522
# 123                0         NaN
# 124              113   -1.215143
# 125                0         NaN
# 126                0         NaN
# 127               90   -0.753030
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                2         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                2         NaN
# 136               10         NaN
# 137                0         NaN
# 138                0         NaN
# 139               99   -0.235292
# 140                0         NaN
# 141                0         NaN
# 142                3         NaN
# 143                0         NaN
# 144               71   -0.112486
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                2         NaN
# 149               72   -1.100679
# 150               61         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               15         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                4         NaN
# 160               31         NaN
# 161                0         NaN
# 162               32         NaN
# 163              101   -1.126575
# 164                4         NaN
# 165                0         NaN
# 166               14         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                1         NaN
# 173                0         NaN
# 174               58         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                5         NaN
# 182                0         NaN
# 183                0         NaN
# 184               52         NaN
# 185               11         NaN
# 186                1         NaN
# 187               51   -1.694130
# 188               44         NaN
# 189                8         NaN
# 190                1         NaN
# 191               45   -0.554212
# 192                0         NaN
# 193                0         NaN
# 194               77   -0.680208
# 195                1         NaN
# 196                0         NaN
# 197                2         NaN
# 198                0         NaN
# 199              159         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               52   18.877710   17309.634615            0.0         0.0
# safe-incomplete    46    0.120896       0.000000            0.0         0.0
# unknown            32  206.086109  298035.968750            0.0         0.0
# unsafe-pgd         70    0.084361       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  18.596154
# safe-incomplete        0.000000
# unknown               63.437500
# unsafe-pgd             0.000000
# safe number 98.0
# safe time 10.07349081632653
# safe domain 9184.704081632653
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((98.0, 10.07349081632653, 17309.634615384617, 0.0),)

# %%
main('cifar_cnn_b_adv/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe   11.4180             256             121          964
# 7     safe    5.5577             100              16          400
# 11    safe    5.4818             100              35          419
# 14    safe    4.5390               0               1           24
# 18    safe   19.8327            1476             127         1635
# 19    safe   34.8175           10770             273         9745
# 37    safe   35.3340            5069             771         4281
# 39    safe   11.2962             231             110          861
# 42    safe   13.2190             261              33          806
# 48    safe   93.2955           76736             459        42487
# 49    safe    4.9979              50              12          400
# 51    safe    4.9083              50               5          318
# 52    safe  144.6037          103052            1736        30705
# 54    safe    7.9057             102              32          412
# 55    safe    9.3932             223              48          876
# 56    safe   22.4753            7800             520         4781
# 59    safe   12.6972             278              68         1402
# 64    safe    4.8915              50              11          151
# 67    safe  128.3961          103999            1831        47293
# 70    safe   18.7180             818             276         1646
# 73    safe    7.0505              50              24          794
# 76    safe  189.5459          137491            1748        49122
# 79    safe    4.8936              50              15          400
# 81    safe   35.3127           24546             338        18404
# 83    safe   41.8527            1064             339         3164
# 93    safe  141.7616           95071            2278        46401
# 95    safe   23.7893            1456             477         2808
# 97    safe  108.4170           39550            2957        21042
# 99    safe   33.3624           15872             304        12001
# 102   safe   39.7286           10211             195         8906
# 104   safe    5.7695             100              17          400
# 106   safe    8.3677             197              46          526
# 107   safe   11.8730             161              53         1063
# 111   safe   31.2873            2522              99         2818
# 115   safe    7.3607             100              13          410
# 120   safe    4.4813               0               1           12
# 131   safe    6.3433             104              16          432
# 132   safe    4.7317               0               1           75
# 135   safe    5.5669             100              67          400
# 136   safe   10.1734             274              38          615
# 142   safe    7.5392             100              33          830
# 144   safe   82.9915           42956            1594        33011
# 148   safe    6.0876             100              23          428
# 150   safe  121.4258           76546            1200        31647
# 154   safe   13.3737             340             106          974
# 159   safe   11.1736             200              31         1025
# 160   safe   27.0268             889             320         1296
# 162   safe   16.0056             429             171         1356
# 164   safe   10.5482             100              40          731
# 166   safe   19.8485             439             138         2477
# 172   safe    5.3186              50               6          191
# 174   safe   30.1553            1818             373         2785
# 181   safe   10.5285             200              40         1144
# 184   safe   31.1916            6201              75         5784
# 185   safe   18.7033             454             150         2496
# 186   safe    4.5593               0               1           22
# 188   safe   31.0947            3222             399         3764
# 189   safe    8.3999             146              58          833
# 190   safe    5.7649             100              16          400
# 191   safe   43.1854           15519              98        11819
# 195   safe    4.8695               0               1           48
# 197   safe    7.4240             100              28          799
# 199   safe   97.1611           15069             515        10296
#
#      BaB Round Count  BaB_lb_rhs
# 6                 18         NaN
# 7                  3         NaN
# 11                 4         NaN
# 14                 1         NaN
# 18                36         NaN
# 19                44         NaN
# 37                71         NaN
# 39                13         NaN
# 42                14         NaN
# 48                51         NaN
# 49                 2         NaN
# 51                 2         NaN
# 52                56         NaN
# 54                 6         NaN
# 55                10         NaN
# 56                33         NaN
# 59                15         NaN
# 64                 2         NaN
# 67                47         NaN
# 70                33         NaN
# 73                 4         NaN
# 76                60         NaN
# 79                 2         NaN
# 81                22         NaN
# 83                51         NaN
# 93                69         NaN
# 95                37         NaN
# 97               137         NaN
# 99                32         NaN
# 102               46         NaN
# 104                3         NaN
# 106               10         NaN
# 107               11         NaN
# 111               46         NaN
# 115                4         NaN
# 120                1         NaN
# 131                5         NaN
# 132                1         NaN
# 135                3         NaN
# 136               12         NaN
# 142                6         NaN
# 144               59         NaN
# 148                4         NaN
# 150               45         NaN
# 154               19         NaN
# 159                9         NaN
# 160               34         NaN
# 162               28         NaN
# 164                8         NaN
# 166               23         NaN
# 172                2         NaN
# 174               55         NaN
# 181               10         NaN
# 184               47         NaN
# 185               21         NaN
# 186                1         NaN
# 188               55         NaN
# 189               10         NaN
# 190                3         NaN
# 191               37         NaN
# 195                1         NaN
# 197                5         NaN
# 199              138         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 2    unknown  201.6158          215269            1503        53340
# 35   unknown  206.9869          422525            1162        17729
# 38   unknown  204.8090          254704            2120        26012
# 53   unknown  205.3247          158782            4673        62475
# 62   unknown  204.6678          307279            5206        20353
# 72   unknown  204.7119          203661            1467        25060
# 75   unknown  208.8616          192197            1998        49135
# 80   unknown  209.2497          141180            2154        60287
# 84   unknown  204.3813          247333            1564        26787
# 85   unknown  212.4964          181715            2384        66060
# 101  unknown  202.0382          156692            2436        57481
# 103  unknown  206.0437          295372            2826        28312
# 112  unknown  204.9724          221597            1798        37844
# 122  unknown  214.4081          328771            3068        19947
# 124  unknown  203.0887          198970            1905        29340
# 127  unknown  206.8334          147796            6264        63229
# 139  unknown  205.5054          276983             927        68155
# 149  unknown  207.7711          238018            3687        54922
# 163  unknown  201.9801          139202            2613        45244
# 187  unknown  204.5119          121830            1484        37323
# 194  unknown  201.9959          205055            3840        41863
#
#      BaB Round Count  BaB_lb_rhs
# 2                 74   -0.901989
# 35                56   -0.423785
# 38                97   -0.754147
# 53                90   -0.489196
# 62                38   -0.975488
# 72                38   -0.437003
# 75                45   -0.620336
# 80                89   -1.095297
# 84                40   -0.720881
# 85                56   -0.368688
# 101               32   -0.647785
# 103               47   -0.514336
# 112               54   -0.639030
# 122               48   -0.808523
# 124              114   -1.081464
# 127              120   -1.164400
# 139               82   -0.117957
# 149               57   -1.017414
# 163               96   -0.603255
# 187              134   -0.044011
# 194               86   -0.604292
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.8971               0               0            0
# 1         unsafe-pgd    0.0939               0               0            0
# 2            unknown  201.6158          215269            1503        53340
# 3         unsafe-pgd    0.0766               0               0            0
# 4         unsafe-pgd    0.0618               0               0            0
# 5         unsafe-pgd    0.0553               0               0            0
# 6               safe   11.4180             256             121          964
# 7               safe    5.5577             100              16          400
# 8    safe-incomplete    0.0449               0               0            0
# 9         unsafe-pgd    0.0566               0               0            0
# 10        unsafe-pgd    0.0574               0               0            0
# 11              safe    5.4818             100              35          419
# 12        unsafe-pgd    0.1237               0               0            0
# 13   safe-incomplete    0.5242               0               0            0
# 14              safe    4.5390               0               1           24
# 15        unsafe-pgd    0.0924               0               0            0
# 16        unsafe-pgd    0.0618               0               0            0
# 17   safe-incomplete    0.0952               0               0            0
# 18              safe   19.8327            1476             127         1635
# 19              safe   34.8175           10770             273         9745
# 20   safe-incomplete    0.0852               0               0            0
# 21        unsafe-pgd    0.0530               0               0            0
# 22   safe-incomplete    0.0389               0               0            0
# 23   safe-incomplete    0.0389               0               0            0
# 24        unsafe-pgd    0.0520               0               0            0
# 25        unsafe-pgd    0.0566               0               0            0
# 26        unsafe-pgd    0.0459               0               0            0
# 27   safe-incomplete    0.0370               0               0            0
# 28   safe-incomplete    0.0384               0               0            0
# 29        unsafe-pgd    0.0543               0               0            0
# 30   safe-incomplete    0.0390               0               0            0
# 31   safe-incomplete    0.0364               0               0            0
# 32        unsafe-pgd    0.0521               0               0            0
# 33   safe-incomplete    0.0391               0               0            0
# 34        unsafe-pgd    0.0554               0               0            0
# 35           unknown  206.9869          422525            1162        17729
# 36   safe-incomplete    0.0687               0               0            0
# 37              safe   35.3340            5069             771         4281
# 38           unknown  204.8090          254704            2120        26012
# 39              safe   11.2962             231             110          861
# 40   safe-incomplete    0.0683               0               0            0
# 41   safe-incomplete    0.0428               0               0            0
# 42              safe   13.2190             261              33          806
# 43        unsafe-pgd    0.0709               0               0            0
# 44        unsafe-pgd    0.0570               0               0            0
# 45        unsafe-pgd    0.0533               0               0            0
# 46        unsafe-pgd    0.0569               0               0            0
# 47   safe-incomplete    0.0374               0               0            0
# 48              safe   93.2955           76736             459        42487
# 49              safe    4.9979              50              12          400
# 50        unsafe-pgd    0.0615               0               0            0
# 51              safe    4.9083              50               5          318
# 52              safe  144.6037          103052            1736        30705
# 53           unknown  205.3247          158782            4673        62475
# 54              safe    7.9057             102              32          412
# 55              safe    9.3932             223              48          876
# 56              safe   22.4753            7800             520         4781
# 57        unsafe-pgd    0.1074               0               0            0
# 58        unsafe-pgd    0.0975               0               0            0
# 59              safe   12.6972             278              68         1402
# 60   safe-incomplete    0.1017               0               0            0
# 61        unsafe-pgd    0.1070               0               0            0
# 62           unknown  204.6678          307279            5206        20353
# 63        unsafe-pgd    0.0603               0               0            0
# 64              safe    4.8915              50              11          151
# 65        unsafe-pgd    0.0711               0               0            0
# 66        unsafe-pgd    0.0491               0               0            0
# 67              safe  128.3961          103999            1831        47293
# 68   safe-incomplete    0.0629               0               0            0
# 69        unsafe-pgd    0.0603               0               0            0
# 70              safe   18.7180             818             276         1646
# 71   safe-incomplete    0.1063               0               0            0
# 72           unknown  204.7119          203661            1467        25060
# 73              safe    7.0505              50              24          794
# 74   safe-incomplete    0.0671               0               0            0
# 75           unknown  208.8616          192197            1998        49135
# 76              safe  189.5459          137491            1748        49122
# 77   safe-incomplete    0.0494               0               0            0
# 78        unsafe-pgd    0.0484               0               0            0
# 79              safe    4.8936              50              15          400
# 80           unknown  209.2497          141180            2154        60287
# 81              safe   35.3127           24546             338        18404
# 82        unsafe-pgd    0.0896               0               0            0
# 83              safe   41.8527            1064             339         3164
# 84           unknown  204.3813          247333            1564        26787
# 85           unknown  212.4964          181715            2384        66060
# 86   safe-incomplete    0.0517               0               0            0
# 87        unsafe-pgd    0.0564               0               0            0
# 88        unsafe-pgd    0.0491               0               0            0
# 89   safe-incomplete    0.0389               0               0            0
# 90        unsafe-pgd    0.0558               0               0            0
# 91        unsafe-pgd    0.0471               0               0            0
# 92        unsafe-pgd    0.0468               0               0            0
# 93              safe  141.7616           95071            2278        46401
# 94        unsafe-pgd    0.1151               0               0            0
# 95              safe   23.7893            1456             477         2808
# 96        unsafe-pgd    0.1008               0               0            0
# 97              safe  108.4170           39550            2957        21042
# 98        unsafe-pgd    0.1057               0               0            0
# 99              safe   33.3624           15872             304        12001
# 100       unsafe-pgd    0.1160               0               0            0
# 101          unknown  202.0382          156692            2436        57481
# 102             safe   39.7286           10211             195         8906
# 103          unknown  206.0437          295372            2826        28312
# 104             safe    5.7695             100              17          400
# 105       unsafe-pgd    0.1229               0               0            0
# 106             safe    8.3677             197              46          526
# 107             safe   11.8730             161              53         1063
# 108       unsafe-pgd    0.0802               0               0            0
# 109  safe-incomplete    0.0413               0               0            0
# 110  safe-incomplete    0.0462               0               0            0
# 111             safe   31.2873            2522              99         2818
# 112          unknown  204.9724          221597            1798        37844
# 113       unsafe-pgd    0.0867               0               0            0
# 114  safe-incomplete    0.0439               0               0            0
# 115             safe    7.3607             100              13          410
# 116       unsafe-pgd    0.1307               0               0            0
# 117  safe-incomplete    0.0962               0               0            0
# 118  safe-incomplete    0.0750               0               0            0
# 119       unsafe-pgd    0.0509               0               0            0
# 120             safe    4.4813               0               1           12
# 121  safe-incomplete    0.0555               0               0            0
# 122          unknown  214.4081          328771            3068        19947
# 123       unsafe-pgd    0.1199               0               0            0
# 124          unknown  203.0887          198970            1905        29340
# 125       unsafe-pgd    0.1153               0               0            0
# 126       unsafe-pgd    0.1052               0               0            0
# 127          unknown  206.8334          147796            6264        63229
# 128       unsafe-pgd    0.0853               0               0            0
# 129       unsafe-pgd    0.0553               0               0            0
# 130       unsafe-pgd    0.0561               0               0            0
# 131             safe    6.3433             104              16          432
# 132             safe    4.7317               0               1           75
# 133  safe-incomplete    0.0579               0               0            0
# 134       unsafe-pgd    0.0488               0               0            0
# 135             safe    5.5669             100              67          400
# 136             safe   10.1734             274              38          615
# 137       unsafe-pgd    0.1084               0               0            0
# 138       unsafe-pgd    0.1050               0               0            0
# 139          unknown  205.5054          276983             927        68155
# 140  safe-incomplete    0.0512               0               0            0
# 141       unsafe-pgd    0.0560               0               0            0
# 142             safe    7.5392             100              33          830
# 143       unsafe-pgd    0.1764               0               0            0
# 144             safe   82.9915           42956            1594        33011
# 145       unsafe-pgd    0.0953               0               0            0
# 146  safe-incomplete    0.0408               0               0            0
# 147  safe-incomplete    0.0410               0               0            0
# 148             safe    6.0876             100              23          428
# 149          unknown  207.7711          238018            3687        54922
# 150             safe  121.4258           76546            1200        31647
# 151       unsafe-pgd    0.0727               0               0            0
# 152  safe-incomplete    0.0401               0               0            0
# 153  safe-incomplete    0.4405               0               0            0
# 154             safe   13.3737             340             106          974
# 155       unsafe-pgd    0.0767               0               0            0
# 156       unsafe-pgd    0.0515               0               0            0
# 157  safe-incomplete    0.0408               0               0            0
# 158  safe-incomplete    0.0377               0               0            0
# 159             safe   11.1736             200              31         1025
# 160             safe   27.0268             889             320         1296
# 161  safe-incomplete    0.1153               0               0            0
# 162             safe   16.0056             429             171         1356
# 163          unknown  201.9801          139202            2613        45244
# 164             safe   10.5482             100              40          731
# 165       unsafe-pgd    0.0657               0               0            0
# 166             safe   19.8485             439             138         2477
# 167       unsafe-pgd    0.1119               0               0            0
# 168       unsafe-pgd    0.1030               0               0            0
# 169  safe-incomplete    0.0402               0               0            0
# 170       unsafe-pgd    0.0471               0               0            0
# 171  safe-incomplete    0.4653               0               0            0
# 172             safe    5.3186              50               6          191
# 173       unsafe-pgd    0.1107               0               0            0
# 174             safe   30.1553            1818             373         2785
# 175       unsafe-pgd    0.0847               0               0            0
# 176       unsafe-pgd    0.0513               0               0            0
# 177  safe-incomplete    0.0464               0               0            0
# 178  safe-incomplete    0.0416               0               0            0
# 179  safe-incomplete    0.0428               0               0            0
# 180  safe-incomplete    0.0492               0               0            0
# 181             safe   10.5285             200              40         1144
# 182  safe-incomplete    0.1047               0               0            0
# 183       unsafe-pgd    0.0817               0               0            0
# 184             safe   31.1916            6201              75         5784
# 185             safe   18.7033             454             150         2496
# 186             safe    4.5593               0               1           22
# 187          unknown  204.5119          121830            1484        37323
# 188             safe   31.0947            3222             399         3764
# 189             safe    8.3999             146              58          833
# 190             safe    5.7649             100              16          400
# 191             safe   43.1854           15519              98        11819
# 192       unsafe-pgd    0.1513               0               0            0
# 193  safe-incomplete    0.0995               0               0            0
# 194          unknown  201.9959          205055            3840        41863
# 195             safe    4.8695               0               1           48
# 196       unsafe-pgd    0.1106               0               0            0
# 197             safe    7.4240             100              28          799
# 198       unsafe-pgd    0.1482               0               0            0
# 199             safe   97.1611           15069             515        10296
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                 74   -0.901989
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 18         NaN
# 7                  3         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                 4         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 1         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                36         NaN
# 19                44         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                 0         NaN
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                56   -0.423785
# 36                 0         NaN
# 37                71         NaN
# 38                97   -0.754147
# 39                13         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                14         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                51         NaN
# 49                 2         NaN
# 50                 0         NaN
# 51                 2         NaN
# 52                56         NaN
# 53                90   -0.489196
# 54                 6         NaN
# 55                10         NaN
# 56                33         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                15         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                38   -0.975488
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                47         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                33         NaN
# 71                 0         NaN
# 72                38   -0.437003
# 73                 4         NaN
# 74                 0         NaN
# 75                45   -0.620336
# 76                60         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 2         NaN
# 80                89   -1.095297
# 81                22         NaN
# 82                 0         NaN
# 83                51         NaN
# 84                40   -0.720881
# 85                56   -0.368688
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                69         NaN
# 94                 0         NaN
# 95                37         NaN
# 96                 0         NaN
# 97               137         NaN
# 98                 0         NaN
# 99                32         NaN
# 100                0         NaN
# 101               32   -0.647785
# 102               46         NaN
# 103               47   -0.514336
# 104                3         NaN
# 105                0         NaN
# 106               10         NaN
# 107               11         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111               46         NaN
# 112               54   -0.639030
# 113                0         NaN
# 114                0         NaN
# 115                4         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                1         NaN
# 121                0         NaN
# 122               48   -0.808523
# 123                0         NaN
# 124              114   -1.081464
# 125                0         NaN
# 126                0         NaN
# 127              120   -1.164400
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                5         NaN
# 132                1         NaN
# 133                0         NaN
# 134                0         NaN
# 135                3         NaN
# 136               12         NaN
# 137                0         NaN
# 138                0         NaN
# 139               82   -0.117957
# 140                0         NaN
# 141                0         NaN
# 142                6         NaN
# 143                0         NaN
# 144               59         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                4         NaN
# 149               57   -1.017414
# 150               45         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154               19         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                9         NaN
# 160               34         NaN
# 161                0         NaN
# 162               28         NaN
# 163               96   -0.603255
# 164                8         NaN
# 165                0         NaN
# 166               23         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                2         NaN
# 173                0         NaN
# 174               55         NaN
# 175                0         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181               10         NaN
# 182                0         NaN
# 183                0         NaN
# 184               47         NaN
# 185               21         NaN
# 186                1         NaN
# 187              134   -0.044011
# 188               55         NaN
# 189               10         NaN
# 190                3         NaN
# 191               37         NaN
# 192                0         NaN
# 193                0         NaN
# 194               86   -0.604292
# 195                1         NaN
# 196                0         NaN
# 197                5         NaN
# 198                0         NaN
# 199              138         NaN
# #Cuts 76006
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               63   30.632127   12782.825397     332.174603   6881.825397
# safe-incomplete    46    0.124404       0.000000       0.000000      0.000000
# unknown            21  205.821619  221663.380952    2622.809524  42423.714286
# unsafe-pgd         70    0.079963       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  25.984127
# safe-incomplete        0.000000
# unknown               71.095238
# unsafe-pgd             0.000000
# safe number 109.0
# safe time 17.757308256880734
# safe domain 7388.238532110092
# safe cut 191.9908256880734
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((109.0, 17.757308256880734, 12782.825396825398, 332.1746031746032),)

# %% [markdown]
# ## cifar_cnn_b_adv4

# %%
plot_multiple_dfs(
    [
log_read('cifar_cnn_b_adv4/beta.log'),
log_read('cifar_cnn_b_adv4/biccos_only_cs.log'),
log_read('cifar_cnn_b_adv4/biccos_all.log'),
log_read('cifar_cnn_b_adv4/gcp.log'),
log_read('cifar_cnn_b_adv4/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],  time_limit=200, dataset='cifar_cnn_b_adv4'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar_cnn_b_adv4/beta.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 13    safe    3.3845              16               0            0
# 18    safe    2.5627               0               0            0
# 37    safe    2.7361               0               0            0
# 48    safe    2.6026               0               0            0
# 54    safe    5.1525             228               0            0
# 56    safe   25.8104           39807               0            0
# 64    safe    2.5425               0               0            0
# 75    safe    2.8799               2               0            0
# 83    safe  164.3059          251459               0            0
# 91    safe   44.5424           71885               0            0
# 95    safe    4.6769              68               0            0
# 97    safe   63.0245           98227               0            0
# 98    safe    2.6364               0               0            0
# 122   safe    3.6379              29               0            0
# 127   safe    3.0290               1               0            0
# 139   safe    2.7096               0               0            0
# 144   safe    2.7616               0               0            0
# 174   safe    2.7113               0               0            0
# 175   safe    3.0255               1               0            0
# 187   safe    2.6169               0               0            0
# 189   safe    2.6310               0               0            0
# 199   safe    2.9808               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 13                 4         NaN
# 18                 1         NaN
# 37                 2         NaN
# 48                 1         NaN
# 54                16         NaN
# 56                33         NaN
# 64                 1         NaN
# 75                 2         NaN
# 83                52         NaN
# 91                34         NaN
# 95                15         NaN
# 97                40         NaN
# 98                 1         NaN
# 122                6         NaN
# 127                3         NaN
# 139                1         NaN
# 144                1         NaN
# 174                1         NaN
# 175                4         NaN
# 187                1         NaN
# 189                1         NaN
# 199                3         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6    unknown  202.9207          382242               0            0
# 11   unknown  200.9570          288806               0            0
# 19   unknown  201.6751          403693               0            0
# 21   unknown  203.2777          426582               0            0
# 24   unknown  202.2652          423071               0            0
# 72   unknown  203.4052          465885               0            0
# 76   unknown  203.0900          360714               0            0
# 93   unknown  203.8778          365891               0            0
# 113  unknown  204.1473          444438               0            0
# 134  unknown  210.9905          510824               0            0
# 149  unknown  203.7012          489376               0            0
# 162  unknown  202.3338          460256               0            0
# 185  unknown  200.8658          345151               0            0
# 191  unknown  202.0166          424589               0            0
# 192  unknown  209.0339          391191               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 6                 53   -0.196783
# 11                34   -0.065877
# 19                57   -0.089606
# 21                30   -0.103462
# 24                34   -0.310168
# 72                53   -0.404129
# 76                34   -0.105286
# 93                64   -0.082495
# 113               32   -0.029958
# 134               35   -0.224666
# 149               49   -0.201581
# 162               45   -0.148282
# 185               61   -0.141013
# 191               48   -0.033824
# 192               39   -0.068514
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.1583               0               0            0
# 1         unsafe-pgd    0.0718               0               0            0
# 2    safe-incomplete    0.0404               0               0            0
# 3         unsafe-pgd    0.0522               0               0            0
# 4         unsafe-pgd    0.0449               0               0            0
# 5         unsafe-pgd    0.0497               0               0            0
# 6            unknown  202.9207          382242               0            0
# 7    safe-incomplete    0.0490               0               0            0
# 8    safe-incomplete    0.0388               0               0            0
# 9         unsafe-pgd    0.0560               0               0            0
# 10        unsafe-pgd    0.0476               0               0            0
# 11           unknown  200.9570          288806               0            0
# 12        unsafe-pgd    0.1194               0               0            0
# 13              safe    3.3845              16               0            0
# 14   safe-incomplete    0.0498               0               0            0
# 15        unsafe-pgd    0.0500               0               0            0
# 16        unsafe-pgd    0.0493               0               0            0
# 17   safe-incomplete    0.0380               0               0            0
# 18              safe    2.5627               0               0            0
# 19           unknown  201.6751          403693               0            0
# 20   safe-incomplete    0.0615               0               0            0
# 21           unknown  203.2777          426582               0            0
# 22   safe-incomplete    0.0916               0               0            0
# 23   safe-incomplete    0.0422               0               0            0
# 24           unknown  202.2652          423071               0            0
# 25        unsafe-pgd    0.0753               0               0            0
# 26   safe-incomplete    0.0394               0               0            0
# 27   safe-incomplete    0.0381               0               0            0
# 28   safe-incomplete    0.0392               0               0            0
# 29        unsafe-pgd    0.0557               0               0            0
# 30   safe-incomplete    0.0429               0               0            0
# 31   safe-incomplete    0.0382               0               0            0
# 32        unsafe-pgd    0.0611               0               0            0
# 33   safe-incomplete    0.0400               0               0            0
# 34        unsafe-pgd    0.0498               0               0            0
# 35        unsafe-pgd    0.0440               0               0            0
# 36   safe-incomplete    0.0410               0               0            0
# 37              safe    2.7361               0               0            0
# 38   safe-incomplete    0.2293               0               0            0
# 39   safe-incomplete    0.0391               0               0            0
# 40   safe-incomplete    0.0380               0               0            0
# 41   safe-incomplete    0.0387               0               0            0
# 42   safe-incomplete    0.0388               0               0            0
# 43        unsafe-pgd    0.0548               0               0            0
# 44        unsafe-pgd    0.0487               0               0            0
# 45        unsafe-pgd    0.0611               0               0            0
# 46        unsafe-pgd    0.0522               0               0            0
# 47   safe-incomplete    0.0387               0               0            0
# 48              safe    2.6026               0               0            0
# 49   safe-incomplete    0.0502               0               0            0
# 50        unsafe-pgd    0.0517               0               0            0
# 51   safe-incomplete    0.0387               0               0            0
# 52   safe-incomplete    0.0402               0               0            0
# 53        unsafe-pgd    0.0468               0               0            0
# 54              safe    5.1525             228               0            0
# 55   safe-incomplete    0.0462               0               0            0
# 56              safe   25.8104           39807               0            0
# 57        unsafe-pgd    0.0694               0               0            0
# 58        unsafe-pgd    0.0531               0               0            0
# 59   safe-incomplete    0.0414               0               0            0
# 60   safe-incomplete    0.0414               0               0            0
# 61        unsafe-pgd    0.0528               0               0            0
# 62   safe-incomplete    0.0384               0               0            0
# 63        unsafe-pgd    0.0491               0               0            0
# 64              safe    2.5425               0               0            0
# 65        unsafe-pgd    0.0606               0               0            0
# 66        unsafe-pgd    0.0472               0               0            0
# 67        unsafe-pgd    0.0447               0               0            0
# 68   safe-incomplete    0.0383               0               0            0
# 69        unsafe-pgd    0.0433               0               0            0
# 70   safe-incomplete    0.0378               0               0            0
# 71   safe-incomplete    0.0385               0               0            0
# 72           unknown  203.4052          465885               0            0
# 73   safe-incomplete    0.0564               0               0            0
# 74   safe-incomplete    0.0391               0               0            0
# 75              safe    2.8799               2               0            0
# 76           unknown  203.0900          360714               0            0
# 77        unsafe-pgd    0.0584               0               0            0
# 78        unsafe-pgd    0.0506               0               0            0
# 79   safe-incomplete    0.0379               0               0            0
# 80        unsafe-pgd    0.0543               0               0            0
# 81        unsafe-pgd    0.0461               0               0            0
# 82        unsafe-pgd    0.0556               0               0            0
# 83              safe  164.3059          251459               0            0
# 84   safe-incomplete    0.0497               0               0            0
# 85   safe-incomplete    0.0400               0               0            0
# 86   safe-incomplete    0.0400               0               0            0
# 87        unsafe-pgd    0.0555               0               0            0
# 88        unsafe-pgd    0.0527               0               0            0
# 89   safe-incomplete    0.0393               0               0            0
# 90        unsafe-pgd    0.0559               0               0            0
# 91              safe   44.5424           71885               0            0
# 92   safe-incomplete    0.0437               0               0            0
# 93           unknown  203.8778          365891               0            0
# 94        unsafe-pgd    0.0674               0               0            0
# 95              safe    4.6769              68               0            0
# 96        unsafe-pgd    0.0521               0               0            0
# 97              safe   63.0245           98227               0            0
# 98              safe    2.6364               0               0            0
# 99   safe-incomplete    0.0469               0               0            0
# 100       unsafe-pgd    0.0541               0               0            0
# 101  safe-incomplete    0.0390               0               0            0
# 102       unsafe-pgd    0.0455               0               0            0
# 103  safe-incomplete    0.0421               0               0            0
# 104  safe-incomplete    0.0933               0               0            0
# 105       unsafe-pgd    0.0926               0               0            0
# 106       unsafe-pgd    0.0457               0               0            0
# 107  safe-incomplete    0.0385               0               0            0
# 108       unsafe-pgd    0.0539               0               0            0
# 109  safe-incomplete    0.0404               0               0            0
# 110  safe-incomplete    0.0403               0               0            0
# 111  safe-incomplete    0.0362               0               0            0
# 112  safe-incomplete    0.0399               0               0            0
# 113          unknown  204.1473          444438               0            0
# 114  safe-incomplete    0.0695               0               0            0
# 115  safe-incomplete    0.0420               0               0            0
# 116  safe-incomplete    0.0425               0               0            0
# 117  safe-incomplete    0.0397               0               0            0
# 118  safe-incomplete    0.0415               0               0            0
# 119       unsafe-pgd    0.0569               0               0            0
# 120  safe-incomplete    0.0406               0               0            0
# 121  safe-incomplete    0.0400               0               0            0
# 122             safe    3.6379              29               0            0
# 123       unsafe-pgd    0.0624               0               0            0
# 124       unsafe-pgd    0.0584               0               0            0
# 125       unsafe-pgd    0.0519               0               0            0
# 126       unsafe-pgd    0.0554               0               0            0
# 127             safe    3.0290               1               0            0
# 128       unsafe-pgd    0.0603               0               0            0
# 129       unsafe-pgd    0.0565               0               0            0
# 130       unsafe-pgd    0.0533               0               0            0
# 131  safe-incomplete    0.0421               0               0            0
# 132  safe-incomplete    0.0399               0               0            0
# 133  safe-incomplete    0.0391               0               0            0
# 134          unknown  210.9905          510824               0            0
# 135  safe-incomplete    0.1051               0               0            0
# 136  safe-incomplete    0.0953               0               0            0
# 137       unsafe-pgd    0.0802               0               0            0
# 138       unsafe-pgd    0.0580               0               0            0
# 139             safe    2.7096               0               0            0
# 140  safe-incomplete    0.0528               0               0            0
# 141       unsafe-pgd    0.0496               0               0            0
# 142  safe-incomplete    0.0404               0               0            0
# 143       unsafe-pgd    0.0452               0               0            0
# 144             safe    2.7616               0               0            0
# 145       unsafe-pgd    0.0555               0               0            0
# 146  safe-incomplete    0.0446               0               0            0
# 147  safe-incomplete    0.2293               0               0            0
# 148  safe-incomplete    0.0420               0               0            0
# 149          unknown  203.7012          489376               0            0
# 150       unsafe-pgd    0.1170               0               0            0
# 151       unsafe-pgd    0.0527               0               0            0
# 152  safe-incomplete    0.0387               0               0            0
# 153  safe-incomplete    0.0439               0               0            0
# 154  safe-incomplete    0.2279               0               0            0
# 155       unsafe-pgd    0.0629               0               0            0
# 156       unsafe-pgd    0.0518               0               0            0
# 157  safe-incomplete    0.0427               0               0            0
# 158  safe-incomplete    0.0392               0               0            0
# 159  safe-incomplete    0.0418               0               0            0
# 160  safe-incomplete    0.0414               0               0            0
# 161  safe-incomplete    0.0393               0               0            0
# 162          unknown  202.3338          460256               0            0
# 163       unsafe-pgd    0.0707               0               0            0
# 164  safe-incomplete    0.0396               0               0            0
# 165       unsafe-pgd    0.0540               0               0            0
# 166  safe-incomplete    0.0408               0               0            0
# 167       unsafe-pgd    0.0566               0               0            0
# 168       unsafe-pgd    0.0491               0               0            0
# 169  safe-incomplete    0.0391               0               0            0
# 170       unsafe-pgd    0.0448               0               0            0
# 171  safe-incomplete    0.0399               0               0            0
# 172  safe-incomplete    0.0400               0               0            0
# 173       unsafe-pgd    0.0463               0               0            0
# 174             safe    2.7113               0               0            0
# 175             safe    3.0255               1               0            0
# 176       unsafe-pgd    0.0560               0               0            0
# 177  safe-incomplete    0.0410               0               0            0
# 178  safe-incomplete    0.0392               0               0            0
# 179  safe-incomplete    0.0391               0               0            0
# 180  safe-incomplete    0.0380               0               0            0
# 181  safe-incomplete    0.0536               0               0            0
# 182  safe-incomplete    0.0401               0               0            0
# 183       unsafe-pgd    0.0497               0               0            0
# 184       unsafe-pgd    0.0461               0               0            0
# 185          unknown  200.8658          345151               0            0
# 186  safe-incomplete    0.0552               0               0            0
# 187             safe    2.6169               0               0            0
# 188       unsafe-pgd    0.1108               0               0            0
# 189             safe    2.6310               0               0            0
# 190  safe-incomplete    0.0495               0               0            0
# 191          unknown  202.0166          424589               0            0
# 192          unknown  209.0339          391191               0            0
# 193  safe-incomplete    0.0598               0               0            0
# 194       unsafe-pgd    0.0515               0               0            0
# 195  safe-incomplete    0.0416               0               0            0
# 196       unsafe-pgd    0.0495               0               0            0
# 197  safe-incomplete    0.0482               0               0            0
# 198       unsafe-pgd    0.0546               0               0            0
# 199             safe    2.9808               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 53   -0.196783
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                34   -0.065877
# 12                 0         NaN
# 13                 4         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 1         NaN
# 19                57   -0.089606
# 20                 0         NaN
# 21                30   -0.103462
# 22                 0         NaN
# 23                 0         NaN
# 24                34   -0.310168
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 2         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                16         NaN
# 55                 0         NaN
# 56                33         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                53   -0.404129
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                34   -0.105286
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                52         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                34         NaN
# 92                 0         NaN
# 93                64   -0.082495
# 94                 0         NaN
# 95                15         NaN
# 96                 0         NaN
# 97                40         NaN
# 98                 1         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113               32   -0.029958
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                6         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                3         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134               35   -0.224666
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139                1         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                1         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149               49   -0.201581
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160                0         NaN
# 161                0         NaN
# 162               45   -0.148282
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                1         NaN
# 175                4         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               61   -0.141013
# 186                0         NaN
# 187                1         NaN
# 188                0         NaN
# 189                1         NaN
# 190                0         NaN
# 191               48   -0.033824
# 192               39   -0.068514
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                3         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               22   16.043677   20987.409091            0.0         0.0
# safe-incomplete    90    0.063453       0.000000            0.0         0.0
# unknown            15  203.637187  412180.600000            0.0         0.0
# unsafe-pgd         73    0.057129       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  10.136364
# safe-incomplete        0.000000
# unknown               44.533333
# unsafe-pgd             0.000000
# safe number 112.0
# safe time 3.2024258928571436
# safe domain 4122.526785714285
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((112.0, 3.2024258928571436, 20987.409090909092, 0.0),)

# %%
main('cifar_cnn_b_adv4/biccos_only_cs.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe  81.2465           79407             341        25016
# 13    safe   4.1864             106              13          420
# 18    safe   2.8749               0               1           42
# 19    safe  17.1404           12180             107         8620
# 37    safe   4.3340              50              10          475
# 48    safe   2.8312               0               1           16
# 54    safe   7.5151             331             103          415
# 56    safe  12.0806            2644              68         2073
# 64    safe   2.8522               0               1           65
# 72    safe  31.6259           21718             408        15756
# 75    safe   3.4748             100               8          338
# 76    safe  20.1944           17015              60        13452
# 83    safe  25.6816           15488             501         8698
# 91    safe  19.7282           10510             192         5293
# 95    safe   5.0046              62              17           74
# 97    safe   8.1114             358              58          887
# 98    safe   3.2091              50               9          366
# 113   safe  24.2783           19205             142        12720
# 122   safe   3.8177             150              78          416
# 127   safe   5.3390             200              26          820
# 134   safe   8.6886            2568              95         2214
# 139   safe   2.8588               0               1          353
# 144   safe   2.8215               0               1           16
# 149   safe  14.4039            6754             168         4860
# 174   safe   3.1933              50               9          319
# 175   safe   2.4498               1               2           32
# 187   safe   2.8358               0               1           33
# 189   safe   3.0812              50               7          416
# 191   safe  47.5018           37378             308        22478
# 199   safe   2.7372               0               0           16
#
#      BaB Round Count  BaB_lb_rhs
# 11                37         NaN
# 13                 6         NaN
# 18                 2         NaN
# 19                25         NaN
# 37                 5         NaN
# 48                 2         NaN
# 54                17         NaN
# 56                35         NaN
# 64                 2         NaN
# 72                56         NaN
# 75                 4         NaN
# 76                23         NaN
# 83                52         NaN
# 91                36         NaN
# 95                14         NaN
# 97                18         NaN
# 98                 3         NaN
# 113               22         NaN
# 122                5         NaN
# 127                8         NaN
# 134               18         NaN
# 139                2         NaN
# 144                2         NaN
# 149               23         NaN
# 174                3         NaN
# 175                4         NaN
# 187                2         NaN
# 189                3         NaN
# 191               27         NaN
# 199                3         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6    unknown  206.3746          219903             306        24273
# 21   unknown  209.1147          342923             413        40668
# 24   unknown  204.3948          399634             357        20073
# 93   unknown  207.5832          255166            1693        68958
# 162  unknown  205.4049          305780             904        45095
# 185  unknown  206.2415          534133             192        13921
# 192  unknown  205.3899          331205             573        56368
#
#      BaB Round Count  BaB_lb_rhs
# 6                 42   -0.157590
# 21                43   -0.086589
# 24                51   -0.281554
# 93                52   -0.065984
# 162               40   -0.128882
# 185               81   -0.185355
# 192               53   -0.051289
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.5546               0               0            0
# 1         unsafe-pgd    0.1246               0               0            0
# 2    safe-incomplete    0.0402               0               0            0
# 3         unsafe-pgd    0.0589               0               0            0
# 4         unsafe-pgd    0.0447               0               0            0
# 5         unsafe-pgd    0.0495               0               0            0
# 6            unknown  206.3746          219903             306        24273
# 7    safe-incomplete    0.0441               0               0            0
# 8    safe-incomplete    0.0392               0               0            0
# 9         unsafe-pgd    0.0573               0               0            0
# 10        unsafe-pgd    0.0481               0               0            0
# 11              safe   81.2465           79407             341        25016
# 12        unsafe-pgd    0.0657               0               0            0
# 13              safe    4.1864             106              13          420
# 14   safe-incomplete    0.0416               0               0            0
# 15        unsafe-pgd    0.0463               0               0            0
# 16        unsafe-pgd    0.0462               0               0            0
# 17   safe-incomplete    0.0381               0               0            0
# 18              safe    2.8749               0               1           42
# 19              safe   17.1404           12180             107         8620
# 20   safe-incomplete    0.0389               0               0            0
# 21           unknown  209.1147          342923             413        40668
# 22   safe-incomplete    0.0449               0               0            0
# 23   safe-incomplete    0.0392               0               0            0
# 24           unknown  204.3948          399634             357        20073
# 25        unsafe-pgd    0.1221               0               0            0
# 26   safe-incomplete    0.0365               0               0            0
# 27   safe-incomplete    0.0357               0               0            0
# 28   safe-incomplete    0.0405               0               0            0
# 29        unsafe-pgd    0.0515               0               0            0
# 30   safe-incomplete    0.0374               0               0            0
# 31   safe-incomplete    0.0357               0               0            0
# 32        unsafe-pgd    0.0580               0               0            0
# 33   safe-incomplete    0.0355               0               0            0
# 34        unsafe-pgd    0.0450               0               0            0
# 35        unsafe-pgd    0.0415               0               0            0
# 36   safe-incomplete    0.0384               0               0            0
# 37              safe    4.3340              50              10          475
# 38   safe-incomplete    0.2237               0               0            0
# 39   safe-incomplete    0.0362               0               0            0
# 40   safe-incomplete    0.0359               0               0            0
# 41   safe-incomplete    0.0376               0               0            0
# 42   safe-incomplete    0.0357               0               0            0
# 43        unsafe-pgd    0.0531               0               0            0
# 44        unsafe-pgd    0.0450               0               0            0
# 45        unsafe-pgd    0.0554               0               0            0
# 46        unsafe-pgd    0.0492               0               0            0
# 47   safe-incomplete    0.0354               0               0            0
# 48              safe    2.8312               0               1           16
# 49   safe-incomplete    0.0391               0               0            0
# 50        unsafe-pgd    0.0495               0               0            0
# 51   safe-incomplete    0.0374               0               0            0
# 52   safe-incomplete    0.0378               0               0            0
# 53        unsafe-pgd    0.0442               0               0            0
# 54              safe    7.5151             331             103          415
# 55   safe-incomplete    0.0389               0               0            0
# 56              safe   12.0806            2644              68         2073
# 57        unsafe-pgd    0.0563               0               0            0
# 58        unsafe-pgd    0.0493               0               0            0
# 59   safe-incomplete    0.0376               0               0            0
# 60   safe-incomplete    0.0376               0               0            0
# 61        unsafe-pgd    0.0496               0               0            0
# 62   safe-incomplete    0.0358               0               0            0
# 63        unsafe-pgd    0.0528               0               0            0
# 64              safe    2.8522               0               1           65
# 65        unsafe-pgd    0.0503               0               0            0
# 66        unsafe-pgd    0.0427               0               0            0
# 67        unsafe-pgd    0.0428               0               0            0
# 68   safe-incomplete    0.0356               0               0            0
# 69        unsafe-pgd    0.0410               0               0            0
# 70   safe-incomplete    0.0355               0               0            0
# 71   safe-incomplete    0.0360               0               0            0
# 72              safe   31.6259           21718             408        15756
# 73   safe-incomplete    0.0365               0               0            0
# 74   safe-incomplete    0.0368               0               0            0
# 75              safe    3.4748             100               8          338
# 76              safe   20.1944           17015              60        13452
# 77        unsafe-pgd    0.0473               0               0            0
# 78        unsafe-pgd    0.0453               0               0            0
# 79   safe-incomplete    0.0354               0               0            0
# 80        unsafe-pgd    0.0482               0               0            0
# 81        unsafe-pgd    0.0439               0               0            0
# 82        unsafe-pgd    0.0507               0               0            0
# 83              safe   25.6816           15488             501         8698
# 84   safe-incomplete    0.0395               0               0            0
# 85   safe-incomplete    0.0355               0               0            0
# 86   safe-incomplete    0.0354               0               0            0
# 87        unsafe-pgd    0.0513               0               0            0
# 88        unsafe-pgd    0.0487               0               0            0
# 89   safe-incomplete    0.0352               0               0            0
# 90        unsafe-pgd    0.0509               0               0            0
# 91              safe   19.7282           10510             192         5293
# 92   safe-incomplete    0.0392               0               0            0
# 93           unknown  207.5832          255166            1693        68958
# 94        unsafe-pgd    0.0499               0               0            0
# 95              safe    5.0046              62              17           74
# 96        unsafe-pgd    0.0475               0               0            0
# 97              safe    8.1114             358              58          887
# 98              safe    3.2091              50               9          366
# 99   safe-incomplete    0.0373               0               0            0
# 100       unsafe-pgd    0.0478               0               0            0
# 101  safe-incomplete    0.0354               0               0            0
# 102       unsafe-pgd    0.0407               0               0            0
# 103  safe-incomplete    0.0355               0               0            0
# 104  safe-incomplete    0.0371               0               0            0
# 105       unsafe-pgd    0.0514               0               0            0
# 106       unsafe-pgd    0.0429               0               0            0
# 107  safe-incomplete    0.0356               0               0            0
# 108       unsafe-pgd    0.0472               0               0            0
# 109  safe-incomplete    0.0354               0               0            0
# 110  safe-incomplete    0.0359               0               0            0
# 111  safe-incomplete    0.0346               0               0            0
# 112  safe-incomplete    0.0368               0               0            0
# 113             safe   24.2783           19205             142        12720
# 114  safe-incomplete    0.0505               0               0            0
# 115  safe-incomplete    0.0370               0               0            0
# 116  safe-incomplete    0.0361               0               0            0
# 117  safe-incomplete    0.0376               0               0            0
# 118  safe-incomplete    0.0380               0               0            0
# 119       unsafe-pgd    0.0499               0               0            0
# 120  safe-incomplete    0.0376               0               0            0
# 121  safe-incomplete    0.0358               0               0            0
# 122             safe    3.8177             150              78          416
# 123       unsafe-pgd    0.0485               0               0            0
# 124       unsafe-pgd    0.0549               0               0            0
# 125       unsafe-pgd    0.0443               0               0            0
# 126       unsafe-pgd    0.0498               0               0            0
# 127             safe    5.3390             200              26          820
# 128       unsafe-pgd    0.0547               0               0            0
# 129       unsafe-pgd    0.0511               0               0            0
# 130       unsafe-pgd    0.0473               0               0            0
# 131  safe-incomplete    0.0356               0               0            0
# 132  safe-incomplete    0.0356               0               0            0
# 133  safe-incomplete    0.0377               0               0            0
# 134             safe    8.6886            2568              95         2214
# 135  safe-incomplete    0.0385               0               0            0
# 136  safe-incomplete    0.0378               0               0            0
# 137       unsafe-pgd    0.0448               0               0            0
# 138       unsafe-pgd    0.0483               0               0            0
# 139             safe    2.8588               0               1          353
# 140  safe-incomplete    0.0371               0               0            0
# 141       unsafe-pgd    0.0430               0               0            0
# 142  safe-incomplete    0.0355               0               0            0
# 143       unsafe-pgd    0.0407               0               0            0
# 144             safe    2.8215               0               1           16
# 145       unsafe-pgd    0.0442               0               0            0
# 146  safe-incomplete    0.0379               0               0            0
# 147  safe-incomplete    0.2150               0               0            0
# 148  safe-incomplete    0.0359               0               0            0
# 149             safe   14.4039            6754             168         4860
# 150       unsafe-pgd    0.0460               0               0            0
# 151       unsafe-pgd    0.0477               0               0            0
# 152  safe-incomplete    0.0355               0               0            0
# 153  safe-incomplete    0.0357               0               0            0
# 154  safe-incomplete    0.2165               0               0            0
# 155       unsafe-pgd    0.0537               0               0            0
# 156       unsafe-pgd    0.0482               0               0            0
# 157  safe-incomplete    0.0357               0               0            0
# 158  safe-incomplete    0.0348               0               0            0
# 159  safe-incomplete    0.0357               0               0            0
# 160  safe-incomplete    0.0379               0               0            0
# 161  safe-incomplete    0.0372               0               0            0
# 162          unknown  205.4049          305780             904        45095
# 163       unsafe-pgd    0.0561               0               0            0
# 164  safe-incomplete    0.0360               0               0            0
# 165       unsafe-pgd    0.0507               0               0            0
# 166  safe-incomplete    0.0356               0               0            0
# 167       unsafe-pgd    0.0487               0               0            0
# 168       unsafe-pgd    0.0444               0               0            0
# 169  safe-incomplete    0.0354               0               0            0
# 170       unsafe-pgd    0.0413               0               0            0
# 171  safe-incomplete    0.0377               0               0            0
# 172  safe-incomplete    0.0357               0               0            0
# 173       unsafe-pgd    0.0431               0               0            0
# 174             safe    3.1933              50               9          319
# 175             safe    2.4498               1               2           32
# 176       unsafe-pgd    0.0530               0               0            0
# 177  safe-incomplete    0.0381               0               0            0
# 178  safe-incomplete    0.0367               0               0            0
# 179  safe-incomplete    0.0369               0               0            0
# 180  safe-incomplete    0.0350               0               0            0
# 181  safe-incomplete    0.0372               0               0            0
# 182  safe-incomplete    0.0404               0               0            0
# 183       unsafe-pgd    0.0442               0               0            0
# 184       unsafe-pgd    0.0434               0               0            0
# 185          unknown  206.2415          534133             192        13921
# 186  safe-incomplete    0.0446               0               0            0
# 187             safe    2.8358               0               1           33
# 188       unsafe-pgd    0.0454               0               0            0
# 189             safe    3.0812              50               7          416
# 190  safe-incomplete    0.0389               0               0            0
# 191             safe   47.5018           37378             308        22478
# 192          unknown  205.3899          331205             573        56368
# 193  safe-incomplete    0.0475               0               0            0
# 194       unsafe-pgd    0.0475               0               0            0
# 195  safe-incomplete    0.0370               0               0            0
# 196       unsafe-pgd    0.0448               0               0            0
# 197  safe-incomplete    0.0399               0               0            0
# 198       unsafe-pgd    0.0504               0               0            0
# 199             safe    2.7372               0               0           16
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 42   -0.157590
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                37         NaN
# 12                 0         NaN
# 13                 6         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 2         NaN
# 19                25         NaN
# 20                 0         NaN
# 21                43   -0.086589
# 22                 0         NaN
# 23                 0         NaN
# 24                51   -0.281554
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 5         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 2         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                17         NaN
# 55                 0         NaN
# 56                35         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 2         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                56         NaN
# 73                 0         NaN
# 74                 0         NaN
# 75                 4         NaN
# 76                23         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                52         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                36         NaN
# 92                 0         NaN
# 93                52   -0.065984
# 94                 0         NaN
# 95                14         NaN
# 96                 0         NaN
# 97                18         NaN
# 98                 3         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113               22         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                5         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                8         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134               18         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139                2         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                2         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149               23         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160                0         NaN
# 161                0         NaN
# 162               40   -0.128882
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                3         NaN
# 175                4         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               81   -0.185355
# 186                0         NaN
# 187                2         NaN
# 188                0         NaN
# 189                3         NaN
# 190                0         NaN
# 191               27         NaN
# 192               53   -0.051289
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                3         NaN
# #Cuts 7174
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               30   12.536607    7545.833333           91.2   4223.300000
# safe-incomplete    90    0.071491       0.000000            0.0      0.000000
# unknown             7  206.357657  341249.142857          634.0  38479.428571
# unsafe-pgd         73    0.050471       0.000000            0.0      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  15.300000
# safe-incomplete        0.000000
# unknown               51.714286
# unsafe-pgd             0.000000
# safe number 120.0
# safe time 3.18777
# safe domain 1886.4583333333333
# safe cut 22.8
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((120.0, 3.18777, 7545.833333333333, 91.2),)

# %%
main('cifar_cnn_b_adv4/biccos_all.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 11    safe   82.2805           75435             386        28588
# 13    safe    4.3073             108              14          406
# 18    safe    2.8323               0               1           26
# 21    safe  167.0538          172949             394        45323
# 37    safe    4.4213              50              10          443
# 48    safe    3.1164               0               1            9
# 54    safe    7.4879             334             103          405
# 56    safe   11.9975            2197              50         1352
# 64    safe    2.8164               0               1           49
# 75    safe    3.5269             100               8          323
# 76    safe   19.6670           13495              58        12723
# 83    safe   20.4715           10014             353         4781
# 91    safe   21.6233           10579             176         5441
# 93    safe    7.7334             635             126          894
# 95    safe   11.2107             219              62         1521
# 97    safe   15.6771            6554              86         3645
# 98    safe    3.1516              50               9          350
# 113   safe   14.1072            8044             201         5226
# 122   safe    3.7966             150              78          400
# 127   safe    5.4435             200              26          788
# 134   safe    8.2369            2345             126         1788
# 139   safe    2.8235               0               1          337
# 144   safe    2.8537               0               1            7
# 149   safe   18.6788           10989             186         8788
# 162   safe   30.0357           24911             177        12017
# 174   safe    3.1771              50               9          303
# 175   safe    6.5144             200              91          815
# 187   safe    2.8265               0               1           17
# 189   safe    3.3669              50               7          400
# 191   safe   26.6776           19354              50        12866
# 199   safe    6.5401             150              26         1034
#
#      BaB Round Count  BaB_lb_rhs
# 11                35         NaN
# 13                 6         NaN
# 18                 1         NaN
# 21                40         NaN
# 37                 3         NaN
# 48                 1         NaN
# 54                17         NaN
# 56                35         NaN
# 64                 1         NaN
# 75                 3         NaN
# 76                23         NaN
# 83                51         NaN
# 91                39         NaN
# 93                19         NaN
# 95                16         NaN
# 97                31         NaN
# 98                 2         NaN
# 113               20         NaN
# 122                4         NaN
# 127                6         NaN
# 134               17         NaN
# 139                1         NaN
# 144                1         NaN
# 149               22         NaN
# 162               22         NaN
# 174                2         NaN
# 175                7         NaN
# 187                1         NaN
# 189                2         NaN
# 191               25         NaN
# 199                7         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6    unknown  200.7238          240349             195        45773
# 19   unknown  203.3259          311383             144        61680
# 24   unknown  207.0381          252477             397        13040
# 72   unknown  201.5608          334734             537        19248
# 185  unknown  202.9889          326737             348        33721
# 192  unknown  204.2922          262750             212        76632
#
#      BaB Round Count  BaB_lb_rhs
# 6                 66   -0.121572
# 19                83   -0.066276
# 24                40   -0.289651
# 72                51   -0.354709
# 185               84   -0.186031
# 192               79   -0.029532
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.1578               0               0            0
# 1         unsafe-pgd    0.0962               0               0            0
# 2    safe-incomplete    0.0404               0               0            0
# 3         unsafe-pgd    0.0588               0               0            0
# 4         unsafe-pgd    0.0448               0               0            0
# 5         unsafe-pgd    0.0494               0               0            0
# 6            unknown  200.7238          240349             195        45773
# 7    safe-incomplete    0.0416               0               0            0
# 8    safe-incomplete    0.0398               0               0            0
# 9         unsafe-pgd    0.0564               0               0            0
# 10        unsafe-pgd    0.0482               0               0            0
# 11              safe   82.2805           75435             386        28588
# 12        unsafe-pgd    0.0554               0               0            0
# 13              safe    4.3073             108              14          406
# 14   safe-incomplete    0.0412               0               0            0
# 15        unsafe-pgd    0.0462               0               0            0
# 16        unsafe-pgd    0.0458               0               0            0
# 17   safe-incomplete    0.0388               0               0            0
# 18              safe    2.8323               0               1           26
# 19           unknown  203.3259          311383             144        61680
# 20   safe-incomplete    0.0433               0               0            0
# 21              safe  167.0538          172949             394        45323
# 22   safe-incomplete    0.0400               0               0            0
# 23   safe-incomplete    0.0385               0               0            0
# 24           unknown  207.0381          252477             397        13040
# 25        unsafe-pgd    0.0608               0               0            0
# 26   safe-incomplete    0.0372               0               0            0
# 27   safe-incomplete    0.0365               0               0            0
# 28   safe-incomplete    0.0387               0               0            0
# 29        unsafe-pgd    0.0515               0               0            0
# 30   safe-incomplete    0.0379               0               0            0
# 31   safe-incomplete    0.0362               0               0            0
# 32        unsafe-pgd    0.0579               0               0            0
# 33   safe-incomplete    0.0371               0               0            0
# 34        unsafe-pgd    0.0457               0               0            0
# 35        unsafe-pgd    0.0409               0               0            0
# 36   safe-incomplete    0.0382               0               0            0
# 37              safe    4.4213              50              10          443
# 38   safe-incomplete    0.2554               0               0            0
# 39   safe-incomplete    0.0383               0               0            0
# 40   safe-incomplete    0.0381               0               0            0
# 41   safe-incomplete    0.0399               0               0            0
# 42   safe-incomplete    0.0378               0               0            0
# 43        unsafe-pgd    0.0553               0               0            0
# 44        unsafe-pgd    0.0472               0               0            0
# 45        unsafe-pgd    0.0581               0               0            0
# 46        unsafe-pgd    0.0514               0               0            0
# 47   safe-incomplete    0.0377               0               0            0
# 48              safe    3.1164               0               1            9
# 49   safe-incomplete    0.0420               0               0            0
# 50        unsafe-pgd    0.0524               0               0            0
# 51   safe-incomplete    0.0400               0               0            0
# 52   safe-incomplete    0.0400               0               0            0
# 53        unsafe-pgd    0.0466               0               0            0
# 54              safe    7.4879             334             103          405
# 55   safe-incomplete    0.0399               0               0            0
# 56              safe   11.9975            2197              50         1352
# 57        unsafe-pgd    0.0590               0               0            0
# 58        unsafe-pgd    0.0505               0               0            0
# 59   safe-incomplete    0.0382               0               0            0
# 60   safe-incomplete    0.0381               0               0            0
# 61        unsafe-pgd    0.0478               0               0            0
# 62   safe-incomplete    0.0374               0               0            0
# 63        unsafe-pgd    0.0478               0               0            0
# 64              safe    2.8164               0               1           49
# 65        unsafe-pgd    0.0509               0               0            0
# 66        unsafe-pgd    0.0430               0               0            0
# 67        unsafe-pgd    0.0424               0               0            0
# 68   safe-incomplete    0.0360               0               0            0
# 69        unsafe-pgd    0.0413               0               0            0
# 70   safe-incomplete    0.0361               0               0            0
# 71   safe-incomplete    0.0361               0               0            0
# 72           unknown  201.5608          334734             537        19248
# 73   safe-incomplete    0.0440               0               0            0
# 74   safe-incomplete    0.0381               0               0            0
# 75              safe    3.5269             100               8          323
# 76              safe   19.6670           13495              58        12723
# 77        unsafe-pgd    0.0477               0               0            0
# 78        unsafe-pgd    0.0461               0               0            0
# 79   safe-incomplete    0.0364               0               0            0
# 80        unsafe-pgd    0.0506               0               0            0
# 81        unsafe-pgd    0.0447               0               0            0
# 82        unsafe-pgd    0.0515               0               0            0
# 83              safe   20.4715           10014             353         4781
# 84   safe-incomplete    0.0410               0               0            0
# 85   safe-incomplete    0.0390               0               0            0
# 86   safe-incomplete    0.0370               0               0            0
# 87        unsafe-pgd    0.0523               0               0            0
# 88        unsafe-pgd    0.0498               0               0            0
# 89   safe-incomplete    0.0362               0               0            0
# 90        unsafe-pgd    0.0518               0               0            0
# 91              safe   21.6233           10579             176         5441
# 92   safe-incomplete    0.0410               0               0            0
# 93              safe    7.7334             635             126          894
# 94        unsafe-pgd    0.0474               0               0            0
# 95              safe   11.2107             219              62         1521
# 96        unsafe-pgd    0.0488               0               0            0
# 97              safe   15.6771            6554              86         3645
# 98              safe    3.1516              50               9          350
# 99   safe-incomplete    0.0403               0               0            0
# 100       unsafe-pgd    0.0481               0               0            0
# 101  safe-incomplete    0.0362               0               0            0
# 102       unsafe-pgd    0.0414               0               0            0
# 103  safe-incomplete    0.0362               0               0            0
# 104  safe-incomplete    0.0370               0               0            0
# 105       unsafe-pgd    0.0518               0               0            0
# 106       unsafe-pgd    0.0432               0               0            0
# 107  safe-incomplete    0.0363               0               0            0
# 108       unsafe-pgd    0.0476               0               0            0
# 109  safe-incomplete    0.0362               0               0            0
# 110  safe-incomplete    0.0364               0               0            0
# 111  safe-incomplete    0.0350               0               0            0
# 112  safe-incomplete    0.0373               0               0            0
# 113             safe   14.1072            8044             201         5226
# 114  safe-incomplete    0.0626               0               0            0
# 115  safe-incomplete    0.0368               0               0            0
# 116  safe-incomplete    0.0366               0               0            0
# 117  safe-incomplete    0.0376               0               0            0
# 118  safe-incomplete    0.0385               0               0            0
# 119       unsafe-pgd    0.0502               0               0            0
# 120  safe-incomplete    0.0383               0               0            0
# 121  safe-incomplete    0.0367               0               0            0
# 122             safe    3.7966             150              78          400
# 123       unsafe-pgd    0.0510               0               0            0
# 124       unsafe-pgd    0.0525               0               0            0
# 125       unsafe-pgd    0.0450               0               0            0
# 126       unsafe-pgd    0.0501               0               0            0
# 127             safe    5.4435             200              26          788
# 128       unsafe-pgd    0.0510               0               0            0
# 129       unsafe-pgd    0.0500               0               0            0
# 130       unsafe-pgd    0.0501               0               0            0
# 131  safe-incomplete    0.0371               0               0            0
# 132  safe-incomplete    0.0364               0               0            0
# 133  safe-incomplete    0.0362               0               0            0
# 134             safe    8.2369            2345             126         1788
# 135  safe-incomplete    0.0404               0               0            0
# 136  safe-incomplete    0.0367               0               0            0
# 137       unsafe-pgd    0.0458               0               0            0
# 138       unsafe-pgd    0.0494               0               0            0
# 139             safe    2.8235               0               1          337
# 140  safe-incomplete    0.0388               0               0            0
# 141       unsafe-pgd    0.0436               0               0            0
# 142  safe-incomplete    0.0363               0               0            0
# 143       unsafe-pgd    0.0415               0               0            0
# 144             safe    2.8537               0               1            7
# 145       unsafe-pgd    0.0451               0               0            0
# 146  safe-incomplete    0.0385               0               0            0
# 147  safe-incomplete    0.2115               0               0            0
# 148  safe-incomplete    0.0374               0               0            0
# 149             safe   18.6788           10989             186         8788
# 150       unsafe-pgd    0.0494               0               0            0
# 151       unsafe-pgd    0.0482               0               0            0
# 152  safe-incomplete    0.0361               0               0            0
# 153  safe-incomplete    0.0365               0               0            0
# 154  safe-incomplete    0.2117               0               0            0
# 155       unsafe-pgd    0.0551               0               0            0
# 156       unsafe-pgd    0.0476               0               0            0
# 157  safe-incomplete    0.0361               0               0            0
# 158  safe-incomplete    0.0354               0               0            0
# 159  safe-incomplete    0.0360               0               0            0
# 160  safe-incomplete    0.0401               0               0            0
# 161  safe-incomplete    0.0361               0               0            0
# 162             safe   30.0357           24911             177        12017
# 163       unsafe-pgd    0.0601               0               0            0
# 164  safe-incomplete    0.0369               0               0            0
# 165       unsafe-pgd    0.0511               0               0            0
# 166  safe-incomplete    0.0374               0               0            0
# 167       unsafe-pgd    0.0494               0               0            0
# 168       unsafe-pgd    0.0450               0               0            0
# 169  safe-incomplete    0.0362               0               0            0
# 170       unsafe-pgd    0.0414               0               0            0
# 171  safe-incomplete    0.0361               0               0            0
# 172  safe-incomplete    0.0363               0               0            0
# 173       unsafe-pgd    0.0446               0               0            0
# 174             safe    3.1771              50               9          303
# 175             safe    6.5144             200              91          815
# 176       unsafe-pgd    0.0523               0               0            0
# 177  safe-incomplete    0.0391               0               0            0
# 178  safe-incomplete    0.0366               0               0            0
# 179  safe-incomplete    0.0384               0               0            0
# 180  safe-incomplete    0.0356               0               0            0
# 181  safe-incomplete    0.0370               0               0            0
# 182  safe-incomplete    0.0385               0               0            0
# 183       unsafe-pgd    0.0439               0               0            0
# 184       unsafe-pgd    0.0459               0               0            0
# 185          unknown  202.9889          326737             348        33721
# 186  safe-incomplete    0.0466               0               0            0
# 187             safe    2.8265               0               1           17
# 188       unsafe-pgd    0.0483               0               0            0
# 189             safe    3.3669              50               7          400
# 190  safe-incomplete    0.0956               0               0            0
# 191             safe   26.6776           19354              50        12866
# 192          unknown  204.2922          262750             212        76632
# 193  safe-incomplete    0.0489               0               0            0
# 194       unsafe-pgd    0.0456               0               0            0
# 195  safe-incomplete    0.0377               0               0            0
# 196       unsafe-pgd    0.0454               0               0            0
# 197  safe-incomplete    0.0411               0               0            0
# 198       unsafe-pgd    0.0502               0               0            0
# 199             safe    6.5401             150              26         1034
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 66   -0.121572
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                35         NaN
# 12                 0         NaN
# 13                 6         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 1         NaN
# 19                83   -0.066276
# 20                 0         NaN
# 21                40         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                40   -0.289651
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 3         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                17         NaN
# 55                 0         NaN
# 56                35         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                51   -0.354709
# 73                 0         NaN
# 74                 0         NaN
# 75                 3         NaN
# 76                23         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                51         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                39         NaN
# 92                 0         NaN
# 93                19         NaN
# 94                 0         NaN
# 95                16         NaN
# 96                 0         NaN
# 97                31         NaN
# 98                 2         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113               20         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                4         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                6         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134               17         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139                1         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                1         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149               22         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160                0         NaN
# 161                0         NaN
# 162               22         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                2         NaN
# 175                7         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               84   -0.186031
# 186                0         NaN
# 187                1         NaN
# 188                0         NaN
# 189                2         NaN
# 190                0         NaN
# 191               25         NaN
# 192               79   -0.029532
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                7         NaN
# #Cuts 4651
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               31   16.917852   11585.870968      90.903226   4873.064516
# safe-incomplete    90    0.068891       0.000000       0.000000      0.000000
# unknown             6  203.321617  288071.666667     305.500000  41682.333333
# unsafe-pgd         73    0.049634       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  14.838710
# safe-incomplete        0.000000
# unknown               67.166667
# unsafe-pgd             0.000000
# safe number 121.0
# safe time 4.38556694214876
# safe domain 2968.280991735537
# safe cut 23.289256198347108
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((121.0, 4.38556694214876, 11585.870967741936, 90.90322580645162),)

# %%
main('cifar_cnn_b_adv4/gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe  123.6749          135502               0            0
# 11    safe  181.2804          195446               0            0
# 13    safe    4.3163              16               0            0
# 18    safe    3.1722               0               0            0
# 37    safe    3.6484               0               0            0
# 48    safe    3.3558               0               0            0
# 54    safe    7.4158             228               0            0
# 56    safe   34.1062           39821               0            0
# 64    safe    3.3076               0               0            0
# 75    safe    3.5937               2               0            0
# 76    safe  161.4464          187278               0            0
# 83    safe   75.3841          102646               0            0
# 91    safe   53.8001           71886               0            0
# 93    safe   88.7771           96154               0            0
# 95    safe    6.6094              68               0            0
# 97    safe   68.2608           92205               0            0
# 98    safe    3.5400               0               0            0
# 122   safe    4.7500              29               0            0
# 127   safe    3.8230               1               0            0
# 139   safe    3.4783               0               0            0
# 144   safe    3.5096               0               0            0
# 174   safe    3.5476               0               0            0
# 175   safe    4.0956               1               0            0
# 187   safe    3.4139               0               0            0
# 189   safe    3.4413               0               0            0
# 192   safe   99.5157           95589               0            0
# 199   safe    4.1474               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 6                 49         NaN
# 11                58         NaN
# 13                 4         NaN
# 18                 1         NaN
# 37                 2         NaN
# 48                 1         NaN
# 54                16         NaN
# 56                33         NaN
# 64                 1         NaN
# 75                 2         NaN
# 76                53         NaN
# 83                37         NaN
# 91                42         NaN
# 93                45         NaN
# 95                15         NaN
# 97                34         NaN
# 98                 1         NaN
# 122                6         NaN
# 127                3         NaN
# 139                1         NaN
# 144                1         NaN
# 174                1         NaN
# 175                4         NaN
# 187                1         NaN
# 189                1         NaN
# 192               35         NaN
# 199                3         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 19   unknown  204.0342          217364               0            0
# 21   unknown  203.1932          203440               0            0
# 24   unknown  210.0462          255519               0            0
# 72   unknown  200.5782          159577               0            0
# 113  unknown  215.5014          294204               0            0
# 134  unknown  204.1987          212940               0            0
# 149  unknown  209.8534          271811               0            0
# 162  unknown  217.7484          221697               0            0
# 185  unknown  203.3286          184105               0            0
# 191  unknown  210.3835          288763               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 19                43   -0.088109
# 21                37   -0.107114
# 24                38   -0.317195
# 72                71   -0.340647
# 113               36   -0.029997
# 134               31   -0.228768
# 149               35   -0.201577
# 162               29   -0.148279
# 185               62   -0.245334
# 191               36   -0.033824
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.7406               0               0            0
# 1         unsafe-pgd    0.0965               0               0            0
# 2    safe-incomplete    0.0401               0               0            0
# 3         unsafe-pgd    0.0549               0               0            0
# 4         unsafe-pgd    0.0437               0               0            0
# 5         unsafe-pgd    0.0485               0               0            0
# 6               safe  123.6749          135502               0            0
# 7    safe-incomplete    0.0684               0               0            0
# 8    safe-incomplete    0.0388               0               0            0
# 9         unsafe-pgd    0.0559               0               0            0
# 10        unsafe-pgd    0.0472               0               0            0
# 11              safe  181.2804          195446               0            0
# 12        unsafe-pgd    0.0794               0               0            0
# 13              safe    4.3163              16               0            0
# 14   safe-incomplete    0.0729               0               0            0
# 15        unsafe-pgd    0.0540               0               0            0
# 16        unsafe-pgd    0.0519               0               0            0
# 17   safe-incomplete    0.0415               0               0            0
# 18              safe    3.1722               0               0            0
# 19           unknown  204.0342          217364               0            0
# 20   safe-incomplete    0.0784               0               0            0
# 21           unknown  203.1932          203440               0            0
# 22   safe-incomplete    0.0489               0               0            0
# 23   safe-incomplete    0.0456               0               0            0
# 24           unknown  210.0462          255519               0            0
# 25        unsafe-pgd    0.0865               0               0            0
# 26   safe-incomplete    0.0425               0               0            0
# 27   safe-incomplete    0.0402               0               0            0
# 28   safe-incomplete    0.0406               0               0            0
# 29        unsafe-pgd    0.0585               0               0            0
# 30   safe-incomplete    0.0441               0               0            0
# 31   safe-incomplete    0.0394               0               0            0
# 32        unsafe-pgd    0.0624               0               0            0
# 33   safe-incomplete    0.0440               0               0            0
# 34        unsafe-pgd    0.0519               0               0            0
# 35        unsafe-pgd    0.0441               0               0            0
# 36   safe-incomplete    0.0408               0               0            0
# 37              safe    3.6484               0               0            0
# 38   safe-incomplete    0.3899               0               0            0
# 39   safe-incomplete    0.1218               0               0            0
# 40   safe-incomplete    0.1072               0               0            0
# 41   safe-incomplete    0.1002               0               0            0
# 42   safe-incomplete    0.0925               0               0            0
# 43        unsafe-pgd    0.1699               0               0            0
# 44        unsafe-pgd    0.1076               0               0            0
# 45        unsafe-pgd    0.1179               0               0            0
# 46        unsafe-pgd    0.1072               0               0            0
# 47   safe-incomplete    0.0953               0               0            0
# 48              safe    3.3558               0               0            0
# 49   safe-incomplete    0.1068               0               0            0
# 50        unsafe-pgd    0.0909               0               0            0
# 51   safe-incomplete    0.0953               0               0            0
# 52   safe-incomplete    0.0960               0               0            0
# 53        unsafe-pgd    0.0822               0               0            0
# 54              safe    7.4158             228               0            0
# 55   safe-incomplete    0.2121               0               0            0
# 56              safe   34.1062           39821               0            0
# 57        unsafe-pgd    0.0674               0               0            0
# 58        unsafe-pgd    0.0571               0               0            0
# 59   safe-incomplete    0.0446               0               0            0
# 60   safe-incomplete    0.0421               0               0            0
# 61        unsafe-pgd    0.0548               0               0            0
# 62   safe-incomplete    0.0413               0               0            0
# 63        unsafe-pgd    0.0515               0               0            0
# 64              safe    3.3076               0               0            0
# 65        unsafe-pgd    0.0767               0               0            0
# 66        unsafe-pgd    0.0557               0               0            0
# 67        unsafe-pgd    0.0521               0               0            0
# 68   safe-incomplete    0.0468               0               0            0
# 69        unsafe-pgd    0.0486               0               0            0
# 70   safe-incomplete    0.0427               0               0            0
# 71   safe-incomplete    0.0465               0               0            0
# 72           unknown  200.5782          159577               0            0
# 73   safe-incomplete    0.0830               0               0            0
# 74   safe-incomplete    0.0421               0               0            0
# 75              safe    3.5937               2               0            0
# 76              safe  161.4464          187278               0            0
# 77        unsafe-pgd    0.0884               0               0            0
# 78        unsafe-pgd    0.0559               0               0            0
# 79   safe-incomplete    0.0443               0               0            0
# 80        unsafe-pgd    0.0623               0               0            0
# 81        unsafe-pgd    0.0520               0               0            0
# 82        unsafe-pgd    0.0577               0               0            0
# 83              safe   75.3841          102646               0            0
# 84   safe-incomplete    0.0986               0               0            0
# 85   safe-incomplete    0.0437               0               0            0
# 86   safe-incomplete    0.0431               0               0            0
# 87        unsafe-pgd    0.0597               0               0            0
# 88        unsafe-pgd    0.0575               0               0            0
# 89   safe-incomplete    0.0415               0               0            0
# 90        unsafe-pgd    0.0585               0               0            0
# 91              safe   53.8001           71886               0            0
# 92   safe-incomplete    0.0514               0               0            0
# 93              safe   88.7771           96154               0            0
# 94        unsafe-pgd    0.1200               0               0            0
# 95              safe    6.6094              68               0            0
# 96        unsafe-pgd    0.1433               0               0            0
# 97              safe   68.2608           92205               0            0
# 98              safe    3.5400               0               0            0
# 99   safe-incomplete    0.1135               0               0            0
# 100       unsafe-pgd    0.1202               0               0            0
# 101  safe-incomplete    0.0537               0               0            0
# 102       unsafe-pgd    0.0541               0               0            0
# 103  safe-incomplete    0.0454               0               0            0
# 104  safe-incomplete    0.0478               0               0            0
# 105       unsafe-pgd    0.0624               0               0            0
# 106       unsafe-pgd    0.0506               0               0            0
# 107  safe-incomplete    0.0419               0               0            0
# 108       unsafe-pgd    0.0556               0               0            0
# 109  safe-incomplete    0.0424               0               0            0
# 110  safe-incomplete    0.0453               0               0            0
# 111  safe-incomplete    0.0405               0               0            0
# 112  safe-incomplete    0.0435               0               0            0
# 113          unknown  215.5014          294204               0            0
# 114  safe-incomplete    0.0670               0               0            0
# 115  safe-incomplete    0.0437               0               0            0
# 116  safe-incomplete    0.0422               0               0            0
# 117  safe-incomplete    0.0408               0               0            0
# 118  safe-incomplete    0.0429               0               0            0
# 119       unsafe-pgd    0.0588               0               0            0
# 120  safe-incomplete    0.0423               0               0            0
# 121  safe-incomplete    0.0433               0               0            0
# 122             safe    4.7500              29               0            0
# 123       unsafe-pgd    0.1128               0               0            0
# 124       unsafe-pgd    0.1164               0               0            0
# 125       unsafe-pgd    0.0583               0               0            0
# 126       unsafe-pgd    0.0591               0               0            0
# 127             safe    3.8230               1               0            0
# 128       unsafe-pgd    0.0753               0               0            0
# 129       unsafe-pgd    0.0603               0               0            0
# 130       unsafe-pgd    0.0563               0               0            0
# 131  safe-incomplete    0.0423               0               0            0
# 132  safe-incomplete    0.0435               0               0            0
# 133  safe-incomplete    0.0412               0               0            0
# 134          unknown  204.1987          212940               0            0
# 135  safe-incomplete    0.0907               0               0            0
# 136  safe-incomplete    0.0444               0               0            0
# 137       unsafe-pgd    0.0528               0               0            0
# 138       unsafe-pgd    0.0598               0               0            0
# 139             safe    3.4783               0               0            0
# 140  safe-incomplete    0.0942               0               0            0
# 141       unsafe-pgd    0.0671               0               0            0
# 142  safe-incomplete    0.0490               0               0            0
# 143       unsafe-pgd    0.0527               0               0            0
# 144             safe    3.5096               0               0            0
# 145       unsafe-pgd    0.1200               0               0            0
# 146  safe-incomplete    0.1002               0               0            0
# 147  safe-incomplete    0.4467               0               0            0
# 148  safe-incomplete    0.1355               0               0            0
# 149          unknown  209.8534          271811               0            0
# 150       unsafe-pgd    0.0974               0               0            0
# 151       unsafe-pgd    0.0585               0               0            0
# 152  safe-incomplete    0.0429               0               0            0
# 153  safe-incomplete    0.0591               0               0            0
# 154  safe-incomplete    0.4222               0               0            0
# 155       unsafe-pgd    0.2576               0               0            0
# 156       unsafe-pgd    0.1157               0               0            0
# 157  safe-incomplete    0.1021               0               0            0
# 158  safe-incomplete    0.1112               0               0            0
# 159  safe-incomplete    0.1029               0               0            0
# 160  safe-incomplete    0.0983               0               0            0
# 161  safe-incomplete    0.0948               0               0            0
# 162          unknown  217.7484          221697               0            0
# 163       unsafe-pgd    0.1106               0               0            0
# 164  safe-incomplete    0.0420               0               0            0
# 165       unsafe-pgd    0.0559               0               0            0
# 166  safe-incomplete    0.0435               0               0            0
# 167       unsafe-pgd    0.0579               0               0            0
# 168       unsafe-pgd    0.0502               0               0            0
# 169  safe-incomplete    0.0408               0               0            0
# 170       unsafe-pgd    0.0462               0               0            0
# 171  safe-incomplete    0.0418               0               0            0
# 172  safe-incomplete    0.0416               0               0            0
# 173       unsafe-pgd    0.0484               0               0            0
# 174             safe    3.5476               0               0            0
# 175             safe    4.0956               1               0            0
# 176       unsafe-pgd    0.1149               0               0            0
# 177  safe-incomplete    0.0982               0               0            0
# 178  safe-incomplete    0.0434               0               0            0
# 179  safe-incomplete    0.0421               0               0            0
# 180  safe-incomplete    0.0389               0               0            0
# 181  safe-incomplete    0.0411               0               0            0
# 182  safe-incomplete    0.0442               0               0            0
# 183       unsafe-pgd    0.0489               0               0            0
# 184       unsafe-pgd    0.0507               0               0            0
# 185          unknown  203.3286          184105               0            0
# 186  safe-incomplete    0.1165               0               0            0
# 187             safe    3.4139               0               0            0
# 188       unsafe-pgd    0.1290               0               0            0
# 189             safe    3.4413               0               0            0
# 190  safe-incomplete    0.1111               0               0            0
# 191          unknown  210.3835          288763               0            0
# 192             safe   99.5157           95589               0            0
# 193  safe-incomplete    0.1129               0               0            0
# 194       unsafe-pgd    0.1166               0               0            0
# 195  safe-incomplete    0.1242               0               0            0
# 196       unsafe-pgd    0.1386               0               0            0
# 197  safe-incomplete    0.1190               0               0            0
# 198       unsafe-pgd    0.0713               0               0            0
# 199             safe    4.1474               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 49         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                58         NaN
# 12                 0         NaN
# 13                 4         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 1         NaN
# 19                43   -0.088109
# 20                 0         NaN
# 21                37   -0.107114
# 22                 0         NaN
# 23                 0         NaN
# 24                38   -0.317195
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 2         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                16         NaN
# 55                 0         NaN
# 56                33         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                71   -0.340647
# 73                 0         NaN
# 74                 0         NaN
# 75                 2         NaN
# 76                53         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                37         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                42         NaN
# 92                 0         NaN
# 93                45         NaN
# 94                 0         NaN
# 95                15         NaN
# 96                 0         NaN
# 97                34         NaN
# 98                 1         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113               36   -0.029997
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                6         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                3         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134               31   -0.228768
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139                1         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                1         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149               35   -0.201577
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160                0         NaN
# 161                0         NaN
# 162               29   -0.148279
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                1         NaN
# 175                4         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               62   -0.245334
# 186                0         NaN
# 187                1         NaN
# 188                0         NaN
# 189                1         NaN
# 190                0         NaN
# 191               36   -0.033824
# 192               35         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                3         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               27   35.533763   37661.925926            0.0         0.0
# safe-incomplete    90    0.095714       0.000000            0.0         0.0
# unknown            10  207.886580  230942.000000            0.0         0.0
# unsafe-pgd         73    0.076593       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  16.666667
# safe-incomplete        0.000000
# unknown               41.800000
# unsafe-pgd             0.000000
# safe number 117.0
# safe time 8.27372564102564
# safe domain 8691.213675213676
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((117.0, 8.27372564102564, 37661.92592592593, 0.0),)

# %%
main('cifar_cnn_b_adv4/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 6     safe  171.7695          117261            1968        70944
# 11    safe  105.1750           75417            1267        29677
# 13    safe    7.3490             108              14          406
# 18    safe    4.4991               0               1           26
# 19    safe   20.2583            1589             119         1869
# 21    safe  124.5830          107554            1028        45530
# 37    safe    6.5177              50              10          443
# 48    safe    4.7096               0               1            9
# 54    safe   13.0460             333             103          403
# 56    safe   20.2437            1994              69         1244
# 64    safe    4.3914               0               1           49
# 75    safe    6.4447             100               8          323
# 76    safe   29.6831           16953              29        13395
# 83    safe   28.6263            5166             126         3167
# 91    safe   33.1486           10626             129         4416
# 93    safe   13.5323             639             105          900
# 95    safe   17.3182             169              62         1521
# 97    safe   32.8382           13147             124         6359
# 98    safe    5.5041              50               9          350
# 113   safe   22.5872            8020             217         5203
# 122   safe    7.1531             150              78          400
# 127   safe    9.5422             200              26          788
# 134   safe   16.6391            3408             133         2049
# 139   safe    4.5342               0               1          337
# 144   safe    4.5519               0               1            7
# 149   safe   25.0483            6849             166         5521
# 162   safe  184.8016          104311            3371        45570
# 174   safe    5.6111              50               9          303
# 175   safe   11.0984             200              91          815
# 187   safe    4.4704               0               1           17
# 189   safe    5.3265              50               7          400
# 191   safe  154.9026           96650            1393        38239
# 192   safe   69.7775           36931            1270        21032
# 199   safe   11.2448             150              26         1034
#
#      BaB Round Count  BaB_lb_rhs
# 6                 45         NaN
# 11                35         NaN
# 13                 6         NaN
# 18                 1         NaN
# 19                22         NaN
# 21                32         NaN
# 37                 3         NaN
# 48                 1         NaN
# 54                17         NaN
# 56                35         NaN
# 64                 1         NaN
# 75                 3         NaN
# 76                22         NaN
# 83                51         NaN
# 91                39         NaN
# 93                19         NaN
# 95                16         NaN
# 97                29         NaN
# 98                 2         NaN
# 113               20         NaN
# 122                4         NaN
# 127                6         NaN
# 134               18         NaN
# 139                1         NaN
# 144                1         NaN
# 149               21         NaN
# 162               32         NaN
# 174                2         NaN
# 175                7         NaN
# 187                1         NaN
# 189                2         NaN
# 191               33         NaN
# 192               35         NaN
# 199                7         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 24   unknown  302.9119          197580            2507        33869
# 72   unknown  208.4347          208570            2390        19285
# 185  unknown  203.3607          110642            3094        29930
#
#      BaB Round Count  BaB_lb_rhs
# 24                32   -0.285737
# 72                89   -0.333407
# 185               82   -0.479898
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.1032               0               0            0
# 1         unsafe-pgd    0.0962               0               0            0
# 2    safe-incomplete    0.0407               0               0            0
# 3         unsafe-pgd    0.0597               0               0            0
# 4         unsafe-pgd    0.0449               0               0            0
# 5         unsafe-pgd    0.0495               0               0            0
# 6               safe  171.7695          117261            1968        70944
# 7    safe-incomplete    0.1006               0               0            0
# 8    safe-incomplete    0.0759               0               0            0
# 9         unsafe-pgd    0.0567               0               0            0
# 10        unsafe-pgd    0.0481               0               0            0
# 11              safe  105.1750           75417            1267        29677
# 12        unsafe-pgd    0.1076               0               0            0
# 13              safe    7.3490             108              14          406
# 14   safe-incomplete    0.0641               0               0            0
# 15        unsafe-pgd    0.0503               0               0            0
# 16        unsafe-pgd    0.0491               0               0            0
# 17   safe-incomplete    0.0409               0               0            0
# 18              safe    4.4991               0               1           26
# 19              safe   20.2583            1589             119         1869
# 20   safe-incomplete    0.0974               0               0            0
# 21              safe  124.5830          107554            1028        45530
# 22   safe-incomplete    0.0736               0               0            0
# 23   safe-incomplete    0.0421               0               0            0
# 24           unknown  302.9119          197580            2507        33869
# 25        unsafe-pgd    0.0964               0               0            0
# 26   safe-incomplete    0.0384               0               0            0
# 27   safe-incomplete    0.0381               0               0            0
# 28   safe-incomplete    0.0390               0               0            0
# 29        unsafe-pgd    0.0532               0               0            0
# 30   safe-incomplete    0.0392               0               0            0
# 31   safe-incomplete    0.0387               0               0            0
# 32        unsafe-pgd    0.0593               0               0            0
# 33   safe-incomplete    0.0386               0               0            0
# 34        unsafe-pgd    0.0485               0               0            0
# 35        unsafe-pgd    0.0422               0               0            0
# 36   safe-incomplete    0.0427               0               0            0
# 37              safe    6.5177              50              10          443
# 38   safe-incomplete    0.3957               0               0            0
# 39   safe-incomplete    0.1221               0               0            0
# 40   safe-incomplete    0.0480               0               0            0
# 41   safe-incomplete    0.0949               0               0            0
# 42   safe-incomplete    0.0913               0               0            0
# 43        unsafe-pgd    0.1639               0               0            0
# 44        unsafe-pgd    0.0924               0               0            0
# 45        unsafe-pgd    0.0643               0               0            0
# 46        unsafe-pgd    0.1063               0               0            0
# 47   safe-incomplete    0.0907               0               0            0
# 48              safe    4.7096               0               1            9
# 49   safe-incomplete    0.1848               0               0            0
# 50        unsafe-pgd    0.1190               0               0            0
# 51   safe-incomplete    0.0933               0               0            0
# 52   safe-incomplete    0.0928               0               0            0
# 53        unsafe-pgd    0.0986               0               0            0
# 54              safe   13.0460             333             103          403
# 55   safe-incomplete    0.1035               0               0            0
# 56              safe   20.2437            1994              69         1244
# 57        unsafe-pgd    0.0621               0               0            0
# 58        unsafe-pgd    0.0512               0               0            0
# 59   safe-incomplete    0.0394               0               0            0
# 60   safe-incomplete    0.0398               0               0            0
# 61        unsafe-pgd    0.0488               0               0            0
# 62   safe-incomplete    0.0373               0               0            0
# 63        unsafe-pgd    0.0489               0               0            0
# 64              safe    4.3914               0               1           49
# 65        unsafe-pgd    0.0592               0               0            0
# 66        unsafe-pgd    0.0459               0               0            0
# 67        unsafe-pgd    0.0443               0               0            0
# 68   safe-incomplete    0.0373               0               0            0
# 69        unsafe-pgd    0.0427               0               0            0
# 70   safe-incomplete    0.0380               0               0            0
# 71   safe-incomplete    0.0371               0               0            0
# 72           unknown  208.4347          208570            2390        19285
# 73   safe-incomplete    0.0866               0               0            0
# 74   safe-incomplete    0.0399               0               0            0
# 75              safe    6.4447             100               8          323
# 76              safe   29.6831           16953              29        13395
# 77        unsafe-pgd    0.0953               0               0            0
# 78        unsafe-pgd    0.0515               0               0            0
# 79   safe-incomplete    0.0376               0               0            0
# 80        unsafe-pgd    0.0585               0               0            0
# 81        unsafe-pgd    0.0468               0               0            0
# 82        unsafe-pgd    0.0538               0               0            0
# 83              safe   28.6263            5166             126         3167
# 84   safe-incomplete    0.0963               0               0            0
# 85   safe-incomplete    0.0380               0               0            0
# 86   safe-incomplete    0.0382               0               0            0
# 87        unsafe-pgd    0.0540               0               0            0
# 88        unsafe-pgd    0.0519               0               0            0
# 89   safe-incomplete    0.0368               0               0            0
# 90        unsafe-pgd    0.0579               0               0            0
# 91              safe   33.1486           10626             129         4416
# 92   safe-incomplete    0.0963               0               0            0
# 93              safe   13.5323             639             105          900
# 94        unsafe-pgd    0.0504               0               0            0
# 95              safe   17.3182             169              62         1521
# 96        unsafe-pgd    0.1084               0               0            0
# 97              safe   32.8382           13147             124         6359
# 98              safe    5.5041              50               9          350
# 99   safe-incomplete    0.0504               0               0            0
# 100       unsafe-pgd    0.0551               0               0            0
# 101  safe-incomplete    0.0388               0               0            0
# 102       unsafe-pgd    0.0477               0               0            0
# 103  safe-incomplete    0.0926               0               0            0
# 104  safe-incomplete    0.0460               0               0            0
# 105       unsafe-pgd    0.0547               0               0            0
# 106       unsafe-pgd    0.0466               0               0            0
# 107  safe-incomplete    0.0379               0               0            0
# 108       unsafe-pgd    0.0494               0               0            0
# 109  safe-incomplete    0.0399               0               0            0
# 110  safe-incomplete    0.0385               0               0            0
# 111  safe-incomplete    0.0368               0               0            0
# 112  safe-incomplete    0.0385               0               0            0
# 113             safe   22.5872            8020             217         5203
# 114  safe-incomplete    0.0506               0               0            0
# 115  safe-incomplete    0.0382               0               0            0
# 116  safe-incomplete    0.0380               0               0            0
# 117  safe-incomplete    0.0387               0               0            0
# 118  safe-incomplete    0.0398               0               0            0
# 119       unsafe-pgd    0.0515               0               0            0
# 120  safe-incomplete    0.0409               0               0            0
# 121  safe-incomplete    0.0376               0               0            0
# 122             safe    7.1531             150              78          400
# 123       unsafe-pgd    0.1764               0               0            0
# 124       unsafe-pgd    0.0693               0               0            0
# 125       unsafe-pgd    0.0465               0               0            0
# 126       unsafe-pgd    0.0524               0               0            0
# 127             safe    9.5422             200              26          788
# 128       unsafe-pgd    0.0632               0               0            0
# 129       unsafe-pgd    0.0545               0               0            0
# 130       unsafe-pgd    0.0502               0               0            0
# 131  safe-incomplete    0.0381               0               0            0
# 132  safe-incomplete    0.0426               0               0            0
# 133  safe-incomplete    0.0382               0               0            0
# 134             safe   16.6391            3408             133         2049
# 135  safe-incomplete    0.1070               0               0            0
# 136  safe-incomplete    0.0385               0               0            0
# 137       unsafe-pgd    0.0494               0               0            0
# 138       unsafe-pgd    0.0530               0               0            0
# 139             safe    4.5342               0               1          337
# 140  safe-incomplete    0.0767               0               0            0
# 141       unsafe-pgd    0.0476               0               0            0
# 142  safe-incomplete    0.0389               0               0            0
# 143       unsafe-pgd    0.0448               0               0            0
# 144             safe    4.5519               0               1            7
# 145       unsafe-pgd    0.0878               0               0            0
# 146  safe-incomplete    0.0412               0               0            0
# 147  safe-incomplete    0.3496               0               0            0
# 148  safe-incomplete    0.0991               0               0            0
# 149             safe   25.0483            6849             166         5521
# 150       unsafe-pgd    0.1189               0               0            0
# 151       unsafe-pgd    0.1034               0               0            0
# 152  safe-incomplete    0.0827               0               0            0
# 153  safe-incomplete    0.0380               0               0            0
# 154  safe-incomplete    0.3498               0               0            0
# 155       unsafe-pgd    0.1362               0               0            0
# 156       unsafe-pgd    0.1066               0               0            0
# 157  safe-incomplete    0.0968               0               0            0
# 158  safe-incomplete    0.1471               0               0            0
# 159  safe-incomplete    0.0927               0               0            0
# 160  safe-incomplete    0.0945               0               0            0
# 161  safe-incomplete    0.0914               0               0            0
# 162             safe  184.8016          104311            3371        45570
# 163       unsafe-pgd    0.1151               0               0            0
# 164  safe-incomplete    0.0905               0               0            0
# 165       unsafe-pgd    0.1102               0               0            0
# 166  safe-incomplete    0.0918               0               0            0
# 167       unsafe-pgd    0.1006               0               0            0
# 168       unsafe-pgd    0.0471               0               0            0
# 169  safe-incomplete    0.0374               0               0            0
# 170       unsafe-pgd    0.0435               0               0            0
# 171  safe-incomplete    0.0375               0               0            0
# 172  safe-incomplete    0.0384               0               0            0
# 173       unsafe-pgd    0.0512               0               0            0
# 174             safe    5.6111              50               9          303
# 175             safe   11.0984             200              91          815
# 176       unsafe-pgd    0.1089               0               0            0
# 177  safe-incomplete    0.0501               0               0            0
# 178  safe-incomplete    0.0384               0               0            0
# 179  safe-incomplete    0.0391               0               0            0
# 180  safe-incomplete    0.0408               0               0            0
# 181  safe-incomplete    0.0381               0               0            0
# 182  safe-incomplete    0.0451               0               0            0
# 183       unsafe-pgd    0.0460               0               0            0
# 184       unsafe-pgd    0.0472               0               0            0
# 185          unknown  203.3607          110642            3094        29930
# 186  safe-incomplete    0.1002               0               0            0
# 187             safe    4.4704               0               1           17
# 188       unsafe-pgd    0.0748               0               0            0
# 189             safe    5.3265              50               7          400
# 190  safe-incomplete    0.0473               0               0            0
# 191             safe  154.9026           96650            1393        38239
# 192             safe   69.7775           36931            1270        21032
# 193  safe-incomplete    0.1116               0               0            0
# 194       unsafe-pgd    0.0581               0               0            0
# 195  safe-incomplete    0.0401               0               0            0
# 196       unsafe-pgd    0.0475               0               0            0
# 197  safe-incomplete    0.0486               0               0            0
# 198       unsafe-pgd    0.0540               0               0            0
# 199             safe   11.2448             150              26         1034
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  0         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  0         NaN
# 5                  0         NaN
# 6                 45         NaN
# 7                  0         NaN
# 8                  0         NaN
# 9                  0         NaN
# 10                 0         NaN
# 11                35         NaN
# 12                 0         NaN
# 13                 6         NaN
# 14                 0         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 0         NaN
# 18                 1         NaN
# 19                22         NaN
# 20                 0         NaN
# 21                32         NaN
# 22                 0         NaN
# 23                 0         NaN
# 24                32   -0.285737
# 25                 0         NaN
# 26                 0         NaN
# 27                 0         NaN
# 28                 0         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 0         NaN
# 34                 0         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 3         NaN
# 38                 0         NaN
# 39                 0         NaN
# 40                 0         NaN
# 41                 0         NaN
# 42                 0         NaN
# 43                 0         NaN
# 44                 0         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 1         NaN
# 49                 0         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 0         NaN
# 54                17         NaN
# 55                 0         NaN
# 56                35         NaN
# 57                 0         NaN
# 58                 0         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 0         NaN
# 63                 0         NaN
# 64                 1         NaN
# 65                 0         NaN
# 66                 0         NaN
# 67                 0         NaN
# 68                 0         NaN
# 69                 0         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                89   -0.333407
# 73                 0         NaN
# 74                 0         NaN
# 75                 3         NaN
# 76                22         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 0         NaN
# 80                 0         NaN
# 81                 0         NaN
# 82                 0         NaN
# 83                51         NaN
# 84                 0         NaN
# 85                 0         NaN
# 86                 0         NaN
# 87                 0         NaN
# 88                 0         NaN
# 89                 0         NaN
# 90                 0         NaN
# 91                39         NaN
# 92                 0         NaN
# 93                19         NaN
# 94                 0         NaN
# 95                16         NaN
# 96                 0         NaN
# 97                29         NaN
# 98                 2         NaN
# 99                 0         NaN
# 100                0         NaN
# 101                0         NaN
# 102                0         NaN
# 103                0         NaN
# 104                0         NaN
# 105                0         NaN
# 106                0         NaN
# 107                0         NaN
# 108                0         NaN
# 109                0         NaN
# 110                0         NaN
# 111                0         NaN
# 112                0         NaN
# 113               20         NaN
# 114                0         NaN
# 115                0         NaN
# 116                0         NaN
# 117                0         NaN
# 118                0         NaN
# 119                0         NaN
# 120                0         NaN
# 121                0         NaN
# 122                4         NaN
# 123                0         NaN
# 124                0         NaN
# 125                0         NaN
# 126                0         NaN
# 127                6         NaN
# 128                0         NaN
# 129                0         NaN
# 130                0         NaN
# 131                0         NaN
# 132                0         NaN
# 133                0         NaN
# 134               18         NaN
# 135                0         NaN
# 136                0         NaN
# 137                0         NaN
# 138                0         NaN
# 139                1         NaN
# 140                0         NaN
# 141                0         NaN
# 142                0         NaN
# 143                0         NaN
# 144                1         NaN
# 145                0         NaN
# 146                0         NaN
# 147                0         NaN
# 148                0         NaN
# 149               21         NaN
# 150                0         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                0         NaN
# 156                0         NaN
# 157                0         NaN
# 158                0         NaN
# 159                0         NaN
# 160                0         NaN
# 161                0         NaN
# 162               32         NaN
# 163                0         NaN
# 164                0         NaN
# 165                0         NaN
# 166                0         NaN
# 167                0         NaN
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                2         NaN
# 175                7         NaN
# 176                0         NaN
# 177                0         NaN
# 178                0         NaN
# 179                0         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                0         NaN
# 184                0         NaN
# 185               82   -0.479898
# 186                0         NaN
# 187                1         NaN
# 188                0         NaN
# 189                2         NaN
# 190                0         NaN
# 191               33         NaN
# 192               35         NaN
# 193                0         NaN
# 194                0         NaN
# 195                0         NaN
# 196                0         NaN
# 197                0         NaN
# 198                0         NaN
# 199                7         NaN
# #Cuts 19954
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe               34   34.909609   17886.029412     351.852941   8904.294118
# safe-incomplete    90    0.093222       0.000000       0.000000      0.000000
# unknown             3  238.235767  172264.000000    2663.666667  27694.666667
# unsafe-pgd         73    0.068592       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  16.735294
# safe-incomplete        0.000000
# unknown               67.666667
# unsafe-pgd             0.000000
# safe number 124.0
# safe time 9.639650806451614
# safe domain 4904.2338709677415
# safe cut 96.4758064516129
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((124.0, 9.639650806451614, 17886.029411764706, 351.8529411764706),)

# %% [markdown]
# ## mnist_cnn_a_adv

# %%
plot_multiple_dfs(
    [
log_read('mnist_cnn_a_adv/beta.log'),
log_read('mnist_cnn_a_adv/biccos_only_cs.log'),
log_read('mnist_cnn_a_adv/biccos_all.log'),
log_read('mnist_cnn_a_adv/gcp.log'),
log_read('mnist_cnn_a_adv/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],  time_limit=200, dataset='mnist_cnn_a_adv'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('mnist_cnn_a_adv/beta.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 1     safe   5.4361               0               0            0
# 2     safe   5.7833             311               0            0
# 3     safe   2.2272               0               0            0
# 4     safe   2.3615               0               0            0
# 8     safe  11.9162           12493               0            0
# 9     safe   2.3778               0               0            0
# 10    safe   5.7009            1861               0            0
# 11    safe   3.8415             102               0            0
# 15    safe   3.3068              22               0            0
# 17    safe   9.0937            4839               0            0
# 18    safe  10.2400           10631               0            0
# 19    safe   3.1644               0               0            0
# 20    safe   2.4812               0               0            0
# 21    safe   2.4401               0               0            0
# 22    safe   2.8467              13               0            0
# 23    safe   2.9413              11               0            0
# 24    safe   2.5250               0               0            0
# 25    safe   2.3928               0               0            0
# 26    safe   3.5095              32               0            0
# 29    safe   2.8114               1               0            0
# 33    safe   2.9465               5               0            0
# 35    safe  12.3073            7981               0            0
# 36    safe   5.2571            1004               0            0
# 37    safe   3.3203              14               0            0
# 39    safe   2.4152               0               0            0
# 41    safe   2.6529               0               0            0
# 42    safe   3.8316             207               0            0
# 44    safe   2.4494               0               0            0
# 48    safe   2.5706               0               0            0
# 49    safe   2.4443               0               0            0
# 50    safe   3.1285              72               0            0
# 51    safe  11.6530           11201               0            0
# 52    safe   2.5297               0               0            0
# 53    safe   2.6732               0               0            0
# 57    safe  10.0069           11255               0            0
# 58    safe   4.1679              56               0            0
# 59    safe   2.8527               0               0            0
# 62    safe   2.8113               0               0            0
# 66    safe   2.6463               0               0            0
# 67    safe   2.5521               0               0            0
# 69    safe   4.6208             530               0            0
# 75    safe   2.6489               0               0            0
# 76    safe   2.5864               4               0            0
# 79    safe   2.5835               0               0            0
# 81    safe   2.6641               3               0            0
# 85    safe   2.5002               0               0            0
# 88    safe   5.8929             466               0            0
# 89    safe   3.2150               0               0            0
# 90    safe   5.4099            1068               0            0
# 94    safe   2.3000               0               0            0
# 95    safe   3.1249              43               0            0
# 96    safe   2.3912               0               0            0
# 98    safe   2.8633               0               0            0
# 99    safe   2.8234               0               0            0
# 100   safe   2.4164               0               0            0
# 101   safe   3.0767              21               0            0
# 102   safe   2.8738               4               0            0
# 103   safe   3.6121              44               0            0
# 106   safe   2.7942               0               0            0
# 107   safe   3.2652             116               0            0
# 108   safe   2.5777               0               0            0
# 109   safe   2.6936               0               0            0
# 111   safe   2.6744               0               0            0
# 114   safe   3.1543               1               0            0
# 116   safe   2.4286               0               0            0
# 117   safe   2.3979               0               0            0
# 119   safe   2.3935               0               0            0
# 123   safe   2.3531               0               0            0
# 125   safe   2.3873               0               0            0
# 127   safe   2.4564               0               0            0
# 128   safe  15.4889           25025               0            0
# 129   safe   2.7715               8               0            0
# 131   safe   2.5386               0               0            0
# 133   safe   2.9754               4               0            0
# 136   safe   2.3464               0               0            0
# 137   safe   2.7886               0               0            0
# 141   safe   3.0249               8               0            0
# 143   safe  39.4158           75056               0            0
# 145   safe   3.8802              42               0            0
# 146   safe   7.6098            3068               0            0
# 147   safe   2.4145               0               0            0
# 149   safe   3.8627              65               0            0
# 150   safe   3.0821               0               0            0
# 155   safe   3.0607              17               0            0
# 156   safe   3.1844               2               0            0
# 159   safe   9.5997            9244               0            0
# 160   safe   2.3404               0               0            0
# 162   safe   2.4058               0               0            0
# 163   safe   2.5834               1               0            0
# 164   safe   2.5031               0               0            0
# 166   safe  61.0103          161289               0            0
# 168   safe   3.7021              69               0            0
# 169   safe   2.8456               0               0            0
# 170   safe   3.5222             419               0            0
# 176   safe   3.5328             808               0            0
# 178   safe   3.8027              55               0            0
# 179   safe   3.3202              13               0            0
# 183   safe   2.4026               0               0            0
# 186   safe   2.1806               0               0            0
# 189   safe   2.2427               0               0            0
# 190   safe   2.6026               0               0            0
# 191   safe   3.2349              17               0            0
# 192   safe   2.9702              43               0            0
# 194   safe   2.4369               0               0            0
# 195   safe   2.4305               0               0            0
# 196   safe   2.3178               0               0            0
# 197   safe   2.3208               0               0            0
# 198   safe   3.1669              12               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 1                  5         NaN
# 2                 21         NaN
# 3                  1         NaN
# 4                  2         NaN
# 8                 41         NaN
# 9                  3         NaN
# 10                23         NaN
# 11                14         NaN
# 15                 9         NaN
# 17                30         NaN
# 18                30         NaN
# 19                 8         NaN
# 20                 2         NaN
# 21                 1         NaN
# 22                 4         NaN
# 23                 5         NaN
# 24                 2         NaN
# 25                 1         NaN
# 26                10         NaN
# 29                 3         NaN
# 33                 5         NaN
# 35                56         NaN
# 36                21         NaN
# 37                 8         NaN
# 39                 1         NaN
# 41                 1         NaN
# 42                10         NaN
# 44                 1         NaN
# 48                 2         NaN
# 49                 1         NaN
# 50                 7         NaN
# 51                45         NaN
# 52                 2         NaN
# 53                 4         NaN
# 57                27         NaN
# 58                12         NaN
# 59                 4         NaN
# 62                 4         NaN
# 66                 2         NaN
# 67                 2         NaN
# 69                12         NaN
# 75                 2         NaN
# 76                 2         NaN
# 79                 2         NaN
# 81                 2         NaN
# 85                 1         NaN
# 88                17         NaN
# 89                 7         NaN
# 90                18         NaN
# 94                 1         NaN
# 95                 6         NaN
# 96                 1         NaN
# 98                 5         NaN
# 99                 5         NaN
# 100                1         NaN
# 101                6         NaN
# 102                5         NaN
# 103                8         NaN
# 106                4         NaN
# 107                4         NaN
# 108                1         NaN
# 109                2         NaN
# 111                3         NaN
# 114                7         NaN
# 116                1         NaN
# 117                1         NaN
# 119                1         NaN
# 123                1         NaN
# 125                1         NaN
# 127                1         NaN
# 128               39         NaN
# 129                4         NaN
# 131                2         NaN
# 133                5         NaN
# 136                1         NaN
# 137                4         NaN
# 141                3         NaN
# 143              104         NaN
# 145               11         NaN
# 146               31         NaN
# 147                1         NaN
# 149               11         NaN
# 150                7         NaN
# 155                6         NaN
# 156                7         NaN
# 159               31         NaN
# 160                1         NaN
# 162                1         NaN
# 163                2         NaN
# 164                2         NaN
# 166               89         NaN
# 168               11         NaN
# 169                7         NaN
# 170               10         NaN
# 176               10         NaN
# 178               13         NaN
# 179               10         NaN
# 183                3         NaN
# 186                1         NaN
# 189                2         NaN
# 190                5         NaN
# 191               10         NaN
# 192                6         NaN
# 194                2         NaN
# 195                2         NaN
# 196                1         NaN
# 197                1         NaN
# 198                8         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 16   unknown  207.0759          559265               0            0
# 27   unknown  203.1752          658602               0            0
# 63   unknown  205.2462          652397               0            0
# 68   unknown  210.0703          702578               0            0
# 74   unknown  212.4210          710568               0            0
# 82   unknown  206.8892          687279               0            0
# 86   unknown  203.8720          744615               0            0
# 87   unknown  201.1712          654434               0            0
# 104  unknown  207.5222          643056               0            0
# 110  unknown  201.2354          648576               0            0
# 135  unknown  200.1977          560246               0            0
# 138  unknown  202.0868          739792               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 16                45   -1.527417
# 27                48   -0.192066
# 63                52   -1.674901
# 68                42   -0.226225
# 74                31   -0.757899
# 82                34   -0.669990
# 86                44   -0.356054
# 87                90   -0.027414
# 104               33   -0.667006
# 110               69   -0.349807
# 135               88   -1.063736
# 138               42   -0.784563
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.8933               0               0            0
# 1               safe    5.4361               0               0            0
# 2               safe    5.7833             311               0            0
# 3               safe    2.2272               0               0            0
# 4               safe    2.3615               0               0            0
# 5         unsafe-pgd    0.0079               0               0            0
# 6    safe-incomplete    0.2641               0               0            0
# 7         unsafe-pgd    0.0064               0               0            0
# 8               safe   11.9162           12493               0            0
# 9               safe    2.3778               0               0            0
# 10              safe    5.7009            1861               0            0
# 11              safe    3.8415             102               0            0
# 12        unsafe-pgd    0.0078               0               0            0
# 13        unsafe-pgd    0.0069               0               0            0
# 14   safe-incomplete    0.3514               0               0            0
# 15              safe    3.3068              22               0            0
# 16           unknown  207.0759          559265               0            0
# 17              safe    9.0937            4839               0            0
# 18              safe   10.2400           10631               0            0
# 19              safe    3.1644               0               0            0
# 20              safe    2.4812               0               0            0
# 21              safe    2.4401               0               0            0
# 22              safe    2.8467              13               0            0
# 23              safe    2.9413              11               0            0
# 24              safe    2.5250               0               0            0
# 25              safe    2.3928               0               0            0
# 26              safe    3.5095              32               0            0
# 27           unknown  203.1752          658602               0            0
# 28        unsafe-pgd    0.0204               0               0            0
# 29              safe    2.8114               1               0            0
# 30        unsafe-pgd    0.0087               0               0            0
# 31        unsafe-pgd    0.0065               0               0            0
# 32        unsafe-pgd    0.0068               0               0            0
# 33              safe    2.9465               5               0            0
# 34        unsafe-pgd    0.0082               0               0            0
# 35              safe   12.3073            7981               0            0
# 36              safe    5.2571            1004               0            0
# 37              safe    3.3203              14               0            0
# 38        unsafe-pgd    0.0086               0               0            0
# 39              safe    2.4152               0               0            0
# 40   safe-incomplete    0.2881               0               0            0
# 41              safe    2.6529               0               0            0
# 42              safe    3.8316             207               0            0
# 43        unsafe-pgd    0.0088               0               0            0
# 44              safe    2.4494               0               0            0
# 45        unsafe-pgd    0.0064               0               0            0
# 46        unsafe-pgd    0.0066               0               0            0
# 47        unsafe-pgd    0.0065               0               0            0
# 48              safe    2.5706               0               0            0
# 49              safe    2.4443               0               0            0
# 50              safe    3.1285              72               0            0
# 51              safe   11.6530           11201               0            0
# 52              safe    2.5297               0               0            0
# 53              safe    2.6732               0               0            0
# 54   safe-incomplete    0.2886               0               0            0
# 55   safe-incomplete    0.2505               0               0            0
# 56   safe-incomplete    0.3014               0               0            0
# 57              safe   10.0069           11255               0            0
# 58              safe    4.1679              56               0            0
# 59              safe    2.8527               0               0            0
# 60        unsafe-pgd    0.0096               0               0            0
# 61   safe-incomplete    0.2511               0               0            0
# 62              safe    2.8113               0               0            0
# 63           unknown  205.2462          652397               0            0
# 64        unsafe-pgd    0.0211               0               0            0
# 65   safe-incomplete    0.3537               0               0            0
# 66              safe    2.6463               0               0            0
# 67              safe    2.5521               0               0            0
# 68           unknown  210.0703          702578               0            0
# 69              safe    4.6208             530               0            0
# 70        unsafe-pgd    0.0076               0               0            0
# 71        unsafe-pgd    0.0074               0               0            0
# 72   safe-incomplete    0.2377               0               0            0
# 73        unsafe-pgd    0.0067               0               0            0
# 74           unknown  212.4210          710568               0            0
# 75              safe    2.6489               0               0            0
# 76              safe    2.5864               4               0            0
# 77   safe-incomplete    0.2529               0               0            0
# 78   safe-incomplete    0.5071               0               0            0
# 79              safe    2.5835               0               0            0
# 80        unsafe-pgd    0.0081               0               0            0
# 81              safe    2.6641               3               0            0
# 82           unknown  206.8892          687279               0            0
# 83        unsafe-pgd    0.0130               0               0            0
# 84   safe-incomplete    0.2517               0               0            0
# 85              safe    2.5002               0               0            0
# 86           unknown  203.8720          744615               0            0
# 87           unknown  201.1712          654434               0            0
# 88              safe    5.8929             466               0            0
# 89              safe    3.2150               0               0            0
# 90              safe    5.4099            1068               0            0
# 91   safe-incomplete    0.3959               0               0            0
# 92        unsafe-pgd    0.0105               0               0            0
# 93        unsafe-pgd    0.0064               0               0            0
# 94              safe    2.3000               0               0            0
# 95              safe    3.1249              43               0            0
# 96              safe    2.3912               0               0            0
# 97   safe-incomplete    0.2743               0               0            0
# 98              safe    2.8633               0               0            0
# 99              safe    2.8234               0               0            0
# 100             safe    2.4164               0               0            0
# 101             safe    3.0767              21               0            0
# 102             safe    2.8738               4               0            0
# 103             safe    3.6121              44               0            0
# 104          unknown  207.5222          643056               0            0
# 105       unsafe-pgd    0.0170               0               0            0
# 106             safe    2.7942               0               0            0
# 107             safe    3.2652             116               0            0
# 108             safe    2.5777               0               0            0
# 109             safe    2.6936               0               0            0
# 110          unknown  201.2354          648576               0            0
# 111             safe    2.6744               0               0            0
# 112       unsafe-pgd    0.0073               0               0            0
# 113       unsafe-pgd    0.0065               0               0            0
# 114             safe    3.1543               1               0            0
# 115       unsafe-pgd    0.0078               0               0            0
# 116             safe    2.4286               0               0            0
# 117             safe    2.3979               0               0            0
# 118  safe-incomplete    0.2322               0               0            0
# 119             safe    2.3935               0               0            0
# 120  safe-incomplete    0.3067               0               0            0
# 121       unsafe-pgd    0.0066               0               0            0
# 122  safe-incomplete    0.2802               0               0            0
# 123             safe    2.3531               0               0            0
# 124  safe-incomplete    0.3821               0               0            0
# 125             safe    2.3873               0               0            0
# 126       unsafe-pgd    0.0103               0               0            0
# 127             safe    2.4564               0               0            0
# 128             safe   15.4889           25025               0            0
# 129             safe    2.7715               8               0            0
# 130       unsafe-pgd    0.0088               0               0            0
# 131             safe    2.5386               0               0            0
# 132       unsafe-pgd    0.0074               0               0            0
# 133             safe    2.9754               4               0            0
# 134  safe-incomplete    0.3307               0               0            0
# 135          unknown  200.1977          560246               0            0
# 136             safe    2.3464               0               0            0
# 137             safe    2.7886               0               0            0
# 138          unknown  202.0868          739792               0            0
# 139       unsafe-pgd    0.0138               0               0            0
# 140       unsafe-pgd    0.0067               0               0            0
# 141             safe    3.0249               8               0            0
# 142  safe-incomplete    0.2616               0               0            0
# 143             safe   39.4158           75056               0            0
# 144  safe-incomplete    0.2524               0               0            0
# 145             safe    3.8802              42               0            0
# 146             safe    7.6098            3068               0            0
# 147             safe    2.4145               0               0            0
# 148  safe-incomplete    0.3256               0               0            0
# 149             safe    3.8627              65               0            0
# 150             safe    3.0821               0               0            0
# 151  safe-incomplete    0.1622               0               0            0
# 152       unsafe-pgd    0.0054               0               0            0
# 153  safe-incomplete    0.2870               0               0            0
# 154       unsafe-pgd    0.0065               0               0            0
# 155             safe    3.0607              17               0            0
# 156             safe    3.1844               2               0            0
# 157       unsafe-pgd    0.0085               0               0            0
# 158       unsafe-pgd    0.0071               0               0            0
# 159             safe    9.5997            9244               0            0
# 160             safe    2.3404               0               0            0
# 161  safe-incomplete    0.2884               0               0            0
# 162             safe    2.4058               0               0            0
# 163             safe    2.5834               1               0            0
# 164             safe    2.5031               0               0            0
# 165  safe-incomplete    0.2713               0               0            0
# 166             safe   61.0103          161289               0            0
# 167  safe-incomplete    0.2609               0               0            0
# 168             safe    3.7021              69               0            0
# 169             safe    2.8456               0               0            0
# 170             safe    3.5222             419               0            0
# 171       unsafe-pgd    0.0081               0               0            0
# 172  safe-incomplete    0.3204               0               0            0
# 173  safe-incomplete    0.2571               0               0            0
# 174       unsafe-pgd    0.0063               0               0            0
# 175       unsafe-pgd    0.0050               0               0            0
# 176             safe    3.5328             808               0            0
# 177       unsafe-pgd    0.0086               0               0            0
# 178             safe    3.8027              55               0            0
# 179             safe    3.3202              13               0            0
# 180  safe-incomplete    0.1768               0               0            0
# 181       unsafe-pgd    0.0063               0               0            0
# 182  safe-incomplete    0.2824               0               0            0
# 183             safe    2.4026               0               0            0
# 184  safe-incomplete    0.2859               0               0            0
# 185       unsafe-pgd    0.0063               0               0            0
# 186             safe    2.1806               0               0            0
# 187       unsafe-pgd    0.0063               0               0            0
# 188  safe-incomplete    0.1815               0               0            0
# 189             safe    2.2427               0               0            0
# 190             safe    2.6026               0               0            0
# 191             safe    3.2349              17               0            0
# 192             safe    2.9702              43               0            0
# 193       unsafe-pgd    0.0067               0               0            0
# 194             safe    2.4369               0               0            0
# 195             safe    2.4305               0               0            0
# 196             safe    2.3178               0               0            0
# 197             safe    2.3208               0               0            0
# 198             safe    3.1669              12               0            0
# 199       unsafe-pgd    0.0091               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  5         NaN
# 2                 21         NaN
# 3                  1         NaN
# 4                  2         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                 41         NaN
# 9                  3         NaN
# 10                23         NaN
# 11                14         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 9         NaN
# 16                45   -1.527417
# 17                30         NaN
# 18                30         NaN
# 19                 8         NaN
# 20                 2         NaN
# 21                 1         NaN
# 22                 4         NaN
# 23                 5         NaN
# 24                 2         NaN
# 25                 1         NaN
# 26                10         NaN
# 27                48   -0.192066
# 28                 0         NaN
# 29                 3         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 5         NaN
# 34                 0         NaN
# 35                56         NaN
# 36                21         NaN
# 37                 8         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                 0         NaN
# 41                 1         NaN
# 42                10         NaN
# 43                 0         NaN
# 44                 1         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 2         NaN
# 49                 1         NaN
# 50                 7         NaN
# 51                45         NaN
# 52                 2         NaN
# 53                 4         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                27         NaN
# 58                12         NaN
# 59                 4         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 4         NaN
# 63                52   -1.674901
# 64                 0         NaN
# 65                 0         NaN
# 66                 2         NaN
# 67                 2         NaN
# 68                42   -0.226225
# 69                12         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                31   -0.757899
# 75                 2         NaN
# 76                 2         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 2         NaN
# 80                 0         NaN
# 81                 2         NaN
# 82                34   -0.669990
# 83                 0         NaN
# 84                 0         NaN
# 85                 1         NaN
# 86                44   -0.356054
# 87                90   -0.027414
# 88                17         NaN
# 89                 7         NaN
# 90                18         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 1         NaN
# 95                 6         NaN
# 96                 1         NaN
# 97                 0         NaN
# 98                 5         NaN
# 99                 5         NaN
# 100                1         NaN
# 101                6         NaN
# 102                5         NaN
# 103                8         NaN
# 104               33   -0.667006
# 105                0         NaN
# 106                4         NaN
# 107                4         NaN
# 108                1         NaN
# 109                2         NaN
# 110               69   -0.349807
# 111                3         NaN
# 112                0         NaN
# 113                0         NaN
# 114                7         NaN
# 115                0         NaN
# 116                1         NaN
# 117                1         NaN
# 118                0         NaN
# 119                1         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                1         NaN
# 124                0         NaN
# 125                1         NaN
# 126                0         NaN
# 127                1         NaN
# 128               39         NaN
# 129                4         NaN
# 130                0         NaN
# 131                2         NaN
# 132                0         NaN
# 133                5         NaN
# 134                0         NaN
# 135               88   -1.063736
# 136                1         NaN
# 137                4         NaN
# 138               42   -0.784563
# 139                0         NaN
# 140                0         NaN
# 141                3         NaN
# 142                0         NaN
# 143              104         NaN
# 144                0         NaN
# 145               11         NaN
# 146               31         NaN
# 147                1         NaN
# 148                0         NaN
# 149               11         NaN
# 150                7         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                6         NaN
# 156                7         NaN
# 157                0         NaN
# 158                0         NaN
# 159               31         NaN
# 160                1         NaN
# 161                0         NaN
# 162                1         NaN
# 163                2         NaN
# 164                2         NaN
# 165                0         NaN
# 166               89         NaN
# 167                0         NaN
# 168               11         NaN
# 169                7         NaN
# 170               10         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176               10         NaN
# 177                0         NaN
# 178               13         NaN
# 179               10         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                3         NaN
# 184                0         NaN
# 185                0         NaN
# 186                1         NaN
# 187                0         NaN
# 188                0         NaN
# 189                2         NaN
# 190                5         NaN
# 191               10         NaN
# 192                6         NaN
# 193                0         NaN
# 194                2         NaN
# 195                2         NaN
# 196                1         NaN
# 197                1         NaN
# 198                8         NaN
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe              108    4.534381    3145.148148            0.0         0.0
# safe-incomplete    34    0.361976       0.000000            0.0         0.0
# unknown            12  205.080258  663450.666667            0.0         0.0
# unsafe-pgd         46    0.008463       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                   9.462963
# safe-incomplete        0.000000
# unknown               51.500000
# unsafe-pgd             0.000000
# safe number 142.0
# safe time 3.535354929577465
# safe domain 2392.0845070422533
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((142.0, 3.535354929577465, 3145.1481481481483, 0.0),)

# %%
main('mnist_cnn_a_adv/biccos_only_cs.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 1     safe    5.9383               0               0          256
# 2     safe   12.2652             305             229         2749
# 3     safe    2.7392               0               1          256
# 4     safe    3.6134               0               1          512
# 8     safe    8.0139            1200             183         2358
# 9     safe    2.5331               0               0          256
# 10    safe    8.2749             870             108         1394
# 11    safe    6.3955             100             144         1489
# 15    safe    4.7734              22              73          992
# 16    safe   47.1905           51661             776        28877
# 17    safe    6.2552            1012             196         1538
# 18    safe    6.5166            1433             138         2377
# 19    safe    3.6235               0               0          256
# 20    safe    4.6562             100              23         1312
# 21    safe    3.1082              50               5          616
# 22    safe    2.9735              13              51          499
# 23    safe    3.1271              11              27          864
# 24    safe    4.3335             100              15          912
# 25    safe    3.3550             100              20          656
# 26    safe    4.7142              32              77          996
# 27    safe   13.7166            4031             159         4006
# 29    safe    6.7327             238              83         1273
# 33    safe    3.3040               5              29          576
# 35    safe   11.0846             929             256         3630
# 36    safe    7.5992             470             178         2661
# 37    safe    4.1858              14              47          896
# 39    safe    2.7843               0               1          256
# 41    safe    2.7397               0               1          256
# 42    safe    4.7429             197              61          896
# 44    safe    3.4277             100              59          656
# 48    safe    4.1091              50               2          512
# 49    safe    2.8143               0               1          256
# 50    safe    3.8910              72              63         1002
# 51    safe    6.8244            1127              86         1927
# 52    safe    4.7241             100              17         1309
# 53    safe    2.6706               0               0          256
# 57    safe    8.6032            2681             128         3466
# 58    safe    5.5671              56             109         1767
# 59    safe    2.6436               0               0          256
# 62    safe    2.6442               0               0          256
# 63    safe   43.7317           51100             541        28044
# 66    safe    4.6782             150              27         1312
# 67    safe    4.3154              50              17         1312
# 68    safe   10.4752            4490             406         4548
# 69    safe    5.0274             327             143         2171
# 74    safe   19.7574           16335             396        11406
# 75    safe    4.0252              50               4          912
# 76    safe    3.5831             100              17          634
# 79    safe    3.6716               0               1          512
# 81    safe    4.5553             115              28          648
# 82    safe   12.4270            6549             360         5255
# 85    safe    3.1723             100              14          656
# 87    safe    8.4524            1968             126         2480
# 88    safe    6.3553             214             238         2187
# 89    safe    3.2590               0               0          256
# 90    safe    5.5866             385             101         1665
# 94    safe    2.6300               0               1          256
# 95    safe    3.6133              43              59          832
# 96    safe    2.7359               0               1          256
# 98    safe    2.8101               0               0          256
# 99    safe    3.0251               0               0          256
# 100   safe    2.9471              50               6          618
# 101   safe    3.4158              21              30          784
# 102   safe    2.7787               4              21          512
# 103   safe    4.0606              44              36         1200
# 104   safe   15.6438           17592             280        11062
# 106   safe    2.5475               0               0          256
# 107   safe    5.3665             286              92          871
# 108   safe    2.7205               0               1          256
# 109   safe    4.2097              50               6          912
# 110   safe   25.8323           25160             556        12462
# 111   safe    2.2815               0               0          256
# 114   safe    3.5241               1              43          512
# 116   safe    3.2889              50               5          640
# 117   safe    2.6741               0               1          256
# 119   safe    3.0934              50               8          656
# 123   safe    3.0325              50               6          656
# 125   safe    2.9575              50               9          656
# 127   safe    2.6457               0               1          256
# 128   safe    7.1503            2714             155         2666
# 129   safe    2.6981               8              19          512
# 131   safe    3.9399              50               4          512
# 133   safe    3.0078               4              52          512
# 135   safe  148.0596          175819            3819       105832
# 136   safe    3.4978              50               5          578
# 137   safe    2.9210               0               0          256
# 138   safe   11.9188            6651             185         6322
# 141   safe    3.8454             103              60          771
# 143   safe   18.3260            6588             606         7150
# 145   safe    4.9007              42              32         1212
# 146   safe    7.1898             264             117         2033
# 147   safe    3.2453              50               6          656
# 149   safe    5.5274              65             189         1027
# 150   safe    3.6056               0               0          256
# 155   safe    3.8129              17              62          753
# 156   safe    3.7189               2              24          512
# 159   safe    7.1487            1349             167         2680
# 160   safe    3.0110              50               4          256
# 162   safe    2.8685              50              16          656
# 163   safe    4.3014             151              35          635
# 164   safe    5.0667             200              28         1312
# 166   safe   20.3255            8202             416         9290
# 168   safe    5.0518              69              98         1333
# 169   safe    3.3420               0               0          256
# 170   safe    3.8357             327              12         1353
# 176   safe    4.5228             573              44         1363
# 178   safe    5.6946              55             103         1715
# 179   safe    4.6255              13              77         1376
# 183   safe    2.2831               0               0          256
# 186   safe    2.6495               0               1          256
# 189   safe    5.0652             200              30         1312
# 190   safe    2.8893               0               0          256
# 191   safe    4.2139              17              22          784
# 192   safe    3.3683              42              89          784
# 194   safe    3.9849              50               4          512
# 195   safe    3.9106              50               1          799
# 196   safe    2.5195               0               1          256
# 197   safe    2.7822              50               5          256
# 198   safe    3.8895              12              74          830
#
#      BaB Round Count BaB_lb_rhs
# 1                  5       None
# 2                 21       None
# 3                  2       None
# 4                  4       None
# 8                 16       None
# 9                  3       None
# 10                17       None
# 11                14       None
# 15                 9       None
# 16                48       None
# 17                15       None
# 18                15       None
# 19                 8       None
# 20                 7       None
# 21                 3       None
# 22                 4       None
# 23                 5       None
# 24                 6       None
# 25                 4       None
# 26                10       None
# 27                29       None
# 29                10       None
# 33                 5       None
# 35                28       None
# 36                18       None
# 37                 8       None
# 39                 2       None
# 41                 2       None
# 42                10       None
# 44                 4       None
# 48                 5       None
# 49                 2       None
# 50                 7       None
# 51                16       None
# 52                 7       None
# 53                 4       None
# 57                19       None
# 58                12       None
# 59                 4       None
# 62                 4       None
# 63                45       None
# 66                 7       None
# 67                 6       None
# 68                25       None
# 69                10       None
# 74                28       None
# 75                 5       None
# 76                 4       None
# 79                 4       None
# 81                 6       None
# 82                26       None
# 85                 4       None
# 87                18       None
# 88                14       None
# 89                 7       None
# 90                15       None
# 94                 2       None
# 95                 6       None
# 96                 2       None
# 98                 5       None
# 99                 5       None
# 100                3       None
# 101                6       None
# 102                5       None
# 103                8       None
# 104               19       None
# 106                4       None
# 107                9       None
# 108                2       None
# 109                6       None
# 110               46       None
# 111                3       None
# 114                7       None
# 116                3       None
# 117                2       None
# 119                3       None
# 123                3       None
# 125                3       None
# 127                2       None
# 128               17       None
# 129                4       None
# 131                5       None
# 133                5       None
# 135              147       None
# 136                3       None
# 137                4       None
# 138               24       None
# 141                5       None
# 143               45       None
# 145               11       None
# 146               19       None
# 147                3       None
# 149               11       None
# 150                7       None
# 155                6       None
# 156                7       None
# 159               16       None
# 160                3       None
# 162                3       None
# 163                6       None
# 164                8       None
# 166               49       None
# 168               11       None
# 169                7       None
# 170                8       None
# 176                9       None
# 178               13       None
# 179               10       None
# 183                3       None
# 186                2       None
# 189                8       None
# 190                5       None
# 191               10       None
# 192                6       None
# 194                5       None
# 195                5       None
# 196                2       None
# 197                3       None
# 198                8       None
# Empty DataFrame
# Columns: [Status, Time, Domain Visited, Cut Generation, Unsat Nodes, BaB Round Count, BaB_lb_rhs]
# Index: []
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.7645               0               0            0
# 1               safe    5.9383               0               0          256
# 2               safe   12.2652             305             229         2749
# 3               safe    2.7392               0               1          256
# 4               safe    3.6134               0               1          512
# 5         unsafe-pgd    0.0078               0               0            0
# 6    safe-incomplete    0.3448               0               0            0
# 7         unsafe-pgd    0.0069               0               0            0
# 8               safe    8.0139            1200             183         2358
# 9               safe    2.5331               0               0          256
# 10              safe    8.2749             870             108         1394
# 11              safe    6.3955             100             144         1489
# 12        unsafe-pgd    0.0099               0               0            0
# 13        unsafe-pgd    0.0095               0               0            0
# 14   safe-incomplete    0.4869               0               0            0
# 15              safe    4.7734              22              73          992
# 16              safe   47.1905           51661             776        28877
# 17              safe    6.2552            1012             196         1538
# 18              safe    6.5166            1433             138         2377
# 19              safe    3.6235               0               0          256
# 20              safe    4.6562             100              23         1312
# 21              safe    3.1082              50               5          616
# 22              safe    2.9735              13              51          499
# 23              safe    3.1271              11              27          864
# 24              safe    4.3335             100              15          912
# 25              safe    3.3550             100              20          656
# 26              safe    4.7142              32              77          996
# 27              safe   13.7166            4031             159         4006
# 28        unsafe-pgd    0.0100               0               0            0
# 29              safe    6.7327             238              83         1273
# 30        unsafe-pgd    0.0098               0               0            0
# 31        unsafe-pgd    0.0077               0               0            0
# 32        unsafe-pgd    0.0076               0               0            0
# 33              safe    3.3040               5              29          576
# 34        unsafe-pgd    0.0089               0               0            0
# 35              safe   11.0846             929             256         3630
# 36              safe    7.5992             470             178         2661
# 37              safe    4.1858              14              47          896
# 38        unsafe-pgd    0.0111               0               0            0
# 39              safe    2.7843               0               1          256
# 40   safe-incomplete    0.3249               0               0            0
# 41              safe    2.7397               0               1          256
# 42              safe    4.7429             197              61          896
# 43        unsafe-pgd    0.0092               0               0            0
# 44              safe    3.4277             100              59          656
# 45        unsafe-pgd    0.0069               0               0            0
# 46        unsafe-pgd    0.0075               0               0            0
# 47        unsafe-pgd    0.0074               0               0            0
# 48              safe    4.1091              50               2          512
# 49              safe    2.8143               0               1          256
# 50              safe    3.8910              72              63         1002
# 51              safe    6.8244            1127              86         1927
# 52              safe    4.7241             100              17         1309
# 53              safe    2.6706               0               0          256
# 54   safe-incomplete    0.3681               0               0            0
# 55   safe-incomplete    0.3093               0               0            0
# 56   safe-incomplete    0.3408               0               0            0
# 57              safe    8.6032            2681             128         3466
# 58              safe    5.5671              56             109         1767
# 59              safe    2.6436               0               0          256
# 60        unsafe-pgd    0.0096               0               0            0
# 61   safe-incomplete    0.2821               0               0            0
# 62              safe    2.6442               0               0          256
# 63              safe   43.7317           51100             541        28044
# 64        unsafe-pgd    0.0088               0               0            0
# 65   safe-incomplete    0.3857               0               0            0
# 66              safe    4.6782             150              27         1312
# 67              safe    4.3154              50              17         1312
# 68              safe   10.4752            4490             406         4548
# 69              safe    5.0274             327             143         2171
# 70        unsafe-pgd    0.0078               0               0            0
# 71        unsafe-pgd    0.0091               0               0            0
# 72   safe-incomplete    0.2498               0               0            0
# 73        unsafe-pgd    0.0083               0               0            0
# 74              safe   19.7574           16335             396        11406
# 75              safe    4.0252              50               4          912
# 76              safe    3.5831             100              17          634
# 77   safe-incomplete    0.2421               0               0            0
# 78   safe-incomplete    0.5614               0               0            0
# 79              safe    3.6716               0               1          512
# 80        unsafe-pgd    0.0078               0               0            0
# 81              safe    4.5553             115              28          648
# 82              safe   12.4270            6549             360         5255
# 83        unsafe-pgd    0.0100               0               0            0
# 84   safe-incomplete    0.2862               0               0            0
# 85              safe    3.1723             100              14          656
# 86        unsafe-pgd    0.0926               0               0            0
# 87              safe    8.4524            1968             126         2480
# 88              safe    6.3553             214             238         2187
# 89              safe    3.2590               0               0          256
# 90              safe    5.5866             385             101         1665
# 91   safe-incomplete    0.4044               0               0            0
# 92        unsafe-pgd    0.0115               0               0            0
# 93        unsafe-pgd    0.0073               0               0            0
# 94              safe    2.6300               0               1          256
# 95              safe    3.6133              43              59          832
# 96              safe    2.7359               0               1          256
# 97   safe-incomplete    0.2756               0               0            0
# 98              safe    2.8101               0               0          256
# 99              safe    3.0251               0               0          256
# 100             safe    2.9471              50               6          618
# 101             safe    3.4158              21              30          784
# 102             safe    2.7787               4              21          512
# 103             safe    4.0606              44              36         1200
# 104             safe   15.6438           17592             280        11062
# 105       unsafe-pgd    0.0085               0               0            0
# 106             safe    2.5475               0               0          256
# 107             safe    5.3665             286              92          871
# 108             safe    2.7205               0               1          256
# 109             safe    4.2097              50               6          912
# 110             safe   25.8323           25160             556        12462
# 111             safe    2.2815               0               0          256
# 112       unsafe-pgd    0.0083               0               0            0
# 113       unsafe-pgd    0.0072               0               0            0
# 114             safe    3.5241               1              43          512
# 115       unsafe-pgd    0.0071               0               0            0
# 116             safe    3.2889              50               5          640
# 117             safe    2.6741               0               1          256
# 118  safe-incomplete    0.2484               0               0            0
# 119             safe    3.0934              50               8          656
# 120  safe-incomplete    0.3646               0               0            0
# 121       unsafe-pgd    0.0081               0               0            0
# 122  safe-incomplete    0.2943               0               0            0
# 123             safe    3.0325              50               6          656
# 124  safe-incomplete    0.4514               0               0            0
# 125             safe    2.9575              50               9          656
# 126       unsafe-pgd    0.0109               0               0            0
# 127             safe    2.6457               0               1          256
# 128             safe    7.1503            2714             155         2666
# 129             safe    2.6981               8              19          512
# 130       unsafe-pgd    0.0088               0               0            0
# 131             safe    3.9399              50               4          512
# 132       unsafe-pgd    0.0082               0               0            0
# 133             safe    3.0078               4              52          512
# 134  safe-incomplete    0.3500               0               0            0
# 135             safe  148.0596          175819            3819       105832
# 136             safe    3.4978              50               5          578
# 137             safe    2.9210               0               0          256
# 138             safe   11.9188            6651             185         6322
# 139       unsafe-pgd    0.0090               0               0            0
# 140       unsafe-pgd    0.0077               0               0            0
# 141             safe    3.8454             103              60          771
# 142  safe-incomplete    0.3170               0               0            0
# 143             safe   18.3260            6588             606         7150
# 144  safe-incomplete    0.2731               0               0            0
# 145             safe    4.9007              42              32         1212
# 146             safe    7.1898             264             117         2033
# 147             safe    3.2453              50               6          656
# 148  safe-incomplete    0.3585               0               0            0
# 149             safe    5.5274              65             189         1027
# 150             safe    3.6056               0               0          256
# 151  safe-incomplete    0.2142               0               0            0
# 152       unsafe-pgd    0.0070               0               0            0
# 153  safe-incomplete    0.3380               0               0            0
# 154       unsafe-pgd    0.0084               0               0            0
# 155             safe    3.8129              17              62          753
# 156             safe    3.7189               2              24          512
# 157       unsafe-pgd    0.0099               0               0            0
# 158       unsafe-pgd    0.0087               0               0            0
# 159             safe    7.1487            1349             167         2680
# 160             safe    3.0110              50               4          256
# 161  safe-incomplete    0.3442               0               0            0
# 162             safe    2.8685              50              16          656
# 163             safe    4.3014             151              35          635
# 164             safe    5.0667             200              28         1312
# 165  safe-incomplete    0.3106               0               0            0
# 166             safe   20.3255            8202             416         9290
# 167  safe-incomplete    0.3211               0               0            0
# 168             safe    5.0518              69              98         1333
# 169             safe    3.3420               0               0          256
# 170             safe    3.8357             327              12         1353
# 171       unsafe-pgd    0.0103               0               0            0
# 172  safe-incomplete    0.3720               0               0            0
# 173  safe-incomplete    0.2833               0               0            0
# 174       unsafe-pgd    0.0077               0               0            0
# 175       unsafe-pgd    0.0060               0               0            0
# 176             safe    4.5228             573              44         1363
# 177       unsafe-pgd    0.0099               0               0            0
# 178             safe    5.6946              55             103         1715
# 179             safe    4.6255              13              77         1376
# 180  safe-incomplete    0.2061               0               0            0
# 181       unsafe-pgd    0.0075               0               0            0
# 182  safe-incomplete    0.3270               0               0            0
# 183             safe    2.2831               0               0          256
# 184  safe-incomplete    0.3418               0               0            0
# 185       unsafe-pgd    0.0080               0               0            0
# 186             safe    2.6495               0               1          256
# 187       unsafe-pgd    0.0067               0               0            0
# 188  safe-incomplete    0.2227               0               0            0
# 189             safe    5.0652             200              30         1312
# 190             safe    2.8893               0               0          256
# 191             safe    4.2139              17              22          784
# 192             safe    3.3683              42              89          784
# 193       unsafe-pgd    0.0071               0               0            0
# 194             safe    3.9849              50               4          512
# 195             safe    3.9106              50               1          799
# 196             safe    2.5195               0               1          256
# 197             safe    2.7822              50               5          256
# 198             safe    3.8895              12              74          830
# 199       unsafe-pgd    0.0081               0               0            0
#
#      BaB Round Count BaB_lb_rhs
# 0                  0       None
# 1                  5       None
# 2                 21       None
# 3                  2       None
# 4                  4       None
# 5                  0       None
# 6                  0       None
# 7                  0       None
# 8                 16       None
# 9                  3       None
# 10                17       None
# 11                14       None
# 12                 0       None
# 13                 0       None
# 14                 0       None
# 15                 9       None
# 16                48       None
# 17                15       None
# 18                15       None
# 19                 8       None
# 20                 7       None
# 21                 3       None
# 22                 4       None
# 23                 5       None
# 24                 6       None
# 25                 4       None
# 26                10       None
# 27                29       None
# 28                 0       None
# 29                10       None
# 30                 0       None
# 31                 0       None
# 32                 0       None
# 33                 5       None
# 34                 0       None
# 35                28       None
# 36                18       None
# 37                 8       None
# 38                 0       None
# 39                 2       None
# 40                 0       None
# 41                 2       None
# 42                10       None
# 43                 0       None
# 44                 4       None
# 45                 0       None
# 46                 0       None
# 47                 0       None
# 48                 5       None
# 49                 2       None
# 50                 7       None
# 51                16       None
# 52                 7       None
# 53                 4       None
# 54                 0       None
# 55                 0       None
# 56                 0       None
# 57                19       None
# 58                12       None
# 59                 4       None
# 60                 0       None
# 61                 0       None
# 62                 4       None
# 63                45       None
# 64                 0       None
# 65                 0       None
# 66                 7       None
# 67                 6       None
# 68                25       None
# 69                10       None
# 70                 0       None
# 71                 0       None
# 72                 0       None
# 73                 0       None
# 74                28       None
# 75                 5       None
# 76                 4       None
# 77                 0       None
# 78                 0       None
# 79                 4       None
# 80                 0       None
# 81                 6       None
# 82                26       None
# 83                 0       None
# 84                 0       None
# 85                 4       None
# 86                 0       None
# 87                18       None
# 88                14       None
# 89                 7       None
# 90                15       None
# 91                 0       None
# 92                 0       None
# 93                 0       None
# 94                 2       None
# 95                 6       None
# 96                 2       None
# 97                 0       None
# 98                 5       None
# 99                 5       None
# 100                3       None
# 101                6       None
# 102                5       None
# 103                8       None
# 104               19       None
# 105                0       None
# 106                4       None
# 107                9       None
# 108                2       None
# 109                6       None
# 110               46       None
# 111                3       None
# 112                0       None
# 113                0       None
# 114                7       None
# 115                0       None
# 116                3       None
# 117                2       None
# 118                0       None
# 119                3       None
# 120                0       None
# 121                0       None
# 122                0       None
# 123                3       None
# 124                0       None
# 125                3       None
# 126                0       None
# 127                2       None
# 128               17       None
# 129                4       None
# 130                0       None
# 131                5       None
# 132                0       None
# 133                5       None
# 134                0       None
# 135              147       None
# 136                3       None
# 137                4       None
# 138               24       None
# 139                0       None
# 140                0       None
# 141                5       None
# 142                0       None
# 143               45       None
# 144                0       None
# 145               11       None
# 146               19       None
# 147                3       None
# 148                0       None
# 149               11       None
# 150                7       None
# 151                0       None
# 152                0       None
# 153                0       None
# 154                0       None
# 155                6       None
# 156                7       None
# 157                0       None
# 158                0       None
# 159               16       None
# 160                3       None
# 161                0       None
# 162                3       None
# 163                6       None
# 164                8       None
# 165                0       None
# 166               49       None
# 167                0       None
# 168               11       None
# 169                7       None
# 170                8       None
# 171                0       None
# 172                0       None
# 173                0       None
# 174                0       None
# 175                0       None
# 176                9       None
# 177                0       None
# 178               13       None
# 179               10       None
# 180                0       None
# 181                0       None
# 182                0       None
# 183                3       None
# 184                0       None
# 185                0       None
# 186                2       None
# 187                0       None
# 188                0       None
# 189                8       None
# 190                5       None
# 191               10       None
# 192                6       None
# 193                0       None
# 194                5       None
# 195                5       None
# 196                2       None
# 197                3       None
# 198                8       None
# 199                0       None
# #Cuts 13490
#                  Time           Domain Visited Cut Generation Unsat Nodes  \
#                 count      mean           mean           mean        mean
# Status
# safe              119  7.099434    3330.672269     113.361345  2807.05042
# safe-incomplete    34  0.398968       0.000000       0.000000     0.00000
# unsafe-pgd         47  0.010257       0.000000       0.000000     0.00000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  11.033613
# safe-incomplete        0.000000
# unsafe-pgd             0.000000
# safe number 153.0
# safe time 5.6104418300653585
# safe domain 2590.5228758169933
# safe cut 88.16993464052288
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((153.0, 5.6104418300653585, 3330.672268907563, 113.36134453781513),)

# %%
main('mnist_cnn_a_adv/biccos_all.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 1     safe   13.0062             300              55         1871
# 2     safe   21.1036            1173             398         5284
# 3     safe    2.6430               0               1           20
# 4     safe    3.5466               0               1           23
# 8     safe   17.3110            1354             222         4483
# 9     safe    4.1847               0               1          122
# 10    safe   16.8662            1370             205         4504
# 11    safe   15.5393             601             153         4253
# 15    safe   13.3344             800              83         3625
# 16    safe   65.8568           61542            1001        32084
# 17    safe   10.9374            1364             100         2491
# 18    safe   15.6031            1500             211         5626
# 19    safe   12.0667             450              94         3031
# 20    safe    4.0053             100              23          800
# 21    safe    2.5730              50               5          360
# 22    safe    6.0570             212              52         1230
# 23    safe    6.9977             159              27         1105
# 24    safe    3.8057             100              15          421
# 25    safe    3.0251             100              20          400
# 26    safe   14.1259             536             122         3400
# 27    safe    8.1020            1077              77         2097
# 29    safe    5.1215             237              68         1273
# 33    safe    6.6918             250              16         1188
# 35    safe   17.2525             998             310         5959
# 36    safe   18.3880            1042             210         5019
# 37    safe   12.0372             526             127         2516
# 39    safe    2.2977               0               1           34
# 41    safe    2.2708               0               1            8
# 42    safe   12.4517             661              92         3533
# 44    safe    2.8011             100              59          400
# 48    safe    3.4218              50               2           97
# 49    safe    2.3118               0               1           15
# 50    safe    9.5035             335              71         2613
# 51    safe   12.8219            1522             201         3709
# 52    safe    4.3209             100              17         1053
# 53    safe    5.8041             150              27          954
# 57    safe   17.4964            3477             202         5462
# 58    safe   18.1112             944             252         4576
# 59    safe    7.1338             308              88         1210
# 62    safe    5.7618             100              18          744
# 63    safe   61.0600           55158            1003        29934
# 66    safe    3.8964             150              27          800
# 67    safe    3.5602              50              17          800
# 68    safe   15.3946            4318             183         6202
# 69    safe    8.7487             644             161         2331
# 74    safe   28.0533           21630             439        12534
# 75    safe    3.4462              50               4          431
# 76    safe    3.0649             100              17          634
# 79    safe    3.1416               0               1           34
# 81    safe    3.4976             114              11          648
# 82    safe   19.9736            5330             321         7904
# 85    safe    2.9038             100              14          400
# 87    safe   18.5117            1700             176         4932
# 88    safe    9.5734             520             142         2727
# 89    safe   11.8639             506              84         3360
# 90    safe   14.2466             645             266         3668
# 94    safe    2.2538               0               1          104
# 95    safe    7.8360             221              93         1718
# 96    safe    2.3690               0               1            9
# 98    safe    9.1910             322              38         2075
# 99    safe    7.4367             250              39         1527
# 100   safe    2.5451              50               6          362
# 101   safe    9.0357             377              60         2441
# 102   safe    7.8504             221              43         1508
# 103   safe   12.0384             604             157         3205
# 104   safe   17.3530           13427             340         8046
# 106   safe    6.3850             150              10          554
# 107   safe    4.9680             269              58         1029
# 108   safe    2.2730               0               1           23
# 109   safe    3.7222              50               6          613
# 110   safe   26.7666           12289             482         9942
# 111   safe    5.2232             100              39         1445
# 114   safe   10.2434             450              75         2221
# 116   safe    2.6074              50               5          384
# 117   safe    2.4206               0               1           19
# 119   safe    2.5187              50               8          400
# 123   safe    2.6293              50               6          400
# 125   safe    2.6269              50               9          400
# 127   safe    2.3123               0               1           57
# 128   safe   15.7860            3060             120         4798
# 129   safe    7.0191             110              33         1195
# 131   safe    3.8837              50               4          273
# 133   safe    7.5228             201              50         1083
# 135   safe  158.7042          164214            3327        66290
# 136   safe    2.7931              50               5          322
# 137   safe    6.8729             200              33         1089
# 138   safe   39.0798           28866             280        24173
# 141   safe    3.9575             106              75          771
# 143   safe   28.5362            2865             291         8129
# 145   safe   16.4243             799             108         4120
# 146   safe   19.0372             759             220         4232
# 147   safe    2.8127              50               6          400
# 149   safe   11.8639             352             238         2043
# 150   safe   12.6123             404              54         2653
# 155   safe    8.0173             261              57         1997
# 156   safe   10.8133             416              69         2260
# 159   safe   14.9811            1991             219         4692
# 160   safe    2.6748              50               4          222
# 162   safe    2.6172              50              16          400
# 163   safe    3.6484             150               9          384
# 164   safe    4.6594             200              28          800
# 166   safe   31.6885            7928             391        12223
# 168   safe   14.1907             507             179         4362
# 169   safe   11.3966             350              63         2766
# 170   safe    7.9821             405              85         1179
# 176   safe    7.6722             581              62         1400
# 178   safe   15.9118             580             159         3244
# 179   safe   13.7977             618             197         3052
# 183   safe    5.5403             127              15          707
# 186   safe    2.4126               0               1           18
# 189   safe    4.5863             200              30          800
# 190   safe    8.4058             250              44         1833
# 191   safe   15.7909             606             124         3430
# 192   safe    7.2934             222             111         1368
# 194   safe    3.6939              50               4          285
# 195   safe    3.6847              50               1          321
# 196   safe    2.5088               0               1           70
# 197   safe    2.7430              50               5          229
# 198   safe   10.6989             353             133         2295
#
#      BaB Round Count BaB_lb_rhs
# 1                 13       None
# 2                 45       None
# 3                  1       None
# 4                  2       None
# 8                 37       None
# 9                  3       None
# 10                37       None
# 11                30       None
# 15                27       None
# 16                71       None
# 17                22       None
# 18                37       None
# 19                21       None
# 20                 5       None
# 21                 2       None
# 22                 9       None
# 23                 9       None
# 24                 4       None
# 25                 3       None
# 26                25       None
# 27                19       None
# 29                 9       None
# 33                10       None
# 35                40       None
# 36                39       None
# 37                22       None
# 39                 1       None
# 41                 1       None
# 42                25       None
# 44                 3       None
# 48                 3       None
# 49                 1       None
# 50                17       None
# 51                29       None
# 52                 6       None
# 53                 7       None
# 57                37       None
# 58                36       None
# 59                11       None
# 62                 7       None
# 63                78       None
# 66                 5       None
# 67                 4       None
# 68                38       None
# 69                17       None
# 74                46       None
# 75                 3       None
# 76                 4       None
# 79                 2       None
# 81                 5       None
# 82                44       None
# 85                 3       None
# 87                38       None
# 88                20       None
# 89                22       None
# 90                26       None
# 94                 1       None
# 95                12       None
# 96                 1       None
# 98                17       None
# 99                11       None
# 100                2       None
# 101               17       None
# 102               12       None
# 103               24       None
# 104               25       None
# 106                7       None
# 107                9       None
# 108                1       None
# 109                4       None
# 110               61       None
# 111                8       None
# 114               17       None
# 116                2       None
# 117                1       None
# 119                2       None
# 123                2       None
# 125                2       None
# 127                1       None
# 128               31       None
# 129                9       None
# 131                3       None
# 133               10       None
# 135              183       None
# 136                2       None
# 137                9       None
# 138               49       None
# 141                5       None
# 143               67       None
# 145               28       None
# 146               33       None
# 147                2       None
# 149               19       None
# 150               20       None
# 155               12       None
# 156               17       None
# 159               33       None
# 160                2       None
# 162                2       None
# 163                5       None
# 164                6       None
# 166               78       None
# 168               26       None
# 169               18       None
# 170               13       None
# 176               12       None
# 178               28       None
# 179               25       None
# 183                7       None
# 186                1       None
# 189                6       None
# 190               12       None
# 191               25       None
# 192               12       None
# 194                3       None
# 195                3       None
# 196                1       None
# 197                2       None
# 198               16       None
# Empty DataFrame
# Columns: [Status, Time, Domain Visited, Cut Generation, Unsat Nodes, BaB Round Count, BaB_lb_rhs]
# Index: []
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.5441               0               0            0
# 1               safe   13.0062             300              55         1871
# 2               safe   21.1036            1173             398         5284
# 3               safe    2.6430               0               1           20
# 4               safe    3.5466               0               1           23
# 5         unsafe-pgd    0.0103               0               0            0
# 6    safe-incomplete    0.3388               0               0            0
# 7         unsafe-pgd    0.0069               0               0            0
# 8               safe   17.3110            1354             222         4483
# 9               safe    4.1847               0               1          122
# 10              safe   16.8662            1370             205         4504
# 11              safe   15.5393             601             153         4253
# 12        unsafe-pgd    0.0078               0               0            0
# 13        unsafe-pgd    0.0067               0               0            0
# 14   safe-incomplete    0.3430               0               0            0
# 15              safe   13.3344             800              83         3625
# 16              safe   65.8568           61542            1001        32084
# 17              safe   10.9374            1364             100         2491
# 18              safe   15.6031            1500             211         5626
# 19              safe   12.0667             450              94         3031
# 20              safe    4.0053             100              23          800
# 21              safe    2.5730              50               5          360
# 22              safe    6.0570             212              52         1230
# 23              safe    6.9977             159              27         1105
# 24              safe    3.8057             100              15          421
# 25              safe    3.0251             100              20          400
# 26              safe   14.1259             536             122         3400
# 27              safe    8.1020            1077              77         2097
# 28        unsafe-pgd    0.0074               0               0            0
# 29              safe    5.1215             237              68         1273
# 30        unsafe-pgd    0.0071               0               0            0
# 31        unsafe-pgd    0.0062               0               0            0
# 32        unsafe-pgd    0.0059               0               0            0
# 33              safe    6.6918             250              16         1188
# 34        unsafe-pgd    0.0070               0               0            0
# 35              safe   17.2525             998             310         5959
# 36              safe   18.3880            1042             210         5019
# 37              safe   12.0372             526             127         2516
# 38        unsafe-pgd    0.0083               0               0            0
# 39              safe    2.2977               0               1           34
# 40   safe-incomplete    0.2699               0               0            0
# 41              safe    2.2708               0               1            8
# 42              safe   12.4517             661              92         3533
# 43        unsafe-pgd    0.0076               0               0            0
# 44              safe    2.8011             100              59          400
# 45        unsafe-pgd    0.0059               0               0            0
# 46        unsafe-pgd    0.0061               0               0            0
# 47        unsafe-pgd    0.0059               0               0            0
# 48              safe    3.4218              50               2           97
# 49              safe    2.3118               0               1           15
# 50              safe    9.5035             335              71         2613
# 51              safe   12.8219            1522             201         3709
# 52              safe    4.3209             100              17         1053
# 53              safe    5.8041             150              27          954
# 54   safe-incomplete    0.2975               0               0            0
# 55   safe-incomplete    0.2451               0               0            0
# 56   safe-incomplete    0.2799               0               0            0
# 57              safe   17.4964            3477             202         5462
# 58              safe   18.1112             944             252         4576
# 59              safe    7.1338             308              88         1210
# 60        unsafe-pgd    0.0082               0               0            0
# 61   safe-incomplete    0.2138               0               0            0
# 62              safe    5.7618             100              18          744
# 63              safe   61.0600           55158            1003        29934
# 64        unsafe-pgd    0.0075               0               0            0
# 65   safe-incomplete    0.3493               0               0            0
# 66              safe    3.8964             150              27          800
# 67              safe    3.5602              50              17          800
# 68              safe   15.3946            4318             183         6202
# 69              safe    8.7487             644             161         2331
# 70        unsafe-pgd    0.0060               0               0            0
# 71        unsafe-pgd    0.0073               0               0            0
# 72   safe-incomplete    0.1891               0               0            0
# 73        unsafe-pgd    0.0062               0               0            0
# 74              safe   28.0533           21630             439        12534
# 75              safe    3.4462              50               4          431
# 76              safe    3.0649             100              17          634
# 77   safe-incomplete    0.2330               0               0            0
# 78   safe-incomplete    0.4730               0               0            0
# 79              safe    3.1416               0               1           34
# 80        unsafe-pgd    0.0068               0               0            0
# 81              safe    3.4976             114              11          648
# 82              safe   19.9736            5330             321         7904
# 83        unsafe-pgd    0.0073               0               0            0
# 84   safe-incomplete    0.2327               0               0            0
# 85              safe    2.9038             100              14          400
# 86        unsafe-pgd    0.0935               0               0            0
# 87              safe   18.5117            1700             176         4932
# 88              safe    9.5734             520             142         2727
# 89              safe   11.8639             506              84         3360
# 90              safe   14.2466             645             266         3668
# 91   safe-incomplete    0.3604               0               0            0
# 92        unsafe-pgd    0.0098               0               0            0
# 93        unsafe-pgd    0.0059               0               0            0
# 94              safe    2.2538               0               1          104
# 95              safe    7.8360             221              93         1718
# 96              safe    2.3690               0               1            9
# 97   safe-incomplete    0.2542               0               0            0
# 98              safe    9.1910             322              38         2075
# 99              safe    7.4367             250              39         1527
# 100             safe    2.5451              50               6          362
# 101             safe    9.0357             377              60         2441
# 102             safe    7.8504             221              43         1508
# 103             safe   12.0384             604             157         3205
# 104             safe   17.3530           13427             340         8046
# 105       unsafe-pgd    0.0075               0               0            0
# 106             safe    6.3850             150              10          554
# 107             safe    4.9680             269              58         1029
# 108             safe    2.2730               0               1           23
# 109             safe    3.7222              50               6          613
# 110             safe   26.7666           12289             482         9942
# 111             safe    5.2232             100              39         1445
# 112       unsafe-pgd    0.0069               0               0            0
# 113       unsafe-pgd    0.0060               0               0            0
# 114             safe   10.2434             450              75         2221
# 115       unsafe-pgd    0.0059               0               0            0
# 116             safe    2.6074              50               5          384
# 117             safe    2.4206               0               1           19
# 118  safe-incomplete    0.2269               0               0            0
# 119             safe    2.5187              50               8          400
# 120  safe-incomplete    0.2855               0               0            0
# 121       unsafe-pgd    0.0065               0               0            0
# 122  safe-incomplete    0.2558               0               0            0
# 123             safe    2.6293              50               6          400
# 124  safe-incomplete    0.3789               0               0            0
# 125             safe    2.6269              50               9          400
# 126       unsafe-pgd    0.0089               0               0            0
# 127             safe    2.3123               0               1           57
# 128             safe   15.7860            3060             120         4798
# 129             safe    7.0191             110              33         1195
# 130       unsafe-pgd    0.0080               0               0            0
# 131             safe    3.8837              50               4          273
# 132       unsafe-pgd    0.0075               0               0            0
# 133             safe    7.5228             201              50         1083
# 134  safe-incomplete    0.3559               0               0            0
# 135             safe  158.7042          164214            3327        66290
# 136             safe    2.7931              50               5          322
# 137             safe    6.8729             200              33         1089
# 138             safe   39.0798           28866             280        24173
# 139       unsafe-pgd    0.0087               0               0            0
# 140       unsafe-pgd    0.0068               0               0            0
# 141             safe    3.9575             106              75          771
# 142  safe-incomplete    0.3025               0               0            0
# 143             safe   28.5362            2865             291         8129
# 144  safe-incomplete    0.2652               0               0            0
# 145             safe   16.4243             799             108         4120
# 146             safe   19.0372             759             220         4232
# 147             safe    2.8127              50               6          400
# 148  safe-incomplete    0.3415               0               0            0
# 149             safe   11.8639             352             238         2043
# 150             safe   12.6123             404              54         2653
# 151  safe-incomplete    0.1945               0               0            0
# 152       unsafe-pgd    0.0051               0               0            0
# 153  safe-incomplete    0.3096               0               0            0
# 154       unsafe-pgd    0.0066               0               0            0
# 155             safe    8.0173             261              57         1997
# 156             safe   10.8133             416              69         2260
# 157       unsafe-pgd    0.0080               0               0            0
# 158       unsafe-pgd    0.0068               0               0            0
# 159             safe   14.9811            1991             219         4692
# 160             safe    2.6748              50               4          222
# 161  safe-incomplete    0.3159               0               0            0
# 162             safe    2.6172              50              16          400
# 163             safe    3.6484             150               9          384
# 164             safe    4.6594             200              28          800
# 165  safe-incomplete    0.2795               0               0            0
# 166             safe   31.6885            7928             391        12223
# 167  safe-incomplete    0.2509               0               0            0
# 168             safe   14.1907             507             179         4362
# 169             safe   11.3966             350              63         2766
# 170             safe    7.9821             405              85         1179
# 171       unsafe-pgd    0.0081               0               0            0
# 172  safe-incomplete    0.3377               0               0            0
# 173  safe-incomplete    0.2954               0               0            0
# 174       unsafe-pgd    0.0066               0               0            0
# 175       unsafe-pgd    0.0048               0               0            0
# 176             safe    7.6722             581              62         1400
# 177       unsafe-pgd    0.0080               0               0            0
# 178             safe   15.9118             580             159         3244
# 179             safe   13.7977             618             197         3052
# 180  safe-incomplete    0.2222               0               0            0
# 181       unsafe-pgd    0.0065               0               0            0
# 182  safe-incomplete    0.3280               0               0            0
# 183             safe    5.5403             127              15          707
# 184  safe-incomplete    0.3124               0               0            0
# 185       unsafe-pgd    0.0066               0               0            0
# 186             safe    2.4126               0               1           18
# 187       unsafe-pgd    0.0055               0               0            0
# 188  safe-incomplete    0.2099               0               0            0
# 189             safe    4.5863             200              30          800
# 190             safe    8.4058             250              44         1833
# 191             safe   15.7909             606             124         3430
# 192             safe    7.2934             222             111         1368
# 193       unsafe-pgd    0.0078               0               0            0
# 194             safe    3.6939              50               4          285
# 195             safe    3.6847              50               1          321
# 196             safe    2.5088               0               1           70
# 197             safe    2.7430              50               5          229
# 198             safe   10.6989             353             133         2295
# 199       unsafe-pgd    0.0082               0               0            0
#
#      BaB Round Count BaB_lb_rhs
# 0                  0       None
# 1                 13       None
# 2                 45       None
# 3                  1       None
# 4                  2       None
# 5                  0       None
# 6                  0       None
# 7                  0       None
# 8                 37       None
# 9                  3       None
# 10                37       None
# 11                30       None
# 12                 0       None
# 13                 0       None
# 14                 0       None
# 15                27       None
# 16                71       None
# 17                22       None
# 18                37       None
# 19                21       None
# 20                 5       None
# 21                 2       None
# 22                 9       None
# 23                 9       None
# 24                 4       None
# 25                 3       None
# 26                25       None
# 27                19       None
# 28                 0       None
# 29                 9       None
# 30                 0       None
# 31                 0       None
# 32                 0       None
# 33                10       None
# 34                 0       None
# 35                40       None
# 36                39       None
# 37                22       None
# 38                 0       None
# 39                 1       None
# 40                 0       None
# 41                 1       None
# 42                25       None
# 43                 0       None
# 44                 3       None
# 45                 0       None
# 46                 0       None
# 47                 0       None
# 48                 3       None
# 49                 1       None
# 50                17       None
# 51                29       None
# 52                 6       None
# 53                 7       None
# 54                 0       None
# 55                 0       None
# 56                 0       None
# 57                37       None
# 58                36       None
# 59                11       None
# 60                 0       None
# 61                 0       None
# 62                 7       None
# 63                78       None
# 64                 0       None
# 65                 0       None
# 66                 5       None
# 67                 4       None
# 68                38       None
# 69                17       None
# 70                 0       None
# 71                 0       None
# 72                 0       None
# 73                 0       None
# 74                46       None
# 75                 3       None
# 76                 4       None
# 77                 0       None
# 78                 0       None
# 79                 2       None
# 80                 0       None
# 81                 5       None
# 82                44       None
# 83                 0       None
# 84                 0       None
# 85                 3       None
# 86                 0       None
# 87                38       None
# 88                20       None
# 89                22       None
# 90                26       None
# 91                 0       None
# 92                 0       None
# 93                 0       None
# 94                 1       None
# 95                12       None
# 96                 1       None
# 97                 0       None
# 98                17       None
# 99                11       None
# 100                2       None
# 101               17       None
# 102               12       None
# 103               24       None
# 104               25       None
# 105                0       None
# 106                7       None
# 107                9       None
# 108                1       None
# 109                4       None
# 110               61       None
# 111                8       None
# 112                0       None
# 113                0       None
# 114               17       None
# 115                0       None
# 116                2       None
# 117                1       None
# 118                0       None
# 119                2       None
# 120                0       None
# 121                0       None
# 122                0       None
# 123                2       None
# 124                0       None
# 125                2       None
# 126                0       None
# 127                1       None
# 128               31       None
# 129                9       None
# 130                0       None
# 131                3       None
# 132                0       None
# 133               10       None
# 134                0       None
# 135              183       None
# 136                2       None
# 137                9       None
# 138               49       None
# 139                0       None
# 140                0       None
# 141                5       None
# 142                0       None
# 143               67       None
# 144                0       None
# 145               28       None
# 146               33       None
# 147                2       None
# 148                0       None
# 149               19       None
# 150               20       None
# 151                0       None
# 152                0       None
# 153                0       None
# 154                0       None
# 155               12       None
# 156               17       None
# 157                0       None
# 158                0       None
# 159               33       None
# 160                2       None
# 161                0       None
# 162                2       None
# 163                5       None
# 164                6       None
# 165                0       None
# 166               78       None
# 167                0       None
# 168               26       None
# 169               18       None
# 170               13       None
# 171                0       None
# 172                0       None
# 173                0       None
# 174                0       None
# 175                0       None
# 176               12       None
# 177                0       None
# 178               28       None
# 179               25       None
# 180                0       None
# 181                0       None
# 182                0       None
# 183                7       None
# 184                0       None
# 185                0       None
# 186                1       None
# 187                0       None
# 188                0       None
# 189                6       None
# 190               12       None
# 191               25       None
# 192               12       None
# 193                0       None
# 194                3       None
# 195                3       None
# 196                1       None
# 197                2       None
# 198               16       None
# 199                0       None
# #Cuts 15825
#                  Time            Domain Visited Cut Generation  Unsat Nodes  \
#                 count       mean           mean           mean         mean
# Status
# safe              119  11.298721    3543.394958     132.983193  3406.067227
# safe-incomplete    34   0.326235       0.000000       0.000000     0.000000
# unsafe-pgd         47   0.008913       0.000000       0.000000     0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  18.109244
# safe-incomplete        0.000000
# unsafe-pgd             0.000000
# safe number 153.0
# safe time 8.860390849673204
# safe domain 2755.97385620915
# safe cut 103.43137254901961
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((153.0, 8.860390849673204, 3543.3949579831933, 132.98319327731093),)

# %%
main('mnist_cnn_a_adv/gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 1     safe    6.1409               0               0            0
# 2     safe    8.4156             292               0            0
# 3     safe    2.6836               0               0            0
# 4     safe    2.9343               0               0            0
# 8     safe   18.5455           12471               0            0
# 9     safe    3.0989               0               0            0
# 10    safe    8.9712            1862               0            0
# 11    safe    6.9818              94               0            0
# 15    safe    4.3917              28               0            0
# 17    safe   21.0113            4816               0            0
# 18    safe   31.4125           12448               0            0
# 19    safe    4.1697               0               0            0
# 20    safe    3.1954               0               0            0
# 21    safe    2.9753               0               0            0
# 22    safe    3.4432              13               0            0
# 23    safe    3.7919              11               0            0
# 24    safe    3.1440               0               0            0
# 25    safe    2.8415               0               0            0
# 26    safe    4.8556              32               0            0
# 29    safe    3.5386               1               0            0
# 33    safe    3.6035               5               0            0
# 36    safe   14.9517             987               0            0
# 37    safe    4.4021              14               0            0
# 39    safe    2.9018               0               0            0
# 41    safe    3.1771               0               0            0
# 42    safe    5.4314             206               0            0
# 44    safe    2.8868               0               0            0
# 48    safe    3.2897               0               0            0
# 49    safe    2.9486               0               0            0
# 50    safe    4.5744              72               0            0
# 51    safe   48.1186           47045               0            0
# 52    safe    3.3123               0               0            0
# 53    safe    3.4519               0               0            0
# 57    safe   25.0856           11255               0            0
# 58    safe    5.5103              54               0            0
# 59    safe    3.6138               0               0            0
# 62    safe    3.5575               0               0            0
# 66    safe    3.5787               0               0            0
# 67    safe    3.2463               0               0            0
# 69    safe    6.8423             544               0            0
# 75    safe    3.4434               0               0            0
# 76    safe    3.2038               4               0            0
# 79    safe    3.7889               0               0            0
# 81    safe    3.6307               3               0            0
# 85    safe    3.4337               0               0            0
# 88    safe    7.5929             461               0            0
# 89    safe    3.9595               0               0            0
# 90    safe    9.0869            1067               0            0
# 94    safe    3.1097               0               0            0
# 95    safe    4.4423              43               0            0
# 96    safe    3.0006               0               0            0
# 98    safe    4.0854               0               0            0
# 99    safe    3.9091               0               0            0
# 100   safe    2.9513               0               0            0
# 101   safe    4.3100              17               0            0
# 102   safe    3.6720               4               0            0
# 103   safe    4.6047              38               0            0
# 106   safe    3.7839               0               0            0
# 107   safe    4.0077             115               0            0
# 108   safe    3.1080               0               0            0
# 109   safe    3.3135               0               0            0
# 111   safe    3.6111               0               0            0
# 114   safe    4.0360               1               0            0
# 116   safe    2.9984               0               0            0
# 117   safe    3.1251               0               0            0
# 119   safe    3.3434               0               0            0
# 123   safe    3.3710               0               0            0
# 125   safe    3.6037               0               0            0
# 127   safe    3.7221               0               0            0
# 128   safe   51.1907           44925               0            0
# 129   safe    3.6902               8               0            0
# 131   safe    3.3650               0               0            0
# 133   safe    3.8181               4               0            0
# 136   safe    3.1039               0               0            0
# 137   safe    3.6951               0               0            0
# 141   safe    3.8224               8               0            0
# 143   safe  198.3634          224313               0            0
# 145   safe    5.5492              42               0            0
# 146   safe   20.4727            3065               0            0
# 147   safe    3.0222               0               0            0
# 149   safe    6.1417              65               0            0
# 150   safe    4.5008               0               0            0
# 155   safe    4.5119              17               0            0
# 156   safe    4.2174               2               0            0
# 159   safe   19.5988            9231               0            0
# 160   safe    3.0536               0               0            0
# 162   safe    3.5176               0               0            0
# 163   safe    4.0721               1               0            0
# 164   safe    3.5071               0               0            0
# 166   safe  169.7966          208104               0            0
# 168   safe    5.9412              69               0            0
# 169   safe    4.4083               0               0            0
# 170   safe    6.6048             419               0            0
# 176   safe    6.9382             811               0            0
# 178   safe    6.5715              45               0            0
# 179   safe    5.1167              11               0            0
# 183   safe    3.8341               0               0            0
# 186   safe    3.4438               0               0            0
# 189   safe    4.6176               0               0            0
# 190   safe    4.4394               0               0            0
# 191   safe    6.0661              17               0            0
# 192   safe    4.4865              42               0            0
# 194   safe    3.3073               0               0            0
# 195   safe    3.3280               0               0            0
# 196   safe    3.0116               0               0            0
# 197   safe    3.1996               0               0            0
# 198   safe    4.5750              12               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 1                  5         NaN
# 2                 21         NaN
# 3                  1         NaN
# 4                  2         NaN
# 8                 41         NaN
# 9                  3         NaN
# 10                23         NaN
# 11                14         NaN
# 15                 9         NaN
# 17                30         NaN
# 18                33         NaN
# 19                 8         NaN
# 20                 2         NaN
# 21                 1         NaN
# 22                 4         NaN
# 23                 5         NaN
# 24                 2         NaN
# 25                 1         NaN
# 26                10         NaN
# 29                 3         NaN
# 33                 5         NaN
# 36                21         NaN
# 37                 8         NaN
# 39                 1         NaN
# 41                 1         NaN
# 42                10         NaN
# 44                 1         NaN
# 48                 2         NaN
# 49                 1         NaN
# 50                 7         NaN
# 51                61         NaN
# 52                 2         NaN
# 53                 4         NaN
# 57                27         NaN
# 58                12         NaN
# 59                 4         NaN
# 62                 4         NaN
# 66                 2         NaN
# 67                 2         NaN
# 69                12         NaN
# 75                 2         NaN
# 76                 2         NaN
# 79                 2         NaN
# 81                 2         NaN
# 85                 1         NaN
# 88                17         NaN
# 89                 7         NaN
# 90                18         NaN
# 94                 1         NaN
# 95                 6         NaN
# 96                 1         NaN
# 98                 5         NaN
# 99                 5         NaN
# 100                1         NaN
# 101                6         NaN
# 102                5         NaN
# 103                8         NaN
# 106                4         NaN
# 107                4         NaN
# 108                1         NaN
# 109                2         NaN
# 111                3         NaN
# 114                7         NaN
# 116                1         NaN
# 117                1         NaN
# 119                1         NaN
# 123                1         NaN
# 125                1         NaN
# 127                1         NaN
# 128               44         NaN
# 129                4         NaN
# 131                2         NaN
# 133                5         NaN
# 136                1         NaN
# 137                4         NaN
# 141                3         NaN
# 143              128         NaN
# 145               11         NaN
# 146               31         NaN
# 147                1         NaN
# 149               11         NaN
# 150                7         NaN
# 155                6         NaN
# 156                7         NaN
# 159               31         NaN
# 160                1         NaN
# 162                1         NaN
# 163                2         NaN
# 164                2         NaN
# 166               90         NaN
# 168               11         NaN
# 169                7         NaN
# 170               10         NaN
# 176               10         NaN
# 178               13         NaN
# 179               10         NaN
# 183                3         NaN
# 186                1         NaN
# 189                2         NaN
# 190                5         NaN
# 191               10         NaN
# 192                6         NaN
# 194                2         NaN
# 195                2         NaN
# 196                1         NaN
# 197                1         NaN
# 198                8         NaN
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 16   unknown  210.2879          332522               0            0
# 27   unknown  201.2415          352390               0            0
# 35   unknown  201.4140          252294               0            0
# 63   unknown  216.0330          322700               0            0
# 68   unknown  209.4127          365756               0            0
# 74   unknown  211.4098          373170               0            0
# 82   unknown  219.6346          305391               0            0
# 86   unknown  227.9619          433964               0            0
# 87   unknown  206.5323          264590               0            0
# 104  unknown  213.3460          354273               0            0
# 110  unknown  217.5901          348066               0            0
# 135  unknown  201.5345          186199               0            0
# 138  unknown  217.4463          374895               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 16                46   -1.628749
# 27                38   -0.213988
# 35                95   -0.023736
# 63                47   -1.369897
# 68                32   -0.258953
# 74                25   -0.749033
# 82                68   -0.780801
# 86                38   -0.434740
# 87                46   -0.195952
# 104               26   -0.709171
# 110               35   -0.500134
# 135              158   -0.917011
# 138               31   -0.802908
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    1.5001               0               0            0
# 1               safe    6.1409               0               0            0
# 2               safe    8.4156             292               0            0
# 3               safe    2.6836               0               0            0
# 4               safe    2.9343               0               0            0
# 5         unsafe-pgd    0.0092               0               0            0
# 6    safe-incomplete    0.3126               0               0            0
# 7         unsafe-pgd    0.0179               0               0            0
# 8               safe   18.5455           12471               0            0
# 9               safe    3.0989               0               0            0
# 10              safe    8.9712            1862               0            0
# 11              safe    6.9818              94               0            0
# 12        unsafe-pgd    0.0124               0               0            0
# 13        unsafe-pgd    0.0091               0               0            0
# 14   safe-incomplete    0.4320               0               0            0
# 15              safe    4.3917              28               0            0
# 16           unknown  210.2879          332522               0            0
# 17              safe   21.0113            4816               0            0
# 18              safe   31.4125           12448               0            0
# 19              safe    4.1697               0               0            0
# 20              safe    3.1954               0               0            0
# 21              safe    2.9753               0               0            0
# 22              safe    3.4432              13               0            0
# 23              safe    3.7919              11               0            0
# 24              safe    3.1440               0               0            0
# 25              safe    2.8415               0               0            0
# 26              safe    4.8556              32               0            0
# 27           unknown  201.2415          352390               0            0
# 28        unsafe-pgd    0.0110               0               0            0
# 29              safe    3.5386               1               0            0
# 30        unsafe-pgd    0.0103               0               0            0
# 31        unsafe-pgd    0.0070               0               0            0
# 32        unsafe-pgd    0.0067               0               0            0
# 33              safe    3.6035               5               0            0
# 34        unsafe-pgd    0.0112               0               0            0
# 35           unknown  201.4140          252294               0            0
# 36              safe   14.9517             987               0            0
# 37              safe    4.4021              14               0            0
# 38        unsafe-pgd    0.0115               0               0            0
# 39              safe    2.9018               0               0            0
# 40   safe-incomplete    0.3994               0               0            0
# 41              safe    3.1771               0               0            0
# 42              safe    5.4314             206               0            0
# 43        unsafe-pgd    0.0099               0               0            0
# 44              safe    2.8868               0               0            0
# 45        unsafe-pgd    0.0098               0               0            0
# 46        unsafe-pgd    0.0075               0               0            0
# 47        unsafe-pgd    0.0071               0               0            0
# 48              safe    3.2897               0               0            0
# 49              safe    2.9486               0               0            0
# 50              safe    4.5744              72               0            0
# 51              safe   48.1186           47045               0            0
# 52              safe    3.3123               0               0            0
# 53              safe    3.4519               0               0            0
# 54   safe-incomplete    0.4640               0               0            0
# 55   safe-incomplete    0.4201               0               0            0
# 56   safe-incomplete    0.4248               0               0            0
# 57              safe   25.0856           11255               0            0
# 58              safe    5.5103              54               0            0
# 59              safe    3.6138               0               0            0
# 60        unsafe-pgd    0.0103               0               0            0
# 61   safe-incomplete    0.3581               0               0            0
# 62              safe    3.5575               0               0            0
# 63           unknown  216.0330          322700               0            0
# 64        unsafe-pgd    0.0144               0               0            0
# 65   safe-incomplete    0.5330               0               0            0
# 66              safe    3.5787               0               0            0
# 67              safe    3.2463               0               0            0
# 68           unknown  209.4127          365756               0            0
# 69              safe    6.8423             544               0            0
# 70        unsafe-pgd    0.0075               0               0            0
# 71        unsafe-pgd    0.0088               0               0            0
# 72   safe-incomplete    0.3516               0               0            0
# 73        unsafe-pgd    0.0123               0               0            0
# 74           unknown  211.4098          373170               0            0
# 75              safe    3.4434               0               0            0
# 76              safe    3.2038               4               0            0
# 77   safe-incomplete    0.3690               0               0            0
# 78   safe-incomplete    0.6913               0               0            0
# 79              safe    3.7889               0               0            0
# 80        unsafe-pgd    0.0107               0               0            0
# 81              safe    3.6307               3               0            0
# 82           unknown  219.6346          305391               0            0
# 83        unsafe-pgd    0.0201               0               0            0
# 84   safe-incomplete    0.3847               0               0            0
# 85              safe    3.4337               0               0            0
# 86           unknown  227.9619          433964               0            0
# 87           unknown  206.5323          264590               0            0
# 88              safe    7.5929             461               0            0
# 89              safe    3.9595               0               0            0
# 90              safe    9.0869            1067               0            0
# 91   safe-incomplete    0.5456               0               0            0
# 92        unsafe-pgd    0.0178               0               0            0
# 93        unsafe-pgd    0.0083               0               0            0
# 94              safe    3.1097               0               0            0
# 95              safe    4.4423              43               0            0
# 96              safe    3.0006               0               0            0
# 97   safe-incomplete    0.4294               0               0            0
# 98              safe    4.0854               0               0            0
# 99              safe    3.9091               0               0            0
# 100             safe    2.9513               0               0            0
# 101             safe    4.3100              17               0            0
# 102             safe    3.6720               4               0            0
# 103             safe    4.6047              38               0            0
# 104          unknown  213.3460          354273               0            0
# 105       unsafe-pgd    0.0106               0               0            0
# 106             safe    3.7839               0               0            0
# 107             safe    4.0077             115               0            0
# 108             safe    3.1080               0               0            0
# 109             safe    3.3135               0               0            0
# 110          unknown  217.5901          348066               0            0
# 111             safe    3.6111               0               0            0
# 112       unsafe-pgd    0.0113               0               0            0
# 113       unsafe-pgd    0.0070               0               0            0
# 114             safe    4.0360               1               0            0
# 115       unsafe-pgd    0.0102               0               0            0
# 116             safe    2.9984               0               0            0
# 117             safe    3.1251               0               0            0
# 118  safe-incomplete    0.4122               0               0            0
# 119             safe    3.3434               0               0            0
# 120  safe-incomplete    0.5477               0               0            0
# 121       unsafe-pgd    0.0138               0               0            0
# 122  safe-incomplete    0.5292               0               0            0
# 123             safe    3.3710               0               0            0
# 124  safe-incomplete    0.6599               0               0            0
# 125             safe    3.6037               0               0            0
# 126       unsafe-pgd    0.0162               0               0            0
# 127             safe    3.7221               0               0            0
# 128             safe   51.1907           44925               0            0
# 129             safe    3.6902               8               0            0
# 130       unsafe-pgd    0.0104               0               0            0
# 131             safe    3.3650               0               0            0
# 132       unsafe-pgd    0.0118               0               0            0
# 133             safe    3.8181               4               0            0
# 134  safe-incomplete    0.5165               0               0            0
# 135          unknown  201.5345          186199               0            0
# 136             safe    3.1039               0               0            0
# 137             safe    3.6951               0               0            0
# 138          unknown  217.4463          374895               0            0
# 139       unsafe-pgd    0.0140               0               0            0
# 140       unsafe-pgd    0.0078               0               0            0
# 141             safe    3.8224               8               0            0
# 142  safe-incomplete    0.5069               0               0            0
# 143             safe  198.3634          224313               0            0
# 144  safe-incomplete    0.4799               0               0            0
# 145             safe    5.5492              42               0            0
# 146             safe   20.4727            3065               0            0
# 147             safe    3.0222               0               0            0
# 148  safe-incomplete    0.5596               0               0            0
# 149             safe    6.1417              65               0            0
# 150             safe    4.5008               0               0            0
# 151  safe-incomplete    0.2104               0               0            0
# 152       unsafe-pgd    0.0060               0               0            0
# 153  safe-incomplete    0.4846               0               0            0
# 154       unsafe-pgd    0.0135               0               0            0
# 155             safe    4.5119              17               0            0
# 156             safe    4.2174               2               0            0
# 157       unsafe-pgd    0.0098               0               0            0
# 158       unsafe-pgd    0.0082               0               0            0
# 159             safe   19.5988            9231               0            0
# 160             safe    3.0536               0               0            0
# 161  safe-incomplete    0.5371               0               0            0
# 162             safe    3.5176               0               0            0
# 163             safe    4.0721               1               0            0
# 164             safe    3.5071               0               0            0
# 165  safe-incomplete    0.4741               0               0            0
# 166             safe  169.7966          208104               0            0
# 167  safe-incomplete    0.5706               0               0            0
# 168             safe    5.9412              69               0            0
# 169             safe    4.4083               0               0            0
# 170             safe    6.6048             419               0            0
# 171       unsafe-pgd    0.0168               0               0            0
# 172  safe-incomplete    0.6060               0               0            0
# 173  safe-incomplete    0.5348               0               0            0
# 174       unsafe-pgd    0.0134               0               0            0
# 175       unsafe-pgd    0.0074               0               0            0
# 176             safe    6.9382             811               0            0
# 177       unsafe-pgd    0.0122               0               0            0
# 178             safe    6.5715              45               0            0
# 179             safe    5.1167              11               0            0
# 180  safe-incomplete    0.4562               0               0            0
# 181       unsafe-pgd    0.0136               0               0            0
# 182  safe-incomplete    0.8585               0               0            0
# 183             safe    3.8341               0               0            0
# 184  safe-incomplete    0.5520               0               0            0
# 185       unsafe-pgd    0.0141               0               0            0
# 186             safe    3.4438               0               0            0
# 187       unsafe-pgd    0.0108               0               0            0
# 188  safe-incomplete    0.4655               0               0            0
# 189             safe    4.6176               0               0            0
# 190             safe    4.4394               0               0            0
# 191             safe    6.0661              17               0            0
# 192             safe    4.4865              42               0            0
# 193       unsafe-pgd    0.0102               0               0            0
# 194             safe    3.3073               0               0            0
# 195             safe    3.3280               0               0            0
# 196             safe    3.0116               0               0            0
# 197             safe    3.1996               0               0            0
# 198             safe    4.5750              12               0            0
# 199       unsafe-pgd    0.0103               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                  5         NaN
# 2                 21         NaN
# 3                  1         NaN
# 4                  2         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                 41         NaN
# 9                  3         NaN
# 10                23         NaN
# 11                14         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                 9         NaN
# 16                46   -1.628749
# 17                30         NaN
# 18                33         NaN
# 19                 8         NaN
# 20                 2         NaN
# 21                 1         NaN
# 22                 4         NaN
# 23                 5         NaN
# 24                 2         NaN
# 25                 1         NaN
# 26                10         NaN
# 27                38   -0.213988
# 28                 0         NaN
# 29                 3         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                 5         NaN
# 34                 0         NaN
# 35                95   -0.023736
# 36                21         NaN
# 37                 8         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                 0         NaN
# 41                 1         NaN
# 42                10         NaN
# 43                 0         NaN
# 44                 1         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 2         NaN
# 49                 1         NaN
# 50                 7         NaN
# 51                61         NaN
# 52                 2         NaN
# 53                 4         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                27         NaN
# 58                12         NaN
# 59                 4         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 4         NaN
# 63                47   -1.369897
# 64                 0         NaN
# 65                 0         NaN
# 66                 2         NaN
# 67                 2         NaN
# 68                32   -0.258953
# 69                12         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                25   -0.749033
# 75                 2         NaN
# 76                 2         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 2         NaN
# 80                 0         NaN
# 81                 2         NaN
# 82                68   -0.780801
# 83                 0         NaN
# 84                 0         NaN
# 85                 1         NaN
# 86                38   -0.434740
# 87                46   -0.195952
# 88                17         NaN
# 89                 7         NaN
# 90                18         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 1         NaN
# 95                 6         NaN
# 96                 1         NaN
# 97                 0         NaN
# 98                 5         NaN
# 99                 5         NaN
# 100                1         NaN
# 101                6         NaN
# 102                5         NaN
# 103                8         NaN
# 104               26   -0.709171
# 105                0         NaN
# 106                4         NaN
# 107                4         NaN
# 108                1         NaN
# 109                2         NaN
# 110               35   -0.500134
# 111                3         NaN
# 112                0         NaN
# 113                0         NaN
# 114                7         NaN
# 115                0         NaN
# 116                1         NaN
# 117                1         NaN
# 118                0         NaN
# 119                1         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                1         NaN
# 124                0         NaN
# 125                1         NaN
# 126                0         NaN
# 127                1         NaN
# 128               44         NaN
# 129                4         NaN
# 130                0         NaN
# 131                2         NaN
# 132                0         NaN
# 133                5         NaN
# 134                0         NaN
# 135              158   -0.917011
# 136                1         NaN
# 137                4         NaN
# 138               31   -0.802908
# 139                0         NaN
# 140                0         NaN
# 141                3         NaN
# 142                0         NaN
# 143              128         NaN
# 144                0         NaN
# 145               11         NaN
# 146               31         NaN
# 147                1         NaN
# 148                0         NaN
# 149               11         NaN
# 150                7         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155                6         NaN
# 156                7         NaN
# 157                0         NaN
# 158                0         NaN
# 159               31         NaN
# 160                1         NaN
# 161                0         NaN
# 162                1         NaN
# 163                2         NaN
# 164                2         NaN
# 165                0         NaN
# 166               90         NaN
# 167                0         NaN
# 168               11         NaN
# 169                7         NaN
# 170               10         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176               10         NaN
# 177                0         NaN
# 178               13         NaN
# 179               10         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                3         NaN
# 184                0         NaN
# 185                0         NaN
# 186                1         NaN
# 187                0         NaN
# 188                0         NaN
# 189                2         NaN
# 190                5         NaN
# 191               10         NaN
# 192                6         NaN
# 193                0         NaN
# 194                2         NaN
# 195                2         NaN
# 196                1         NaN
# 197                1         NaN
# 198                8         NaN
# 199                0         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe              107    9.515663     5469.28972            0.0         0.0
# safe-incomplete    34    0.516982        0.00000            0.0         0.0
# unknown            13  211.834200   328170.00000            0.0         0.0
# unsafe-pgd         46    0.011091        0.00000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                   9.485981
# safe-incomplete        0.000000
# unknown               52.692308
# unsafe-pgd             0.000000
# safe number 141.0
# safe time 7.345768085106384
# safe domain 4150.45390070922
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((141.0, 7.345768085106384, 5469.289719626168, 0.0),)

# %%
main('mnist_cnn_a_adv/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 1     safe   17.2712             200              54         1871
# 2     safe   42.2000            1102            3011         5376
# 3     safe    3.6464               0               1           20
# 4     safe    4.7020               0               1           35
# 8     safe   31.8653            1361            1798         4652
# 9     safe    5.6660               0               1          164
# 10    safe   31.1556            1337            1359         4450
# 11    safe   28.0074             556            1246         4212
# 15    safe   26.1206             750            1193         3680
# 16    safe  129.0884           97314            7736        54672
# 17    safe   17.2182            1315             100         2435
# 18    safe   29.0199            1577            1312         4914
# 19    safe   19.5634             400             641         3031
# 20    safe    6.7024             100              23          800
# 21    safe    4.3035              50               5          360
# 22    safe    9.3814             212              67         1229
# 23    safe    9.7981             159              24         1126
# 24    safe    6.0860             100              15          421
# 25    safe    4.9447             100              20          400
# 26    safe   23.5192             486             658         3397
# 27    safe   13.4549            1077              77         2097
# 29    safe    8.7227             237              68         1273
# 33    safe   10.3848             200              15         1188
# 35    safe   26.9388            1033            1367         6069
# 36    safe   31.3636            1199            2028         4904
# 37    safe   18.9259             523             687         2526
# 39    safe    3.6749               0               1           34
# 41    safe    4.0770               0               1            8
# 42    safe   20.8488             611             768         3502
# 44    safe    4.7784             100              59          400
# 48    safe    5.5007              50               2           97
# 49    safe    3.9248               0               1           15
# 50    safe   15.7596             285              69         2613
# 51    safe   21.2654            1515             838         3790
# 52    safe    6.8993             100              17         1053
# 53    safe    8.9755             150              27          954
# 57    safe   31.8564            3565            1264         5588
# 58    safe   35.0069             944            2414         4570
# 59    safe   11.9491             308              88         1210
# 62    safe    8.4843             100              17          774
# 63    safe  103.7974           57098            7836        43620
# 66    safe    7.0593             100              27          800
# 67    safe    6.0437              50              17          800
# 68    safe   26.9717            4350            1337         6471
# 69    safe   14.7111             643             222         2332
# 74    safe   51.8087           31194            2513        22908
# 75    safe    5.3733              50               4          431
# 76    safe    5.2154             100              17          634
# 79    safe    5.1792               0               1           34
# 81    safe    5.9895             114              11          648
# 82    safe   64.6117           45280            4090        32853
# 85    safe    5.0348             100              14          400
# 87    safe   32.7042            1568            1242         4628
# 88    safe   17.5519             530             142         2837
# 89    safe   22.0329             506             675         3314
# 90    safe   24.0037             669             854         3735
# 94    safe    3.9484               0               1          103
# 95    safe   11.7077             171              67         1718
# 96    safe    4.1810               0               1            9
# 98    safe   15.8036             322              37         2075
# 99    safe   11.7017             200              38         1527
# 100   safe    4.4425              50               6          362
# 101   safe   14.8464             377              54         2441
# 102   safe   11.7950             221              39         1508
# 103   safe   21.9001             609            1229         3214
# 104   safe   29.4580           19328             866        10964
# 106   safe    9.5962             150              10          542
# 107   safe    8.4828             269              58         1029
# 108   safe    3.6918               0               1           23
# 109   safe    6.2285              50               6          613
# 111   safe    9.2926             100              39         1445
# 114   safe   16.4362             500              74         2221
# 116   safe    4.3958              50               5          384
# 117   safe    3.7855               0               1           19
# 119   safe    4.6268              50               8          400
# 123   safe    5.0785              50               6          400
# 125   safe    5.3088              50               9          400
# 127   safe    4.0795               0               1           57
# 128   safe   25.6428            3258             646         5212
# 129   safe    9.5695             110              33         1195
# 131   safe    5.4271              50               4          273
# 133   safe   11.0357             201              58         1058
# 136   safe    5.2011              50               5          322
# 137   safe   10.9411             200              33         1089
# 138   safe   56.6015           24837            3614        25071
# 141   safe    6.3332             106              67          771
# 143   safe   53.0778            4068            4921         9096
# 145   safe   27.9416             750             673         4119
# 146   safe   28.9855             715            1162         4095
# 147   safe    4.5841              50               6          400
# 149   safe   18.5367             352             207         2043
# 150   safe   18.6767             354              54         2653
# 155   safe   12.6742             211              59         1998
# 156   safe   17.8379             416              69         2260
# 159   safe   25.7937            2274             852         4562
# 160   safe    4.9708              50               4          222
# 162   safe    4.9507              50              16          400
# 163   safe    6.4283             150               9          384
# 164   safe    7.7399             200              28          800
# 166   safe   66.3777            7138            5131        12219
# 168   safe   24.3706             515             844         4433
# 169   safe   17.9883             300              63         2766
# 170   safe   12.1375             405              79         1200
# 176   safe   12.2093             581              60         1400
# 178   safe   24.3158             649             715         3441
# 179   safe   23.4301             610             739         3075
# 183   safe    8.4862             127              14          707
# 186   safe    4.3182               0               1           18
# 189   safe    8.4805             200              30          800
# 190   safe   12.7430             200              51         1833
# 191   safe   27.5863             556            1702         3438
# 192   safe   10.8234             172             109         1368
# 194   safe    5.3031              50               4          285
# 195   safe    5.3346              50               1          321
# 196   safe    3.7167               0               1           70
# 197   safe    4.5942              50               5          229
# 198   safe   16.8604             303             133         2295
#
#      BaB Round Count  BaB_lb_rhs
# 1                 13         NaN
# 2                 45         NaN
# 3                  1         NaN
# 4                  2         NaN
# 8                 37         NaN
# 9                  3         NaN
# 10                37         NaN
# 11                30         NaN
# 15                26         NaN
# 16                67         NaN
# 17                22         NaN
# 18                36         NaN
# 19                21         NaN
# 20                 5         NaN
# 21                 2         NaN
# 22                 9         NaN
# 23                 9         NaN
# 24                 4         NaN
# 25                 3         NaN
# 26                25         NaN
# 27                19         NaN
# 29                 9         NaN
# 33                10         NaN
# 35                38         NaN
# 36                40         NaN
# 37                22         NaN
# 39                 1         NaN
# 41                 1         NaN
# 42                25         NaN
# 44                 3         NaN
# 48                 3         NaN
# 49                 1         NaN
# 50                17         NaN
# 51                29         NaN
# 52                 6         NaN
# 53                 7         NaN
# 57                37         NaN
# 58                36         NaN
# 59                11         NaN
# 62                 7         NaN
# 63                78         NaN
# 66                 5         NaN
# 67                 4         NaN
# 68                39         NaN
# 69                17         NaN
# 74                46         NaN
# 75                 3         NaN
# 76                 4         NaN
# 79                 2         NaN
# 81                 5         NaN
# 82                52         NaN
# 85                 3         NaN
# 87                37         NaN
# 88                22         NaN
# 89                22         NaN
# 90                26         NaN
# 94                 1         NaN
# 95                12         NaN
# 96                 1         NaN
# 98                17         NaN
# 99                11         NaN
# 100                2         NaN
# 101               17         NaN
# 102               12         NaN
# 103               24         NaN
# 104               25         NaN
# 106                7         NaN
# 107                9         NaN
# 108                1         NaN
# 109                4         NaN
# 111                8         NaN
# 114               17         NaN
# 116                2         NaN
# 117                1         NaN
# 119                2         NaN
# 123                2         NaN
# 125                2         NaN
# 127                1         NaN
# 128               31         NaN
# 129                9         NaN
# 131                3         NaN
# 133               10         NaN
# 136                2         NaN
# 137                9         NaN
# 138               50         NaN
# 141                5         NaN
# 143               70         NaN
# 145               28         NaN
# 146               34         NaN
# 147                2         NaN
# 149               19         NaN
# 150               20         NaN
# 155               12         NaN
# 156               17         NaN
# 159               31         NaN
# 160                2         NaN
# 162                2         NaN
# 163                5         NaN
# 164                6         NaN
# 166               85         NaN
# 168               27         NaN
# 169               18         NaN
# 170               13         NaN
# 176               12         NaN
# 178               28         NaN
# 179               25         NaN
# 183                7         NaN
# 186                1         NaN
# 189                6         NaN
# 190               12         NaN
# 191               25         NaN
# 192               12         NaN
# 194                3         NaN
# 195                3         NaN
# 196                1         NaN
# 197                2         NaN
# 198               16         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 110  unknown  252.6578          242613            5007        89275
# 135  unknown  203.9617          110719           12747        63825
#
#      BaB Round Count  BaB_lb_rhs
# 110               56   -0.261197
# 135              159   -1.538656
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe-incomplete    2.9650               0               0            0
# 1               safe   17.2712             200              54         1871
# 2               safe   42.2000            1102            3011         5376
# 3               safe    3.6464               0               1           20
# 4               safe    4.7020               0               1           35
# 5         unsafe-pgd    0.0085               0               0            0
# 6    safe-incomplete    0.3845               0               0            0
# 7         unsafe-pgd    0.0111               0               0            0
# 8               safe   31.8653            1361            1798         4652
# 9               safe    5.6660               0               1          164
# 10              safe   31.1556            1337            1359         4450
# 11              safe   28.0074             556            1246         4212
# 12        unsafe-pgd    0.0085               0               0            0
# 13        unsafe-pgd    0.0075               0               0            0
# 14   safe-incomplete    0.4343               0               0            0
# 15              safe   26.1206             750            1193         3680
# 16              safe  129.0884           97314            7736        54672
# 17              safe   17.2182            1315             100         2435
# 18              safe   29.0199            1577            1312         4914
# 19              safe   19.5634             400             641         3031
# 20              safe    6.7024             100              23          800
# 21              safe    4.3035              50               5          360
# 22              safe    9.3814             212              67         1229
# 23              safe    9.7981             159              24         1126
# 24              safe    6.0860             100              15          421
# 25              safe    4.9447             100              20          400
# 26              safe   23.5192             486             658         3397
# 27              safe   13.4549            1077              77         2097
# 28        unsafe-pgd    0.0088               0               0            0
# 29              safe    8.7227             237              68         1273
# 30        unsafe-pgd    0.0092               0               0            0
# 31        unsafe-pgd    0.0070               0               0            0
# 32        unsafe-pgd    0.0068               0               0            0
# 33              safe   10.3848             200              15         1188
# 34        unsafe-pgd    0.0084               0               0            0
# 35              safe   26.9388            1033            1367         6069
# 36              safe   31.3636            1199            2028         4904
# 37              safe   18.9259             523             687         2526
# 38        unsafe-pgd    0.0096               0               0            0
# 39              safe    3.6749               0               1           34
# 40   safe-incomplete    0.3507               0               0            0
# 41              safe    4.0770               0               1            8
# 42              safe   20.8488             611             768         3502
# 43        unsafe-pgd    0.0099               0               0            0
# 44              safe    4.7784             100              59          400
# 45        unsafe-pgd    0.0062               0               0            0
# 46        unsafe-pgd    0.0063               0               0            0
# 47        unsafe-pgd    0.0061               0               0            0
# 48              safe    5.5007              50               2           97
# 49              safe    3.9248               0               1           15
# 50              safe   15.7596             285              69         2613
# 51              safe   21.2654            1515             838         3790
# 52              safe    6.8993             100              17         1053
# 53              safe    8.9755             150              27          954
# 54   safe-incomplete    0.4124               0               0            0
# 55   safe-incomplete    0.3535               0               0            0
# 56   safe-incomplete    0.4062               0               0            0
# 57              safe   31.8564            3565            1264         5588
# 58              safe   35.0069             944            2414         4570
# 59              safe   11.9491             308              88         1210
# 60        unsafe-pgd    0.0092               0               0            0
# 61   safe-incomplete    0.3221               0               0            0
# 62              safe    8.4843             100              17          774
# 63              safe  103.7974           57098            7836        43620
# 64        unsafe-pgd    0.0087               0               0            0
# 65   safe-incomplete    0.4497               0               0            0
# 66              safe    7.0593             100              27          800
# 67              safe    6.0437              50              17          800
# 68              safe   26.9717            4350            1337         6471
# 69              safe   14.7111             643             222         2332
# 70        unsafe-pgd    0.0070               0               0            0
# 71        unsafe-pgd    0.0084               0               0            0
# 72   safe-incomplete    0.3181               0               0            0
# 73        unsafe-pgd    0.0154               0               0            0
# 74              safe   51.8087           31194            2513        22908
# 75              safe    5.3733              50               4          431
# 76              safe    5.2154             100              17          634
# 77   safe-incomplete    0.2759               0               0            0
# 78   safe-incomplete    0.6001               0               0            0
# 79              safe    5.1792               0               1           34
# 80        unsafe-pgd    0.0104               0               0            0
# 81              safe    5.9895             114              11          648
# 82              safe   64.6117           45280            4090        32853
# 83        unsafe-pgd    0.0087               0               0            0
# 84   safe-incomplete    0.3298               0               0            0
# 85              safe    5.0348             100              14          400
# 86        unsafe-pgd    0.0903               0               0            0
# 87              safe   32.7042            1568            1242         4628
# 88              safe   17.5519             530             142         2837
# 89              safe   22.0329             506             675         3314
# 90              safe   24.0037             669             854         3735
# 91   safe-incomplete    0.4956               0               0            0
# 92        unsafe-pgd    0.0182               0               0            0
# 93        unsafe-pgd    0.0079               0               0            0
# 94              safe    3.9484               0               1          103
# 95              safe   11.7077             171              67         1718
# 96              safe    4.1810               0               1            9
# 97   safe-incomplete    0.3626               0               0            0
# 98              safe   15.8036             322              37         2075
# 99              safe   11.7017             200              38         1527
# 100             safe    4.4425              50               6          362
# 101             safe   14.8464             377              54         2441
# 102             safe   11.7950             221              39         1508
# 103             safe   21.9001             609            1229         3214
# 104             safe   29.4580           19328             866        10964
# 105       unsafe-pgd    0.0088               0               0            0
# 106             safe    9.5962             150              10          542
# 107             safe    8.4828             269              58         1029
# 108             safe    3.6918               0               1           23
# 109             safe    6.2285              50               6          613
# 110          unknown  252.6578          242613            5007        89275
# 111             safe    9.2926             100              39         1445
# 112       unsafe-pgd    0.0088               0               0            0
# 113       unsafe-pgd    0.0067               0               0            0
# 114             safe   16.4362             500              74         2221
# 115       unsafe-pgd    0.0066               0               0            0
# 116             safe    4.3958              50               5          384
# 117             safe    3.7855               0               1           19
# 118  safe-incomplete    0.2966               0               0            0
# 119             safe    4.6268              50               8          400
# 120  safe-incomplete    0.4331               0               0            0
# 121       unsafe-pgd    0.0140               0               0            0
# 122  safe-incomplete    0.3942               0               0            0
# 123             safe    5.0785              50               6          400
# 124  safe-incomplete    0.5828               0               0            0
# 125             safe    5.3088              50               9          400
# 126       unsafe-pgd    0.0136               0               0            0
# 127             safe    4.0795               0               1           57
# 128             safe   25.6428            3258             646         5212
# 129             safe    9.5695             110              33         1195
# 130       unsafe-pgd    0.0083               0               0            0
# 131             safe    5.4271              50               4          273
# 132       unsafe-pgd    0.0085               0               0            0
# 133             safe   11.0357             201              58         1058
# 134  safe-incomplete    0.4433               0               0            0
# 135          unknown  203.9617          110719           12747        63825
# 136             safe    5.2011              50               5          322
# 137             safe   10.9411             200              33         1089
# 138             safe   56.6015           24837            3614        25071
# 139       unsafe-pgd    0.0090               0               0            0
# 140       unsafe-pgd    0.0071               0               0            0
# 141             safe    6.3332             106              67          771
# 142  safe-incomplete    0.3671               0               0            0
# 143             safe   53.0778            4068            4921         9096
# 144  safe-incomplete    0.3514               0               0            0
# 145             safe   27.9416             750             673         4119
# 146             safe   28.9855             715            1162         4095
# 147             safe    4.5841              50               6          400
# 148  safe-incomplete    0.4165               0               0            0
# 149             safe   18.5367             352             207         2043
# 150             safe   18.6767             354              54         2653
# 151  safe-incomplete    0.3376               0               0            0
# 152       unsafe-pgd    0.0061               0               0            0
# 153  safe-incomplete    0.4170               0               0            0
# 154       unsafe-pgd    0.0130               0               0            0
# 155             safe   12.6742             211              59         1998
# 156             safe   17.8379             416              69         2260
# 157       unsafe-pgd    0.0087               0               0            0
# 158       unsafe-pgd    0.0079               0               0            0
# 159             safe   25.7937            2274             852         4562
# 160             safe    4.9708              50               4          222
# 161  safe-incomplete    0.3997               0               0            0
# 162             safe    4.9507              50              16          400
# 163             safe    6.4283             150               9          384
# 164             safe    7.7399             200              28          800
# 165  safe-incomplete    0.3525               0               0            0
# 166             safe   66.3777            7138            5131        12219
# 167  safe-incomplete    0.4057               0               0            0
# 168             safe   24.3706             515             844         4433
# 169             safe   17.9883             300              63         2766
# 170             safe   12.1375             405              79         1200
# 171       unsafe-pgd    0.0098               0               0            0
# 172  safe-incomplete    0.4388               0               0            0
# 173  safe-incomplete    0.4170               0               0            0
# 174       unsafe-pgd    0.0208               0               0            0
# 175       unsafe-pgd    0.0068               0               0            0
# 176             safe   12.2093             581              60         1400
# 177       unsafe-pgd    0.0089               0               0            0
# 178             safe   24.3158             649             715         3441
# 179             safe   23.4301             610             739         3075
# 180  safe-incomplete    0.3214               0               0            0
# 181       unsafe-pgd    0.0120               0               0            0
# 182  safe-incomplete    0.4413               0               0            0
# 183             safe    8.4862             127              14          707
# 184  safe-incomplete    0.4116               0               0            0
# 185       unsafe-pgd    0.0122               0               0            0
# 186             safe    4.3182               0               1           18
# 187       unsafe-pgd    0.0088               0               0            0
# 188  safe-incomplete    0.3030               0               0            0
# 189             safe    8.4805             200              30          800
# 190             safe   12.7430             200              51         1833
# 191             safe   27.5863             556            1702         3438
# 192             safe   10.8234             172             109         1368
# 193       unsafe-pgd    0.0080               0               0            0
# 194             safe    5.3031              50               4          285
# 195             safe    5.3346              50               1          321
# 196             safe    3.7167               0               1           70
# 197             safe    4.5942              50               5          229
# 198             safe   16.8604             303             133         2295
# 199       unsafe-pgd    0.0084               0               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  0         NaN
# 1                 13         NaN
# 2                 45         NaN
# 3                  1         NaN
# 4                  2         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                  0         NaN
# 8                 37         NaN
# 9                  3         NaN
# 10                37         NaN
# 11                30         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                 0         NaN
# 15                26         NaN
# 16                67         NaN
# 17                22         NaN
# 18                36         NaN
# 19                21         NaN
# 20                 5         NaN
# 21                 2         NaN
# 22                 9         NaN
# 23                 9         NaN
# 24                 4         NaN
# 25                 3         NaN
# 26                25         NaN
# 27                19         NaN
# 28                 0         NaN
# 29                 9         NaN
# 30                 0         NaN
# 31                 0         NaN
# 32                 0         NaN
# 33                10         NaN
# 34                 0         NaN
# 35                38         NaN
# 36                40         NaN
# 37                22         NaN
# 38                 0         NaN
# 39                 1         NaN
# 40                 0         NaN
# 41                 1         NaN
# 42                25         NaN
# 43                 0         NaN
# 44                 3         NaN
# 45                 0         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                 3         NaN
# 49                 1         NaN
# 50                17         NaN
# 51                29         NaN
# 52                 6         NaN
# 53                 7         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                 0         NaN
# 57                37         NaN
# 58                36         NaN
# 59                11         NaN
# 60                 0         NaN
# 61                 0         NaN
# 62                 7         NaN
# 63                78         NaN
# 64                 0         NaN
# 65                 0         NaN
# 66                 5         NaN
# 67                 4         NaN
# 68                39         NaN
# 69                17         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                 0         NaN
# 74                46         NaN
# 75                 3         NaN
# 76                 4         NaN
# 77                 0         NaN
# 78                 0         NaN
# 79                 2         NaN
# 80                 0         NaN
# 81                 5         NaN
# 82                52         NaN
# 83                 0         NaN
# 84                 0         NaN
# 85                 3         NaN
# 86                 0         NaN
# 87                37         NaN
# 88                22         NaN
# 89                22         NaN
# 90                26         NaN
# 91                 0         NaN
# 92                 0         NaN
# 93                 0         NaN
# 94                 1         NaN
# 95                12         NaN
# 96                 1         NaN
# 97                 0         NaN
# 98                17         NaN
# 99                11         NaN
# 100                2         NaN
# 101               17         NaN
# 102               12         NaN
# 103               24         NaN
# 104               25         NaN
# 105                0         NaN
# 106                7         NaN
# 107                9         NaN
# 108                1         NaN
# 109                4         NaN
# 110               56   -0.261197
# 111                8         NaN
# 112                0         NaN
# 113                0         NaN
# 114               17         NaN
# 115                0         NaN
# 116                2         NaN
# 117                1         NaN
# 118                0         NaN
# 119                2         NaN
# 120                0         NaN
# 121                0         NaN
# 122                0         NaN
# 123                2         NaN
# 124                0         NaN
# 125                2         NaN
# 126                0         NaN
# 127                1         NaN
# 128               31         NaN
# 129                9         NaN
# 130                0         NaN
# 131                3         NaN
# 132                0         NaN
# 133               10         NaN
# 134                0         NaN
# 135              159   -1.538656
# 136                2         NaN
# 137                9         NaN
# 138               50         NaN
# 139                0         NaN
# 140                0         NaN
# 141                5         NaN
# 142                0         NaN
# 143               70         NaN
# 144                0         NaN
# 145               28         NaN
# 146               34         NaN
# 147                2         NaN
# 148                0         NaN
# 149               19         NaN
# 150               20         NaN
# 151                0         NaN
# 152                0         NaN
# 153                0         NaN
# 154                0         NaN
# 155               12         NaN
# 156               17         NaN
# 157                0         NaN
# 158                0         NaN
# 159               31         NaN
# 160                2         NaN
# 161                0         NaN
# 162                2         NaN
# 163                5         NaN
# 164                6         NaN
# 165                0         NaN
# 166               85         NaN
# 167                0         NaN
# 168               27         NaN
# 169               18         NaN
# 170               13         NaN
# 171                0         NaN
# 172                0         NaN
# 173                0         NaN
# 174                0         NaN
# 175                0         NaN
# 176               12         NaN
# 177                0         NaN
# 178               28         NaN
# 179               25         NaN
# 180                0         NaN
# 181                0         NaN
# 182                0         NaN
# 183                7         NaN
# 184                0         NaN
# 185                0         NaN
# 186                1         NaN
# 187                0         NaN
# 188                0         NaN
# 189                6         NaN
# 190               12         NaN
# 191               25         NaN
# 192               12         NaN
# 193                0         NaN
# 194                3         NaN
# 195                3         NaN
# 196                1         NaN
# 197                2         NaN
# 198               16         NaN
# 199                0         NaN
# #Cuts 90587
#                  Time             Domain Visited Cut Generation   Unsat Nodes  \
#                 count        mean           mean           mean          mean
# Status
# safe              117   17.127805    2857.888889     622.504274   3467.777778
# safe-incomplete    34    0.470326       0.000000       0.000000      0.000000
# unknown             2  228.309750  176666.000000    8877.000000  76550.000000
# unsafe-pgd         47    0.011083       0.000000       0.000000      0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  16.452991
# safe-incomplete        0.000000
# unknown              107.500000
# unsafe-pgd             0.000000
# safe number 151.0
# safe time 13.377114569536424
# safe domain 2214.390728476821
# safe cut 482.3377483443709
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((151.0, 13.377114569536424, 2857.8888888888887, 622.5042735042736),)

# %% [markdown]
# # Oval22

# %%
plot_multiple_dfs(
    [
log_read('oval22/beta.log'),
log_read('oval22/biccos_only_cs.log'),
log_read('oval22/biccos_all.log'),
log_read('oval22/gcp.log'),
log_read('oval22/biccos_all_selective_mts_plus_gcp.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],
     time_limit=720, dataset='oval22'
)
# Out:
# /tmp/ipykernel_20992/406527908.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('oval22/beta.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe    9.2995             134               0            0
# 1    safe    6.7363             310               0            0
# 2    safe    2.6957               2               0            0
# 4    safe    2.4432               0               0            0
# 5    safe    3.2916              14               0            0
# 6    safe    5.5623             405               0            0
# 7    safe    2.3401               0               0            0
# 8    safe    8.2712            1932               0            0
# 9    safe   17.4208            9391               0            0
# 12   safe   11.3070            4140               0            0
# 17   safe    3.5968              20               0            0
# 21   safe    5.3676              47               0            0
# 22   safe  360.6074          600262               0            0
# 23   safe    4.8765               2               0            0
# 24   safe    9.2947             277               0            0
# 25   safe    3.7183               0               0            0
# 29   safe    7.5433             154               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 5         NaN
# 1                12         NaN
# 2                 2         NaN
# 4                 1         NaN
# 5                 3         NaN
# 6                11         NaN
# 7                 1         NaN
# 8                17         NaN
# 9                30         NaN
# 12               19         NaN
# 17                4         NaN
# 21                3         NaN
# 22              163         NaN
# 23                3         NaN
# 24               13         NaN
# 25                1         NaN
# 29                8         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 3   unknown  721.5988         1478121               0            0
# 10  unknown  721.0141         1320719               0            0
# 11  unknown  722.9274         1328328               0            0
# 13  unknown  721.9809         1303331               0            0
# 15  unknown  721.4854         1362136               0            0
# 16  unknown  721.4959         1433517               0            0
# 19  unknown  721.0946         1419216               0            0
# 20  unknown  721.4273         1092144               0            0
# 26  unknown  721.1992         1232830               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 3               363   -1.119092
# 10              312   -0.959396
# 11              310   -1.735777
# 13              341   -1.880240
# 15              328   -0.599183
# 16              356   -0.652027
# 19              351   -0.034450
# 20              275   -0.631092
# 26              310   -0.094585
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe    9.2995             134               0            0
# 1              safe    6.7363             310               0            0
# 2              safe    2.6957               2               0            0
# 3           unknown  721.5988         1478121               0            0
# 4              safe    2.4432               0               0            0
# 5              safe    3.2916              14               0            0
# 6              safe    5.5623             405               0            0
# 7              safe    2.3401               0               0            0
# 8              safe    8.2712            1932               0            0
# 9              safe   17.4208            9391               0            0
# 10          unknown  721.0141         1320719               0            0
# 11          unknown  722.9274         1328328               0            0
# 12             safe   11.3070            4140               0            0
# 13          unknown  721.9809         1303331               0            0
# 14       unsafe-pgd    0.2729               0               0            0
# 15          unknown  721.4854         1362136               0            0
# 16          unknown  721.4959         1433517               0            0
# 17             safe    3.5968              20               0            0
# 18  safe-incomplete    0.1756               0               0            0
# 19          unknown  721.0946         1419216               0            0
# 20          unknown  721.4273         1092144               0            0
# 21             safe    5.3676              47               0            0
# 22             safe  360.6074          600262               0            0
# 23             safe    4.8765               2               0            0
# 24             safe    9.2947             277               0            0
# 25             safe    3.7183               0               0            0
# 26          unknown  721.1992         1232830               0            0
# 27  safe-incomplete    0.3974               0               0            0
# 28  safe-incomplete    0.3111               0               0            0
# 29             safe    7.5433             154               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 5         NaN
# 1                12         NaN
# 2                 2         NaN
# 3               363   -1.119092
# 4                 1         NaN
# 5                 3         NaN
# 6                11         NaN
# 7                 1         NaN
# 8                17         NaN
# 9                30         NaN
# 10              312   -0.959396
# 11              310   -1.735777
# 12               19         NaN
# 13              341   -1.880240
# 14                0         NaN
# 15              328   -0.599183
# 16              356   -0.652027
# 17                4         NaN
# 18                0         NaN
# 19              351   -0.034450
# 20              275   -0.631092
# 21                3         NaN
# 22              163         NaN
# 23                3         NaN
# 24               13         NaN
# 25                1         NaN
# 26              310   -0.094585
# 27                0         NaN
# 28                0         NaN
# 29                8         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               17   27.316018   3.629941e+04            0.0         0.0
# safe-incomplete     3    0.294700   0.000000e+00            0.0         0.0
# unknown             9  721.580400   1.330038e+06            0.0         0.0
# unsafe-pgd          1    0.272900   0.000000e+00            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  17.411765
# safe-incomplete        0.000000
# unknown              327.333333
# unsafe-pgd             0.000000
# safe number 20.0
# safe time 23.262819999999998
# safe domain 30854.5
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((20.0, 23.262819999999998, 36299.41176470588, 0.0),)

# %%
main('oval22/biccos_only_cs.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe   16.1922             268              75         1214
# 1    safe   10.4966             415             159         2155
# 2    safe    4.2127             150              46          656
# 4    safe    3.6151             100              11          575
# 5    safe    6.7505             198              41         1266
# 6    safe    5.9388             208             110         1230
# 7    safe    4.2870             136              68          616
# 8    safe    6.9577             531             158         1724
# 9    safe    9.9973            1921             130         2415
# 12   safe   11.5225            1415             258         1928
# 17   safe    6.6732             167             189          897
# 19   safe   14.1739            9208             316         8676
# 21   safe   11.9962             211             104         1262
# 22   safe   75.7813           54684             663        26483
# 23   safe   10.8180             222              82         1312
# 24   safe    9.6049             148             105         1704
# 25   safe    4.7412              50               7          656
# 26   safe  185.0620          130921             178        86508
# 29   safe   12.9435             244             111         1714
#
#     BaB Round Count  BaB_lb_rhs
# 0                10         NaN
# 1                15         NaN
# 2                 5         NaN
# 4                 4         NaN
# 5                 8         NaN
# 6                 9         NaN
# 7                 5         NaN
# 8                12         NaN
# 9                18         NaN
# 12               18         NaN
# 17                8         NaN
# 19               14         NaN
# 21                8         NaN
# 22               27         NaN
# 23               10         NaN
# 24               12         NaN
# 25                3         NaN
# 26               71         NaN
# 29               12         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 3   unknown  725.8336         1554318             911       217010
# 10  unknown  725.6743         1343696             753       140994
# 11  unknown  726.1063         1357199             866       140636
# 13  unknown  722.6974         1030958            3483       266691
# 15  unknown  729.3368         1330973             657       190529
# 16  unknown  724.3622         1334590            1671       238542
# 20  unknown  725.2212         1005793            1181       133501
#
#     BaB Round Count  BaB_lb_rhs
# 3               255   -0.864882
# 10              212   -0.862112
# 11              214   -1.527740
# 13              280   -0.541552
# 15              217   -0.504991
# 16              227   -0.462643
# 20              175   -0.497750
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe   16.1922             268              75         1214
# 1              safe   10.4966             415             159         2155
# 2              safe    4.2127             150              46          656
# 3           unknown  725.8336         1554318             911       217010
# 4              safe    3.6151             100              11          575
# 5              safe    6.7505             198              41         1266
# 6              safe    5.9388             208             110         1230
# 7              safe    4.2870             136              68          616
# 8              safe    6.9577             531             158         1724
# 9              safe    9.9973            1921             130         2415
# 10          unknown  725.6743         1343696             753       140994
# 11          unknown  726.1063         1357199             866       140636
# 12             safe   11.5225            1415             258         1928
# 13          unknown  722.6974         1030958            3483       266691
# 14       unsafe-pgd    0.2651               0               0            0
# 15          unknown  729.3368         1330973             657       190529
# 16          unknown  724.3622         1334590            1671       238542
# 17             safe    6.6732             167             189          897
# 18  safe-incomplete    0.1152               0               0            0
# 19             safe   14.1739            9208             316         8676
# 20          unknown  725.2212         1005793            1181       133501
# 21             safe   11.9962             211             104         1262
# 22             safe   75.7813           54684             663        26483
# 23             safe   10.8180             222              82         1312
# 24             safe    9.6049             148             105         1704
# 25             safe    4.7412              50               7          656
# 26             safe  185.0620          130921             178        86508
# 27  safe-incomplete    0.3997               0               0            0
# 28  safe-incomplete    0.3455               0               0            0
# 29             safe   12.9435             244             111         1714
#
#     BaB Round Count  BaB_lb_rhs
# 0                10         NaN
# 1                15         NaN
# 2                 5         NaN
# 3               255   -0.864882
# 4                 4         NaN
# 5                 8         NaN
# 6                 9         NaN
# 7                 5         NaN
# 8                12         NaN
# 9                18         NaN
# 10              212   -0.862112
# 11              214   -1.527740
# 12               18         NaN
# 13              280   -0.541552
# 14                0         NaN
# 15              217   -0.504991
# 16              227   -0.462643
# 17                8         NaN
# 18                0         NaN
# 19               14         NaN
# 20              175   -0.497750
# 21                8         NaN
# 22               27         NaN
# 23               10         NaN
# 24               12         NaN
# 25                3         NaN
# 26               71         NaN
# 27                0         NaN
# 28                0         NaN
# 29               12         NaN
# #Cuts 12333
#                  Time             Domain Visited Cut Generation  \
#                 count        mean           mean           mean
# Status
# safe               19   21.671821   1.058932e+04     147.947368
# safe-incomplete     3    0.286800   0.000000e+00       0.000000
# unknown             7  725.604543   1.279647e+06    1360.285714
# unsafe-pgd          1    0.265100   0.000000e+00       0.000000
#
#                    Unsat Nodes BaB Round Count
#                           mean            mean
# Status
# safe               7525.842105       14.157895
# safe-incomplete       0.000000        0.000000
# unknown          189700.428571      225.714286
# unsafe-pgd            0.000000        0.000000
# safe number 22.0
# safe time 18.755681818181817
# safe domain 9145.318181818184
# safe cut 127.77272727272727
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((22.0, 18.755681818181817, 10589.315789473685, 147.94736842105263),)

# %%
main('oval22/biccos_all.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe   15.9124             257              43         1260
# 1    safe    8.5892             342              76         1612
# 2    safe    3.9201             150              48          400
# 4    safe    3.5082             100              11          319
# 5    safe    6.7007             189              64         1023
# 6    safe   11.4739             387              60         1763
# 7    safe    4.1074             136              29          360
# 8    safe   12.4658             833              99         1611
# 9    safe   15.2152            1455             245         3012
# 12   safe   11.5364            1237             225         1961
# 17   safe    7.7919             171             227         1209
# 21   safe   11.1752             213             138         1301
# 22   safe   43.8259           28233             602        11481
# 23   safe   11.7245             222              81         1056
# 24   safe   23.6275             496             204         3415
# 25   safe    5.2814              50               7          400
# 26   safe  151.7259           98087             161        55769
# 29   safe   12.5085             242             107         1694
#
#     BaB Round Count  BaB_lb_rhs
# 0                10         NaN
# 1                12         NaN
# 2                 4         NaN
# 4                 3         NaN
# 5                 8         NaN
# 6                15         NaN
# 7                 4         NaN
# 8                18         NaN
# 9                24         NaN
# 12               17         NaN
# 17                9         NaN
# 21                8         NaN
# 22               20         NaN
# 23                9         NaN
# 24               23         NaN
# 25                2         NaN
# 26               67         NaN
# 29               11         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 3   unknown  724.0957         1463993             884       202806
# 10  unknown  734.6725         1297748             655       145601
# 11  unknown  724.1105         1284440             867       135126
# 13  unknown  722.1957          956715            3513       253388
# 15  unknown  724.2722         1258000             674       192987
# 16  unknown  726.1309         1297604            1781       225214
# 19  unknown  721.8458          941516            1166       331589
# 20  unknown  725.4808          973102            1160       128542
#
#     BaB Round Count  BaB_lb_rhs
# 3               246   -0.864899
# 10              211   -0.862109
# 11              209   -1.527754
# 13              296   -0.541547
# 15              211   -0.504991
# 16              231   -0.462650
# 19              203   -0.021779
# 20              177   -0.497739
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe   15.9124             257              43         1260
# 1              safe    8.5892             342              76         1612
# 2              safe    3.9201             150              48          400
# 3           unknown  724.0957         1463993             884       202806
# 4              safe    3.5082             100              11          319
# 5              safe    6.7007             189              64         1023
# 6              safe   11.4739             387              60         1763
# 7              safe    4.1074             136              29          360
# 8              safe   12.4658             833              99         1611
# 9              safe   15.2152            1455             245         3012
# 10          unknown  734.6725         1297748             655       145601
# 11          unknown  724.1105         1284440             867       135126
# 12             safe   11.5364            1237             225         1961
# 13          unknown  722.1957          956715            3513       253388
# 14       unsafe-pgd    0.2756               0               0            0
# 15          unknown  724.2722         1258000             674       192987
# 16          unknown  726.1309         1297604            1781       225214
# 17             safe    7.7919             171             227         1209
# 18  safe-incomplete    0.1223               0               0            0
# 19          unknown  721.8458          941516            1166       331589
# 20          unknown  725.4808          973102            1160       128542
# 21             safe   11.1752             213             138         1301
# 22             safe   43.8259           28233             602        11481
# 23             safe   11.7245             222              81         1056
# 24             safe   23.6275             496             204         3415
# 25             safe    5.2814              50               7          400
# 26             safe  151.7259           98087             161        55769
# 27  safe-incomplete    0.3663               0               0            0
# 28  safe-incomplete    0.3180               0               0            0
# 29             safe   12.5085             242             107         1694
#
#     BaB Round Count  BaB_lb_rhs
# 0                10         NaN
# 1                12         NaN
# 2                 4         NaN
# 3               246   -0.864899
# 4                 3         NaN
# 5                 8         NaN
# 6                15         NaN
# 7                 4         NaN
# 8                18         NaN
# 9                24         NaN
# 10              211   -0.862109
# 11              209   -1.527754
# 12               17         NaN
# 13              296   -0.541547
# 14                0         NaN
# 15              211   -0.504991
# 16              231   -0.462650
# 17                9         NaN
# 18                0         NaN
# 19              203   -0.021779
# 20              177   -0.497739
# 21                8         NaN
# 22               20         NaN
# 23                9         NaN
# 24               23         NaN
# 25                2         NaN
# 26               67         NaN
# 27                0         NaN
# 28                0         NaN
# 29               11         NaN
# #Cuts 13127
#                  Time             Domain Visited Cut Generation  \
#                 count        mean           mean           mean
# Status
# safe               18   20.060561   7.377778e+03     134.833333
# safe-incomplete     3    0.268867   0.000000e+00       0.000000
# unknown             8  725.350513   1.184140e+06    1337.500000
# unsafe-pgd          1    0.275600   0.000000e+00       0.000000
#
#                    Unsat Nodes BaB Round Count
#                           mean            mean
# Status
# safe               4980.333333       14.666667
# safe-incomplete       0.000000        0.000000
# unknown          201906.625000      223.000000
# unsafe-pgd            0.000000        0.000000
# safe number 21.0
# safe time 17.23317619047619
# safe domain 6323.809523809524
# safe cut 115.57142857142857
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((21.0, 17.23317619047619, 7377.777777777777, 134.83333333333334),)

# %%
main('oval22/gcp.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe   35.0019             134               0            0
# 1    safe    7.3679             310               0            0
# 2    safe    3.0164               2               0            0
# 4    safe    3.3144               0               0            0
# 5    safe    3.6891              14               0            0
# 6    safe    6.8192             405               0            0
# 7    safe    2.9198               0               0            0
# 8    safe   11.1099            1931               0            0
# 9    safe   12.2731            3133               0            0
# 12   safe   14.0202            4140               0            0
# 13   safe  257.6644           72727               0            0
# 16   safe  195.7084           97489               0            0
# 17   safe    4.4513              20               0            0
# 19   safe   47.8797           48317               0            0
# 20   safe   72.0183           14164               0            0
# 21   safe    6.2961              47               0            0
# 22   safe   30.7659           24966               0            0
# 23   safe    5.8660               2               0            0
# 24   safe   12.1090             277               0            0
# 25   safe    5.2639               0               0            0
# 26   safe   53.5708           21779               0            0
# 29   safe   10.5297             154               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 5         NaN
# 1                12         NaN
# 2                 2         NaN
# 4                 1         NaN
# 5                 3         NaN
# 6                11         NaN
# 7                 1         NaN
# 8                17         NaN
# 9                15         NaN
# 12               19         NaN
# 13              143         NaN
# 16               43         NaN
# 17                4         NaN
# 19               23         NaN
# 20               50         NaN
# 21                3         NaN
# 22               15         NaN
# 23                3         NaN
# 24               13         NaN
# 25                1         NaN
# 26               31         NaN
# 29                8         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 3   unknown  727.8170          295220               0            0
# 10  unknown  722.2746          195909               0            0
# 11  unknown  733.2222          276666               0            0
# 15  unknown  731.9163          236474               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 3                78   -0.163506
# 10              124   -0.782964
# 11              100   -1.118246
# 15               65   -0.599188
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe   35.0019             134               0            0
# 1              safe    7.3679             310               0            0
# 2              safe    3.0164               2               0            0
# 3           unknown  727.8170          295220               0            0
# 4              safe    3.3144               0               0            0
# 5              safe    3.6891              14               0            0
# 6              safe    6.8192             405               0            0
# 7              safe    2.9198               0               0            0
# 8              safe   11.1099            1931               0            0
# 9              safe   12.2731            3133               0            0
# 10          unknown  722.2746          195909               0            0
# 11          unknown  733.2222          276666               0            0
# 12             safe   14.0202            4140               0            0
# 13             safe  257.6644           72727               0            0
# 14       unsafe-pgd    0.3113               0               0            0
# 15          unknown  731.9163          236474               0            0
# 16             safe  195.7084           97489               0            0
# 17             safe    4.4513              20               0            0
# 18  safe-incomplete    0.1915               0               0            0
# 19             safe   47.8797           48317               0            0
# 20             safe   72.0183           14164               0            0
# 21             safe    6.2961              47               0            0
# 22             safe   30.7659           24966               0            0
# 23             safe    5.8660               2               0            0
# 24             safe   12.1090             277               0            0
# 25             safe    5.2639               0               0            0
# 26             safe   53.5708           21779               0            0
# 27  safe-incomplete    0.6641               0               0            0
# 28  safe-incomplete    0.6449               0               0            0
# 29             safe   10.5297             154               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 5         NaN
# 1                12         NaN
# 2                 2         NaN
# 3                78   -0.163506
# 4                 1         NaN
# 5                 3         NaN
# 6                11         NaN
# 7                 1         NaN
# 8                17         NaN
# 9                15         NaN
# 10              124   -0.782964
# 11              100   -1.118246
# 12               19         NaN
# 13              143         NaN
# 14                0         NaN
# 15               65   -0.599188
# 16               43         NaN
# 17                4         NaN
# 18                0         NaN
# 19               23         NaN
# 20               50         NaN
# 21                3         NaN
# 22               15         NaN
# 23                3         NaN
# 24               13         NaN
# 25                1         NaN
# 26               31         NaN
# 27                0         NaN
# 28                0         NaN
# 29                8         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               22   36.438882   13182.318182            0.0         0.0
# safe-incomplete     3    0.500167       0.000000            0.0         0.0
# unknown             4  728.807525  251067.250000            0.0         0.0
# unsafe-pgd          1    0.311300       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  19.227273
# safe-incomplete        0.000000
# unknown               91.750000
# unsafe-pgd             0.000000
# safe number 25.0
# safe time 32.126236
# safe domain 11600.44
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((25.0, 32.126236, 13182.318181818182, 0.0),)

# %%
main('oval22/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe   16.8705             230             286          968
# 1    safe   10.5120             342              78         1612
# 2    safe    5.6331             150              48          400
# 3    safe  402.9608          123496           50980        74856
# 4    safe    4.9044             100              11          319
# 5    safe    8.4169             199             101          881
# 6    safe   13.9030             387              57         1763
# 7    safe    5.7354             136              69          360
# 8    safe   16.2240             734             616         1212
# 9    safe   17.5002             816             603         2496
# 12   safe   14.7150            1235             208         1951
# 13   safe  415.1779          180044           40888       114249
# 16   safe  162.3256           60446           13083        32774
# 17   safe    9.9869             171             531         1209
# 19   safe   63.0606           27336            3306        12793
# 20   safe  202.0615           57257           14083        31611
# 21   safe   14.3130             213             210         1301
# 22   safe   33.4537            9839             725         8292
# 23   safe   15.2057             172              84         1056
# 24   safe   31.8096             496            1442         3415
# 25   safe    6.7865              50               7          400
# 26   safe   65.7338           17532            3981        14166
# 29   safe   17.4292             192             121         1694
#
#     BaB Round Count  BaB_lb_rhs
# 0                 8         NaN
# 1                12         NaN
# 2                 4         NaN
# 3               133         NaN
# 4                 3         NaN
# 5                 8         NaN
# 6                15         NaN
# 7                 4         NaN
# 8                15         NaN
# 9                21         NaN
# 12               17         NaN
# 13              188         NaN
# 16               48         NaN
# 17                9         NaN
# 19               23         NaN
# 20               85         NaN
# 21                8         NaN
# 22               17         NaN
# 23                9         NaN
# 24               23         NaN
# 25                2         NaN
# 26               40         NaN
# 29               11         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 10  unknown  724.6403          172863           21050        90118
# 11  unknown  729.3858          301662           26170       121613
# 15  unknown  734.9436          209669           18214        88667
#
#     BaB Round Count  BaB_lb_rhs
# 10              117   -0.097806
# 11              127   -1.024406
# 15               62   -0.170894
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe   16.8705             230             286          968
# 1              safe   10.5120             342              78         1612
# 2              safe    5.6331             150              48          400
# 3              safe  402.9608          123496           50980        74856
# 4              safe    4.9044             100              11          319
# 5              safe    8.4169             199             101          881
# 6              safe   13.9030             387              57         1763
# 7              safe    5.7354             136              69          360
# 8              safe   16.2240             734             616         1212
# 9              safe   17.5002             816             603         2496
# 10          unknown  724.6403          172863           21050        90118
# 11          unknown  729.3858          301662           26170       121613
# 12             safe   14.7150            1235             208         1951
# 13             safe  415.1779          180044           40888       114249
# 14       unsafe-pgd    0.2355               0               0            0
# 15          unknown  734.9436          209669           18214        88667
# 16             safe  162.3256           60446           13083        32774
# 17             safe    9.9869             171             531         1209
# 18  safe-incomplete    0.1425               0               0            0
# 19             safe   63.0606           27336            3306        12793
# 20             safe  202.0615           57257           14083        31611
# 21             safe   14.3130             213             210         1301
# 22             safe   33.4537            9839             725         8292
# 23             safe   15.2057             172              84         1056
# 24             safe   31.8096             496            1442         3415
# 25             safe    6.7865              50               7          400
# 26             safe   65.7338           17532            3981        14166
# 27  safe-incomplete    0.5419               0               0            0
# 28  safe-incomplete    0.5271               0               0            0
# 29             safe   17.4292             192             121         1694
#
#     BaB Round Count  BaB_lb_rhs
# 0                 8         NaN
# 1                12         NaN
# 2                 4         NaN
# 3               133         NaN
# 4                 3         NaN
# 5                 8         NaN
# 6                15         NaN
# 7                 4         NaN
# 8                15         NaN
# 9                21         NaN
# 10              117   -0.097806
# 11              127   -1.024406
# 12               17         NaN
# 13              188         NaN
# 14                0         NaN
# 15               62   -0.170894
# 16               48         NaN
# 17                9         NaN
# 18                0         NaN
# 19               23         NaN
# 20               85         NaN
# 21                8         NaN
# 22               17         NaN
# 23                9         NaN
# 24               23         NaN
# 25                2         NaN
# 26               40         NaN
# 27                0         NaN
# 28                0         NaN
# 29               11         NaN
# #Cuts 196952
#                  Time             Domain Visited Cut Generation  \
#                 count        mean           mean           mean
# Status
# safe               23   67.596491   20937.956522    5718.173913
# safe-incomplete     3    0.403833       0.000000       0.000000
# unknown             3  729.656567  228064.666667   21811.333333
# unsafe-pgd          1    0.235500       0.000000       0.000000
#
#                    Unsat Nodes BaB Round Count
#                           mean            mean
# Status
# safe              13468.608696       30.565217
# safe-incomplete       0.000000        0.000000
# unknown          100132.666667      102.000000
# unsafe-pgd            0.000000        0.000000
# safe number 26.0
# safe time 59.8434923076923
# safe domain 18522.038461538465
# safe cut 5058.384615384615
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((26.0, 59.8434923076923, 20937.956521739132, 5718.173913043478),)

# %%
main('oval21/beta.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe    6.3020               0               0            0
# 1    safe    3.3086               2               0            0
# 2    safe   12.0253            4895               0            0
# 4    safe    3.8141              45               0            0
# 6    safe    2.8971               4               0            0
# 10   safe    7.3286             592               0            0
# 13   safe   27.1041           26888               0            0
# 18   safe    2.5405               0               0            0
# 19   safe  376.3257          761646               0            0
# 21   safe    5.3287              10               0            0
# 23   safe    6.5046              55               0            0
# 26   safe  299.9599          486308               0            0
# 28   safe    3.9717               0               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 1         NaN
# 1                 4         NaN
# 2                24         NaN
# 4                 7         NaN
# 6                 3         NaN
# 10               11         NaN
# 13               31         NaN
# 18                1         NaN
# 19              128         NaN
# 21                3         NaN
# 23                5         NaN
# 26               62         NaN
# 28                1         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 5   unknown  761.7303         1661861               0            0
# 8   unknown  738.7612         1850694               0            0
# 9   unknown  720.2766         1612011               0            0
# 11  unknown  746.4468         1357611               0            0
# 12  unknown  738.1872         1260590               0            0
# 14  unknown  728.4786         1337486               0            0
# 15  unknown  722.3327         1195940               0            0
# 17  unknown  757.6444         1203638               0            0
# 20  unknown  745.1208         1285847               0            0
# 22  unknown  730.2293         1693988               0            0
# 24  unknown  737.9242         1547339               0            0
# 25  unknown  736.5924         1249342               0            0
# 27  unknown  726.9446         1688892               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 5                68   -0.090061
# 8                63   -0.456239
# 9               211   -0.197837
# 11               42   -1.029700
# 12               47   -0.189778
# 14               43   -0.103086
# 15               46   -0.118342
# 17               30   -3.338025
# 20               48   -0.429411
# 22               46   -0.694723
# 24               47   -0.171786
# 25               94   -0.331056
# 27               49   -2.049857
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe    6.3020               0               0            0
# 1              safe    3.3086               2               0            0
# 2              safe   12.0253            4895               0            0
# 3        unsafe-pgd    0.2331               0               0            0
# 4              safe    3.8141              45               0            0
# 5           unknown  761.7303         1661861               0            0
# 6              safe    2.8971               4               0            0
# 7        unsafe-pgd    0.2689               0               0            0
# 8           unknown  738.7612         1850694               0            0
# 9           unknown  720.2766         1612011               0            0
# 10             safe    7.3286             592               0            0
# 11          unknown  746.4468         1357611               0            0
# 12          unknown  738.1872         1260590               0            0
# 13             safe   27.1041           26888               0            0
# 14          unknown  728.4786         1337486               0            0
# 15          unknown  722.3327         1195940               0            0
# 16       unsafe-pgd    0.1908               0               0            0
# 17          unknown  757.6444         1203638               0            0
# 18             safe    2.5405               0               0            0
# 19             safe  376.3257          761646               0            0
# 20          unknown  745.1208         1285847               0            0
# 21             safe    5.3287              10               0            0
# 22          unknown  730.2293         1693988               0            0
# 23             safe    6.5046              55               0            0
# 24          unknown  737.9242         1547339               0            0
# 25          unknown  736.5924         1249342               0            0
# 26             safe  299.9599          486308               0            0
# 27          unknown  726.9446         1688892               0            0
# 28             safe    3.9717               0               0            0
# 29  safe-incomplete    0.1553               0               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 1         NaN
# 1                 4         NaN
# 2                24         NaN
# 3                 0         NaN
# 4                 7         NaN
# 5                68   -0.090061
# 6                 3         NaN
# 7                 0         NaN
# 8                63   -0.456239
# 9               211   -0.197837
# 10               11         NaN
# 11               42   -1.029700
# 12               47   -0.189778
# 13               31         NaN
# 14               43   -0.103086
# 15               46   -0.118342
# 16                0         NaN
# 17               30   -3.338025
# 18                1         NaN
# 19              128         NaN
# 20               48   -0.429411
# 21                3         NaN
# 22               46   -0.694723
# 23                5         NaN
# 24               47   -0.171786
# 25               94   -0.331056
# 26               62         NaN
# 27               49   -2.049857
# 28                1         NaN
# 29                0         NaN
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               13   58.262377   9.849577e+04            0.0         0.0
# safe-incomplete     1    0.155300   0.000000e+00            0.0         0.0
# unknown            13  737.743777   1.457326e+06            0.0         0.0
# unsafe-pgd          3    0.230933   0.000000e+00            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  21.615385
# safe-incomplete        0.000000
# unknown               64.153846
# unsafe-pgd             0.000000
# safe number 14.0
# safe time 54.111871428571426
# safe domain 91460.35714285714
# safe cut 0.0
# ((14.0, 54.111871428571426, 98495.76923076923, 0.0),)

# %%
main('oval21/biccos_only_cs.log'),
# Out:
#    Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0    safe    7.7053               0               1          256
# 1    safe    3.5405               2              30          512
# 2    safe   15.8831            2480             622         2169
# 4    safe    4.4837              45              73         1122
# 6    safe    6.5831             107              41         1358
# 9    safe   63.0616           43384             548        27488
# 10   safe   10.1080             498             235         2302
# 13   safe   24.9238           15102            1251        10438
# 18   safe    4.4898             110              25          618
# 21   safe   10.4515             167              44          906
# 23   safe   12.0315             160             148         1022
# 26   safe  603.4611          472201             588       196418
# 28   safe    6.0427              58              67          656
#
#     BaB Round Count  BaB_lb_rhs
# 0                 2         NaN
# 1                 4         NaN
# 2                24         NaN
# 4                 7         NaN
# 6                 9         NaN
# 9                63         NaN
# 10               13         NaN
# 13               26         NaN
# 18                5         NaN
# 21                8         NaN
# 23                9         NaN
# 26              135         NaN
# 28                4         NaN
#      Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 5   unknown  751.9219          843221             630       134994
# 8   unknown  752.4361         1519132            1079        84005
# 11  unknown  762.9615          973130             804        71461
# 12  unknown  735.8266          830440             520       196656
# 14  unknown  749.5435          864573             607        78132
# 15  unknown  722.6702         1049802             619       246840
# 17  unknown  765.4584          890252             310       124911
# 19  unknown  730.6900          662745             628       219400
# 20  unknown  745.2966          965021             630       127249
# 22  unknown  745.5358         1207062             609        92049
# 24  unknown  734.4415          872290             636       159135
# 25  unknown  752.6535          813336            1244       229974
# 27  unknown  735.9915         1378426             837       105970
#
#     BaB Round Count  BaB_lb_rhs
# 5                39   -0.070772
# 8                56   -0.362690
# 11               31   -0.906635
# 12               56   -0.091228
# 14               33   -0.094966
# 15              200   -0.093980
# 17               29   -3.135431
# 19               66   -0.012697
# 20               42   -0.370389
# 22               37   -0.660160
# 24               52   -0.169348
# 25               74   -0.283003
# 27               44   -1.976494
# All:
#               Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0              safe    7.7053               0               1          256
# 1              safe    3.5405               2              30          512
# 2              safe   15.8831            2480             622         2169
# 3        unsafe-pgd    0.2396               0               0            0
# 4              safe    4.4837              45              73         1122
# 5           unknown  751.9219          843221             630       134994
# 6              safe    6.5831             107              41         1358
# 7        unsafe-pgd    0.4059               0               0            0
# 8           unknown  752.4361         1519132            1079        84005
# 9              safe   63.0616           43384             548        27488
# 10             safe   10.1080             498             235         2302
# 11          unknown  762.9615          973130             804        71461
# 12          unknown  735.8266          830440             520       196656
# 13             safe   24.9238           15102            1251        10438
# 14          unknown  749.5435          864573             607        78132
# 15          unknown  722.6702         1049802             619       246840
# 16       unsafe-pgd    0.2528               0               0            0
# 17          unknown  765.4584          890252             310       124911
# 18             safe    4.4898             110              25          618
# 19          unknown  730.6900          662745             628       219400
# 20          unknown  745.2966          965021             630       127249
# 21             safe   10.4515             167              44          906
# 22          unknown  745.5358         1207062             609        92049
# 23             safe   12.0315             160             148         1022
# 24          unknown  734.4415          872290             636       159135
# 25          unknown  752.6535          813336            1244       229974
# 26             safe  603.4611          472201             588       196418
# 27          unknown  735.9915         1378426             837       105970
# 28             safe    6.0427              58              67          656
# 29  safe-incomplete    0.2222               0               0            0
#
#     BaB Round Count  BaB_lb_rhs
# 0                 2         NaN
# 1                 4         NaN
# 2                24         NaN
# 3                 0         NaN
# 4                 7         NaN
# 5                39   -0.070772
# 6                 9         NaN
# 7                 0         NaN
# 8                56   -0.362690
# 9                63         NaN
# 10               13         NaN
# 11               31   -0.906635
# 12               56   -0.091228
# 13               26         NaN
# 14               33   -0.094966
# 15              200   -0.093980
# 16                0         NaN
# 17               29   -3.135431
# 18                5         NaN
# 19               66   -0.012697
# 20               42   -0.370389
# 21                8         NaN
# 22               37   -0.660160
# 23                9         NaN
# 24               52   -0.169348
# 25               74   -0.283003
# 26              135         NaN
# 27               44   -1.976494
# 28                4         NaN
# 29                0         NaN
# #Cuts 12826
#                  Time             Domain Visited Cut Generation  \
#                 count        mean           mean           mean
# Status
# safe               13   59.443515   41101.076923     282.538462
# safe-incomplete     1    0.222200       0.000000       0.000000
# unknown            13  745.032854  989956.153846     704.076923
# unsafe-pgd          3    0.299433       0.000000       0.000000
#
#                    Unsat Nodes BaB Round Count
#                           mean            mean
# Status
# safe              18866.538462       23.769231
# safe-incomplete       0.000000        0.000000
# unknown          143905.846154       58.384615
# unsafe-pgd            0.000000        0.000000
# safe number 14.0
# safe time 55.21342142857143
# safe domain 38165.28571428572
# safe cut 262.35714285714283
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((14.0, 55.21342142857143, 41101.07692307692, 282.53846153846155),)

# %% [markdown]
# # cifar100

# %%
def plot_multiple_dfs(dfs, labels, venus=False, dataset=None, Cut=False, time_limit=200):
    fig, ax1 = plt.subplots(figsize=(10, 6))
    
    # Define a color map for different dataframes
    colors = plt.cm.get_cmap('tab10', len(dfs))
    
    # Check if any dataframe has 'Cut Generation' with non-zero values
    if Cut:
        has_cut_generation = any('Cut Generation' in df.columns and df['Cut Generation'].sum() > 0 for df in dfs)
    else:
        has_cut_generation = False
    ax2 = None
    for i, (df, label) in enumerate(zip(dfs, labels)):
        # Filter out rows where Status is 'safe'
        if venus:
            df_filtered = df.loc[(df['Status'] == 'safe-incomplete') | (df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        else:
            df_filtered = df.loc[(df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        
        # Sort the dataframe by Time
        df_filtered = df_filtered.sort_values(by='Time')
        
        # Compute the cumulative count of verified instances
        df_filtered['Cumulative Count'] = range(1, len(df_filtered) + 1)
        
        # Plot Cumulative Count vs. Time
        ax1.plot(df_filtered['Cumulative Count'], df_filtered['Time'], marker='o', linestyle='-', color=colors(i), label=label)
        
        # If 'Cut Generation' exists and has non-zero values, plot it as well
        if Cut:
            if has_cut_generation and 'Cut Generation' in df.columns and df['Cut Generation'].sum() > 0:
                if ax2 is None:
                    ax2 = ax1.twinx()  # Create a second y-axis if needed
                ax2.bar(df_filtered['Cumulative Count'], df_filtered['Cut Generation'], color=colors(i), alpha=0.3, label=f'{label} Cut Generation')
                ax2.set_ylabel('Cut Generation', fontsize=20)

    ax1.set_xlabel(f'Number of Instances Verified in {dataset}', fontsize=20)
    ax1.set_ylabel('Time', fontsize=20)
    ax1.set_title('Number of Instances Verified vs. Time', fontsize=20)
    ax1.grid(True)

    # Set the y-axis limit
    max_time = max(df_filtered['Time'].max(), time_limit)
    ax1.set_ylim(0, max_time + 5)
    
    # Add a horizontal line at y=200 to emphasize the time limitation
    if max_time + 5 > time_limit:
        ax1.axhline(y=time_limit, color='red', linestyle='--', linewidth=2, label='Time Limit (200)')
    
    # Combine legends from both y-axes if 'Cut Generation' was plotted
    lines, labels = ax1.get_legend_handles_labels()
    if has_cut_generation:
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines + lines2, labels + labels2, fontsize=20)
    else:
        ax1.legend(lines, labels, fontsize=20)
    
    plt.show()

plot_multiple_dfs(
    [
log_read('cifar100/beta.log'),
log_read('cifar100/biccos_only_cs.log'),
log_read('cifar100/biccos_all.log'),
log_read('cifar100/gcp.log'),
log_read('cifar100/biccos_all_selective_mts.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],
     time_limit=100, dataset='cifar100_2024'
)
# Out:
# /tmp/ipykernel_20992/1472281028.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
import matplotlib.pyplot as plt

def plot_multiple_dfs(dfs, labels, venus=True, dataset=None, Cut=False, time_limit=200, min_count=90):
    fig, ax1 = plt.subplots(figsize=(10, 6))
    
    # Define a color map for different dataframes
    colors = plt.cm.get_cmap('tab10', len(dfs))
    
    # Check if any dataframe has 'Cut Generation' with non-zero values
    if Cut:
        has_cut_generation = any('Cut Generation' in df.columns and df['Cut Generation'].sum() > 0 for df in dfs)
    else:
        has_cut_generation = False
    ax2 = None
    for i, (df, label) in enumerate(zip(dfs, labels)):
        # Filter out rows where Status is 'safe'
        if venus:
            df_filtered = df.loc[(df['Status'] == 'safe-incomplete') | (df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        else:
            df_filtered = df.loc[(df['Status'] == 'safe') | (df['Status'] == 'safe-mip') | (df['Status'] == 'safe-mip (timed out)')]
        
        # Sort the dataframe by Time
        df_filtered = df_filtered.sort_values(by='Time')
        
        # Compute the cumulative count of verified instances
        df_filtered['Cumulative Count'] = range(1, len(df_filtered) + 1)
        
        # Filter based on min_count
        df_filtered = df_filtered[df_filtered['Cumulative Count'] >= min_count]
        
        # Plot Cumulative Count vs. Time
        ax1.plot(df_filtered['Cumulative Count'], df_filtered['Time'], marker='o', linestyle='-', color=colors(i), label=label)
        
        # If 'Cut Generation' exists and has non-zero values, plot it as well
        if Cut:
            if has_cut_generation and 'Cut Generation' in df.columns and df['Cut Generation'].sum() > 0:
                if ax2 is None:
                    ax2 = ax1.twinx()  # Create a second y-axis if needed
                ax2.bar(df_filtered['Cumulative Count'], df_filtered['Cut Generation'], color=colors(i), alpha=0.3, label=f'{label} Cut Generation')
                ax2.set_ylabel('Cut Generation', fontsize=20)

    ax1.set_xlabel(f'Number of Instances Verified in {dataset}', fontsize=20)
    ax1.set_ylabel('Time', fontsize=20)
    ax1.set_title('Number of Instances Verified vs. Time', fontsize=20)
    ax1.grid(True)

    # Set the y-axis limit
    max_time = max(df_filtered['Time'].max(), time_limit)
    ax1.set_ylim(0, max_time + 5)
    
    # Add a horizontal line at y=200 to emphasize the time limitation
    if max_time + 5 > time_limit:
        ax1.axhline(y=time_limit, color='red', linestyle='--', linewidth=2, label='Time Limit')
    
    # Combine legends from both y-axes if 'Cut Generation' was plotted
    lines, labels = ax1.get_legend_handles_labels()
    if has_cut_generation:
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines + lines2, labels + labels2, fontsize=20)
    else:
        ax1.legend(lines, labels, fontsize=20)
    
    plt.show()


plot_multiple_dfs(
    [
log_read('cifar100/beta.log'),
log_read('cifar100/biccos_only_cs.log'),
log_read('cifar100/biccos_all.log'),
log_read('cifar100/gcp.log'),
log_read('cifar100/biccos_all_selective_mts.log'),
    ],
    [
        'Beta CROWN',
        'Biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],
     time_limit=100, dataset='cifar100_2024'
)
# Out:
# /tmp/ipykernel_20992/2956103369.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('cifar100/beta.log'),
main('cifar100/biccos_only_cs.log'),
main('cifar100/biccos_all.log'),
main('cifar100/gcp.log'),
main('cifar100/biccos_all_selective_mts_plus_gcp.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  35.2178            2548               0            0
# 1     safe  11.3097               0               0            0
# 3     safe  16.2724             218               0            0
# 4     safe  19.9624             736               0            0
# 6     safe  11.1832               0               0            0
# 8     safe  20.9203            1474               0            0
# 17    safe  18.8598             511               0            0
# 18    safe  12.3676              14               0            0
# 19    safe  11.6350               1               0            0
# 22    safe  11.4630               1               0            0
# 23    safe  17.4644             307               0            0
# 26    safe  11.3360               0               0            0
# 27    safe  46.0858           19888               0            0
# 29    safe  11.3107               0               0            0
# 32    safe  21.5057            3124               0            0
# 33    safe  12.5215              10               0            0
# 34    safe  11.4406               0               0            0
# 35    safe  12.0530               5               0            0
# 36    safe  12.4582              11               0            0
# 39    safe  11.5951               0               0            0
# 40    safe  11.7209               1               0            0
# 42    safe  11.4342               0               0            0
# 45    safe  17.8066             507               0            0
# 49    safe  50.3559           23241               0            0
# 53    safe  11.8509               4               0            0
# 56    safe  14.3817              57               0            0
# 58    safe  75.4895           42789               0            0
# 61    safe  12.9100               5               0            0
# 62    safe  21.8142            1202               0            0
# 63    safe  54.3246           18408               0            0
# 64    safe  11.8608               1               0            0
# 65    safe  17.4825              42               0            0
# 66    safe  14.8460              41               0            0
# 67    safe  12.0007               2               0            0
# 68    safe  11.5074               0               0            0
# 69    safe  11.7572               0               0            0
# 71    safe  74.7811           40979               0            0
# 73    safe  14.3594              21               0            0
# 74    safe  12.8884               0               0            0
# 77    safe  13.9362               9               0            0
# 78    safe  13.4989               6               0            0
# 82    safe  12.8762               0               0            0
# 83    safe  12.8463               0               0            0
# 84    safe  14.5598              15               0            0
# 86    safe  17.0492             283               0            0
# 88    safe  14.3715              16               0            0
# 89    safe  15.5349             129               0            0
# 90    safe  14.3467              14               0            0
# 91    safe  14.1448              15               0            0
# 94    safe  17.9250             225               0            0
# 95    safe  20.2815             425               0            0
# 97    safe  13.1522               1               0            0
# 100   safe  16.4062               3               0            0
# 102   safe  14.8072               6               0            0
# 103   safe  14.1057               0               0            0
# 107   safe  14.2179               0               0            0
# 109   safe  15.5437               0               0            0
# 115   safe  44.2712            5325               0            0
# 118   safe  17.2553              79               0            0
# 119   safe  48.4646            6517               0            0
# 120   safe  14.1864               1               0            0
# 122   safe  19.0422              90               0            0
# 124   safe  22.1380            1105               0            0
# 125   safe  14.1526               1               0            0
# 126   safe  15.6599               9               0            0
# 131   safe  15.6230               3               0            0
# 132   safe  14.3007               0               0            0
# 133   safe  19.2092             236               0            0
# 134   safe  14.7093               3               0            0
# 137   safe  15.1516               5               0            0
# 140   safe  13.7493               1               0            0
# 141   safe  14.8411              14               0            0
# 144   safe  42.3608            5620               0            0
# 145   safe  30.6414            1601               0            0
# 152   safe  17.3621              36               0            0
# 154   safe  13.6839               0               0            0
# 159   safe  14.2001               1               0            0
# 161   safe  13.3007               0               0            0
# 162   safe  13.6182               2               0            0
# 163   safe  15.0222              21               0            0
# 166   safe  13.4805               0               0            0
# 171   safe  13.7171               0               0            0
# 174   safe  14.1680               1               0            0
# 177   safe  23.4335             404               0            0
# 180   safe  13.4375               0               0            0
# 182   safe  14.1851               4               0            0
# 183   safe  14.5934               3               0            0
# 185   safe  13.4209               0               0            0
# 186   safe  15.1707              33               0            0
# 187   safe  16.8362             128               0            0
# 191   safe  13.2985               0               0            0
# 192   safe  36.9947            4118               0            0
# 195   safe  13.9555               0               0            0
# 196   safe  18.4957             267               0            0
# 197   safe  14.5459              11               0            0
# 198   safe  14.7573               7               0            0
# 199   safe  15.5969               8               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                 59         NaN
# 1                  1         NaN
# 3                 23         NaN
# 4                 38         NaN
# 6                  1         NaN
# 8                 39         NaN
# 17                32         NaN
# 18                 5         NaN
# 19                 2         NaN
# 22                 2         NaN
# 23                27         NaN
# 26                 1         NaN
# 27                48         NaN
# 29                 1         NaN
# 32                29         NaN
# 33                 5         NaN
# 34                 1         NaN
# 35                 4         NaN
# 36                 6         NaN
# 39                 1         NaN
# 40                 2         NaN
# 42                 1         NaN
# 45                27         NaN
# 49                45         NaN
# 53                 3         NaN
# 56                13         NaN
# 58                48         NaN
# 61                 7         NaN
# 62                41         NaN
# 63                92         NaN
# 64                 2         NaN
# 65                27         NaN
# 66                15         NaN
# 67                 3         NaN
# 68                 1         NaN
# 69                 1         NaN
# 71                48         NaN
# 73                 7         NaN
# 74                 1         NaN
# 77                 6         NaN
# 78                 4         NaN
# 82                 1         NaN
# 83                 1         NaN
# 84                 7         NaN
# 86                19         NaN
# 88                 8         NaN
# 89                13         NaN
# 90                 8         NaN
# 91                 7         NaN
# 94                22         NaN
# 95                32         NaN
# 97                 2         NaN
# 100                4         NaN
# 102                5         NaN
# 103                1         NaN
# 107                1         NaN
# 109                2         NaN
# 115               43         NaN
# 118               14         NaN
# 119               36         NaN
# 120                2         NaN
# 122               22         NaN
# 124               21         NaN
# 125                2         NaN
# 126                6         NaN
# 131                6         NaN
# 132                1         NaN
# 133               21         NaN
# 134                3         NaN
# 137                4         NaN
# 140                2         NaN
# 141                6         NaN
# 144               33         NaN
# 145               55         NaN
# 152               16         NaN
# 154                1         NaN
# 159                3         NaN
# 161                1         NaN
# 162                2         NaN
# 163                9         NaN
# 166                1         NaN
# 171                1         NaN
# 174                2         NaN
# 177               40         NaN
# 180                1         NaN
# 182                3         NaN
# 183                4         NaN
# 185                1         NaN
# 186                8         NaN
# 187               15         NaN
# 191                1         NaN
# 192               30         NaN
# 195                1         NaN
# 196               20         NaN
# 197                6         NaN
# 198                5         NaN
# 199                6         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 5    unknown  106.5706           89753               0            0
# 7    unknown  103.0672           95362               0            0
# 9    unknown  100.9116           71564               0            0
# 10   unknown  100.3705           60587               0            0
# 14   unknown  103.8102           78607               0            0
# 16   unknown  104.2562           83553               0            0
# 24   unknown  103.1527           66749               0            0
# 30   unknown  103.6166           85194               0            0
# 37   unknown  102.6605          100380               0            0
# 38   unknown  102.2245           72572               0            0
# 43   unknown  101.8479           80614               0            0
# 44   unknown  103.0710           84748               0            0
# 48   unknown  100.8005           87045               0            0
# 70   unknown  103.6478           87524               0            0
# 75   unknown  104.3895           83184               0            0
# 76   unknown  103.8817           76262               0            0
# 79   unknown  102.8033           78950               0            0
# 81   unknown  105.2035           74692               0            0
# 87   unknown  102.3666           95026               0            0
# 92   unknown  102.7463           98167               0            0
# 93   unknown  102.4474           90331               0            0
# 96   unknown  102.7788           76597               0            0
# 106  unknown  102.7431           31185               0            0
# 108  unknown  103.0720           31794               0            0
# 111  unknown  100.7641           28912               0            0
# 112  unknown  101.7010           23615               0            0
# 114  unknown  102.1440           17062               0            0
# 116  unknown  102.9167           30925               0            0
# 121  unknown  101.1458           24299               0            0
# 123  unknown  103.0081           25268               0            0
# 127  unknown  101.1066           28617               0            0
# 128  unknown  102.5898           25362               0            0
# 130  unknown  100.6609           32099               0            0
# 138  unknown  104.0233           30156               0            0
# 139  unknown  102.8718           27823               0            0
# 143  unknown  101.3177           22332               0            0
# 147  unknown  103.7067           31240               0            0
# 151  unknown  104.4327           28780               0            0
# 156  unknown  102.7201           27126               0            0
# 157  unknown  101.0345           28948               0            0
# 158  unknown  102.4215           29062               0            0
# 160  unknown  100.4119           23377               0            0
# 164  unknown  104.9699           32403               0            0
# 167  unknown  102.2821           32701               0            0
# 176  unknown  103.9344           33007               0            0
# 178  unknown  104.5074           28413               0            0
# 179  unknown  102.5856           27380               0            0
# 181  unknown  101.9440           27787               0            0
# 194  unknown  101.2584           25507               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 5                 42   -0.153704
# 7                 31   -0.355395
# 9                 70   -0.282899
# 10               115   -0.563258
# 14                49   -0.136876
# 16                32   -0.412269
# 24                46   -0.817351
# 30                35   -0.356280
# 37                30   -0.809682
# 38                43   -0.079914
# 43                68   -0.499030
# 44                30   -0.341526
# 48                36   -0.355845
# 70                43   -0.496096
# 75                31   -0.173066
# 76                88   -0.819896
# 79                34   -0.231807
# 81                37   -0.128486
# 87                31   -0.284173
# 92                28   -0.175235
# 93                32   -0.321943
# 96                62   -0.739225
# 106               27   -0.628036
# 108               28   -0.135867
# 111               31   -0.156649
# 112               49   -0.146707
# 114              104   -0.217890
# 116               32   -0.576733
# 121               30   -0.207519
# 123               32   -0.228945
# 127               28   -0.411729
# 128               38   -0.098371
# 130               30   -0.296100
# 138               29   -0.195203
# 139               32   -0.105346
# 143               39   -0.037902
# 147               34   -0.274562
# 151               36   -0.280970
# 156               31   -0.173366
# 157               44   -0.069304
# 158               33   -0.359536
# 160               45   -0.149240
# 164               32   -0.166647
# 167               31   -0.245660
# 176               28   -0.329109
# 178               42   -0.064511
# 179               49   -0.187474
# 181               51   -0.472387
# 194               33   -0.110362
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   35.2178            2548               0            0
# 1               safe   11.3097               0               0            0
# 2         unsafe-pgd    0.8889               0               0            0
# 3               safe   16.2724             218               0            0
# 4               safe   19.9624             736               0            0
# 5            unknown  106.5706           89753               0            0
# 6               safe   11.1832               0               0            0
# 7            unknown  103.0672           95362               0            0
# 8               safe   20.9203            1474               0            0
# 9            unknown  100.9116           71564               0            0
# 10           unknown  100.3705           60587               0            0
# 11   safe-incomplete    1.1052               0               0            0
# 12        unsafe-pgd    0.8337               0               0            0
# 13        unsafe-pgd    0.8172               0               0            0
# 14           unknown  103.8102           78607               0            0
# 15        unsafe-pgd    0.8193               0               0            0
# 16           unknown  104.2562           83553               0            0
# 17              safe   18.8598             511               0            0
# 18              safe   12.3676              14               0            0
# 19              safe   11.6350               1               0            0
# 20        unsafe-pgd    1.0543               0               0            0
# 21        unsafe-pgd    0.8259               0               0            0
# 22              safe   11.4630               1               0            0
# 23              safe   17.4644             307               0            0
# 24           unknown  103.1527           66749               0            0
# 25        unsafe-pgd    0.8158               0               0            0
# 26              safe   11.3360               0               0            0
# 27              safe   46.0858           19888               0            0
# 28        unsafe-pgd    0.9077               0               0            0
# 29              safe   11.3107               0               0            0
# 30           unknown  103.6166           85194               0            0
# 31        unsafe-pgd    0.8313               0               0            0
# 32              safe   21.5057            3124               0            0
# 33              safe   12.5215              10               0            0
# 34              safe   11.4406               0               0            0
# 35              safe   12.0530               5               0            0
# 36              safe   12.4582              11               0            0
# 37           unknown  102.6605          100380               0            0
# 38           unknown  102.2245           72572               0            0
# 39              safe   11.5951               0               0            0
# 40              safe   11.7209               1               0            0
# 41        unsafe-pgd    0.8363               0               0            0
# 42              safe   11.4342               0               0            0
# 43           unknown  101.8479           80614               0            0
# 44           unknown  103.0710           84748               0            0
# 45              safe   17.8066             507               0            0
# 46   safe-incomplete    0.9982               0               0            0
# 47        unsafe-pgd    0.7909               0               0            0
# 48           unknown  100.8005           87045               0            0
# 49              safe   50.3559           23241               0            0
# 50        unsafe-pgd    0.8093               0               0            0
# 51        unsafe-pgd    0.8300               0               0            0
# 52        unsafe-pgd    0.8937               0               0            0
# 53              safe   11.8509               4               0            0
# 54        unsafe-pgd    0.9106               0               0            0
# 55        unsafe-pgd    0.7900               0               0            0
# 56              safe   14.3817              57               0            0
# 57   safe-incomplete    1.0178               0               0            0
# 58              safe   75.4895           42789               0            0
# 59   safe-incomplete    1.1194               0               0            0
# 60        unsafe-pgd    0.9446               0               0            0
# 61              safe   12.9100               5               0            0
# 62              safe   21.8142            1202               0            0
# 63              safe   54.3246           18408               0            0
# 64              safe   11.8608               1               0            0
# 65              safe   17.4825              42               0            0
# 66              safe   14.8460              41               0            0
# 67              safe   12.0007               2               0            0
# 68              safe   11.5074               0               0            0
# 69              safe   11.7572               0               0            0
# 70           unknown  103.6478           87524               0            0
# 71              safe   74.7811           40979               0            0
# 72   safe-incomplete    1.0372               0               0            0
# 73              safe   14.3594              21               0            0
# 74              safe   12.8884               0               0            0
# 75           unknown  104.3895           83184               0            0
# 76           unknown  103.8817           76262               0            0
# 77              safe   13.9362               9               0            0
# 78              safe   13.4989               6               0            0
# 79           unknown  102.8033           78950               0            0
# 80        unsafe-pgd    0.9674               0               0            0
# 81           unknown  105.2035           74692               0            0
# 82              safe   12.8762               0               0            0
# 83              safe   12.8463               0               0            0
# 84              safe   14.5598              15               0            0
# 85        unsafe-pgd    0.5407               0               0            0
# 86              safe   17.0492             283               0            0
# 87           unknown  102.3666           95026               0            0
# 88              safe   14.3715              16               0            0
# 89              safe   15.5349             129               0            0
# 90              safe   14.3467              14               0            0
# 91              safe   14.1448              15               0            0
# 92           unknown  102.7463           98167               0            0
# 93           unknown  102.4474           90331               0            0
# 94              safe   17.9250             225               0            0
# 95              safe   20.2815             425               0            0
# 96           unknown  102.7788           76597               0            0
# 97              safe   13.1522               1               0            0
# 98   safe-incomplete    0.9311               0               0            0
# 99        unsafe-pgd    0.8075               0               0            0
# 100             safe   16.4062               3               0            0
# 101  safe-incomplete    1.4845               0               0            0
# 102             safe   14.8072               6               0            0
# 103             safe   14.1057               0               0            0
# 104       unsafe-pgd    1.2790               0               0            0
# 105  safe-incomplete    1.2882               0               0            0
# 106          unknown  102.7431           31185               0            0
# 107             safe   14.2179               0               0            0
# 108          unknown  103.0720           31794               0            0
# 109             safe   15.5437               0               0            0
# 110       unsafe-pgd    1.1645               0               0            0
# 111          unknown  100.7641           28912               0            0
# 112          unknown  101.7010           23615               0            0
# 113  safe-incomplete    1.3095               0               0            0
# 114          unknown  102.1440           17062               0            0
# 115             safe   44.2712            5325               0            0
# 116          unknown  102.9167           30925               0            0
# 117  safe-incomplete    1.5320               0               0            0
# 118             safe   17.2553              79               0            0
# 119             safe   48.4646            6517               0            0
# 120             safe   14.1864               1               0            0
# 121          unknown  101.1458           24299               0            0
# 122             safe   19.0422              90               0            0
# 123          unknown  103.0081           25268               0            0
# 124             safe   22.1380            1105               0            0
# 125             safe   14.1526               1               0            0
# 126             safe   15.6599               9               0            0
# 127          unknown  101.1066           28617               0            0
# 128          unknown  102.5898           25362               0            0
# 129       unsafe-pgd    1.2664               0               0            0
# 130          unknown  100.6609           32099               0            0
# 131             safe   15.6230               3               0            0
# 132             safe   14.3007               0               0            0
# 133             safe   19.2092             236               0            0
# 134             safe   14.7093               3               0            0
# 135  safe-incomplete    1.4498               0               0            0
# 136  safe-incomplete    1.6418               0               0            0
# 137             safe   15.1516               5               0            0
# 138          unknown  104.0233           30156               0            0
# 139          unknown  102.8718           27823               0            0
# 140             safe   13.7493               1               0            0
# 141             safe   14.8411              14               0            0
# 142  safe-incomplete    1.5434               0               0            0
# 143          unknown  101.3177           22332               0            0
# 144             safe   42.3608            5620               0            0
# 145             safe   30.6414            1601               0            0
# 146  safe-incomplete    1.3214               0               0            0
# 147          unknown  103.7067           31240               0            0
# 148       unsafe-pgd    1.0819               0               0            0
# 149       unsafe-pgd    1.4942               0               0            0
# 150  safe-incomplete    1.5070               0               0            0
# 151          unknown  104.4327           28780               0            0
# 152             safe   17.3621              36               0            0
# 153  safe-incomplete    1.6799               0               0            0
# 154             safe   13.6839               0               0            0
# 155  safe-incomplete    1.6167               0               0            0
# 156          unknown  102.7201           27126               0            0
# 157          unknown  101.0345           28948               0            0
# 158          unknown  102.4215           29062               0            0
# 159             safe   14.2001               1               0            0
# 160          unknown  100.4119           23377               0            0
# 161             safe   13.3007               0               0            0
# 162             safe   13.6182               2               0            0
# 163             safe   15.0222              21               0            0
# 164          unknown  104.9699           32403               0            0
# 165  safe-incomplete    1.6285               0               0            0
# 166             safe   13.4805               0               0            0
# 167          unknown  102.2821           32701               0            0
# 168  safe-incomplete    1.3486               0               0            0
# 169       unsafe-pgd    1.1776               0               0            0
# 170  safe-incomplete    1.4391               0               0            0
# 171             safe   13.7171               0               0            0
# 172       unsafe-pgd    1.1198               0               0            0
# 173       unsafe-pgd    1.1077               0               0            0
# 174             safe   14.1680               1               0            0
# 175  safe-incomplete    1.7255               0               0            0
# 176          unknown  103.9344           33007               0            0
# 177             safe   23.4335             404               0            0
# 178          unknown  104.5074           28413               0            0
# 179          unknown  102.5856           27380               0            0
# 180             safe   13.4375               0               0            0
# 181          unknown  101.9440           27787               0            0
# 182             safe   14.1851               4               0            0
# 183             safe   14.5934               3               0            0
# 184       unsafe-pgd    0.7524               0               0            0
# 185             safe   13.4209               0               0            0
# 186             safe   15.1707              33               0            0
# 187             safe   16.8362             128               0            0
# 188       unsafe-pgd    1.2078               0               0            0
# 189       unsafe-pgd    1.0930               0               0            0
# 190  safe-incomplete    1.2386               0               0            0
# 191             safe   13.2985               0               0            0
# 192             safe   36.9947            4118               0            0
# 193       unsafe-pgd    0.7085               0               0            0
# 194          unknown  101.2584           25507               0            0
# 195             safe   13.9555               0               0            0
# 196             safe   18.4957             267               0            0
# 197             safe   14.5459              11               0            0
# 198             safe   14.7573               7               0            0
# 199             safe   15.5969               8               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                 59         NaN
# 1                  1         NaN
# 2                  0         NaN
# 3                 23         NaN
# 4                 38         NaN
# 5                 42   -0.153704
# 6                  1         NaN
# 7                 31   -0.355395
# 8                 39         NaN
# 9                 70   -0.282899
# 10               115   -0.563258
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                49   -0.136876
# 15                 0         NaN
# 16                32   -0.412269
# 17                32         NaN
# 18                 5         NaN
# 19                 2         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 2         NaN
# 23                27         NaN
# 24                46   -0.817351
# 25                 0         NaN
# 26                 1         NaN
# 27                48         NaN
# 28                 0         NaN
# 29                 1         NaN
# 30                35   -0.356280
# 31                 0         NaN
# 32                29         NaN
# 33                 5         NaN
# 34                 1         NaN
# 35                 4         NaN
# 36                 6         NaN
# 37                30   -0.809682
# 38                43   -0.079914
# 39                 1         NaN
# 40                 2         NaN
# 41                 0         NaN
# 42                 1         NaN
# 43                68   -0.499030
# 44                30   -0.341526
# 45                27         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                36   -0.355845
# 49                45         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 3         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                13         NaN
# 57                 0         NaN
# 58                48         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 7         NaN
# 62                41         NaN
# 63                92         NaN
# 64                 2         NaN
# 65                27         NaN
# 66                15         NaN
# 67                 3         NaN
# 68                 1         NaN
# 69                 1         NaN
# 70                43   -0.496096
# 71                48         NaN
# 72                 0         NaN
# 73                 7         NaN
# 74                 1         NaN
# 75                31   -0.173066
# 76                88   -0.819896
# 77                 6         NaN
# 78                 4         NaN
# 79                34   -0.231807
# 80                 0         NaN
# 81                37   -0.128486
# 82                 1         NaN
# 83                 1         NaN
# 84                 7         NaN
# 85                 0         NaN
# 86                19         NaN
# 87                31   -0.284173
# 88                 8         NaN
# 89                13         NaN
# 90                 8         NaN
# 91                 7         NaN
# 92                28   -0.175235
# 93                32   -0.321943
# 94                22         NaN
# 95                32         NaN
# 96                62   -0.739225
# 97                 2         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                4         NaN
# 101                0         NaN
# 102                5         NaN
# 103                1         NaN
# 104                0         NaN
# 105                0         NaN
# 106               27   -0.628036
# 107                1         NaN
# 108               28   -0.135867
# 109                2         NaN
# 110                0         NaN
# 111               31   -0.156649
# 112               49   -0.146707
# 113                0         NaN
# 114              104   -0.217890
# 115               43         NaN
# 116               32   -0.576733
# 117                0         NaN
# 118               14         NaN
# 119               36         NaN
# 120                2         NaN
# 121               30   -0.207519
# 122               22         NaN
# 123               32   -0.228945
# 124               21         NaN
# 125                2         NaN
# 126                6         NaN
# 127               28   -0.411729
# 128               38   -0.098371
# 129                0         NaN
# 130               30   -0.296100
# 131                6         NaN
# 132                1         NaN
# 133               21         NaN
# 134                3         NaN
# 135                0         NaN
# 136                0         NaN
# 137                4         NaN
# 138               29   -0.195203
# 139               32   -0.105346
# 140                2         NaN
# 141                6         NaN
# 142                0         NaN
# 143               39   -0.037902
# 144               33         NaN
# 145               55         NaN
# 146                0         NaN
# 147               34   -0.274562
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151               36   -0.280970
# 152               16         NaN
# 153                0         NaN
# 154                1         NaN
# 155                0         NaN
# 156               31   -0.173366
# 157               44   -0.069304
# 158               33   -0.359536
# 159                3         NaN
# 160               45   -0.149240
# 161                1         NaN
# 162                2         NaN
# 163                9         NaN
# 164               32   -0.166647
# 165                0         NaN
# 166                1         NaN
# 167               31   -0.245660
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                1         NaN
# 172                0         NaN
# 173                0         NaN
# 174                2         NaN
# 175                0         NaN
# 176               28   -0.329109
# 177               40         NaN
# 178               42   -0.064511
# 179               49   -0.187474
# 180                1         NaN
# 181               51   -0.472387
# 182                3         NaN
# 183                4         NaN
# 184                0         NaN
# 185                1         NaN
# 186                8         NaN
# 187               15         NaN
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                1         NaN
# 192               30         NaN
# 193                0         NaN
# 194               33   -0.110362
# 195                1         NaN
# 196               20         NaN
# 197                6         NaN
# 198                5         NaN
# 199                6         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe               97   18.692467    1886.072165            0.0         0.0
# safe-incomplete    22    1.361973       0.000000            0.0         0.0
# unknown            49  102.712224   52502.877551            0.0         0.0
# unsafe-pgd         32    0.948997       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  13.463918
# safe-incomplete        0.000000
# unknown               41.448980
# unsafe-pgd             0.000000
# safe number 119.0
# safe time 15.488510084033614
# safe domain 1537.3865546218487
# safe cut 0.0
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  30.4629            1204             280          613
# 1     safe   5.3317              50              16          408
# 3     safe  13.6254             269             264          701
# 4     safe  19.5283             437             258         1027
# 6     safe   4.5326               0               1           79
# 8     safe  18.7489             801             206          790
# 17    safe  19.4773             531             466          835
# 18    safe   6.3708             101              66          407
# 19    safe   5.2745              50              11          406
# 22    safe   5.2021              50               7          406
# 23    safe  14.4521             276             161          501
# 26    safe   4.5226               0               1           67
# 27    safe  37.3473            9049            1399         4372
# 29    safe   5.1364              50              30          408
# 32    safe  15.5745            1341              96         1121
# 33    safe   7.1957             107              30          387
# 34    safe   4.4922               0               1           25
# 35    safe   5.9385             100              59          408
# 36    safe   9.1626             100              74          777
# 38    safe  54.6262           15922             786         7768
# 39    safe   4.5272               0               1           25
# 40    safe   5.0918              50              46          408
# 42    safe   5.1238              50              10          408
# 45    safe  16.3554             518             499          771
# 49    safe  36.4866            8445             806         6019
# 53    safe   5.8998             100              28          395
# 56    safe   6.7213              57              16           50
# 58    safe  50.2750           15458             465         8173
# 61    safe   9.1332             150             110          736
# 62    safe  17.9583             731             270         1008
# 63    safe  43.9236            9433             476         5288
# 64    safe   5.0421              50              24          408
# 65    safe  11.5333              42              37          115
# 66    safe   9.2597             132              92          383
# 67    safe   7.4038              50              18          443
# 68    safe   5.1093              50              29          408
# 69    safe   4.6721               0               1           86
# 71    safe  32.0741            6764             800         2916
# 73    safe   7.3617             111              55          415
# 74    safe   5.0526              50              42          408
# 77    safe   6.1724             101              55          407
# 78    safe   7.1787             109              71          408
# 82    safe   5.0423              50              10          408
# 83    safe   4.9957              50               9          408
# 84    safe   7.2438             106              99          415
# 86    safe  12.8176             229             165          447
# 87    safe  55.7302           20252             342        13409
# 88    safe   7.0760             103              63          387
# 89    safe   9.3807             159              71          400
# 90    safe   4.6235              14              13           30
# 91    safe   8.1105             100              54          477
# 94    safe  13.5585             234             349          471
# 95    safe  17.4108             392             101         1121
# 97    safe   4.8720              50              17          408
# 100   safe  16.4895             106              58          450
# 102   safe   9.5045             150              66          408
# 103   safe   6.0776               0               1           36
# 107   safe   6.8416              50              26          408
# 108   safe  80.3171           12404             212         2423
# 109   safe  11.0325              50               6          786
# 114   safe  90.7819           10727             609         5026
# 115   safe  18.6842            1145             118          991
# 118   safe  17.6990             269             147         1191
# 119   safe  37.2549            3345             434         2520
# 120   safe   7.0796              50               7          315
# 122   safe  10.6431              89              49           57
# 124   safe  18.3754             823             241          723
# 125   safe   7.0080              50               7          396
# 126   safe  12.6294             237              37          596
# 131   safe   6.0900               3               6           16
# 132   safe   6.0599               0               1           60
# 133   safe  16.6232             273             181          671
# 134   safe   8.3304             100              14          304
# 137   safe  11.1205             200              32          510
# 140   safe   7.2906              50              11          408
# 141   safe  10.9987             174              58          539
# 143   safe  50.6111            5903             163         3184
# 144   safe  23.2778            1642             129         1382
# 145   safe  23.2075            1385             267          768
# 152   safe  10.4893              36              21           70
# 154   safe   7.0511              50              25          408
# 159   safe  11.2689              50              13          622
# 160   safe  87.4994           14068             193         3795
# 161   safe   5.8643               0               1           53
# 162   safe   7.1616              50               6          256
# 163   safe  11.2424             107              63          408
# 166   safe   6.0386               0               1           24
# 171   safe   6.2125               0               1           31
# 174   safe   7.5026              50              10          264
# 177   safe  16.8477             350              45          264
# 180   safe   5.8818               0               1           20
# 182   safe   7.4452              50              19          408
# 183   safe   9.7937             120              68          408
# 185   safe   7.0697              50               9          408
# 186   safe  10.7643             158              42          414
# 187   safe  12.5120             191              30          429
# 191   safe   6.6004              50              19          408
# 192   safe  16.1728             678              87          814
# 195   safe   7.9491              50               8          227
# 196   safe  15.4494             362             110          486
# 197   safe   9.6223             150              69          408
# 198   safe  10.7429             168              57          404
# 199   safe  12.4744             255              28          447
#
#      BaB Round Count  BaB_lb_rhs
# 0                 52         NaN
# 1                  3         NaN
# 3                 23         NaN
# 4                 41         NaN
# 6                  2         NaN
# 8                 42         NaN
# 17                37         NaN
# 18                 5         NaN
# 19                 3         NaN
# 22                 3         NaN
# 23                28         NaN
# 26                 2         NaN
# 27                44         NaN
# 29                 3         NaN
# 32                28         NaN
# 33                 8         NaN
# 34                 2         NaN
# 35                 4         NaN
# 36                 7         NaN
# 38                61         NaN
# 39                 2         NaN
# 40                 3         NaN
# 42                 3         NaN
# 45                30         NaN
# 49                40         NaN
# 53                 4         NaN
# 56                13         NaN
# 58                51         NaN
# 61                 7         NaN
# 62                40         NaN
# 63                88         NaN
# 64                 3         NaN
# 65                27         NaN
# 66                12         NaN
# 67                 5         NaN
# 68                 3         NaN
# 69                 2         NaN
# 71                50         NaN
# 73                 8         NaN
# 74                 3         NaN
# 77                 5         NaN
# 78                 6         NaN
# 82                 3         NaN
# 83                 3         NaN
# 84                 8         NaN
# 86                20         NaN
# 87                35         NaN
# 88                 7         NaN
# ...
# 133             safe   36.1021             272             257          667
# 134             safe   23.5787             100              14          296
# 135  safe-incomplete    1.7438               0               0            0
# 136  safe-incomplete    3.0707               0               0            0
# 137             safe   29.6265             200              32          502
# 138          unknown  101.7103           17915             260         1755
# 139          unknown  107.3575           19093             105         2113
# 140             safe   20.6881              50              11          400
# 141             safe   27.4607             174              58          531
# 142  safe-incomplete    1.9988               0               0            0
# 143             safe   50.0980            1859             176         1217
# 144             safe   51.7241            2126             140         1551
# 145             safe   70.5146            1169             684         1604
# 146  safe-incomplete    2.6664               0               0            0
# 147          unknown  102.2241           18402             372         2299
# 148       unsafe-pgd    2.1533               0               0            0
# 149       unsafe-pgd    2.1103               0               0            0
# 150  safe-incomplete    2.8530               0               0            0
# 151          unknown  106.5435           20184             584         1981
# 152             safe   53.8334             208              67         1639
# 153  safe-incomplete    3.0779               0               0            0
# 154             safe   22.1435              50              25          400
# 155  safe-incomplete    2.8903               0               0            0
# 156          unknown  103.4141           13504             783         3169
# 157          unknown  106.0066           19169             146         1488
# 158          unknown  101.7565           14594             945         1529
# 159             safe   26.7034              50              13          606
# 160          unknown  104.3424           14059             256         3501
# 161             safe   19.0340               0               1           45
# 162             safe   21.1522              50               6          248
# 163             safe   27.5048             107              62          408
# 164          unknown  103.5625           20119             475         2115
# 165  safe-incomplete    1.9826               0               0            0
# 166             safe   20.5700               0               1           16
# 167          unknown  102.2023           17436             261         2067
# 168  safe-incomplete    2.5852               0               0            0
# 169       unsafe-pgd    2.2507               0               0            0
# 170  safe-incomplete    2.7194               0               0            0
# 171             safe   21.3635               0               1           23
# 172       unsafe-pgd    2.4202               0               0            0
# 173       unsafe-pgd    2.2937               0               0            0
# 174             safe   23.4239              50              10          256
# 175  safe-incomplete    2.7940               0               0            0
# 176          unknown  101.6703           18430             727         1714
# 177             safe   73.0789             676             118         1916
# 178          unknown  101.8051           14766             447         2386
# 179          unknown  103.0702           18230             790         1609
# 180             safe   19.3075               0               1           12
# 181          unknown  104.8868            8376             286         3013
# 182             safe   21.0840              50              19          400
# 183             safe   26.0822             120              68          400
# 184       unsafe-pgd    0.7841               0               0            0
# 185             safe   20.9675              50               9          400
# 186             safe   27.9302             157              42          420
# 187             safe   29.9888             187              29          425
# 188       unsafe-pgd    1.3061               0               0            0
# 189       unsafe-pgd    1.1464               0               0            0
# 190  safe-incomplete    1.6199               0               0            0
# 191             safe   21.8761              50              19          400
# 192             safe   34.9141             489              62          767
# 193       unsafe-pgd    1.8330               0               0            0
# 194          unknown  104.8177           16821             402         2555
# 195             safe   22.6046              50               8          219
# 196             safe   37.2320             354             105          538
# 197             safe   25.6731             150              69          400
# 198             safe   27.4363             168              57          396
# 199             safe   30.2818             256              29          440
#
#      BaB Round Count  BaB_lb_rhs
# 0                 60         NaN
# 1                  2         NaN
# 2                  0         NaN
# 3                 24         NaN
# 4                 39         NaN
# 5                 41   -0.145824
# 6                  1         NaN
# 7                 30   -0.323816
# 8                 42         NaN
# 9                 93   -0.262576
# 10                79   -0.552780
# 11                 0         NaN
# 12                 0         NaN
# 13                 0         NaN
# 14                57   -0.134427
# 15                 0         NaN
# 16                28   -0.358294
# 17                36         NaN
# 18                 5         NaN
# 19                 2         NaN
# 20                 0         NaN
# 21                 0         NaN
# 22                 2         NaN
# 23                28         NaN
# 24                54   -0.518776
# 25                 0         NaN
# 26                 1         NaN
# 27                31         NaN
# 28                 0         NaN
# 29                 2         NaN
# 30                32   -0.335824
# 31                 0         NaN
# 32                28         NaN
# 33                 7         NaN
# 34                 1         NaN
# 35                 3         NaN
# 36                 5         NaN
# 37                30   -0.806126
# 38                35         NaN
# 39                 1         NaN
# 40                 2         NaN
# 41                 0         NaN
# 42                 2         NaN
# 43                83   -0.484112
# 44                29   -0.294257
# 45                29         NaN
# 46                 0         NaN
# 47                 0         NaN
# 48                37   -0.346383
# 49                38         NaN
# 50                 0         NaN
# 51                 0         NaN
# 52                 0         NaN
# 53                 3         NaN
# 54                 0         NaN
# 55                 0         NaN
# 56                16         NaN
# 57                 0         NaN
# 58                52         NaN
# 59                 0         NaN
# 60                 0         NaN
# 61                 5         NaN
# 62                40         NaN
# 63                83         NaN
# 64                 2         NaN
# 65                21         NaN
# 66                12         NaN
# 67                 3         NaN
# 68                 2         NaN
# 69                 1         NaN
# 70               126   -0.451993
# 71                50         NaN
# 72                 0         NaN
# 73                 8         NaN
# 74                 2         NaN
# 75                31   -0.158036
# 76                94   -0.521251
# 77                 3         NaN
# 78                 6         NaN
# 79                29   -0.188701
# 80                 0         NaN
# 81               173   -0.120482
# 82                 2         NaN
# 83                 2         NaN
# 84                 8         NaN
# 85                 0         NaN
# 86                21         NaN
# 87                42   -0.233680
# 88                 7         NaN
# 89                14         NaN
# 90                10         NaN
# 91                 5         NaN
# 92                34   -0.146299
# 93                53   -0.303305
# 94                25         NaN
# 95                35         NaN
# 96                56   -0.668843
# 97                 2         NaN
# 98                 0         NaN
# 99                 0         NaN
# 100                8         NaN
# 101                0         NaN
# 102                4         NaN
# 103                1         NaN
# 104                0         NaN
# 105                0         NaN
# 106               33   -0.612046
# 107                2         NaN
# 108               28   -0.117465
# 109                3         NaN
# 110                0         NaN
# 111               31   -0.144595
# 112               78   -0.123535
# 113                0         NaN
# 114               64   -0.162822
# 115               40         NaN
# 116               35   -0.533894
# 117                0         NaN
# 118               16         NaN
# 119               38         NaN
# 120                2         NaN
# 121               35   -0.188140
# 122               24         NaN
# 123               35   -0.214401
# 124               27         NaN
# 125                2         NaN
# 126                7         NaN
# 127               35   -0.393164
# 128               35   -0.087048
# 129                0         NaN
# 130               76   -0.290690
# 131                7         NaN
# 132                1         NaN
# 133               25         NaN
# 134                3         NaN
# 135                0         NaN
# 136                0         NaN
# 137                5         NaN
# 138               33   -0.171923
# 139               32   -0.081349
# 140                2         NaN
# 141                5         NaN
# 142                0         NaN
# 143               31         NaN
# 144               36         NaN
# 145               57         NaN
# 146                0         NaN
# 147               29   -0.264777
# 148                0         NaN
# 149                0         NaN
# 150                0         NaN
# 151               30   -0.244515
# 152               17         NaN
# 153                0         NaN
# 154                2         NaN
# 155                0         NaN
# 156               34   -0.161043
# 157               27   -0.066825
# 158               79   -0.376953
# 159                4         NaN
# 160               42   -0.127538
# 161                1         NaN
# 162                2         NaN
# 163                8         NaN
# 164               27   -0.163949
# 165                0         NaN
# 166                1         NaN
# 167               28   -0.220522
# 168                0         NaN
# 169                0         NaN
# 170                0         NaN
# 171                1         NaN
# 172                0         NaN
# 173                0         NaN
# 174                2         NaN
# 175                0         NaN
# 176               34   -0.316255
# 177               40         NaN
# 178               46   -0.051257
# 179               35   -0.165169
# 180                1         NaN
# 181               44   -0.458461
# 182                2         NaN
# 183                4         NaN
# 184                0         NaN
# 185                2         NaN
# 186                8         NaN
# 187               16         NaN
# 188                0         NaN
# 189                0         NaN
# 190                0         NaN
# 191                2         NaN
# 192               15         NaN
# 193                0         NaN
# 194               32   -0.117338
# 195                2         NaN
# 196               22         NaN
# 197                4         NaN
# 198                5         NaN
# 199               10         NaN
# #Cuts 47821
#                  Time             Domain Visited Cut Generation  Unsat Nodes  \
#                 count        mean           mean           mean         mean
# Status
# safe               99   29.866359     729.888889     142.989899   829.919192
# safe-incomplete    22    2.111132       0.000000       0.000000     0.000000
# unknown            47  103.371666   24078.489362     716.276596  4889.914894
# unsafe-pgd         32    1.314750       0.000000       0.000000     0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  13.969697
# safe-incomplete        0.000000
# unknown               48.255319
# unsafe-pgd             0.000000
# safe number 121.0
# safe time 24.819953719008264
# safe domain 597.1818181818181
# safe cut 116.99173553719008
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((121.0, 24.819953719008264, 729.8888888888889, 142.989898989899),)

# %%
import pandas as pd

new_headers = ['Column1', 'Column2', 'Column3', 'Status', 'Time']  # Modify as needed

# Load the CSV with custom headers
df = pd.read_csv('cifar100_pyrat.csv', header=None, names=new_headers)

df.groupby('Status').agg({
            'Time': ['count', 'mean'],
        })
# Out:
#          Time
#         count        mean
# Status
# sat        25    6.457840
# unknown   108  111.251915
# unsat      68   42.389024

# %%
new_headers = ['Column1', 'Column2', 'Column3', 'Status', 'Time']  # Modify as needed

# Load the CSV with custom headers
df = pd.read_csv('tinyimagenet.csv', header=None, names=new_headers)

df.groupby('Status').agg({
            'Time': ['count', 'mean'],
        })
# Out:
#          Time
#         count        mean
# Status
# sat        31    6.658420
# unknown   121  111.595317
# unsat      49   55.641629

# %% [markdown]
# # tinyimagenet 2024

# %%
plot_multiple_dfs(
    [
log_read('tinyimagenet/beta.log'),
log_read('tinyimagenet/biccos_only_cs.log'),
log_read('tinyimagenet/biccos_all.log'),
log_read('tinyimagenet/gcp.log'),
log_read('tinyimagenet/biccos_all_selective_mts.log'),
     ],
    [
        'Beta CROWN',
        'biccos_base',
        'Biccos_MTS',
        'GCP-CROWN with MIP cuts',
        'Biccos_auto'
    ],  time_limit=100, dataset='tinyimagenet'
)
# Out:
# /tmp/ipykernel_20992/2956103369.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(dfs))

# %%
main('tinyimagenet/beta.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  27.6563               0               0            0
# 1     safe  22.1909               1               0            0
# 4     safe  23.4299              22               0            0
# 7     safe  29.4149             311               0            0
# 9     safe  25.5656               1               0            0
# 10    safe  26.3134               0               0            0
# 12    safe  27.3122               9               0            0
# 13    safe  25.2682               0               0            0
# 14    safe  27.6233              14               0            0
# 17    safe  27.5000               1               0            0
# 18    safe  26.7579               1               0            0
# 20    safe  38.2063            1602               0            0
# 21    safe  25.8530               0               0            0
# 22    safe  39.2582            3033               0            0
# 23    safe  63.5067           12812               0            0
# 24    safe  22.6335               3               0            0
# 26    safe  23.2712               0               0            0
# 28    safe  22.5766               0               0            0
# 31    safe  26.4204              41               0            0
# 34    safe  27.1103              31               0            0
# 38    safe  25.6029               0               0            0
# 39    safe  33.7728             483               0            0
# 40    safe  37.0542            1233               0            0
# 41    safe  30.2608             335               0            0
# 43    safe  29.0853              59               0            0
# 44    safe  28.8639              14               0            0
# 45    safe  32.9770             510               0            0
# 46    safe  43.1025            3968               0            0
# 49    safe  29.9508              29               0            0
# 50    safe  35.5901            2068               0            0
# 53    safe  30.3794             660               0            0
# 54    safe  25.4390              10               0            0
# 56    safe  46.3503            5757               0            0
# 57    safe  25.9020               9               0            0
# 58    safe  26.4108               0               0            0
# 59    safe  27.8532             127               0            0
# 60    safe  25.8063               1               0            0
# 61    safe  74.8156           17638               0            0
# 62    safe  26.2151               0               0            0
# 64    safe  27.2246              66               0            0
# 66    safe  23.7731               0               0            0
# 67    safe  24.5525               0               0            0
# 68    safe  25.1433              13               0            0
# 69    safe  23.9540               2               0            0
# 73    safe  28.2798              57               0            0
# 76    safe  24.2761               0               0            0
# 77    safe  34.3840             994               0            0
# 78    safe  37.8553             391               0            0
# 79    safe  26.3698               0               0            0
# 80    safe  29.6180             121               0            0
# 83    safe  30.1136              14               0            0
# 84    safe  27.4725               0               0            0
# 86    safe  27.1241               0               0            0
# 89    safe  29.8898              34               0            0
# 90    safe  28.1663               7               0            0
# 91    safe  29.3982              19               0            0
# 92    safe  36.1763            1539               0            0
# 94    safe  27.2075               0               0            0
# 95    safe  27.6122               5               0            0
# 99    safe  28.3623               1               0            0
# 100   safe  27.5352               1               0            0
# 102   safe  29.5830              27               0            0
# 104   safe  30.9788              67               0            0
# 105   safe  37.7971             851               0            0
# 106   safe  28.0141               6               0            0
# 107   safe  31.9016             287               0            0
# 108   safe  29.9331              43               0            0
# 111   safe  29.7129              16               0            0
# 113   safe  27.4516               0               0            0
# 114   safe  28.6767              10               0            0
# 115   safe  31.0993             159               0            0
# 116   safe  27.7333               1               0            0
# 118   safe  27.8527               0               0            0
# 120   safe  32.4422             234               0            0
# 121   safe  29.0777               4               0            0
# 122   safe  28.0178               0               0            0
# 123   safe  28.1074               0               0            0
# 127   safe  79.9275           12671               0            0
# 128   safe  38.1882            1453               0            0
# 130   safe  27.6684               0               0            0
# 132   safe  55.9155            8263               0            0
# 136   safe  35.5443             575               0            0
# 137   safe  44.3259            2086               0            0
# 138   safe  28.4007               0               0            0
# 139   safe  28.2599               0               0            0
# 140   safe  29.8966              86               0            0
# 141   safe  28.8825               1               0            0
# 142   safe  29.1532              13               0            0
# 143   safe  31.9656              69               0            0
# 145   safe  32.5902             304               0            0
# 147   safe  29.1650               9               0            0
# 148   safe  41.0500            1151               0            0
# 150   safe  34.6864             349               0            0
# 152   safe  32.6661             221               0            0
# 153   safe  34.2701             203               0            0
# 154   safe  51.5600            1880               0            0
# 155   safe  82.3016           19698               0            0
# 156   safe  25.9975               0               0            0
# 160   safe  27.4396              44               0            0
# 161   safe  27.3186               4               0            0
# 163   safe  29.4908               8               0            0
# 164   safe  28.0672               4               0            0
# 165   safe  29.2374              33               0            0
# 168   safe  27.2087               0               0            0
# 169   safe  28.9979              32               0            0
# 170   safe  27.5227               0               0            0
# 171   safe  37.1864            1324               0            0
# 172   safe  30.3996             113               0            0
# 173   safe  26.7335               0               0            0
# 174   safe  39.1738            1587               0            0
# 177   safe  31.8881              28               0            0
# 178   safe  29.8805               0               0            0
# 180   safe  24.8419               1               0            0
# 181   safe  34.6943             218               0            0
# 182   safe  26.4346               0               0            0
# 184   safe  25.7887               0               0            0
# 191   safe  36.9382             437               0            0
# 195   safe  39.2945             943               0            0
# 196   safe  30.7598              14               0            0
# 197   safe  30.6287              18               0            0
# 198   safe  35.1470             424               0            0
# 199   safe  35.4824             601               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 1                  3         NaN
# 4                  6         NaN
# 7                 26         NaN
# 9                  2         NaN
# 10                 1         NaN
# 12                 4         NaN
# 13                 1         NaN
# 14                 5         NaN
# 17                 3         NaN
# 18                 2         NaN
# 20                38         NaN
# 21                 1         NaN
# 22                34         NaN
# 23                50         NaN
# 24                 2         NaN
# 26                 2         NaN
# 28                 2         NaN
# 31                15         NaN
# 34                 7         NaN
# 38                 1         NaN
# 39                36         NaN
# 40                37         NaN
# 41                18         NaN
# 43                12         NaN
# 44                10         NaN
# 45                29         NaN
# 46                39         NaN
# 49                13         NaN
# 50                23         NaN
# 53                21         NaN
# 54                 5         NaN
# 56                43         NaN
# 57                 3         NaN
# 58                 1         NaN
# 59                10         NaN
# 60                 2         NaN
# 61                51         NaN
# 62                 3         NaN
# 64                10         NaN
# 66                 1         NaN
# 67                 2         NaN
# 68                 6         NaN
# 69                 2         NaN
# 73                15         NaN
# 76                 1         NaN
# 77                29         NaN
# 78                42         NaN
# 79                 1         NaN
# 80                10         NaN
# 83                13         NaN
# 84                 1         NaN
# 86                 2         NaN
# 89                10         NaN
# 90                 4         NaN
# 91                 7         NaN
# 92                31         NaN
# 94                 1         NaN
# 95                 2         NaN
# 99                 3         NaN
# 100                2         NaN
# 102               12         NaN
# 104               14         NaN
# 105               40         NaN
# 106                4         NaN
# 107               16         NaN
# 108                8         NaN
# 111               10         NaN
# 113                1         NaN
# 114                5         NaN
# 115               14         NaN
# 116                2         NaN
# 118                2         NaN
# 120               20         NaN
# 121                6         NaN
# 122                2         NaN
# 123                1         NaN
# 127              125         NaN
# 128               38         NaN
# 130                1         NaN
# 132               52         NaN
# 136               29         NaN
# 137               57         NaN
# 138                1         NaN
# 139                1         NaN
# 140               10         NaN
# 141                3         NaN
# 142                5         NaN
# 143               15         NaN
# 145               21         NaN
# 147                3         NaN
# 148               46         NaN
# 150               24         NaN
# 152               18         NaN
# 153               22         NaN
# 154               87         NaN
# 155               51         NaN
# 156                1         NaN
# 160                7         NaN
# 161                4         NaN
# 163                5         NaN
# 164                2         NaN
# 165                7         NaN
# 168                1         NaN
# 169                7         NaN
# 170                1         NaN
# 171               31         NaN
# 172               12         NaN
# 173                1         NaN
# 174               35         NaN
# 177               14         NaN
# 178                3         NaN
# 180                2         NaN
# 181               33         NaN
# 182                3         NaN
# 184                2         NaN
# 191               33         NaN
# 195               36         NaN
# 196                7         NaN
# 197                9         NaN
# 198               25         NaN
# 199               24         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 8    unknown  102.4097           31764               0            0
# 32   unknown  100.6561           27182               0            0
# 52   unknown  101.2561           38571               0            0
# 63   unknown  101.5467           41108               0            0
# 65   unknown  102.4249           38831               0            0
# 82   unknown  102.7495           50130               0            0
# 85   unknown  103.3100           27687               0            0
# 87   unknown  102.2553           48457               0            0
# 98   unknown  100.8143           34738               0            0
# 101  unknown  101.9018           44470               0            0
# 103  unknown  101.0955           47925               0            0
# 110  unknown  103.1567           46998               0            0
# 117  unknown  102.4345           34585               0            0
# 126  unknown  102.4538           38989               0            0
# 144  unknown  100.6332           45181               0            0
# 157  unknown  103.0405           44930               0            0
# 162  unknown  102.1010           43260               0            0
# 167  unknown  100.9080           38611               0            0
# 187  unknown  103.0765           33173               0            0
# 189  unknown  101.8440           34302               0            0
# 190  unknown  101.3843           34405               0            0
# 192  unknown  101.0380           45842               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 8                 69   -0.207836
# 32               126   -0.589068
# 52                62   -0.079027
# 63                37   -0.125319
# 65                49   -0.090776
# 82                46   -0.187735
# 85               100   -0.648044
# 87                51   -0.283464
# 98                56   -0.133847
# 101               39   -0.746526
# 103               50   -0.231339
# 110               48   -0.345923
# 117               55   -0.238760
# 126               56   -0.100060
# 144               48   -0.209374
# 157               47   -0.590435
# 162               57   -0.258974
# 167               63   -0.487476
# 187               68   -0.309451
# 189               50   -0.183814
# 190               52   -0.180467
# 192               50   -0.520152
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   27.6563               0               0            0
# 1               safe   22.1909               1               0            0
# 2         unsafe-pgd    1.3772               0               0            0
# 3         unsafe-pgd    1.3244               0               0            0
# 4               safe   23.4299              22               0            0
# 5         unsafe-pgd    1.3582               0               0            0
# 6         unsafe-pgd    1.3124               0               0            0
# 7               safe   29.4149             311               0            0
# 8            unknown  102.4097           31764               0            0
# 9               safe   25.5656               1               0            0
# 10              safe   26.3134               0               0            0
# 11        unsafe-pgd    1.1645               0               0            0
# 12              safe   27.3122               9               0            0
# 13              safe   25.2682               0               0            0
# 14              safe   27.6233              14               0            0
# 15        unsafe-pgd    1.3865               0               0            0
# 16        unsafe-pgd    1.7070               0               0            0
# 17              safe   27.5000               1               0            0
# 18              safe   26.7579               1               0            0
# 19        unsafe-pgd    1.2682               0               0            0
# 20              safe   38.2063            1602               0            0
# 21              safe   25.8530               0               0            0
# 22              safe   39.2582            3033               0            0
# 23              safe   63.5067           12812               0            0
# 24              safe   22.6335               3               0            0
# 25        unsafe-pgd    1.3588               0               0            0
# 26              safe   23.2712               0               0            0
# 27        unsafe-pgd    1.2012               0               0            0
# 28              safe   22.5766               0               0            0
# 29        unsafe-pgd    0.9651               0               0            0
# 30        unsafe-pgd    1.4265               0               0            0
# 31              safe   26.4204              41               0            0
# 32           unknown  100.6561           27182               0            0
# 33        unsafe-pgd    1.2404               0               0            0
# 34              safe   27.1103              31               0            0
# 35        unsafe-pgd    1.5728               0               0            0
# 36        unsafe-pgd    1.8860               0               0            0
# 37        unsafe-pgd    1.4723               0               0            0
# 38              safe   25.6029               0               0            0
# 39              safe   33.7728             483               0            0
# 40              safe   37.0542            1233               0            0
# 41              safe   30.2608             335               0            0
# 42   safe-incomplete    1.5621               0               0            0
# 43              safe   29.0853              59               0            0
# 44              safe   28.8639              14               0            0
# 45              safe   32.9770             510               0            0
# 46              safe   43.1025            3968               0            0
# 47        unsafe-pgd    1.2097               0               0            0
# 48        unsafe-pgd    1.2823               0               0            0
# 49              safe   29.9508              29               0            0
# 50              safe   35.5901            2068               0            0
# 51        unsafe-pgd    1.6073               0               0            0
# 52           unknown  101.2561           38571               0            0
# 53              safe   30.3794             660               0            0
# 54              safe   25.4390              10               0            0
# 55        unsafe-pgd    1.0861               0               0            0
# 56              safe   46.3503            5757               0            0
# 57              safe   25.9020               9               0            0
# 58              safe   26.4108               0               0            0
# 59              safe   27.8532             127               0            0
# 60              safe   25.8063               1               0            0
# 61              safe   74.8156           17638               0            0
# 62              safe   26.2151               0               0            0
# 63           unknown  101.5467           41108               0            0
# 64              safe   27.2246              66               0            0
# 65           unknown  102.4249           38831               0            0
# 66              safe   23.7731               0               0            0
# 67              safe   24.5525               0               0            0
# 68              safe   25.1433              13               0            0
# 69              safe   23.9540               2               0            0
# 70        unsafe-pgd    1.3751               0               0            0
# 71        unsafe-pgd    1.3094               0               0            0
# 72        unsafe-pgd    1.2763               0               0            0
# 73              safe   28.2798              57               0            0
# 74   safe-incomplete    0.9168               0               0            0
# 75        unsafe-pgd    1.6627               0               0            0
# 76              safe   24.2761               0               0            0
# 77              safe   34.3840             994               0            0
# 78              safe   37.8553             391               0            0
# 79              safe   26.3698               0               0            0
# 80              safe   29.6180             121               0            0
# 81        unsafe-pgd    2.1478               0               0            0
# 82           unknown  102.7495           50130               0            0
# 83              safe   30.1136              14               0            0
# 84              safe   27.4725               0               0            0
# 85           unknown  103.3100           27687               0            0
# 86              safe   27.1241               0               0            0
# 87           unknown  102.2553           48457               0            0
# 88   safe-incomplete    0.7262               0               0            0
# 89              safe   29.8898              34               0            0
# 90              safe   28.1663               7               0            0
# 91              safe   29.3982              19               0            0
# 92              safe   36.1763            1539               0            0
# 93   safe-incomplete    1.7126               0               0            0
# 94              safe   27.2075               0               0            0
# 95              safe   27.6122               5               0            0
# 96        unsafe-pgd    1.3561               0               0            0
# 97        unsafe-pgd    1.5868               0               0            0
# 98           unknown  100.8143           34738               0            0
# 99              safe   28.3623               1               0            0
# 100             safe   27.5352               1               0            0
# 101          unknown  101.9018           44470               0            0
# 102             safe   29.5830              27               0            0
# 103          unknown  101.0955           47925               0            0
# 104             safe   30.9788              67               0            0
# 105             safe   37.7971             851               0            0
# 106             safe   28.0141               6               0            0
# 107             safe   31.9016             287               0            0
# 108             safe   29.9331              43               0            0
# 109       unsafe-pgd    1.1938               0               0            0
# 110          unknown  103.1567           46998               0            0
# 111             safe   29.7129              16               0            0
# 112       unsafe-pgd    1.1975               0               0            0
# 113             safe   27.4516               0               0            0
# 114             safe   28.6767              10               0            0
# 115             safe   31.0993             159               0            0
# 116             safe   27.7333               1               0            0
# 117          unknown  102.4345           34585               0            0
# 118             safe   27.8527               0               0            0
# 119       unsafe-pgd    1.1108               0               0            0
# 120             safe   32.4422             234               0            0
# 121             safe   29.0777               4               0            0
# 122             safe   28.0178               0               0            0
# 123             safe   28.1074               0               0            0
# 124       unsafe-pgd    1.5006               0               0            0
# 125  safe-incomplete    1.5213               0               0            0
# 126          unknown  102.4538           38989               0            0
# 127             safe   79.9275           12671               0            0
# 128             safe   38.1882            1453               0            0
# 129       unsafe-pgd    1.5032               0               0            0
# 130             safe   27.6684               0               0            0
# 131  safe-incomplete    1.7742               0               0            0
# 132             safe   55.9155            8263               0            0
# 133       unsafe-pgd    2.7166               0               0            0
# 134       unsafe-pgd    1.8173               0               0            0
# 135       unsafe-pgd    1.4511               0               0            0
# 136             safe   35.5443             575               0            0
# 137             safe   44.3259            2086               0            0
# 138             safe   28.4007               0               0            0
# 139             safe   28.2599               0               0            0
# 140             safe   29.8966              86               0            0
# 141             safe   28.8825               1               0            0
# 142             safe   29.1532              13               0            0
# 143             safe   31.9656              69               0            0
# 144          unknown  100.6332           45181               0            0
# 145             safe   32.5902             304               0            0
# 146  safe-incomplete    1.7822               0               0            0
# 147             safe   29.1650               9               0            0
# 148             safe   41.0500            1151               0            0
# 149  safe-incomplete    1.7624               0               0            0
# 150             safe   34.6864             349               0            0
# 151  safe-incomplete    1.6035               0               0            0
# 152             safe   32.6661             221               0            0
# 153             safe   34.2701             203               0            0
# 154             safe   51.5600            1880               0            0
# 155             safe   82.3016           19698               0            0
# 156             safe   25.9975               0               0            0
# 157          unknown  103.0405           44930               0            0
# 158       unsafe-pgd    1.3438               0               0            0
# 159       unsafe-pgd    1.3185               0               0            0
# 160             safe   27.4396              44               0            0
# 161             safe   27.3186               4               0            0
# 162          unknown  102.1010           43260               0            0
# 163             safe   29.4908               8               0            0
# 164             safe   28.0672               4               0            0
# 165             safe   29.2374              33               0            0
# 166       unsafe-pgd    2.5828               0               0            0
# 167          unknown  100.9080           38611               0            0
# 168             safe   27.2087               0               0            0
# 169             safe   28.9979              32               0            0
# 170             safe   27.5227               0               0            0
# 171             safe   37.1864            1324               0            0
# 172             safe   30.3996             113               0            0
# 173             safe   26.7335               0               0            0
# 174             safe   39.1738            1587               0            0
# 175  safe-incomplete    1.4192               0               0            0
# 176  safe-incomplete    1.5076               0               0            0
# 177             safe   31.8881              28               0            0
# 178             safe   29.8805               0               0            0
# 179  safe-incomplete    1.7074               0               0            0
# 180             safe   24.8419               1               0            0
# 181             safe   34.6943             218               0            0
# 182             safe   26.4346               0               0            0
# 183       unsafe-pgd    1.4097               0               0            0
# 184             safe   25.7887               0               0            0
# 185  safe-incomplete    1.4361               0               0            0
# 186       unsafe-pgd    1.2540               0               0            0
# 187          unknown  103.0765           33173               0            0
# 188       unsafe-pgd    1.3099               0               0            0
# 189          unknown  101.8440           34302               0            0
# 190          unknown  101.3843           34405               0            0
# 191             safe   36.9382             437               0            0
# 192          unknown  101.0380           45842               0            0
# 193       unsafe-pgd    1.1596               0               0            0
# 194       unsafe-pgd    1.3716               0               0            0
# 195             safe   39.2945             943               0            0
# 196             safe   30.7598              14               0            0
# 197             safe   30.6287              18               0            0
# 198             safe   35.1470             424               0            0
# 199             safe   35.4824             601               0            0
#
#      BaB Round Count  BaB_lb_rhs
# 0                  2         NaN
# 1                  3         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  6         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 26         NaN
# 8                 69   -0.207836
# 9                  2         NaN
# 10                 1         NaN
# 11                 0         NaN
# 12                 4         NaN
# 13                 1         NaN
# 14                 5         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 3         NaN
# 18                 2         NaN
# 19                 0         NaN
# 20                38         NaN
# 21                 1         NaN
# 22                34         NaN
# 23                50         NaN
# 24                 2         NaN
# 25                 0         NaN
# 26                 2         NaN
# 27                 0         NaN
# 28                 2         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                15         NaN
# 32               126   -0.589068
# 33                 0         NaN
# 34                 7         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 1         NaN
# 39                36         NaN
# 40                37         NaN
# 41                18         NaN
# 42                 0         NaN
# 43                12         NaN
# 44                10         NaN
# 45                29         NaN
# 46                39         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                13         NaN
# 50                23         NaN
# 51                 0         NaN
# 52                62   -0.079027
# 53                21         NaN
# 54                 5         NaN
# 55                 0         NaN
# 56                43         NaN
# 57                 3         NaN
# 58                 1         NaN
# 59                10         NaN
# 60                 2         NaN
# 61                51         NaN
# 62                 3         NaN
# 63                37   -0.125319
# 64                10         NaN
# 65                49   -0.090776
# 66                 1         NaN
# 67                 2         NaN
# 68                 6         NaN
# 69                 2         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                15         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 1         NaN
# 77                29         NaN
# 78                42         NaN
# 79                 1         NaN
# 80                10         NaN
# 81                 0         NaN
# 82                46   -0.187735
# 83                13         NaN
# 84                 1         NaN
# 85               100   -0.648044
# 86                 2         NaN
# 87                51   -0.283464
# 88                 0         NaN
# 89                10         NaN
# 90                 4         NaN
# 91                 7         NaN
# 92                31         NaN
# 93                 0         NaN
# 94                 1         NaN
# 95                 2         NaN
# 96                 0         NaN
# 97                 0         NaN
# 98                56   -0.133847
# 99                 3         NaN
# 100                2         NaN
# 101               39   -0.746526
# 102               12         NaN
# 103               50   -0.231339
# 104               14         NaN
# 105               40         NaN
# 106                4         NaN
# 107               16         NaN
# 108                8         NaN
# 109                0         NaN
# 110               48   -0.345923
# 111               10         NaN
# 112                0         NaN
# 113                1         NaN
# 114                5         NaN
# 115               14         NaN
# 116                2         NaN
# 117               55   -0.238760
# 118                2         NaN
# 119                0         NaN
# 120               20         NaN
# 121                6         NaN
# 122                2         NaN
# 123                1         NaN
# 124                0         NaN
# 125                0         NaN
# 126               56   -0.100060
# 127              125         NaN
# 128               38         NaN
# 129                0         NaN
# 130                1         NaN
# 131                0         NaN
# 132               52         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136               29         NaN
# 137               57         NaN
# 138                1         NaN
# 139                1         NaN
# 140               10         NaN
# 141                3         NaN
# 142                5         NaN
# 143               15         NaN
# 144               48   -0.209374
# 145               21         NaN
# 146                0         NaN
# 147                3         NaN
# 148               46         NaN
# 149                0         NaN
# 150               24         NaN
# 151                0         NaN
# 152               18         NaN
# 153               22         NaN
# 154               87         NaN
# 155               51         NaN
# 156                1         NaN
# 157               47   -0.590435
# 158                0         NaN
# 159                0         NaN
# 160                7         NaN
# 161                4         NaN
# 162               57   -0.258974
# 163                5         NaN
# 164                2         NaN
# 165                7         NaN
# 166                0         NaN
# 167               63   -0.487476
# 168                1         NaN
# 169                7         NaN
# 170                1         NaN
# 171               31         NaN
# 172               12         NaN
# 173                1         NaN
# 174               35         NaN
# 175                0         NaN
# 176                0         NaN
# 177               14         NaN
# 178                3         NaN
# 179                0         NaN
# 180                2         NaN
# 181               33         NaN
# 182                3         NaN
# 183                0         NaN
# 184                2         NaN
# 185                0         NaN
# 186                0         NaN
# 187               68   -0.309451
# 188                0         NaN
# 189               50   -0.183814
# 190               52   -0.180467
# 191               33         NaN
# 192               50   -0.520152
# 193                0         NaN
# 194                0         NaN
# 195               36         NaN
# 196                7         NaN
# 197                9         NaN
# 198               25         NaN
# 199               24         NaN
# #Cuts 0
#                  Time             Domain Visited Cut Generation Unsat Nodes  \
#                 count        mean           mean           mean        mean
# Status
# safe              122   31.796219     906.696721            0.0         0.0
# safe-incomplete    13    1.494738       0.000000            0.0         0.0
# unknown            22  101.931382   39597.227273            0.0         0.0
# unsafe-pgd         43    1.445626       0.000000            0.0         0.0
#
#                 BaB Round Count
#                            mean
# Status
# safe                  14.991803
# safe-incomplete        0.000000
# unknown               58.136364
# unsafe-pgd             0.000000
# safe number 135.0
# safe time 28.878298518518516
# safe domain 819.3851851851852
# safe cut 0.0
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((135.0, 28.878298518518516, 906.6967213114754, 0.0),)

# %%
main('tinyimagenet/biccos_only_cs.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  17.8246              50              19          496
# 1     safe  12.5417             100              32          788
# 4     safe  10.2682             116              11          378
# 7     safe  16.7402             309             590          537
# 8     safe  49.8977           10203             826         4003
# 9     safe   6.9767              50               9          227
# 10    safe   6.8701              50              13          416
# 12    safe   8.8871             102              44          416
# 13    safe   7.5588              50               8          192
# 14    safe   8.7868             103              51          431
# 17    safe   9.7881              50              22          569
# 18    safe   7.8328             100              20          416
# 20    safe  25.9963            1270             214         1224
# 21    safe   7.0167              50              17          410
# 22    safe  23.6722            1141             318          996
# 23    safe  35.6883            2769             816         1778
# 24    safe   7.8173             100              18          416
# 26    safe  10.0274              50              19          436
# 28    safe   9.3230               0               1           80
# 31    safe   9.2108              41              54          152
# 34    safe  12.1133             139              21          377
# 38    safe   7.0163              50              19          415
# 39    safe  24.2917             622             293          995
# 40    safe  20.7307            1016              93          542
# 41    safe  14.5379             387             181          554
# 43    safe  14.7495             215              68          827
# 44    safe   8.0583              14              19          106
# 45    safe  14.2148             440              84          353
# 46    safe  25.1839            2651             252         1814
# 49    safe   9.5501              29              32           87
# 50    safe  14.9454            1418             191         1007
# 53    safe  16.4193             463             160          572
# 54    safe  10.5196             105              62          410
# 56    safe  26.2205            2393             164         1627
# 57    safe   9.0322             102              34          409
# 58    safe   7.9295              50              18          416
# 59    safe  14.2061             296              42          622
# 60    safe   7.5969              50              12          335
# 61    safe  47.2119            7967             512         4577
# 62    safe   5.4700               0               0           16
# 64    safe  12.8277             184              34          606
# 66    safe   7.5559              50              10          416
# 67    safe  11.3262              50              11          625
# 68    safe   6.3581              13              10           53
# 69    safe   7.0736              50              10          296
# 73    safe  11.2311              56              67          122
# 76    safe   7.8082              50              29          416
# 77    safe  18.1217             525             107          470
# 78    safe  22.2730             377             107          423
# 79    safe   6.5336               0               1           42
# 80    safe  12.5308             199              58          418
# 83    safe  10.3934              14              22          155
# 84    safe   8.7962             100              19          416
# 85    safe  76.6600           13546             437         9041
# 86    safe  11.4520              50              34          810
# 89    safe  10.3431              34               8           74
# 90    safe  11.6013             100              77          832
# 91    safe  13.3520             109              46          459
# 92    safe  18.6091             754             139          882
# 94    safe   8.0728              50              15          387
# 95    safe   7.9608              50              13          337
# 98    safe  23.7965            2399             229         1623
# 99    safe  11.3476              50              37          677
# 100   safe   7.5887             100              21          416
# 102   safe   8.0656              26              21           82
# 104   safe  14.5203             246             130          481
# 105   safe  19.3813             777             329          971
# 106   safe   7.8803             100              28          264
# 107   safe  12.8076             221              65          698
# 108   safe  10.7233             111              67          435
# 111   safe   7.5766              16              27           92
# 113   safe   7.0827              50               6          320
# 114   safe  11.4341             235              50          527
# 115   safe   8.9011             139              13          143
# 116   safe   7.5469              50              14          383
# 118   safe  10.4667              50              12          481
# 120   safe  13.6473             237             112          461
# 121   safe   6.8552               4               6           48
# 122   safe  10.3702              50               6          352
# 123   safe   7.6391              50              13          416
# 127   safe  53.7433            4382             544         2655
# 128   safe  20.3116            1022             145          646
# 130   safe   7.5006               0               1           16
# 132   safe  23.3614            2385             193         1667
# 136   safe  21.6420             430              91         1129
# 137   safe  22.1401            1040             289          701
# 138   safe   6.6628               0               1          234
# 139   safe   8.2083             100              30          416
# 140   safe  11.5204             173             108          459
# 141   safe  11.0531              50              31          816
# 142   safe   9.9904             104              48          412
# 143   safe   9.3001              62              82          108
# 145   safe  10.6140             208              75          151
# 147   safe   8.5397             100              44          416
# 148   safe  17.1827             808             215          537
# 150   safe  19.4665             409             493          901
# 152   safe  16.6491             241              19          369
# 153   safe  11.8707             156              97          107
# 154   safe  36.4488            1600             335         1131
# 155   safe  25.0075            2352             231         1784
# 156   safe   7.7039              50              27          416
# 160   safe  10.8094             127              57          711
# 161   safe  11.0477             100              25          441
# 163   safe  11.7811             124              31          662
# 164   safe   8.1445             100              13          386
# 165   safe  13.1369             157              98          786
# 168   safe   6.7217               0               1          150
# 169   safe  10.0050             112              39          413
# 170   safe   6.3909               0               1          416
# 171   safe  23.4677             775             160         1096
# 172   safe  16.0393             267             101          657
# 173   safe   6.0770               0               1           38
# 174   safe  16.0828            1019             183          646
# 177   safe   9.9469              28              37          106
# 178   safe   6.2623               0               0           16
# 180   safe   6.6330              50              21          416
# 181   safe  16.2316             198             132          286
# 182   safe   5.4150               0               0           16
# 184   safe  10.1949              50              18          483
# 189   safe  97.8045           19925            3928        11450
# 190   safe  72.8804           17551             771         8680
# 191   safe  13.8887             350             142          282
# 195   safe  17.6023             848             150          540
# 196   safe  11.9256             102             147          830
# 197   safe   7.6877              18              14           91
# 198   safe  11.7528             300              76          230
# 199   safe  18.9607             422             100          834
#
#      BaB Round Count  BaB_lb_rhs
# 0                  5         NaN
# 1                  7         NaN
# 4                  8         NaN
# 7                 27         NaN
# 8                 44         NaN
# 9                  3         NaN
# 10                 3         NaN
# 12                 6         NaN
# 13                 3         NaN
# 14                 6         NaN
# 17                 5         NaN
# 18                 4         NaN
# 20                42         NaN
# 21                 3         NaN
# 22                38         NaN
# 23                56         NaN
# 24                 4         NaN
# 26                 5         NaN
# 28                 4         NaN
# 31                15         NaN
# 34                 8         NaN
# 38                 3         NaN
# 39                41         NaN
# 40                34         NaN
# 41                21         NaN
# 43                12         NaN
# 44                10         NaN
# 45                27         NaN
# 46                40         NaN
# 49                13         NaN
# 50                22         NaN
# 53                24         NaN
# 54                 7         NaN
# 56                46         NaN
# 57                 5         NaN
# 58                 3         NaN
# 59                15         NaN
# 60                 3         NaN
# 61                39         NaN
# 62                 3         NaN
# 64                11         NaN
# 66                 3         NaN
# 67                 6         NaN
# 68                 6         NaN
# 69                 3         NaN
# 73                15         NaN
# 76                 3         NaN
# 77                30         NaN
# 78                41         NaN
# 79                 2         NaN
# 80                12         NaN
# 83                13         NaN
# 84                 4         NaN
# 85                93         NaN
# 86                 6         NaN
# 89                10         NaN
# 90                 7         NaN
# 91                 9         NaN
# 92                30         NaN
# 94                 3         NaN
# 95                 3         NaN
# 98                38         NaN
# 99                 6         NaN
# 100                4         NaN
# 102               12         NaN
# 104               17         NaN
# 105               35         NaN
# 106                4         NaN
# 107               15         NaN
# 108                8         NaN
# 111               10         NaN
# 113                3         NaN
# 114                9         NaN
# 115               13         NaN
# 116                3         NaN
# 118                5         NaN
# 120               18         NaN
# 121                6         NaN
# 122                5         NaN
# 123                3         NaN
# 127              117         NaN
# 128               36         NaN
# 130                2         NaN
# 132               49         NaN
# 136               27         NaN
# 137               53         NaN
# 138                2         NaN
# 139                4         NaN
# 140               10         NaN
# 141                6         NaN
# 142                6         NaN
# 143               14         NaN
# 145               18         NaN
# 147                4         NaN
# 148               44         NaN
# 150               28         NaN
# 152               19         NaN
# 153               18         NaN
# 154               83         NaN
# 155               41         NaN
# 156                3         NaN
# 160                8         NaN
# 161                6         NaN
# 163                7         NaN
# 164                4         NaN
# 165                9         NaN
# 168                2         NaN
# 169                7         NaN
# 170                2         NaN
# 171               34         NaN
# 172               15         NaN
# 173                2         NaN
# 174               32         NaN
# 177               14         NaN
# 178                3         NaN
# 180                3         NaN
# 181               32         NaN
# 182                3         NaN
# 184                5         NaN
# 189               69         NaN
# 190               55         NaN
# 191               29         NaN
# 195               36         NaN
# 196                9         NaN
# 197                9         NaN
# 198               22         NaN
# 199               25         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 32   unknown  101.7050           20497            1483         9297
# 52   unknown  101.5764           29892             960         6760
# 63   unknown  107.2471           41699             581         4103
# 65   unknown  101.0205           34778             314         6246
# 82   unknown  102.5251           39443             803         4198
# 87   unknown  102.0410           38826             530         8176
# 101  unknown  100.9471           40247             693         7235
# 103  unknown  102.4002           31864            1072         9905
# 110  unknown  103.9615           42626             639         6201
# 117  unknown  101.2546           27812            1227         8691
# 126  unknown  103.5790           33273             446         9634
# 144  unknown  103.7496           38435             534         7204
# 157  unknown  103.3896           36984            1114        11742
# 162  unknown  101.8221           26457            2049        12694
# 167  unknown  103.1728           29998             701        11540
# 187  unknown  102.9262           28393             393        10420
# 192  unknown  101.0217           31145            1968         9654
#
#      BaB Round Count  BaB_lb_rhs
# 32               121   -0.493498
# 52                74   -0.361196
# 63                39   -0.113261
# 65                52   -0.054759
# 82                42   -0.166406
# 87                44   -0.215667
# 101               38   -0.550841
# 103               40   -0.196258
# 110               40   -0.310305
# 117               52   -0.123688
# 126               55   -0.047071
# 144               42   -0.181848
# 157               47   -0.506168
# 162               51   -0.175007
# 167               72   -0.063182
# 187               68   -0.144534
# 192               40   -0.407837
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   17.8246              50              19          496
# 1               safe   12.5417             100              32          788
# 2         unsafe-pgd    1.3881               0               0            0
# 3         unsafe-pgd    1.1675               0               0            0
# 4               safe   10.2682             116              11          378
# 5         unsafe-pgd    1.4474               0               0            0
# 6         unsafe-pgd    1.8795               0               0            0
# 7               safe   16.7402             309             590          537
# 8               safe   49.8977           10203             826         4003
# 9               safe    6.9767              50               9          227
# 10              safe    6.8701              50              13          416
# 11        unsafe-pgd    1.3334               0               0            0
# 12              safe    8.8871             102              44          416
# 13              safe    7.5588              50               8          192
# 14              safe    8.7868             103              51          431
# 15        unsafe-pgd    1.2841               0               0            0
# 16        unsafe-pgd    1.5490               0               0            0
# 17              safe    9.7881              50              22          569
# 18              safe    7.8328             100              20          416
# 19        unsafe-pgd    1.3528               0               0            0
# 20              safe   25.9963            1270             214         1224
# 21              safe    7.0167              50              17          410
# 22              safe   23.6722            1141             318          996
# 23              safe   35.6883            2769             816         1778
# 24              safe    7.8173             100              18          416
# 25        unsafe-pgd    1.2734               0               0            0
# 26              safe   10.0274              50              19          436
# 27        unsafe-pgd    1.3601               0               0            0
# 28              safe    9.3230               0               1           80
# 29        unsafe-pgd    0.7768               0               0            0
# 30        unsafe-pgd    1.5020               0               0            0
# 31              safe    9.2108              41              54          152
# 32           unknown  101.7050           20497            1483         9297
# 33        unsafe-pgd    1.2629               0               0            0
# 34              safe   12.1133             139              21          377
# 35        unsafe-pgd    1.5782               0               0            0
# 36        unsafe-pgd    1.6945               0               0            0
# 37        unsafe-pgd    1.1159               0               0            0
# 38              safe    7.0163              50              19          415
# 39              safe   24.2917             622             293          995
# 40              safe   20.7307            1016              93          542
# 41              safe   14.5379             387             181          554
# 42   safe-incomplete    1.3156               0               0            0
# 43              safe   14.7495             215              68          827
# 44              safe    8.0583              14              19          106
# 45              safe   14.2148             440              84          353
# 46              safe   25.1839            2651             252         1814
# 47        unsafe-pgd    1.2228               0               0            0
# 48        unsafe-pgd    1.6020               0               0            0
# 49              safe    9.5501              29              32           87
# 50              safe   14.9454            1418             191         1007
# 51        unsafe-pgd    1.9725               0               0            0
# 52           unknown  101.5764           29892             960         6760
# 53              safe   16.4193             463             160          572
# 54              safe   10.5196             105              62          410
# 55        unsafe-pgd    1.1517               0               0            0
# 56              safe   26.2205            2393             164         1627
# 57              safe    9.0322             102              34          409
# 58              safe    7.9295              50              18          416
# 59              safe   14.2061             296              42          622
# 60              safe    7.5969              50              12          335
# 61              safe   47.2119            7967             512         4577
# 62              safe    5.4700               0               0           16
# 63           unknown  107.2471           41699             581         4103
# 64              safe   12.8277             184              34          606
# 65           unknown  101.0205           34778             314         6246
# 66              safe    7.5559              50              10          416
# 67              safe   11.3262              50              11          625
# 68              safe    6.3581              13              10           53
# 69              safe    7.0736              50              10          296
# 70        unsafe-pgd    1.8005               0               0            0
# 71        unsafe-pgd    2.1553               0               0            0
# 72        unsafe-pgd    1.6014               0               0            0
# 73              safe   11.2311              56              67          122
# 74   safe-incomplete    0.9554               0               0            0
# 75        unsafe-pgd    1.7931               0               0            0
# 76              safe    7.8082              50              29          416
# 77              safe   18.1217             525             107          470
# 78              safe   22.2730             377             107          423
# 79              safe    6.5336               0               1           42
# 80              safe   12.5308             199              58          418
# 81        unsafe-pgd    2.4337               0               0            0
# 82           unknown  102.5251           39443             803         4198
# 83              safe   10.3934              14              22          155
# 84              safe    8.7962             100              19          416
# 85              safe   76.6600           13546             437         9041
# 86              safe   11.4520              50              34          810
# 87           unknown  102.0410           38826             530         8176
# 88   safe-incomplete    0.7713               0               0            0
# 89              safe   10.3431              34               8           74
# 90              safe   11.6013             100              77          832
# 91              safe   13.3520             109              46          459
# 92              safe   18.6091             754             139          882
# 93   safe-incomplete    1.9635               0               0            0
# 94              safe    8.0728              50              15          387
# 95              safe    7.9608              50              13          337
# 96        unsafe-pgd    1.7402               0               0            0
# 97        unsafe-pgd    1.2490               0               0            0
# 98              safe   23.7965            2399             229         1623
# 99              safe   11.3476              50              37          677
# 100             safe    7.5887             100              21          416
# 101          unknown  100.9471           40247             693         7235
# 102             safe    8.0656              26              21           82
# 103          unknown  102.4002           31864            1072         9905
# 104             safe   14.5203             246             130          481
# 105             safe   19.3813             777             329          971
# 106             safe    7.8803             100              28          264
# 107             safe   12.8076             221              65          698
# 108             safe   10.7233             111              67          435
# 109       unsafe-pgd    1.4501               0               0            0
# 110          unknown  103.9615           42626             639         6201
# 111             safe    7.5766              16              27           92
# 112       unsafe-pgd    1.3393               0               0            0
# 113             safe    7.0827              50               6          320
# 114             safe   11.4341             235              50          527
# 115             safe    8.9011             139              13          143
# 116             safe    7.5469              50              14          383
# 117          unknown  101.2546           27812            1227         8691
# 118             safe   10.4667              50              12          481
# 119       unsafe-pgd    1.1344               0               0            0
# 120             safe   13.6473             237             112          461
# 121             safe    6.8552               4               6           48
# 122             safe   10.3702              50               6          352
# 123             safe    7.6391              50              13          416
# 124       unsafe-pgd    1.8377               0               0            0
# 125  safe-incomplete    2.3578               0               0            0
# 126          unknown  103.5790           33273             446         9634
# 127             safe   53.7433            4382             544         2655
# 128             safe   20.3116            1022             145          646
# 129       unsafe-pgd    2.2132               0               0            0
# 130             safe    7.5006               0               1           16
# 131  safe-incomplete    1.7067               0               0            0
# 132             safe   23.3614            2385             193         1667
# 133       unsafe-pgd    2.9571               0               0            0
# 134       unsafe-pgd    1.3817               0               0            0
# 135       unsafe-pgd    1.4083               0               0            0
# 136             safe   21.6420             430              91         1129
# 137             safe   22.1401            1040             289          701
# 138             safe    6.6628               0               1          234
# 139             safe    8.2083             100              30          416
# 140             safe   11.5204             173             108          459
# 141             safe   11.0531              50              31          816
# 142             safe    9.9904             104              48          412
# 143             safe    9.3001              62              82          108
# 144          unknown  103.7496           38435             534         7204
# 145             safe   10.6140             208              75          151
# 146  safe-incomplete    1.6854               0               0            0
# 147             safe    8.5397             100              44          416
# 148             safe   17.1827             808             215          537
# 149  safe-incomplete    2.0731               0               0            0
# 150             safe   19.4665             409             493          901
# 151  safe-incomplete    1.9008               0               0            0
# 152             safe   16.6491             241              19          369
# 153             safe   11.8707             156              97          107
# 154             safe   36.4488            1600             335         1131
# 155             safe   25.0075            2352             231         1784
# 156             safe    7.7039              50              27          416
# 157          unknown  103.3896           36984            1114        11742
# 158       unsafe-pgd    1.7934               0               0            0
# 159       unsafe-pgd    1.9078               0               0            0
# 160             safe   10.8094             127              57          711
# 161             safe   11.0477             100              25          441
# 162          unknown  101.8221           26457            2049        12694
# 163             safe   11.7811             124              31          662
# 164             safe    8.1445             100              13          386
# 165             safe   13.1369             157              98          786
# 166       unsafe-pgd    2.6090               0               0            0
# 167          unknown  103.1728           29998             701        11540
# 168             safe    6.7217               0               1          150
# 169             safe   10.0050             112              39          413
# 170             safe    6.3909               0               1          416
# 171             safe   23.4677             775             160         1096
# 172             safe   16.0393             267             101          657
# 173             safe    6.0770               0               1           38
# 174             safe   16.0828            1019             183          646
# 175  safe-incomplete    1.7850               0               0            0
# 176  safe-incomplete    1.5739               0               0            0
# 177             safe    9.9469              28              37          106
# 178             safe    6.2623               0               0           16
# 179  safe-incomplete    1.9087               0               0            0
# 180             safe    6.6330              50              21          416
# 181             safe   16.2316             198             132          286
# 182             safe    5.4150               0               0           16
# 183       unsafe-pgd    1.5275               0               0            0
# 184             safe   10.1949              50              18          483
# 185  safe-incomplete    1.5268               0               0            0
# 186       unsafe-pgd    1.3731               0               0            0
# 187          unknown  102.9262           28393             393        10420
# 188       unsafe-pgd    1.2486               0               0            0
# 189             safe   97.8045           19925            3928        11450
# 190             safe   72.8804           17551             771         8680
# 191             safe   13.8887             350             142          282
# 192          unknown  101.0217           31145            1968         9654
# 193       unsafe-pgd    1.4063               0               0            0
# 194       unsafe-pgd    1.7214               0               0            0
# 195             safe   17.6023             848             150          540
# 196             safe   11.9256             102             147          830
# 197             safe    7.6877              18              14           91
# 198             safe   11.7528             300              76          230
# 199             safe   18.9607             422             100          834
#
#      BaB Round Count  BaB_lb_rhs
# 0                  5         NaN
# 1                  7         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  8         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 27         NaN
# 8                 44         NaN
# 9                  3         NaN
# 10                 3         NaN
# 11                 0         NaN
# 12                 6         NaN
# 13                 3         NaN
# 14                 6         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 5         NaN
# 18                 4         NaN
# 19                 0         NaN
# 20                42         NaN
# 21                 3         NaN
# 22                38         NaN
# 23                56         NaN
# 24                 4         NaN
# 25                 0         NaN
# 26                 5         NaN
# 27                 0         NaN
# 28                 4         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                15         NaN
# 32               121   -0.493498
# 33                 0         NaN
# 34                 8         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 3         NaN
# 39                41         NaN
# 40                34         NaN
# 41                21         NaN
# 42                 0         NaN
# 43                12         NaN
# 44                10         NaN
# 45                27         NaN
# 46                40         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                13         NaN
# 50                22         NaN
# 51                 0         NaN
# 52                74   -0.361196
# 53                24         NaN
# 54                 7         NaN
# 55                 0         NaN
# 56                46         NaN
# 57                 5         NaN
# 58                 3         NaN
# 59                15         NaN
# 60                 3         NaN
# 61                39         NaN
# 62                 3         NaN
# 63                39   -0.113261
# 64                11         NaN
# 65                52   -0.054759
# 66                 3         NaN
# 67                 6         NaN
# 68                 6         NaN
# 69                 3         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                15         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 3         NaN
# 77                30         NaN
# 78                41         NaN
# 79                 2         NaN
# 80                12         NaN
# 81                 0         NaN
# 82                42   -0.166406
# 83                13         NaN
# 84                 4         NaN
# 85                93         NaN
# 86                 6         NaN
# 87                44   -0.215667
# 88                 0         NaN
# 89                10         NaN
# 90                 7         NaN
# 91                 9         NaN
# 92                30         NaN
# 93                 0         NaN
# 94                 3         NaN
# 95                 3         NaN
# 96                 0         NaN
# 97                 0         NaN
# 98                38         NaN
# 99                 6         NaN
# 100                4         NaN
# 101               38   -0.550841
# 102               12         NaN
# 103               40   -0.196258
# 104               17         NaN
# 105               35         NaN
# 106                4         NaN
# 107               15         NaN
# 108                8         NaN
# 109                0         NaN
# 110               40   -0.310305
# 111               10         NaN
# 112                0         NaN
# 113                3         NaN
# 114                9         NaN
# 115               13         NaN
# 116                3         NaN
# 117               52   -0.123688
# 118                5         NaN
# 119                0         NaN
# 120               18         NaN
# 121                6         NaN
# 122                5         NaN
# 123                3         NaN
# 124                0         NaN
# 125                0         NaN
# 126               55   -0.047071
# 127              117         NaN
# 128               36         NaN
# 129                0         NaN
# 130                2         NaN
# 131                0         NaN
# 132               49         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136               27         NaN
# 137               53         NaN
# 138                2         NaN
# 139                4         NaN
# 140               10         NaN
# 141                6         NaN
# 142                6         NaN
# 143               14         NaN
# 144               42   -0.181848
# 145               18         NaN
# 146                0         NaN
# 147                4         NaN
# 148               44         NaN
# 149                0         NaN
# 150               28         NaN
# 151                0         NaN
# 152               19         NaN
# 153               18         NaN
# 154               83         NaN
# 155               41         NaN
# 156                3         NaN
# 157               47   -0.506168
# 158                0         NaN
# 159                0         NaN
# 160                8         NaN
# 161                6         NaN
# 162               51   -0.175007
# 163                7         NaN
# 164                4         NaN
# 165                9         NaN
# 166                0         NaN
# 167               72   -0.063182
# 168                2         NaN
# 169                7         NaN
# 170                2         NaN
# 171               34         NaN
# 172               15         NaN
# 173                2         NaN
# 174               32         NaN
# 175                0         NaN
# 176                0         NaN
# 177               14         NaN
# 178                3         NaN
# 179                0         NaN
# 180                3         NaN
# 181               32         NaN
# 182                3         NaN
# 183                0         NaN
# 184                5         NaN
# 185                0         NaN
# 186                0         NaN
# 187               68   -0.144534
# 188                0         NaN
# 189               69         NaN
# 190               55         NaN
# 191               29         NaN
# 192               40   -0.407837
# 193                0         NaN
# 194                0         NaN
# 195               36         NaN
# 196                9         NaN
# 197                9         NaN
# 198               22         NaN
# 199               25         NaN
# #Cuts 32651
#                  Time             Domain Visited Cut Generation  Unsat Nodes  \
#                 count        mean           mean           mean         mean
# Status
# safe              127   15.094817     902.976378     134.992126   805.551181
# safe-incomplete    13    1.655692       0.000000       0.000000     0.000000
# unknown            17  102.608206   33668.764706     912.176471  8452.941176
# unsafe-pgd         43    1.581319       0.000000       0.000000     0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  17.433071
# safe-incomplete        0.000000
# unknown               53.941176
# unsafe-pgd             0.000000
# safe number 140.0
# safe time 13.84689857142857
# safe domain 819.1285714285714
# safe cut 122.45714285714286
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((140.0, 13.84689857142857, 902.9763779527559, 134.99212598425197),)

# %%
main('tinyimagenet/biccos_all.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  16.6384              50              19          480
# 1     safe  12.1753             100              32          756
# 4     safe  10.0096             127              13          387
# 7     safe  17.1772             309             592          523
# 8     safe  72.6940            9978             939         6695
# 9     safe   7.6286              50               9          211
# 10    safe   7.5845              50              13          400
# 12    safe   9.1690             102              42          416
# 13    safe   7.0345              50               8          176
# 14    safe   9.6956             104              51          416
# 17    safe  10.7693              50              22          553
# 18    safe   8.1820             100              20          400
# 20    safe  25.4694            1301             305         1208
# 21    safe   6.6806              50              17          394
# 22    safe  23.2283            1167             379          992
# 23    safe  35.1663            2756             759         1871
# 24    safe   8.4265             100              18          416
# 26    safe  10.3617              50              19          420
# 28    safe   9.5404               0               1           39
# 31    safe  22.0616             238              47         1061
# 34    safe  12.6155             139              22          361
# 38    safe   7.5727              50              19          399
# 39    safe  25.9047             621             400          978
# 40    safe  40.2255            1148             169         2378
# 41    safe  14.1691             300             148          528
# 43    safe  15.4562             215              67          811
# 44    safe  21.6074             251              78         1414
# 45    safe  28.0203             721             137         1415
# 46    safe  20.3639            1450             153         1214
# 49    safe  20.6948             256             155         1563
# 50    safe  27.9029            1726             534         2174
# 53    safe  15.8111             449             187          569
# 54    safe   8.9572             103              85          410
# 56    safe  26.1560            2755             239         1640
# 57    safe   8.2746             101              33          409
# 58    safe   8.0451              50              18          400
# 59    safe  12.9595             277              54          608
# 60    safe   7.6246              50              12          319
# 61    safe  30.6513            2119             326         2394
# 62    safe  12.9076              50              32          819
# 64    safe  12.9930             180              36          590
# 66    safe   7.1617              50              10          400
# 67    safe  10.8228              50              11          593
# 68    safe  15.3956             154              49          822
# 69    safe   6.8698              50              10          280
# 73    safe  20.3129             310              90         1175
# 76    safe   7.9099              50              29          400
# 77    safe  19.9092             533              81          523
# 78    safe  49.3379             888             384         3557
# 79    safe   6.0507               0               1           26
# 80    safe  12.3842             186              51          418
# 83    safe  26.6322             400             209         1955
# 84    safe   8.4222             100              19          400
# 85    safe  89.5089           13400            1205        10618
# 86    safe  11.2574              50              34          794
# 89    safe  23.8440             382             100         1260
# 90    safe  11.8094             100              77          816
# 91    safe  12.3817             106              43          423
# 92    safe  21.2611            1062             196          975
# 94    safe   7.7534              50              15          371
# 95    safe   8.5919              50              13          321
# 98    safe  78.6919           13462             401         9702
# 99    safe  10.9382              50              37          661
# 100   safe   7.9122             100              21          400
# 102   safe  17.3590             212             129          882
# 104   safe  14.6791             240             272          451
# 105   safe  19.5904             672             287          954
# 106   safe   7.8185             100              28          248
# 107   safe  13.0771             245             106          712
# 108   safe  10.0508             110              47          434
# 111   safe  19.3196             253              55         1215
# 113   safe   6.9179              50               6          304
# 114   safe  11.7134             235              89          527
# 115   safe  18.1863             267             120          784
# 116   safe   6.6243              50              14          367
# 118   safe   9.4010              50              12          449
# 120   safe  12.6202             206             112          457
# 121   safe  15.9747             100              94         1020
# 122   safe   9.9359              50               6          320
# 123   safe   7.3106              50              13          400
# 127   safe  82.1617            3349            1407         5013
# 128   safe  54.5051            1139             291         4045
# 130   safe   6.2712               0               1           14
# 132   safe  36.1155            1951             410         2459
# 136   safe  20.8812             372              98         1103
# 137   safe  39.2353             912             346         2127
# 138   safe   6.6484               0               1          218
# 139   safe   8.5482             100              30          400
# 140   safe  11.8309             172             145          460
# 141   safe  10.8873              50              31          800
# 142   safe  10.5945             104              49          412
# 143   safe  18.1913             170             108          859
# 145   safe  26.6341             364             127         1555
# 147   safe   8.7762             100              44          416
# 148   safe  29.2906             804             235         1385
# 150   safe  20.4117             396             328          944
# 152   safe  16.9385             231              19          342
# 153   safe  24.1367             258             334         1299
# 154   safe  71.8750            2081             851         4181
# 155   safe  26.2129            2005             109         1545
# 156   safe   8.0029              50              27          400
# 160   safe  11.9156             128              56          695
# 161   safe  11.3903             100              25          425
# 163   safe  12.1238             124              31          641
# 164   safe   8.4786             100              13          370
# 165   safe  14.8493             157              72          770
# 168   safe   6.3504               0               1          134
# 169   safe  10.9962             108              38          413
# 170   safe   6.9593               0               1          400
# 171   safe  25.4321             724             170         1122
# 172   safe  16.8571             265             116          632
# 173   safe   6.1873               0               1           22
# 174   safe  29.6608            1050             370         1887
# 177   safe  26.2320             260             133         1876
# 178   safe  12.7727              50              36          447
# 180   safe   6.5740              50              18          400
# 181   safe  33.6021             626             429         2073
# 182   safe  13.3237              50              25          656
# 184   safe  10.1588              50              18          467
# 189   safe  74.7062           14315            1625         6101
# 190   safe  80.8633           14408            1123         7580
# 191   safe  27.7283             505             478         1328
# 195   safe  32.6244             920             496         1570
# 196   safe  12.8153             103             147          814
# 197   safe  18.8137             156              53         1162
# 198   safe  21.2201             392             212          949
# 199   safe  20.0234             393             153          843
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 1                  5         NaN
# 4                  9         NaN
# 7                 27         NaN
# 8                 67         NaN
# 9                  2         NaN
# 10                 2         NaN
# 12                 6         NaN
# 13                 2         NaN
# 14                 6         NaN
# 17                 3         NaN
# 18                 3         NaN
# 20                41         NaN
# 21                 2         NaN
# 22                37         NaN
# 23                52         NaN
# 24                 4         NaN
# 26                 3         NaN
# 28                 2         NaN
# 31                21         NaN
# 34                 7         NaN
# 38                 2         NaN
# 39                41         NaN
# 40                43         NaN
# 41                19         NaN
# 43                11         NaN
# 44                12         NaN
# 45                33         NaN
# 46                35         NaN
# 49                13         NaN
# 50                30         NaN
# 53                23         NaN
# 54                 6         NaN
# 56                44         NaN
# 57                 5         NaN
# 58                 2         NaN
# 59                14         NaN
# 60                 2         NaN
# 61                49         NaN
# 62                 5         NaN
# 64                10         NaN
# 66                 2         NaN
# 67                 4         NaN
# 68                 9         NaN
# 69                 2         NaN
# 73                13         NaN
# 76                 2         NaN
# 77                30         NaN
# 78                49         NaN
# 79                 1         NaN
# 80                11         NaN
# 83                15         NaN
# 84                 3         NaN
# 85                89         NaN
# 86                 4         NaN
# 89                16         NaN
# 90                 6         NaN
# 91                 7         NaN
# 92                30         NaN
# 94                 2         NaN
# 95                 2         NaN
# 98                90         NaN
# 99                 4         NaN
# 100                3         NaN
# 102               13         NaN
# 104               17         NaN
# 105               35         NaN
# 106                3         NaN
# 107               17         NaN
# 108                8         NaN
# 111               13         NaN
# 113                2         NaN
# 114                9         NaN
# 115               15         NaN
# 116                2         NaN
# 118                3         NaN
# 120               16         NaN
# 121                7         NaN
# 122                3         NaN
# 123                2         NaN
# 127              137         NaN
# 128               45         NaN
# 130                1         NaN
# 132               53         NaN
# 136               25         NaN
# 137               45         NaN
# 138                1         NaN
# 139                3         NaN
# 140               10         NaN
# 141                4         NaN
# 142                6         NaN
# 143               13         NaN
# 145               24         NaN
# 147                4         NaN
# 148               46         NaN
# 150               27         NaN
# 152               17         NaN
# 153               22         NaN
# 154               97         NaN
# 155               45         NaN
# 156                2         NaN
# 160                9         NaN
# 161                4         NaN
# 163                5         NaN
# 164                3         NaN
# 165                8         NaN
# 168                1         NaN
# 169                6         NaN
# 170                1         NaN
# 171               36         NaN
# 172               14         NaN
# 173                1         NaN
# 174               36         NaN
# 177               19         NaN
# 178                4         NaN
# 180                2         NaN
# 181               32         NaN
# 182                5         NaN
# 184                3         NaN
# 189               68         NaN
# 190               64         NaN
# 191               36         NaN
# 195               42         NaN
# 196                8         NaN
# 197               11         NaN
# 198               23         NaN
# 199               24         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 32   unknown  101.0379            9142            1533         9138
# 52   unknown  102.3278           24171            1473         7499
# 63   unknown  103.3239           40827             997         4903
# 65   unknown  102.8226           36316             367         5913
# 82   unknown  102.7060           39455            1025         4566
# 87   unknown  100.8920           34031             876         6893
# 101  unknown  103.6019           41190            1169         7407
# 103  unknown  102.3336           32253             854         7508
# 110  unknown  103.3831           38643             734         6099
# 117  unknown  102.3262           27566            1164         9799
# 126  unknown  101.6215           30820             272         7608
# 144  unknown  101.3956           36910             522         6574
# 157  unknown  102.4364           34212             988        11469
# 162  unknown  100.7723           25614            1725        11143
# 167  unknown  102.8516           23661             813         7749
# 187  unknown  103.2773           19830             575         9772
# 192  unknown  101.7312           28415            1651         7432
#
#      BaB Round Count  BaB_lb_rhs
# 32                94    1.000000
# 52                79   -0.355489
# 63                38   -0.111658
# 65                50   -0.058685
# 82                42   -0.166409
# 87                44   -0.216466
# 101               39   -0.550838
# 103               41   -0.193394
# 110               44   -0.301521
# 117               52   -0.127345
# 126               57   -0.045940
# 144               41   -0.181867
# 157               47   -0.502795
# 162               47   -0.203585
# 167               78   -0.057664
# 187               79   -0.145117
# 192               43   -0.406538
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   16.6384              50              19          480
# 1               safe   12.1753             100              32          756
# 2         unsafe-pgd    1.3425               0               0            0
# 3         unsafe-pgd    1.1145               0               0            0
# 4               safe   10.0096             127              13          387
# 5         unsafe-pgd    1.2806               0               0            0
# 6         unsafe-pgd    1.2198               0               0            0
# 7               safe   17.1772             309             592          523
# 8               safe   72.6940            9978             939         6695
# 9               safe    7.6286              50               9          211
# 10              safe    7.5845              50              13          400
# 11        unsafe-pgd    1.1959               0               0            0
# 12              safe    9.1690             102              42          416
# 13              safe    7.0345              50               8          176
# 14              safe    9.6956             104              51          416
# 15        unsafe-pgd    1.3525               0               0            0
# 16        unsafe-pgd    1.3054               0               0            0
# 17              safe   10.7693              50              22          553
# 18              safe    8.1820             100              20          400
# 19        unsafe-pgd    1.2462               0               0            0
# 20              safe   25.4694            1301             305         1208
# 21              safe    6.6806              50              17          394
# 22              safe   23.2283            1167             379          992
# 23              safe   35.1663            2756             759         1871
# 24              safe    8.4265             100              18          416
# 25        unsafe-pgd    1.2365               0               0            0
# 26              safe   10.3617              50              19          420
# 27        unsafe-pgd    1.1914               0               0            0
# 28              safe    9.5404               0               1           39
# 29        unsafe-pgd    1.4004               0               0            0
# 30        unsafe-pgd    1.3731               0               0            0
# 31              safe   22.0616             238              47         1061
# 32           unknown  101.0379            9142            1533         9138
# 33        unsafe-pgd    1.6534               0               0            0
# 34              safe   12.6155             139              22          361
# 35        unsafe-pgd    1.4704               0               0            0
# 36        unsafe-pgd    1.3631               0               0            0
# 37        unsafe-pgd    1.1096               0               0            0
# 38              safe    7.5727              50              19          399
# 39              safe   25.9047             621             400          978
# 40              safe   40.2255            1148             169         2378
# 41              safe   14.1691             300             148          528
# 42   safe-incomplete    1.4036               0               0            0
# 43              safe   15.4562             215              67          811
# 44              safe   21.6074             251              78         1414
# 45              safe   28.0203             721             137         1415
# 46              safe   20.3639            1450             153         1214
# 47        unsafe-pgd    1.1123               0               0            0
# 48        unsafe-pgd    1.0514               0               0            0
# 49              safe   20.6948             256             155         1563
# 50              safe   27.9029            1726             534         2174
# 51        unsafe-pgd    1.5803               0               0            0
# 52           unknown  102.3278           24171            1473         7499
# 53              safe   15.8111             449             187          569
# 54              safe    8.9572             103              85          410
# 55        unsafe-pgd    1.0105               0               0            0
# 56              safe   26.1560            2755             239         1640
# 57              safe    8.2746             101              33          409
# 58              safe    8.0451              50              18          400
# 59              safe   12.9595             277              54          608
# 60              safe    7.6246              50              12          319
# 61              safe   30.6513            2119             326         2394
# 62              safe   12.9076              50              32          819
# 63           unknown  103.3239           40827             997         4903
# 64              safe   12.9930             180              36          590
# 65           unknown  102.8226           36316             367         5913
# 66              safe    7.1617              50              10          400
# 67              safe   10.8228              50              11          593
# 68              safe   15.3956             154              49          822
# 69              safe    6.8698              50              10          280
# 70        unsafe-pgd    1.3544               0               0            0
# 71        unsafe-pgd    1.2697               0               0            0
# 72        unsafe-pgd    1.2048               0               0            0
# 73              safe   20.3129             310              90         1175
# 74   safe-incomplete    0.7360               0               0            0
# 75        unsafe-pgd    1.5236               0               0            0
# 76              safe    7.9099              50              29          400
# 77              safe   19.9092             533              81          523
# 78              safe   49.3379             888             384         3557
# 79              safe    6.0507               0               1           26
# 80              safe   12.3842             186              51          418
# 81        unsafe-pgd    2.1194               0               0            0
# 82           unknown  102.7060           39455            1025         4566
# 83              safe   26.6322             400             209         1955
# 84              safe    8.4222             100              19          400
# 85              safe   89.5089           13400            1205        10618
# 86              safe   11.2574              50              34          794
# 87           unknown  100.8920           34031             876         6893
# 88   safe-incomplete    0.7284               0               0            0
# 89              safe   23.8440             382             100         1260
# 90              safe   11.8094             100              77          816
# 91              safe   12.3817             106              43          423
# 92              safe   21.2611            1062             196          975
# 93   safe-incomplete    1.6096               0               0            0
# 94              safe    7.7534              50              15          371
# 95              safe    8.5919              50              13          321
# 96        unsafe-pgd    1.3243               0               0            0
# 97        unsafe-pgd    1.2886               0               0            0
# 98              safe   78.6919           13462             401         9702
# 99              safe   10.9382              50              37          661
# 100             safe    7.9122             100              21          400
# 101          unknown  103.6019           41190            1169         7407
# 102             safe   17.3590             212             129          882
# 103          unknown  102.3336           32253             854         7508
# 104             safe   14.6791             240             272          451
# 105             safe   19.5904             672             287          954
# 106             safe    7.8185             100              28          248
# 107             safe   13.0771             245             106          712
# 108             safe   10.0508             110              47          434
# 109       unsafe-pgd    1.1902               0               0            0
# 110          unknown  103.3831           38643             734         6099
# 111             safe   19.3196             253              55         1215
# 112       unsafe-pgd    1.2360               0               0            0
# 113             safe    6.9179              50               6          304
# 114             safe   11.7134             235              89          527
# 115             safe   18.1863             267             120          784
# 116             safe    6.6243              50              14          367
# 117          unknown  102.3262           27566            1164         9799
# 118             safe    9.4010              50              12          449
# 119       unsafe-pgd    0.7757               0               0            0
# 120             safe   12.6202             206             112          457
# 121             safe   15.9747             100              94         1020
# 122             safe    9.9359              50               6          320
# 123             safe    7.3106              50              13          400
# 124       unsafe-pgd    1.4563               0               0            0
# 125  safe-incomplete    1.5236               0               0            0
# 126          unknown  101.6215           30820             272         7608
# 127             safe   82.1617            3349            1407         5013
# 128             safe   54.5051            1139             291         4045
# 129       unsafe-pgd    1.5213               0               0            0
# 130             safe    6.2712               0               1           14
# 131  safe-incomplete    1.3758               0               0            0
# 132             safe   36.1155            1951             410         2459
# 133       unsafe-pgd    2.5526               0               0            0
# 134       unsafe-pgd    1.5599               0               0            0
# 135       unsafe-pgd    1.6171               0               0            0
# 136             safe   20.8812             372              98         1103
# 137             safe   39.2353             912             346         2127
# 138             safe    6.6484               0               1          218
# 139             safe    8.5482             100              30          400
# 140             safe   11.8309             172             145          460
# 141             safe   10.8873              50              31          800
# 142             safe   10.5945             104              49          412
# 143             safe   18.1913             170             108          859
# 144          unknown  101.3956           36910             522         6574
# 145             safe   26.6341             364             127         1555
# 146  safe-incomplete    1.7409               0               0            0
# 147             safe    8.7762             100              44          416
# 148             safe   29.2906             804             235         1385
# 149  safe-incomplete    1.7038               0               0            0
# 150             safe   20.4117             396             328          944
# 151  safe-incomplete    1.6596               0               0            0
# 152             safe   16.9385             231              19          342
# 153             safe   24.1367             258             334         1299
# 154             safe   71.8750            2081             851         4181
# 155             safe   26.2129            2005             109         1545
# 156             safe    8.0029              50              27          400
# 157          unknown  102.4364           34212             988        11469
# 158       unsafe-pgd    1.3763               0               0            0
# 159       unsafe-pgd    1.2181               0               0            0
# 160             safe   11.9156             128              56          695
# 161             safe   11.3903             100              25          425
# 162          unknown  100.7723           25614            1725        11143
# 163             safe   12.1238             124              31          641
# 164             safe    8.4786             100              13          370
# 165             safe   14.8493             157              72          770
# 166       unsafe-pgd    2.4823               0               0            0
# 167          unknown  102.8516           23661             813         7749
# 168             safe    6.3504               0               1          134
# 169             safe   10.9962             108              38          413
# 170             safe    6.9593               0               1          400
# 171             safe   25.4321             724             170         1122
# 172             safe   16.8571             265             116          632
# 173             safe    6.1873               0               1           22
# 174             safe   29.6608            1050             370         1887
# 175  safe-incomplete    1.3280               0               0            0
# 176  safe-incomplete    1.2152               0               0            0
# 177             safe   26.2320             260             133         1876
# 178             safe   12.7727              50              36          447
# 179  safe-incomplete    1.3307               0               0            0
# 180             safe    6.5740              50              18          400
# 181             safe   33.6021             626             429         2073
# 182             safe   13.3237              50              25          656
# 183       unsafe-pgd    1.1359               0               0            0
# 184             safe   10.1588              50              18          467
# 185  safe-incomplete    1.2737               0               0            0
# 186       unsafe-pgd    1.3203               0               0            0
# 187          unknown  103.2773           19830             575         9772
# 188       unsafe-pgd    1.1738               0               0            0
# 189             safe   74.7062           14315            1625         6101
# 190             safe   80.8633           14408            1123         7580
# 191             safe   27.7283             505             478         1328
# 192          unknown  101.7312           28415            1651         7432
# 193       unsafe-pgd    1.1618               0               0            0
# 194       unsafe-pgd    1.2735               0               0            0
# 195             safe   32.6244             920             496         1570
# 196             safe   12.8153             103             147          814
# 197             safe   18.8137             156              53         1162
# 198             safe   21.2201             392             212          949
# 199             safe   20.0234             393             153          843
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 1                  5         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  9         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 27         NaN
# 8                 67         NaN
# 9                  2         NaN
# 10                 2         NaN
# 11                 0         NaN
# 12                 6         NaN
# 13                 2         NaN
# 14                 6         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 3         NaN
# 18                 3         NaN
# 19                 0         NaN
# 20                41         NaN
# 21                 2         NaN
# 22                37         NaN
# 23                52         NaN
# 24                 4         NaN
# 25                 0         NaN
# 26                 3         NaN
# 27                 0         NaN
# 28                 2         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                21         NaN
# 32                94    1.000000
# 33                 0         NaN
# 34                 7         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 2         NaN
# 39                41         NaN
# 40                43         NaN
# 41                19         NaN
# 42                 0         NaN
# 43                11         NaN
# 44                12         NaN
# 45                33         NaN
# 46                35         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                13         NaN
# 50                30         NaN
# 51                 0         NaN
# 52                79   -0.355489
# 53                23         NaN
# 54                 6         NaN
# 55                 0         NaN
# 56                44         NaN
# 57                 5         NaN
# 58                 2         NaN
# 59                14         NaN
# 60                 2         NaN
# 61                49         NaN
# 62                 5         NaN
# 63                38   -0.111658
# 64                10         NaN
# 65                50   -0.058685
# 66                 2         NaN
# 67                 4         NaN
# 68                 9         NaN
# 69                 2         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                13         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 2         NaN
# 77                30         NaN
# 78                49         NaN
# 79                 1         NaN
# 80                11         NaN
# 81                 0         NaN
# 82                42   -0.166409
# 83                15         NaN
# 84                 3         NaN
# 85                89         NaN
# 86                 4         NaN
# 87                44   -0.216466
# 88                 0         NaN
# 89                16         NaN
# 90                 6         NaN
# 91                 7         NaN
# 92                30         NaN
# 93                 0         NaN
# 94                 2         NaN
# 95                 2         NaN
# 96                 0         NaN
# 97                 0         NaN
# 98                90         NaN
# 99                 4         NaN
# 100                3         NaN
# 101               39   -0.550838
# 102               13         NaN
# 103               41   -0.193394
# 104               17         NaN
# 105               35         NaN
# 106                3         NaN
# 107               17         NaN
# 108                8         NaN
# 109                0         NaN
# 110               44   -0.301521
# 111               13         NaN
# 112                0         NaN
# 113                2         NaN
# 114                9         NaN
# 115               15         NaN
# 116                2         NaN
# 117               52   -0.127345
# 118                3         NaN
# 119                0         NaN
# 120               16         NaN
# 121                7         NaN
# 122                3         NaN
# 123                2         NaN
# 124                0         NaN
# 125                0         NaN
# 126               57   -0.045940
# 127              137         NaN
# 128               45         NaN
# 129                0         NaN
# 130                1         NaN
# 131                0         NaN
# 132               53         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136               25         NaN
# 137               45         NaN
# 138                1         NaN
# 139                3         NaN
# 140               10         NaN
# 141                4         NaN
# 142                6         NaN
# 143               13         NaN
# 144               41   -0.181867
# 145               24         NaN
# 146                0         NaN
# 147                4         NaN
# 148               46         NaN
# 149                0         NaN
# 150               27         NaN
# 151                0         NaN
# 152               17         NaN
# 153               22         NaN
# 154               97         NaN
# 155               45         NaN
# 156                2         NaN
# 157               47   -0.502795
# 158                0         NaN
# 159                0         NaN
# 160                9         NaN
# 161                4         NaN
# 162               47   -0.203585
# 163                5         NaN
# 164                3         NaN
# 165                8         NaN
# 166                0         NaN
# 167               78   -0.057664
# 168                1         NaN
# 169                6         NaN
# 170                1         NaN
# 171               36         NaN
# 172               14         NaN
# 173                1         NaN
# 174               36         NaN
# 175                0         NaN
# 176                0         NaN
# 177               19         NaN
# 178                4         NaN
# 179                0         NaN
# 180                2         NaN
# 181               32         NaN
# 182                5         NaN
# 183                0         NaN
# 184                3         NaN
# 185                0         NaN
# 186                0         NaN
# 187               79   -0.145117
# 188                0         NaN
# 189               68         NaN
# 190               64         NaN
# 191               36         NaN
# 192               43   -0.406538
# 193                0         NaN
# 194                0         NaN
# 195               42         NaN
# 196                8         NaN
# 197               11         NaN
# 198               23         NaN
# 199               24         NaN
# #Cuts 38254
#                  Time             Domain Visited Cut Generation  Unsat Nodes  \
#                 count        mean           mean           mean         mean
# Status
# safe              127   19.489384     896.519685     169.417323  1176.181102
# safe-incomplete    13    1.356069       0.000000       0.000000     0.000000
# unknown            17  102.284759   30768.000000     984.588235  7733.647059
# unsafe-pgd         43    1.366179       0.000000       0.000000     0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  18.535433
# safe-incomplete        0.000000
# unknown               53.823529
# unsafe-pgd             0.000000
# safe number 140.0
# safe time 17.80557642857143
# safe domain 813.2714285714286
# safe cut 153.68571428571428
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((140.0, 17.80557642857143, 896.5196850393701, 169.41732283464566),)

# %%
main('tinyimagenet/biccos_all_selective_mts.log'),
# Out:
#     Status     Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0     safe  16.6809              50              19          480
# 1     safe  11.8851             100              32          756
# 4     safe   9.7886             127              17          387
# 7     safe  16.0727             312             576          533
# 8     safe  66.5242            9732            1051         6405
# 9     safe   6.5386              50               9          211
# 10    safe   6.5932              50              13          400
# 12    safe   8.5887             102              43          416
# 13    safe   6.7118              50               8          176
# 14    safe   8.5040             104              51          416
# 17    safe   9.5774              50              22          553
# 18    safe   7.6297             100              20          400
# 20    safe  24.0030            1187             213         1195
# 21    safe   6.5645              50              17          394
# 22    safe  22.0702            1135             313         1011
# 23    safe  32.7834            2783             886         1836
# 24    safe   7.8013             100              18          416
# 26    safe   9.4064              50              19          420
# 28    safe   8.0993               0               1           39
# 31    safe  20.4198             237              45         1061
# 34    safe  11.5191             139              22          361
# 38    safe   6.6152              50              19          399
# 39    safe  23.2036             600             355          974
# 40    safe  37.9197            1144             149         2372
# 41    safe  13.0822             300             147          528
# 43    safe  13.5858             215              64          811
# 44    safe  19.4894             251              79         1414
# 45    safe  25.0454             721             139         1415
# 46    safe  23.7426            2668             270         1982
# 49    safe  19.9129             256             155         1563
# 50    safe  25.8237            1728             469         2410
# 53    safe  14.8722             467             150          593
# 54    safe   8.8010             103              67          410
# 56    safe  25.2304            2713             258         1877
# 57    safe   8.0214             101              34          409
# 58    safe   7.0090              50              18          400
# 59    safe  12.3736             275              53          621
# 60    safe   7.0170              50              12          319
# 61    safe  28.6825            2063             327         2364
# 62    safe  12.1220              50              32          819
# 64    safe  11.4339             180              35          590
# 66    safe   6.3573              50              10          400
# 67    safe  10.0222              50              11          593
# 68    safe  14.0769             154              47          822
# 69    safe   6.5854              50              10          280
# 73    safe  17.7280             310              92         1175
# 76    safe   6.9204              50              29          400
# 77    safe  16.8421             532              81          521
# 78    safe  45.0288             888             405         3557
# 79    safe   5.6710               0               1           26
# 80    safe  11.4379             186              51          418
# 83    safe  23.7274             400             209         1955
# 84    safe   7.6678             100              19          400
# 85    safe  87.2453           14750            1473         8107
# 86    safe  10.2449              50              34          794
# 89    safe  21.7475             382              99         1260
# 90    safe  10.8348             100              77          816
# 91    safe  11.2433             106              41          423
# 92    safe  16.6928             784             146          839
# 94    safe   6.6022              50              15          371
# 95    safe   6.8594              50              13          321
# 98    safe  31.6521            2024             421         2718
# 99    safe  10.0733              50              37          661
# 100   safe   7.3952             100              21          400
# 102   safe  16.3912             212             128          882
# 104   safe  14.3426             240             272          451
# 105   safe  19.4841             791             299          993
# 106   safe   7.4491             100              28          248
# 107   safe  12.4696             245             105          712
# 108   safe   9.4986             110              45          434
# 111   safe  18.4071             253              58         1212
# 113   safe   6.4874              50               6          304
# 114   safe  11.1091             235              89          527
# 115   safe  17.9148             267             119          784
# 116   safe   6.6356              50              14          367
# 118   safe   9.2133              50              12          449
# 120   safe  11.6495             206             114          457
# 121   safe  14.3137             100              94         1020
# 122   safe   9.3271              50               6          320
# 123   safe   6.3080              50              13          400
# 127   safe  82.6666            5733            1427         6354
# 128   safe  51.1336            1272             359         4186
# 130   safe   5.8146               0               1           14
# 132   safe  32.1665            1859             410         2309
# 136   safe  18.8950             372             102         1103
# 137   safe  37.3404            1104             408         2273
# 138   safe   5.8536               0               1          218
# 139   safe   7.5679             100              30          400
# 140   safe  11.1214             173              80          459
# 141   safe   9.8981              50              31          800
# 142   safe   9.5770             104              48          412
# 143   safe  15.9045             170             111          859
# 145   safe  23.7848             364             127         1555
# 147   safe   7.7564             100              44          416
# 148   safe  25.8627             822             278         1408
# 150   safe  18.5942             399             398          947
# 152   safe  14.8270             231              19          342
# 153   safe  22.1665             258             335         1299
# 154   safe  67.0986            2076             884         4171
# 155   safe  23.8808            1818             112         1559
# 156   safe   6.8151              50              27          400
# 160   safe  10.5856             128              54          695
# 161   safe  10.4628             100              25          425
# 163   safe  11.4399             124              31          641
# 164   safe   7.4829             100              13          370
# 165   safe  12.4623             157              73          770
# 168   safe   5.9012               0               1          134
# 169   safe   8.9632             108              37          413
# 170   safe   5.6624               0               1          400
# 171   safe  22.9871             724             171         1121
# 172   safe  14.3298             265             116          631
# 173   safe   5.4485               0               1           22
# 174   safe  26.5913            1043             291         1931
# 177   safe  24.5185             260             155         1876
# 178   safe  11.9222              50              36          447
# 180   safe   5.8860              50              19          400
# 181   safe  32.0229             626             417         2073
# 182   safe  12.4459              50              25          656
# 184   safe   8.9319              50              18          467
# 189   safe  88.5707           18688            2810        11905
# 190   safe  77.7315           14256            1154         7305
# 191   safe  25.4298             504             417         1327
# 195   safe  30.0175             927             513         1568
# 196   safe  11.8438             103             118          814
# 197   safe  17.5816             156              36         1162
# 198   safe  19.5763             393             201          948
# 199   safe  17.0652             370             119          820
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 1                  5         NaN
# 4                  9         NaN
# 7                 27         NaN
# 8                 62         NaN
# 9                  2         NaN
# 10                 2         NaN
# 12                 6         NaN
# 13                 2         NaN
# 14                 6         NaN
# 17                 3         NaN
# 18                 3         NaN
# 20                41         NaN
# 21                 2         NaN
# 22                37         NaN
# 23                52         NaN
# 24                 4         NaN
# 26                 3         NaN
# 28                 2         NaN
# 31                20         NaN
# 34                 7         NaN
# 38                 2         NaN
# 39                39         NaN
# 40                43         NaN
# 41                19         NaN
# 43                11         NaN
# 44                12         NaN
# 45                33         NaN
# 46                39         NaN
# 49                13         NaN
# 50                29         NaN
# 53                24         NaN
# 54                 6         NaN
# 56                44         NaN
# 57                 5         NaN
# 58                 2         NaN
# 59                14         NaN
# 60                 2         NaN
# 61                49         NaN
# 62                 5         NaN
# 64                10         NaN
# 66                 2         NaN
# 67                 4         NaN
# 68                 9         NaN
# 69                 2         NaN
# 73                13         NaN
# 76                 2         NaN
# 77                30         NaN
# 78                49         NaN
# 79                 1         NaN
# 80                11         NaN
# 83                15         NaN
# 84                 3         NaN
# 85                92         NaN
# 86                 4         NaN
# 89                16         NaN
# 90                 6         NaN
# 91                 7         NaN
# 92                29         NaN
# 94                 2         NaN
# 95                 2         NaN
# 98                43         NaN
# 99                 4         NaN
# 100                3         NaN
# 102               13         NaN
# 104               17         NaN
# 105               36         NaN
# 106                3         NaN
# 107               17         NaN
# 108                8         NaN
# 111               13         NaN
# 113                2         NaN
# 114                9         NaN
# 115               15         NaN
# 116                2         NaN
# 118                3         NaN
# 120               16         NaN
# 121                7         NaN
# 122                3         NaN
# 123                2         NaN
# 127              133         NaN
# 128               46         NaN
# 130                1         NaN
# 132               52         NaN
# 136               25         NaN
# 137               54         NaN
# 138                1         NaN
# 139                3         NaN
# 140               10         NaN
# 141                4         NaN
# 142                6         NaN
# 143               13         NaN
# 145               24         NaN
# 147                4         NaN
# 148               46         NaN
# 150               27         NaN
# 152               17         NaN
# 153               22         NaN
# 154               97         NaN
# 155               45         NaN
# 156                2         NaN
# 160                9         NaN
# 161                4         NaN
# 163                5         NaN
# 164                3         NaN
# 165                8         NaN
# 168                1         NaN
# 169                6         NaN
# 170                1         NaN
# 171               36         NaN
# 172               14         NaN
# 173                1         NaN
# 174               36         NaN
# 177               19         NaN
# 178                4         NaN
# 180                2         NaN
# 181               32         NaN
# 182                5         NaN
# 184                3         NaN
# 189               68         NaN
# 190               64         NaN
# 191               36         NaN
# 195               42         NaN
# 196                8         NaN
# 197               11         NaN
# 198               23         NaN
# 199               22         NaN
#       Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 32   unknown  100.5009            8862            1594         9362
# 52   unknown  101.5246           25305            1443         7412
# 63   unknown  102.9409           41839             579         5700
# 65   unknown  102.3747           37730             324         5739
# 82   unknown  107.4332           41225             835         4676
# 87   unknown  101.4269           37371             803         8398
# 101  unknown  101.7471           43079            1320         8323
# 103  unknown  101.6078           32928            1275         6740
# 110  unknown  103.2496           40244             622         7549
# 117  unknown  103.2498           29753            1127         8652
# 126  unknown  103.1553           32850             424         8951
# 144  unknown  100.9674           38432             586         6567
# 157  unknown  101.4686           37001             688        10953
# 162  unknown  100.6719           31567            2263         9497
# 167  unknown  103.5808           18954             940        12651
# 187  unknown  100.5137           19838             506        12675
# 192  unknown  101.6025           29659            1620         9897
#
#      BaB Round Count  BaB_lb_rhs
# 32               105   -0.373273
# 52                80   -0.354587
# 63                39   -0.109950
# 65                51   -0.057189
# 82                43   -0.166406
# 87                46   -0.215135
# 101               40   -0.531165
# 103               42   -0.188344
# 110               45   -0.301523
# 117               54   -0.123623
# 126               58   -0.044972
# 144               42   -0.181870
# 157               49   -0.502798
# 162               48   -0.214658
# 167               99    1.000000
# 187               77   -0.146410
# 192               44   -0.406516
# All:
#                Status      Time  Domain Visited  Cut Generation  Unsat Nodes  \
# 0               safe   16.6809              50              19          480
# 1               safe   11.8851             100              32          756
# 2         unsafe-pgd    1.2605               0               0            0
# 3         unsafe-pgd    1.0795               0               0            0
# 4               safe    9.7886             127              17          387
# 5         unsafe-pgd    1.2612               0               0            0
# 6         unsafe-pgd    1.1605               0               0            0
# 7               safe   16.0727             312             576          533
# 8               safe   66.5242            9732            1051         6405
# 9               safe    6.5386              50               9          211
# 10              safe    6.5932              50              13          400
# 11        unsafe-pgd    1.0643               0               0            0
# 12              safe    8.5887             102              43          416
# 13              safe    6.7118              50               8          176
# 14              safe    8.5040             104              51          416
# 15        unsafe-pgd    1.1564               0               0            0
# 16        unsafe-pgd    0.9892               0               0            0
# 17              safe    9.5774              50              22          553
# 18              safe    7.6297             100              20          400
# 19        unsafe-pgd    1.1857               0               0            0
# 20              safe   24.0030            1187             213         1195
# 21              safe    6.5645              50              17          394
# 22              safe   22.0702            1135             313         1011
# 23              safe   32.7834            2783             886         1836
# 24              safe    7.8013             100              18          416
# 25        unsafe-pgd    1.1838               0               0            0
# 26              safe    9.4064              50              19          420
# 27        unsafe-pgd    1.0843               0               0            0
# 28              safe    8.0993               0               1           39
# 29        unsafe-pgd    0.7394               0               0            0
# 30        unsafe-pgd    1.2795               0               0            0
# 31              safe   20.4198             237              45         1061
# 32           unknown  100.5009            8862            1594         9362
# 33        unsafe-pgd    1.1704               0               0            0
# 34              safe   11.5191             139              22          361
# 35        unsafe-pgd    1.4664               0               0            0
# 36        unsafe-pgd    1.2492               0               0            0
# 37        unsafe-pgd    0.9926               0               0            0
# 38              safe    6.6152              50              19          399
# 39              safe   23.2036             600             355          974
# 40              safe   37.9197            1144             149         2372
# 41              safe   13.0822             300             147          528
# 42   safe-incomplete    1.2236               0               0            0
# 43              safe   13.5858             215              64          811
# 44              safe   19.4894             251              79         1414
# 45              safe   25.0454             721             139         1415
# 46              safe   23.7426            2668             270         1982
# 47        unsafe-pgd    1.0592               0               0            0
# 48        unsafe-pgd    0.9950               0               0            0
# 49              safe   19.9129             256             155         1563
# 50              safe   25.8237            1728             469         2410
# 51        unsafe-pgd    1.4457               0               0            0
# 52           unknown  101.5246           25305            1443         7412
# 53              safe   14.8722             467             150          593
# 54              safe    8.8010             103              67          410
# 55        unsafe-pgd    1.0230               0               0            0
# 56              safe   25.2304            2713             258         1877
# 57              safe    8.0214             101              34          409
# 58              safe    7.0090              50              18          400
# 59              safe   12.3736             275              53          621
# 60              safe    7.0170              50              12          319
# 61              safe   28.6825            2063             327         2364
# 62              safe   12.1220              50              32          819
# 63           unknown  102.9409           41839             579         5700
# 64              safe   11.4339             180              35          590
# 65           unknown  102.3747           37730             324         5739
# 66              safe    6.3573              50              10          400
# 67              safe   10.0222              50              11          593
# 68              safe   14.0769             154              47          822
# 69              safe    6.5854              50              10          280
# 70        unsafe-pgd    1.3295               0               0            0
# 71        unsafe-pgd    1.2382               0               0            0
# 72        unsafe-pgd    1.0455               0               0            0
# 73              safe   17.7280             310              92         1175
# 74   safe-incomplete    0.6776               0               0            0
# 75        unsafe-pgd    1.3772               0               0            0
# 76              safe    6.9204              50              29          400
# 77              safe   16.8421             532              81          521
# 78              safe   45.0288             888             405         3557
# 79              safe    5.6710               0               1           26
# 80              safe   11.4379             186              51          418
# 81        unsafe-pgd    2.0252               0               0            0
# 82           unknown  107.4332           41225             835         4676
# 83              safe   23.7274             400             209         1955
# 84              safe    7.6678             100              19          400
# 85              safe   87.2453           14750            1473         8107
# 86              safe   10.2449              50              34          794
# 87           unknown  101.4269           37371             803         8398
# 88   safe-incomplete    0.6929               0               0            0
# 89              safe   21.7475             382              99         1260
# 90              safe   10.8348             100              77          816
# 91              safe   11.2433             106              41          423
# 92              safe   16.6928             784             146          839
# 93   safe-incomplete    1.3595               0               0            0
# 94              safe    6.6022              50              15          371
# 95              safe    6.8594              50              13          321
# 96        unsafe-pgd    1.2257               0               0            0
# 97        unsafe-pgd    1.1161               0               0            0
# 98              safe   31.6521            2024             421         2718
# 99              safe   10.0733              50              37          661
# 100             safe    7.3952             100              21          400
# 101          unknown  101.7471           43079            1320         8323
# 102             safe   16.3912             212             128          882
# 103          unknown  101.6078           32928            1275         6740
# 104             safe   14.3426             240             272          451
# 105             safe   19.4841             791             299          993
# 106             safe    7.4491             100              28          248
# 107             safe   12.4696             245             105          712
# 108             safe    9.4986             110              45          434
# 109       unsafe-pgd    1.1485               0               0            0
# 110          unknown  103.2496           40244             622         7549
# 111             safe   18.4071             253              58         1212
# 112       unsafe-pgd    1.1427               0               0            0
# 113             safe    6.4874              50               6          304
# 114             safe   11.1091             235              89          527
# 115             safe   17.9148             267             119          784
# 116             safe    6.6356              50              14          367
# 117          unknown  103.2498           29753            1127         8652
# 118             safe    9.2133              50              12          449
# 119       unsafe-pgd    0.7467               0               0            0
# 120             safe   11.6495             206             114          457
# 121             safe   14.3137             100              94         1020
# 122             safe    9.3271              50               6          320
# 123             safe    6.3080              50              13          400
# 124       unsafe-pgd    1.3910               0               0            0
# 125  safe-incomplete    1.4065               0               0            0
# 126          unknown  103.1553           32850             424         8951
# 127             safe   82.6666            5733            1427         6354
# 128             safe   51.1336            1272             359         4186
# 129       unsafe-pgd    1.2933               0               0            0
# 130             safe    5.8146               0               1           14
# 131  safe-incomplete    1.1224               0               0            0
# 132             safe   32.1665            1859             410         2309
# 133       unsafe-pgd    2.4753               0               0            0
# 134       unsafe-pgd    1.2715               0               0            0
# 135       unsafe-pgd    1.1355               0               0            0
# 136             safe   18.8950             372             102         1103
# 137             safe   37.3404            1104             408         2273
# 138             safe    5.8536               0               1          218
# 139             safe    7.5679             100              30          400
# 140             safe   11.1214             173              80          459
# 141             safe    9.8981              50              31          800
# 142             safe    9.5770             104              48          412
# 143             safe   15.9045             170             111          859
# 144          unknown  100.9674           38432             586         6567
# 145             safe   23.7848             364             127         1555
# 146  safe-incomplete    1.5493               0               0            0
# 147             safe    7.7564             100              44          416
# 148             safe   25.8627             822             278         1408
# 149  safe-incomplete    1.5619               0               0            0
# 150             safe   18.5942             399             398          947
# 151  safe-incomplete    1.4519               0               0            0
# 152             safe   14.8270             231              19          342
# 153             safe   22.1665             258             335         1299
# 154             safe   67.0986            2076             884         4171
# 155             safe   23.8808            1818             112         1559
# 156             safe    6.8151              50              27          400
# 157          unknown  101.4686           37001             688        10953
# 158       unsafe-pgd    1.2398               0               0            0
# 159       unsafe-pgd    1.0381               0               0            0
# 160             safe   10.5856             128              54          695
# 161             safe   10.4628             100              25          425
# 162          unknown  100.6719           31567            2263         9497
# 163             safe   11.4399             124              31          641
# 164             safe    7.4829             100              13          370
# 165             safe   12.4623             157              73          770
# 166       unsafe-pgd    2.2415               0               0            0
# 167          unknown  103.5808           18954             940        12651
# 168             safe    5.9012               0               1          134
# 169             safe    8.9632             108              37          413
# 170             safe    5.6624               0               1          400
# 171             safe   22.9871             724             171         1121
# 172             safe   14.3298             265             116          631
# 173             safe    5.4485               0               1           22
# 174             safe   26.5913            1043             291         1931
# 175  safe-incomplete    1.2868               0               0            0
# 176  safe-incomplete    1.2298               0               0            0
# 177             safe   24.5185             260             155         1876
# 178             safe   11.9222              50              36          447
# 179  safe-incomplete    1.2145               0               0            0
# 180             safe    5.8860              50              19          400
# 181             safe   32.0229             626             417         2073
# 182             safe   12.4459              50              25          656
# 183       unsafe-pgd    1.0546               0               0            0
# 184             safe    8.9319              50              18          467
# 185  safe-incomplete    1.2056               0               0            0
# 186       unsafe-pgd    1.0491               0               0            0
# 187          unknown  100.5137           19838             506        12675
# 188       unsafe-pgd    1.0655               0               0            0
# 189             safe   88.5707           18688            2810        11905
# 190             safe   77.7315           14256            1154         7305
# 191             safe   25.4298             504             417         1327
# 192          unknown  101.6025           29659            1620         9897
# 193       unsafe-pgd    1.0335               0               0            0
# 194       unsafe-pgd    1.2282               0               0            0
# 195             safe   30.0175             927             513         1568
# 196             safe   11.8438             103             118          814
# 197             safe   17.5816             156              36         1162
# 198             safe   19.5763             393             201          948
# 199             safe   17.0652             370             119          820
#
#      BaB Round Count  BaB_lb_rhs
# 0                  3         NaN
# 1                  5         NaN
# 2                  0         NaN
# 3                  0         NaN
# 4                  9         NaN
# 5                  0         NaN
# 6                  0         NaN
# 7                 27         NaN
# 8                 62         NaN
# 9                  2         NaN
# 10                 2         NaN
# 11                 0         NaN
# 12                 6         NaN
# 13                 2         NaN
# 14                 6         NaN
# 15                 0         NaN
# 16                 0         NaN
# 17                 3         NaN
# 18                 3         NaN
# 19                 0         NaN
# 20                41         NaN
# 21                 2         NaN
# 22                37         NaN
# 23                52         NaN
# 24                 4         NaN
# 25                 0         NaN
# 26                 3         NaN
# 27                 0         NaN
# 28                 2         NaN
# 29                 0         NaN
# 30                 0         NaN
# 31                20         NaN
# 32               105   -0.373273
# 33                 0         NaN
# 34                 7         NaN
# 35                 0         NaN
# 36                 0         NaN
# 37                 0         NaN
# 38                 2         NaN
# 39                39         NaN
# 40                43         NaN
# 41                19         NaN
# 42                 0         NaN
# 43                11         NaN
# 44                12         NaN
# 45                33         NaN
# 46                39         NaN
# 47                 0         NaN
# 48                 0         NaN
# 49                13         NaN
# 50                29         NaN
# 51                 0         NaN
# 52                80   -0.354587
# 53                24         NaN
# 54                 6         NaN
# 55                 0         NaN
# 56                44         NaN
# 57                 5         NaN
# 58                 2         NaN
# 59                14         NaN
# 60                 2         NaN
# 61                49         NaN
# 62                 5         NaN
# 63                39   -0.109950
# 64                10         NaN
# 65                51   -0.057189
# 66                 2         NaN
# 67                 4         NaN
# 68                 9         NaN
# 69                 2         NaN
# 70                 0         NaN
# 71                 0         NaN
# 72                 0         NaN
# 73                13         NaN
# 74                 0         NaN
# 75                 0         NaN
# 76                 2         NaN
# 77                30         NaN
# 78                49         NaN
# 79                 1         NaN
# 80                11         NaN
# 81                 0         NaN
# 82                43   -0.166406
# 83                15         NaN
# 84                 3         NaN
# 85                92         NaN
# 86                 4         NaN
# 87                46   -0.215135
# 88                 0         NaN
# 89                16         NaN
# 90                 6         NaN
# 91                 7         NaN
# 92                29         NaN
# 93                 0         NaN
# 94                 2         NaN
# 95                 2         NaN
# 96                 0         NaN
# 97                 0         NaN
# 98                43         NaN
# 99                 4         NaN
# 100                3         NaN
# 101               40   -0.531165
# 102               13         NaN
# 103               42   -0.188344
# 104               17         NaN
# 105               36         NaN
# 106                3         NaN
# 107               17         NaN
# 108                8         NaN
# 109                0         NaN
# 110               45   -0.301523
# 111               13         NaN
# 112                0         NaN
# 113                2         NaN
# 114                9         NaN
# 115               15         NaN
# 116                2         NaN
# 117               54   -0.123623
# 118                3         NaN
# 119                0         NaN
# 120               16         NaN
# 121                7         NaN
# 122                3         NaN
# 123                2         NaN
# 124                0         NaN
# 125                0         NaN
# 126               58   -0.044972
# 127              133         NaN
# 128               46         NaN
# 129                0         NaN
# 130                1         NaN
# 131                0         NaN
# 132               52         NaN
# 133                0         NaN
# 134                0         NaN
# 135                0         NaN
# 136               25         NaN
# 137               54         NaN
# 138                1         NaN
# 139                3         NaN
# 140               10         NaN
# 141                4         NaN
# 142                6         NaN
# 143               13         NaN
# 144               42   -0.181870
# 145               24         NaN
# 146                0         NaN
# 147                4         NaN
# 148               46         NaN
# 149                0         NaN
# 150               27         NaN
# 151                0         NaN
# 152               17         NaN
# 153               22         NaN
# 154               97         NaN
# 155               45         NaN
# 156                2         NaN
# 157               49   -0.502798
# 158                0         NaN
# 159                0         NaN
# 160                9         NaN
# 161                4         NaN
# 162               48   -0.214658
# 163                5         NaN
# 164                3         NaN
# 165                8         NaN
# 166                0         NaN
# 167               99    1.000000
# 168                1         NaN
# 169                6         NaN
# 170                1         NaN
# 171               36         NaN
# 172               14         NaN
# 173                1         NaN
# 174               36         NaN
# 175                0         NaN
# 176                0         NaN
# 177               19         NaN
# 178                4         NaN
# 179                0         NaN
# 180                2         NaN
# 181               32         NaN
# 182                5         NaN
# 183                0         NaN
# 184                3         NaN
# 185                0         NaN
# 186                0         NaN
# 187               77   -0.146410
# 188                0         NaN
# 189               68         NaN
# 190               64         NaN
# 191               36         NaN
# 192               44   -0.406516
# 193                0         NaN
# 194                0         NaN
# 195               42         NaN
# 196                8         NaN
# 197               11         NaN
# 198               23         NaN
# 199               22         NaN
# #Cuts 40004
#                  Time             Domain Visited Cut Generation  Unsat Nodes  \
#                 count        mean           mean           mean         mean
# Status
# safe              127   17.873924     874.055118     181.535433  1163.448819
# safe-incomplete    13    1.229408       0.000000       0.000000     0.000000
# unknown            17  102.236218   32155.117647     997.000000  8455.411765
# unsafe-pgd         43    1.226930       0.000000       0.000000     0.000000
#
#                 BaB Round Count
#                            mean
# Status
# safe                  18.181102
# safe-incomplete        0.000000
# unknown               56.588235
# unsafe-pgd             0.000000
# safe number 140.0
# safe time 16.32836142857143
# safe domain 792.8928571428571
# safe cut 164.67857142857142
# /home/calus/Documents/biccos_results/data_analysis.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_num = aggregated_data.iloc[0][0]
# /home/calus/Documents/biccos_results/data_analysis.py:242: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_num = aggregated_data.iloc[1][0]
# /home/calus/Documents/biccos_results/data_analysis.py:243: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_time = aggregated_data.iloc[0][1]
# /home/calus/Documents/biccos_results/data_analysis.py:244: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_time = aggregated_data.iloc[1][1]
# /home/calus/Documents/biccos_results/data_analysis.py:245: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_domain = aggregated_data.iloc[0][2]
# /home/calus/Documents/biccos_results/data_analysis.py:246: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_domain = aggregated_data.iloc[1][2]
# /home/calus/Documents/biccos_results/data_analysis.py:247: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_cut = aggregated_data.iloc[0][3]
# /home/calus/Documents/biccos_results/data_analysis.py:248: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   safe_inc_cut = aggregated_data.iloc[1][3]
# ((140.0, 16.32836142857143, 874.0551181102362, 181.53543307086613),)
